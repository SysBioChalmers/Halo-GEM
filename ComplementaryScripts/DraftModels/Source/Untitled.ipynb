# %%
import cobra
import pickle

# %%
def create_universal_met(eco_met,halomodel,universal,mnx2meta):
    is_in_halo = dict()
    for met in halomodel.metabolites: is_in_halo[met.id] = True
    mnx_id = eco_met.annotation.get('metanetx.chemical')
    
    comp = eco_met.compartment
    if comp == 'p': comp = 'e'
    met_id = None
    
    if mnx_id is None or mnx2meta.get(mnx_id,None) is None: 
        # if there is no mnx id or no metacyc id, use bigg id instead
        met_id = eco_met.annotation['bigg.metabolite'] + '_' + comp
    else:
        meta_ids = mnx2meta[mnx_id]
        for item in meta_ids:
            if is_in_halo.get(item+ '_' + comp,False): 
                met_id = item+ '_' + comp
                break
        if met_id is None: met_id = meta_ids[0] + '_' + comp
    try: 
        new_met = halomodel.metabolites.get_by_id(met_id)
    except:
        try:
            new_met = universal.metabolites.get_by_id(met_id)
        except:
            new_met = eco_met.copy()
            new_met.id = met_id
            new_met.compartment = comp
    return new_met

# %%
def update_rxnid(new_rxn,halomodel,universal):
    # metacyc reaction ids in halomodel:
    halo_rxn_ids = dict()
    halo_rxn_mets = dict()
    mets_rxn = dict()
    for rxn in halomodel.reactions: 
        halo_rxn_ids[rxn.id] = True
        mets = [met.id for met in rxn.metabolites]
        mets.sort()
        mets = tuple(mets)
        halo_rxn_mets[mets] = True
        mets_rxn[mets] = rxn
        
    # 1. check metacyc id
    meta_ids = new_rxn.annotation.get('biocyc')
    new_rxn_id = new_rxn.id
    # case 1: there is metacyc ids, map metacyc id
    if meta_ids is not None:
        if type(meta_ids) == str: meta_ids = [meta_ids]
        for meta_id in meta_ids:
            meta_id = meta_id.replace('META:','')
            if halo_rxn_ids.get(meta_id,False): new_rxn_id = meta_id
    
    # case 2: if case 1 failed, check reaction equations
    else:
        new_mets = [met.id for met in new_rxn.metabolites]
        new_mets.sort()
        new_mets = tuple(new_mets)
        if halo_rxn_mets.get(new_mets,False): 
            # the two reactions contain the same metabolites. Now compare the equations, including direction
            eq1 = new_rxn.reaction
            eq2 = mets_rxn[new_mets].reaction
            eq1 = eq1.split()
            eq2 = eq2.split()
            
            eq1.sort()
            eq2.sort()
            if eq1 == eq2:
                # print(new_rxn.id,new_rxn.reaction)
                # print(mets_rxn[new_mets].id,mets_rxn[new_mets].reaction)
                # print('')
                new_rxn_id = mets_rxn[new_mets].id
            
    new_rxn.id = new_rxn_id
    
    # if new_rxn_id is in universal model, use the reactions in univeral model
    try: 
        rxn_universal = universal.reactions.get_by_id(new_rxn_id)
        gr_rule = new_rxn.gene_reaction_rule 
        new_rxn = rxn_universal.copy()
        new_rxn.gene_reaction_rule = gr_rule
    except: None
    
    
    return new_rxn

# %%
def create_universal_rxn(eco_rxn,halomodel,universal,mnx2meta):
    coeffs = dict()
    is_transport = False
    
    # convert metabolite ids
    mets = list()
    for eco_met in eco_rxn.metabolites:
        new_met = create_universal_met(eco_met,halomodel,universal,mnx2meta)
        if new_met.id in mets:
            is_transport = True

        mets.append(new_met.id)
        coeffs[new_met] = coeffs.get(new_met,0) + eco_rxn.get_coefficient(eco_met)

    if is_transport and 'BIOMASS' not in eco_rxn.id: return None
    else:
        # convert reaction ids
        new_rxn = eco_rxn.copy()
        new_rxn.subtract_metabolites(new_rxn.metabolites)
        new_rxn.add_metabolites(coeffs)
        
        new_rxn = update_rxnid(new_rxn,halomodel,universal)
        return new_rxn

# %%
def is_transport_in_universal(rxn):
    is_transport = False
    mets = dict()
    for met in rxn.metabolites: 
        comp = met.compartment
        met_id = met.id.replace('_{0}'.format(comp),'')
        if mets.get(met_id) is not None: is_transport = True
        else: mets[met_id] = 0
    if is_transport: print(rxn.reaction)
    return is_transport

# %%
def remove_transport_rxn_from_model_on_template(model):
    rxns = list()
    
    
    for rxn in model.reactions:
        is_transport = is_transport_in_universal(rxn)
        if not is_transport: rxns.append(rxn)
    
    new_model = cobra.Model('model_from_template_without_transport')
    new_model.add_reactions(rxns)
    print('{0} transport reactions were removed'.format(len(model.reactions)-len(rxns)))
    return new_model

# %%
eco = pickle.load(open('../Results/eco.pkl','rb'))
# Out:
# Read LP format model from file /var/folders/dx/ghtq02dx2w307xx_5hncb421qny3_w/T/tmpy7001q7_.lp
# Reading time = 0.02 seconds
# : 1877 rows, 5424 columns, 21150 nonzeros

# %%
halo_meta = pickle.load(open('../Results/halo_meta.pkl','rb'))
# Out:
# Read LP format model from file /var/folders/dx/ghtq02dx2w307xx_5hncb421qny3_w/T/tmp76fxk72u.lp
# Reading time = 0.02 seconds
# : 1677 rows, 2608 columns, 12534 nonzeros

# %%
universal = cobra.Model('universal')
mnx2meta = dict()
for line in open('../../../ComplementaryData/MNX2metacyc.tsv'):
    cont = line.split()
    mnx2meta[cont[0]] = mnx2meta.get(cont[0],[]) + [cont[1]]

univeral_rxns = dict()
for eco_rxn in eco.reactions:
    
    new_rxn = create_universal_rxn(eco_rxn,halo_meta,universal,mnx2meta)
    if new_rxn is None: 
        print(eco_rxn.id)
        print(eco_rxn.reaction)
        continue
    
    
    univeral_rxns[new_rxn.id] = new_rxn
universal.add_reactions(univeral_rxns.values())
# Out:
# GLUtex
# glu__L_e <=> glu__L_p
# GLYtex
# gly_e <=> gly_p
# GLYALDtex
# glyald_e <=> glyald_p
# GLYBtex
# glyb_e <=> glyb_p
# GLYCtex
# glyc_e <=> glyc_p
# GLYC3Ptex
# glyc3p_e <=> glyc3p_p
# GLYCLTtex
# glyclt_e <=> glyclt_p
# GTPtex
# gtp_e <=> gtp_p
# GUAtex
# gua_e <=> gua_p
# Htex
# h_e <=> h_p
# H2tex
# h2_e <=> h2_p
# H2Otex
# h2o_e <=> h2o_p
# DAPtex
# 15dap_e <=> 15dap_p
# 12PPDStex
# 12ppd__S_e <=> 12ppd__S_p
# DDGLCNtex
# 2ddglcn_e <=> 2ddglcn_p
# 26DAHtex
# 26dap__M_e <=> 26dap__M_p
# HCINNMtex
# 3hcinnm_e <=> 3hcinnm_p
# HPPPNtex
# 3hpppn_e <=> 3hpppn_p
# ACtex
# ac_e <=> ac_p
# ACALDtex
# acald_e <=> acald_p
# ACMANAtex
# acmana_e <=> acmana_p
# ACMUMtex
# acmum_e --> acmum_p
# GALtex
# gal_e <=> gal_p
# GALCTtex
# galct__D_e <=> galct__D_p
# GALCTNtex
# galctn__D_e <=> galctn__D_p
# GALTtex
# galt_e <=> galt_p
# GALURtex
# galur_e <=> galur_p
# GAMtex
# gam_e <=> gam_p
# GBBTNtex
# gbbtn_e <=> gbbtn_p
# HIStex
# his__L_e <=> his__L_p
# HXAtex
# hxa_e <=> hxa_p
# HYXNtex
# hxan_e <=> hxan_p
# IDONtex
# idon__L_e <=> idon__L_p
# ILEtex
# ile__L_e <=> ile__L_p
# INSTtex
# inost_e <=> inost_p
# INStex
# ins_e <=> ins_p
# Ktex
# k_e <=> k_p
# D_LACtex
# lac__D_e <=> lac__D_p
# FRULYStex
# frulys_e <=> frulys_p
# ASPtex
# asp__L_e <=> asp__L_p
# INDOLEtex
# indole_e <=> indole_p
# L_LACtex
# lac__L_e <=> lac__L_p
# CPGNtonex
# cpgn_e + h_p --> cpgn_p + h_c
# GLCRtex
# glcr_e <=> glcr_p
# GLCNtex
# glcn_e <=> glcn_p
# GLCURtex
# glcur_e <=> glcur_p
# GLNtex
# gln__L_e <=> gln__L_p
# O2tex
# o2_e <=> o2_p
# OCTAtex
# octa_e <=> octa_p
# ORNtex
# orn_e <=> orn_p
# FEENTERtonex
# feenter_e + h_p --> feenter_p + h_c
# RMNtex
# rmn_e <=> rmn_p
# MALTTRtexi
# malttr_e --> malttr_p
# MALTTTRtexi
# maltttr_e --> maltttr_p
# MALTPTtexi
# maltpt_e --> maltpt_p
# MALTtexi
# malt_e --> malt_p
# GLCtex_copy1
# glc__D_e --> glc__D_p
# FE3DCITtonex
# fe3dcit_e + h_p --> fe3dcit_p + h_c
# PHEtex
# phe__L_e <=> phe__L_p
# PItex
# pi_e <=> pi_p
# PNTOtex
# pnto__R_e <=> pnto__R_p
# PPPNtex
# pppn_e <=> pppn_p
# PPTtex
# ppt_e <=> ppt_p
# PTRCtex
# ptrc_e <=> ptrc_p
# PYRtex
# pyr_e <=> pyr_p
# DSERtex
# ser__D_e <=> ser__D_p
# SERtex
# ser__L_e <=> ser__L_p
# SO4tex
# so4_e <=> so4_p
# SPMDtex
# spmd_e <=> spmd_p
# SUCCtex
# succ_e <=> succ_p
# SUCRtex
# sucr_e <=> sucr_p
# TARTRtex
# tartr__L_e <=> tartr__L_p
# TAURtex
# taur_e <=> taur_p
# THRtex
# thr__L_e <=> thr__L_p
# THMDtex
# thymd_e <=> thymd_p
# METDtex
# met__D_e <=> met__D_p
# METtex
# met__L_e <=> met__L_p
# MNLtex
# mnl_e <=> mnl_p
# NAtex
# na1_e <=> na1_p
# NACtex
# nac_e <=> nac_p
# NH4tex
# nh4_e <=> nh4_p
# BUTtex
# but_e <=> but_p
# CHLtex
# chol_e <=> chol_p
# CO2tex
# co2_e <=> co2_p
# CRNtex
# crn_e <=> crn_p
# DINStex
# din_e <=> din_p
# DMStex
# dms_e <=> dms_p
# CSNtex
# csn_e <=> csn_p
# CYNTtex
# cynt_e <=> cynt_p
# CYStex
# cys__L_e <=> cys__L_p
# CYTDtex
# cytd_e <=> cytd_p
# DCAtex
# dca_e <=> dca_p
# DCYTtex
# dcyt_e <=> dcyt_p
# DGSNtex
# dgsn_e <=> dgsn_p
# LCTStex
# lcts_e <=> lcts_p
# LEUtex
# leu__L_e <=> leu__L_p
# LYStex
# lys__L_e <=> lys__L_p
# LYXtex
# lyx__L_e <=> lyx__L_p
# MANtex
# man_e <=> man_p
# MAN6Ptex
# man6p_e <=> man6p_p
# MELIBtex
# melib_e <=> melib_p
# DMSOtex
# dmso_e <=> dmso_p
# DURItex
# duri_e <=> duri_p
# FRUtex
# fru_e <=> fru_p
# FUCtex
# fuc__L_e <=> fuc__L_p
# FUMtex
# fum_e <=> fum_p
# FE2tex
# fe2_e <=> fe2_p
# NMNtex
# nmn_e <=> nmn_p
# NO2tex
# no2_e <=> no2_p
# GDPtex
# gdp_e <=> gdp_p
# TMAtex
# tma_e <=> tma_p
# TMAOtex
# tmao_e <=> tmao_p
# TREtex
# tre_e <=> tre_p
# TRPtex
# trp__L_e <=> trp__L_p
# TSULtex
# tsul_e <=> tsul_p
# TYRtex
# tyr__L_e <=> tyr__L_p
# URAtex
# ura_e <=> ura_p
# UREAtex
# urea_e <=> urea_p
# URItex
# uri_e <=> uri_p
# VALtex
# val__L_e <=> val__L_p
# XANtex
# xan_e <=> xan_p
# XYLtex
# xyl__D_e <=> xyl__D_p
# ABUTtex
# 4abut_e <=> 4abut_p
# FEOXAMUtex
# feoxam_un_p + h_p --> feoxam_un_e + h_c
# ARBTNtex
# arbtn_p + h_p --> arbtn_e + h_c
# 23CAMPtex
# 23camp_e <=> 23camp_p
# 23CCMPtex
# 23ccmp_e <=> 23ccmp_p
# 23CUMPtex
# 23cump_e <=> 23cump_p
# 23CGMPtex
# 23cgmp_e <=> 23cgmp_p
# 3AMPtex
# 3amp_e <=> 3amp_p
# 3CMPtex
# 3cmp_e <=> 3cmp_p
# FEENTERtex
# enter_p + h_p --> enter_e + h_c
# FE3HOXUtpp
# fe3hox_un_p + h_p --> fe3hox_un_e + h_c
# ETHSO3tex
# ethso3_e <=> ethso3_p
# BUTSO3tex
# butso3_e <=> butso3_p
# LIPOtex
# lipoate_e <=> lipoate_p
# GALBDtex
# gal_bD_e <=> gal_bD_p
# SULFACtex
# sulfac_e <=> sulfac_p
# NOtex
# no_e <=> no_p
# N2Otex
# n2o_e <=> n2o_p
# PEAMNtex
# peamn_e <=> peamn_p
# PACALDtex
# pacald_e <=> pacald_p
# PHEMEtiex
# pheme_p --> pheme_e
# CYANtex
# cyan_e <=> cyan_p
# SO3tex
# so3_e <=> so3_p
# TCYNTtex
# tcynt_e <=> tcynt_p
# METSOX1tex
# metsox_S__L_e <=> metsox_S__L_p
# METSOX2tex
# metsox_R__L_e <=> metsox_R__L_p
# 3UMPtex
# 3ump_e <=> 3ump_p
# 3GMPtex
# 3gmp_e <=> 3gmp_p
# DOPAtex
# dopa_e <=> dopa_p
# 4HOXPACDtex
# 4hoxpacd_e <=> 4hoxpacd_p
# ETHAtex
# etha_e <=> etha_p
# G3PStex
# g3ps_e <=> g3ps_p
# ACGAL1Ptex
# acgal1p_e <=> acgal1p_p
# ACGALtex
# acgal_e <=> acgal_p
# GLCUR1Ptex
# glcur1p_e <=> glcur1p_p
# UDPGLCURtex
# udpglcur_e <=> udpglcur_p
# ISETACtex
# isetac_e <=> isetac_p
# UDPGtex
# udpg_e <=> udpg_p
# UDPGALtex
# udpgal_e <=> udpgal_p
# ACGAM1Ptex
# acgam1p_e <=> acgam1p_p
# UACGAMtex
# uacgam_e <=> uacgam_p
# UDPACGALtex
# udpacgal_e <=> udpacgal_p
# MSO3tex
# mso3_e <=> mso3_p
# GLYC2Ptex
# glyc2p_e <=> glyc2p_p
# PSERtex
# pser__L_e <=> pser__L_p
# R5Ptex
# r5p_e <=> r5p_p
# THRPtex
# thrp_e <=> thrp_p
# TYRPtex
# tyrp_e <=> tyrp_p
# CPGNUtex
# cpgn_un_p + h_p --> cpgn_un_e + h_c
# CITtex
# cit_e <=> cit_p
# ACGAtex
# acgam_e <=> acgam_p
# DDCAtexi
# ddca_e --> ddca_p
# TTDCAtexi
# ttdca_e --> ttdca_p
# HDCAtexi
# hdca_e --> hdca_p
# OCDCAtexi
# ocdca_e --> ocdca_p
# OCDCEAtexi
# ocdcea_e --> ocdcea_p
# G6Ptex
# g6p_e <=> g6p_p
# MOBDtex
# mobd_e <=> mobd_p
# NI2tex
# ni2_e <=> ni2_p
# FECRMtonex
# fecrm_e + h_p --> fecrm_p + h_c
# ARBTNtonex
# arbtn_fe3_e + h_p --> arbtn_fe3_p + h_c
# H2O2tex
# h2o2_e <=> h2o2_p
# ADEtex
# ade_e <=> ade_p
# ADNtex
# adn_e <=> adn_p
# AGMtex
# agm_e <=> agm_p
# ALAtex
# ala__L_e <=> ala__L_p
# BALAtex
# ala_B_e <=> ala_B_p
# DALAtex
# ala__D_e <=> ala__D_p
# AMPtex
# amp_e <=> amp_p
# ARBtex
# arab__L_e <=> arab__L_p
# ARGtex
# arg__L_e <=> arg__L_p
# ASCBtex
# ascb__L_e <=> ascb__L_p
# FE3HOXtonex
# fe3hox_e + h_p --> fe3hox_p + h_c
# MMETtex
# mmet_e <=> mmet_p
# FE3tex
# fe3_e <=> fe3_p
# MG2tex
# mg2_e <=> mg2_p
# Zn2tex
# zn2_e <=> zn2_p
# CD2tex
# cd2_e <=> cd2_p
# 14GLUCANtexi
# 14glucan_e --> 14glucan_p
# ASO3tex
# aso3_e <=> aso3_p
# MANGLYCtex
# manglyc_e <=> manglyc_p
# FRUURtex
# fruur_e <=> fruur_p
# GLYCAtex
# glyc__R_e <=> glyc__R_p
# COBALT2tex
# cobalt2_e <=> cobalt2_p
# DIMPtex
# dimp_e <=> dimp_p
# XTSNtex
# xtsn_e <=> xtsn_p
# HG2tex
# hg2_e <=> hg2_p
# DADNtex
# dad_2_e <=> dad_2_p
# DHAtex
# dha_e <=> dha_p
# ETOHtex
# etoh_e <=> etoh_p
# ACACtex
# acac_e <=> acac_p
# ACNAMtex
# acnam_e <=> acnam_p
# H2Stex
# h2s_e <=> h2s_p
# 4PEPTtex
# LalaDgluMdapDala_e <=> LalaDgluMdapDala_p
# CU2tex
# cu2_e <=> cu2_p
# FECRMUtex
# fecrm_un_p + h_p --> fecrm_un_e + h_c
# CLtex
# cl_e <=> cl_p
# PROtex
# pro__L_e <=> pro__L_p
# SBTtex
# sbt__D_e <=> sbt__D_p
# AKGtex
# akg_e <=> akg_p
# ALLTNtex
# alltn_e <=> alltn_p
# ASNtex
# asn__L_e <=> asn__L_p
# TYMtex
# tym_e <=> tym_p
# CMPtex
# cmp_e <=> cmp_p
# DUMPtex
# dump_e <=> dump_p
# XMPtex
# xmp_e <=> xmp_p
# 3PEPTtex
# LalaDgluMdap_e <=> LalaDgluMdap_p
# ANHGMtex
# anhgm_e <=> anhgm_p
# FALDtex
# fald_e <=> fald_p
# CYSDtex
# cys__D_e <=> cys__D_p
# G3PItex
# g3pi_e <=> g3pi_p
# G3PGtex
# g3pg_e <=> g3pg_p
# G3PEtex
# g3pe_e <=> g3pe_p
# G3PCtex
# g3pc_e <=> g3pc_p
# DAMPtex
# damp_e <=> damp_p
# DCMPtex
# dcmp_e <=> dcmp_p
# DGMPtex
# dgmp_e <=> dgmp_p
# DTMPtex
# dtmp_e <=> dtmp_p
# GMPtex
# gmp_e <=> gmp_p
# IMPtex
# imp_e <=> imp_p
# UMPtex
# ump_e <=> ump_p
# G1Ptex
# g1p_e <=> g1p_p
# SKMtex
# skm_e <=> skm_p
# MNtex
# mn2_e <=> mn2_p
# GAL1Ptex
# gal1p_e <=> gal1p_p
# O2Stex
# o2s_e <=> o2s_p
# HOMtex
# hom__L_e <=> hom__L_p
# SO2tex
# so2_e <=> so2_p
# ACSERtex
# acser_e <=> acser_p
# ALAALAtex
# alaala_e <=> alaala_p
# MALtex
# mal__L_e <=> mal__L_p
# NO3tex
# no3_e <=> no3_p
# TTDCEAtexi
# ttdcea_e --> ttdcea_p
# HDCEAtexi
# hdcea_e --> hdcea_p
# GSNtex
# gsn_e <=> gsn_p
# FORtex
# for_e <=> for_p
# RIBtex
# rib__D_e <=> rib__D_p
# THMtex
# thm_e <=> thm_p
# XYLUtex
# xylu__L_e <=> xylu__L_p
# ALLtex
# all__D_e <=> all__D_p
# 34dhpactex
# 34dhpac_e <=> 34dhpac_p
# MALTHXtexi
# malthx_e --> malthx_p
# FE3DHBZStonex
# fe3dhbzs_e + h_p --> fe3dhbzs_p + h_c
# 23DAPPAtex
# 23dappa_e <=> 23dappa_p
# FEOXAMtonex
# feoxam_e + h_p --> feoxam_p + h_c
# GLCtex_copy2
# glc__D_e <=> glc__D_p
# MINOHPtexi
# minohp_e --> minohp_p
# PPALtex
# ppal_e <=> ppal_p
# CA2tex
# ca2_e <=> ca2_p
# CUtex
# cu_e <=> cu_p
# 12PPDRtex
# 12ppd__R_e <=> 12ppd__R_p
# F6Ptex
# f6p_e <=> f6p_p
# GAMAN6Ptex
# gam6p_e <=> gam6p_p
# PROGLYtex
# progly_e <=> progly_p
# CGLYtex
# cgly_e <=> cgly_p
# GTHOXtex
# gthox_e <=> gthox_p
# GTHRDtex
# gthrd_e <=> gthrd_p
# TUNGStex
# tungs_e <=> tungs_p
# GALCTNLtex
# galctn__L_e <=> galctn__L_p
# MALDtex
# mal__D_e <=> mal__D_p
# OROTtex
# orot_e <=> orot_p
# 5DGLCNtex
# 5dglcn_e <=> 5dglcn_p
# PPAtex
# ppa_e <=> ppa_p
# PSCLYStex
# psclys_e <=> psclys_p
# THYMtex
# thym_e <=> thym_p
# LIPAabctex
# atp_c + h2o_c + lipa_p --> adp_c + h_c + lipa_e + pi_c
# CMtpp
# cm_p + h_p --> cm_e + h_c
# FUSAtpp
# fusa_p + h_p --> fusa_e + h_c
# RFAMPtex
# rfamp_e <=> rfamp_p
# MINCYCtex
# mincyc_e <=> mincyc_p
# MINCYCtpp
# h_p + mincyc_p --> h_c + mincyc_e
# DOXRBCNtex
# doxrbcn_e <=> doxrbcn_p
# DOXRBCNtpp
# doxrbcn_p + h_p --> doxrbcn_e + h_c
# NOVBCNtpp
# h_p + novbcn_p --> h_c + novbcn_e
# CMtex
# cm_e <=> cm_p
# LALALGLUtex
# LalaLglu_e <=> LalaLglu_p
# 5MTRtex
# 5mtr_e <=> 5mtr_p
# LALADGLUtex
# LalaDglu_e <=> LalaDglu_p
# 3HPPtex
# 3hpp_e <=> 3hpp_p
# FUSAtex
# fusa_e <=> fusa_p
# NOVBCNtex
# novbcn_e <=> novbcn_p
# QUIN2tex
# quin_e <=> quin_p
# O16A4COLIPAabctex
# atp_c + h2o_c + o16a4colipa_p --> adp_c + h_c + o16a4colipa_e + pi_c
# COLIPAabctex
# atp_c + colipa_p + h2o_c --> adp_c + colipa_e + h_c + pi_c
# ENLIPAabctex
# atp_c + enlipa_p + h2o_c --> adp_c + enlipa_e + h_c + pi_c
# CLIPAabctex
# atp_c + h2o_c + lipa_cold_p --> adp_c + h_c + lipa_cold_e + pi_c
# K2L4Aabctex
# atp_c + h2o_c + kdo2lipid4_p --> adp_c + h_c + kdo2lipid4_e + pi_c
# SELtex
# sel_e <=> sel_p
# MEOHtex
# meoh_e <=> meoh_p
# TTRCYCtex
# ttrcyc_e <=> ttrcyc_p
# TTRCYCtpp
# h_p + ttrcyc_p --> h_c + ttrcyc_e
# SLNTtex
# slnt_e <=> slnt_p
# RFAMPtpp
# h_p + rfamp_p --> h_c + rfamp_e
# ACOLIPAabctex
# acolipa_p + atp_c + h2o_c --> acolipa_e + adp_c + h_c + pi_c
# ECA4COLIPAabctex
# atp_c + eca4colipa_p + h2o_c --> adp_c + eca4colipa_e + h_c + pi_c
# COLIPAPabctex
# atp_c + colipap_p + h2o_c --> adp_c + colipap_e + h_c + pi_c
# CH4tex
# ch4_e <=> ch4_p
# TARTRDtex
# tartr__D_e <=> tartr__D_p
# BTNtex
# btn_e <=> btn_p
# ARBTtex
# arbt_e --> arbt_p
# PYDXtex
# pydx_e <=> pydx_p
# PYDXNtex
# pydxn_e <=> pydxn_p
# PYDAMtex
# pydam_e <=> pydam_p
# CHTBStex
# chtbs_e <=> chtbs_p
# CRNDtex
# crn__D_e <=> crn__D_p
# DXYLONtex
# dxylnt_e <=> dxylnt_p
# PSURItex
# psuri_e <=> psuri_p
# DHPStex
# dhps_e <=> dhps_p
# FMNtex
# fmn_p <=> fmn_e
# CLBtex
# cellb_e <=> cellb_p
# FADtex
# fad_p <=> fad_e
# 2DGLCtex
# 2dglc_e <=> 2dglc_p
# SQtex
# sq_e <=> sq_p
# URATEtex
# urate_e <=> urate_p
# CBL1tonex
# cbl1_e + h_p --> cbl1_p + h_c
# CBItonex
# cbi_e + h_p --> cbi_p + h_c
# Ftex
# f_p <=> f_e
# CYSItex
# cysi__L_e <=> cysi__L_p
# CS1tex
# cs1_e <=> cs1_p
# ADOCBLtonex
# adocbl_e + h_p --> adocbl_p + h_c
# MEPNtex
# mepn_e <=> mepn_p
# 4ABZGLUtex
# 4abzglu_e <=> 4abzglu_p
# METGLCURtex
# metglcur_e <=> metglcur_p
# AI2tex
# mththf_e <=> mththf_p

# %%
universal.objective = 'ATPASE-RXN'
universal.objective_direction = 'max'
#eco.objective = 'BIOMASS_Ec_iML1515_core_75p37M'

# check why? make sure growth rate is higher after removal of compartment p. 
s = universal.optimize()
print(s)
#print(eco.optimize())
# Out:
# <Solution 235.000 at 0x131a01d7f0>

# %%
for rxn in universal.reactions:
    if s[rxn.id] !=0: 
        print(rxn.id,s[rxn.id])
        print(rxn.reaction)
        print()
# Out:
# EX_h_e -1.7053025658242404e-12
# PROTON_e <=>
#
# CITSYN-RXN 20.000000000000114
# ACETYL-COA_c + OXALACETIC_ACID_c + WATER_c --> CIT_c + CO-A_c + PROTON_c
#
# ICDHyr 20.000000000000114
# NADP_c + icit_c <=> 2-KETOGLUTARATE_c + CARBON-DIOXIDE_c + NADPH_c
#
# 2PGADEHYDRAT-RXN 20.0
# 2-PG_c <=> PHOSPHO-ENOL-PYRUVATE_c + WATER_c
#
# PGLUCISOM-RXN 10.0
# D-glucopyranose-6-phosphate_c <=> FRUCTOSE-6P_c
#
# PHOSGLYPHOS-RXN -20.0
# ATP_c + G3P_c <=> ADP_c + DPG_c
#
# EX_co2_e 60.00000000000034
# CARBON-DIOXIDE_e <=>
#
# FRD2 100.00000000000045
# FUM_c + REDUCED-MENAQUINONE_c --> CPD-9728_c + SUC_c
#
# EX_glc__D_e -10.0
# Glucopyranose_e <=>
#
# MALATE-DEH-RXN 20.000000000000114
# MAL_c + NAD_c <=> NADH_c + OXALACETIC_ACID_c + PROTON_c
#
# FUMHYDR-RXN 20.000000000000114
# FUM_c + WATER_c <=> MAL_c
#
# PYRNUTRANSHYDROGEN-RXN 20.000000000000114
# NADPH_c + NAD_c --> NADH_c + NADP_c
#
# DHAPT 10.0
# DIHYDROXYACETONE_c + PHOSPHO-ENOL-PYRUVATE_c --> DIHYDROXY-ACETONE-PHOSPHATE_c + PYRUVATE_c
#
# F6PA 10.0
# FRUCTOSE-6P_c <=> DIHYDROXYACETONE_c + GAP_c
#
# 2OXOGLUTARATEDEH-RXN 20.000000000000114
# 2-KETOGLUTARATE_c + CO-A_c + NAD_c --> CARBON-DIOXIDE_c + NADH_c + SUC-COA_c
#
# GAPOXNPHOSPHN-RXN 20.0
# GAP_c + NAD_c + Pi_c <=> DPG_c + NADH_c + PROTON_c
#
# O2tpp 60.000000000000284
# OXYGEN-MOLECULE_e <=> OXYGEN-MOLECULE_c
#
# CO2tpp -60.00000000000034
# CARBON-DIOXIDE_e <=> CARBON-DIOXIDE_c
#
# ATPSYN-RXN 195.00000000000134
# ADP_c + 4.0 PROTON_e + Pi_c <=> ATP_c + 3.0 PROTON_c + WATER_c
#
# TRANS-RXN-145 -60.0
# WATER_e <=> WATER_c
#
# GLCptspp 10.0
# Glucopyranose_e + PHOSPHO-ENOL-PYRUVATE_c --> D-glucopyranose-6-phosphate_c + PYRUVATE_c
#
# EX_h2o_e 60.0
# WATER_e <=>
#
# ATPASE-RXN 235.00000000000168
# ATP_c + WATER_c --> ADP_c + PROTON_c + Pi_c
#
# PYRUVDEH-RXN 20.000000000000114
# CO-A_c + NAD_c + PYRUVATE_c --> ACETYL-COA_c + CARBON-DIOXIDE_c + NADH_c
#
# SUCCCOASYN-RXN -20.000000000000114
# ATP_c + CO-A_c + SUC_c <=> ADP_c + Pi_c + SUC-COA_c
#
# 3PGAREARR-RXN -20.0
# 2-PG_c <=> G3P_c
#
# TRIOSEPISOMERIZATION-RXN 10.0
# DIHYDROXY-ACETONE-PHOSPHATE_c <=> GAP_c
#
# EX_o2_e -60.000000000000284
# OXYGEN-MOLECULE_e <=>
#
# CYTBO3_4pp 120.00000000000057
# CPD-9956_c + 0.5 OXYGEN-MOLECULE_c + 4.0 PROTON_c --> 4.0 PROTON_e + UBIQUINONE-8_c + WATER_c
#
# SUCDi 120.00000000000057
# SUC_c + UBIQUINONE-8_c --> CPD-9956_c + FUM_c
#
# ACONTb 20.000000000000114
# CIS-ACONITATE_c + WATER_c <=> icit_c
#
# ACONITATEDEHYDR-RXN 20.000000000000114
# CIT_c <=> CIS-ACONITATE_c + WATER_c
#
# NADH17pp 100.00000000000045
# CPD-9728_c + NADH_c + 4.0 PROTON_c --> NAD_c + 3.0 PROTON_e + REDUCED-MENAQUINONE_c

# %%
universal.objective = 'BIOMASS_Ec_iML1515_core_75p37M'
#eco.objective = 'BIOMASS_Ec_iML1515_core_75p37M'

# check why? make sure growth rate is higher after removal of compartment p. 
print(universal.optimize())
#print(eco.optimize())
# Out:
# <Solution 1.384 at 0x1328d17ac8>

# %%
for rxn in model.metabolites.ATP_c.reactions:
    if rxn.lower_bound :
        print(rxn.id)
        print(rxn.reaction,rxn.lower_bound)
# Out:
# SERASr
# ATP_c + PROTON_c + SER_c <=> PPI_c + SERYL-AMP_c -1000.0
# BTUR2-RXN
# ATP_c + COBINAMIDE_c + PROTON_c <=> ADENOSYLCOBINAMIDE_c + P3I_c -1000.0
# RXN-12002
# ATP_c + UMP_c <=> ADP_c + UDP_c -1000.0
# UDPKIN-RXN
# ATP_c + UDP_c <=> ADP_c + UTP_c -1000.0
# ADENYL-KIN-RXN
# AMP_c + ATP_c <=> 2.0 ADP_c -1000.0
# PHOSGLYPHOS-RXN
# ATP_c + G3P_c <=> ADP_c + DPG_c -1000.0
# CBLAT
# ATP_c + COB-I-ALAMIN_c + PROTON_c <=> ADENOSYLCOBALAMIN_c + P3I_c -1000.0
# CDPKIN-RXN
# ATP_c + CDP_c <=> ADP_c + CTP_c -1000.0
# PRPPS
# ATP_c + CPD-15318_c <=> AMP_c + PROTON_c + PRPP_c -1000.0
# NICONUCADENYLYLTRAN-RXN
# ATP_c + NICOTINATE_NUCLEOTIDE_c + PROTON_c <=> DEAMIDO-NAD_c + PPI_c -1000.0
# DTDPKIN-RXN
# ATP_c + TDP_c <=> ADP_c + TTP_c -1000.0
# ACETATEKIN-RXN
# ACET_c + ATP_c <=> ACETYL-P_c + ADP_c -1000.0
# GLYRIBONUCSYN-RXN
# 5-P-BETA-D-RIBOSYL-AMINE_c + ATP_c + GLY_c <=> 5-PHOSPHO-RIBOSYL-GLYCINEAMIDE_c + ADP_c + PROTON_c + Pi_c -1000.0
# DUDPKIN-RXN
# ATP_c + DUDP_c <=> ADP_c + DUTP_c -1000.0
# GMKALT-RXN
# ATP_c + DGMP_c <=> ADP_c + DGDP_c -1000.0
# SUCCCOASYN-RXN
# ATP_c + CO-A_c + SUC_c <=> ADP_c + Pi_c + SUC-COA_c -1000.0
# DGDPKIN-RXN
# ATP_c + DGDP_c <=> ADP_c + DGTP_c -1000.0
# RXN-11832
# ATP_c + CMP_c <=> ADP_c + CDP_c -1000.0
# ASPARTATEKIN-RXN
# ATP_c + L-ASPARTATE_c <=> ADP_c + L-BETA-ASPARTYL-P_c -1000.0
# DTMPKI-RXN
# ATP_c + TMP_c <=> ADP_c + TDP_c -1000.0
# GALKr
# ALPHA-D-GALACTOSE_c + ATP_c <=> ADP_c + GALACTOSE-1P_c + PROTON_c -1000.0
# PPAKr
# ADP_c + PROPIONYL-P_c <=> ATP_c + ppa_c -1000.0
# RXN-7913
# ATP_c + DCMP_c <=> ADP_c + DCDP_c -1000.0
# DCDPKIN-RXN
# ATP_c + DCDP_c <=> ADP_c + DCTP_c -1000.0
# GDPKIN-RXN
# ATP_c + GDP_c <=> ADP_c + GTP_c -1000.0
# DADPKIN-RXN
# ATP_c + DADP_c <=> ADP_c + DATP_c -1000.0
# DALADALALIG-RXN
# ATP_c + 2.0 D-ALANINE_c <=> ADP_c + D-ALA-D-ALA_c + PROTON_c + Pi_c -1000.0
# DADK
# ATP_c + DAMP_c <=> ADP_c + DADP_c -1000.0
# GUANYL-KIN-RXN
# ATP_c + GMP_c <=> ADP_c + GDP_c -1000.0
# CBMKr
# AMMONIUM_c + ATP_c + CARBON-DIOXIDE_c <=> ADP_c + CARBAMOYL-P_c + 2.0 PROTON_c -1000.0

# %%
eco.reactions.ATPM
# Out:
# <Reaction ATPM at 0x132ecc8358>

# %%
model = cobra.io.load_json_model('../../../ModelFiles/json/Halo_GEM_v1.2.json')

# %%
for rxn in model.reactions:
    if rxn.id.startswith('GLC'): 
        print(rxn.id)
        print(rxn.reaction,rxn.lower_bound,rxn.upper_bound)
        print()
# Out:
# GLCRAL
# 5-KETO-4-DEOXY-D-GLUCARATE_c --> PYRUVATE_c + TARTRONATE-S-ALD_c 0.0 1000.0
#
# GLCptspp
# Glucopyranose_c + PHOSPHO-ENOL-PYRUVATE_c --> D-glucopyranose-6-phosphate_c + PYRUVATE_c 0.0 1000.0
#
# GLCDpp
# Glucopyranose_c + UBIQUINONE-8_c + WATER_c --> CPD-9956_c + GLUCONATE_c + PROTON_c 0.0 1000.0
#
# GLCTR1
# CPD-12575_c + CPD0-2295_c --> CPD0-2247_c + PROTON_c + UDP_c 0.0 1000.0
#
# GLCtex_copy2
# Glucopyranose_e <=> Glucopyranose_c -1000.0 1000.0
#
# GLCtex_copy1
# Glucopyranose_e --> Glucopyranose_c 0.0 1000.0

# %%
for rxn in eco.reactions:
    if rxn.id.startswith('GLCtex'): 
        print(rxn.id)
        print(rxn.reaction,rxn.lower_bound,rxn.upper_bound,rxn.gene_reaction_rule)
        print()
# Out:
# GLCtex_copy1
# glc__D_e --> glc__D_p 0.0 1000.0 b4036
#
# GLCtex_copy2
# glc__D_e <=> glc__D_p -1000.0 1000.0 b0241 or b0929 or b1377 or b2215

# %%
for rxn in eco.reactions:
    e, p = False, False
    for met in rxn.metabolites:
        if met.id.endswith('_e'): e = True
        if met.id.endswith('_p'): p = True
    if e and p:
        print(rxn.id)
        print(rxn.reaction,rxn.gene_reaction_rule)
        print()
# Out:
# GLUtex
# glu__L_e <=> glu__L_p b1377 or b0241 or b0929 or b2215
#
# GLYtex
# gly_e <=> gly_p b1377 or b0241 or b0929 or b2215
#
# GLYALDtex
# glyald_e <=> glyald_p b1377 or b0241 or b0929 or b2215
#
# GLYBtex
# glyb_e <=> glyb_p b1377 or b0241 or b0929 or b2215
#
# GLYCtex
# glyc_e <=> glyc_p b1377 or b0241 or b0929 or b2215
#
# GLYC3Ptex
# glyc3p_e <=> glyc3p_p b1377 or b0241 or b0929 or b2215
#
# GLYCLTtex
# glyclt_e <=> glyclt_p b1377 or b0241 or b0929 or b2215
#
# GTPtex
# gtp_e <=> gtp_p b0241 or b1377 or b2215 or b0929
#
# GUAtex
# gua_e <=> gua_p b0411
#
# Htex
# h_e <=> h_p b1377 or b0241 or b0929 or b2215
#
# H2tex
# h2_e <=> h2_p b1377 or b0241 or b0929 or b2215
#
# H2Otex
# h2o_e <=> h2o_p b1377 or b2215 or b1319 or b3875 or s0001 or b0957 or b0241 or b0929
#
# DAPtex
# 15dap_e <=> 15dap_p b1377 or b0241 or b0929 or b2215
#
# 12PPDStex
# 12ppd__S_e <=> 12ppd__S_p b1377 or b0241 or b0929 or b2215
#
# DDGLCNtex
# 2ddglcn_e <=> 2ddglcn_p b1377 or b0241 or b0929 or b2215
#
# 26DAHtex
# 26dap__M_e <=> 26dap__M_p b1377 or b0241 or b0929 or b2215
#
# HCINNMtex
# 3hcinnm_e <=> 3hcinnm_p b1377 or b0241 or b0929 or b2215
#
# HPPPNtex
# 3hpppn_e <=> 3hpppn_p b2215 or b0929 or b1377 or b0241
#
# ACtex
# ac_e <=> ac_p b1377 or b0241 or b0929 or b2215
#
# ACALDtex
# acald_e <=> acald_p b1377 or b0241 or b0929 or b2215
#
# ACMANAtex
# acmana_e <=> acmana_p b0929 or b2215 or b0241 or b1377
#
# ACMUMtex
# acmum_e --> acmum_p b1377 or b0241 or b0929 or b2215
#
# GALtex
# gal_e <=> gal_p b1377 or b0241 or b0929 or b2215
#
# GALCTtex
# galct__D_e <=> galct__D_p b1377 or b0241 or b0929 or b2215
#
# GALCTNtex
# galctn__D_e <=> galctn__D_p b1377 or b0241 or b0929 or b2215
#
# GALTtex
# galt_e <=> galt_p b1377 or b0241 or b0929 or b2215
#
# GALURtex
# galur_e <=> galur_p b1377 or b0241 or b0929 or b2215
#
# GAMtex
# gam_e <=> gam_p b1377 or b0241 or b0929 or b2215
#
# GBBTNtex
# gbbtn_e <=> gbbtn_p b1377 or b0241 or b0929 or b2215
#
# HIStex
# his__L_e <=> his__L_p b1377 or b0241 or b0929 or b2215
#
# HXAtex
# hxa_e <=> hxa_p b1377 or b0241 or b0929 or b2215
#
# HYXNtex
# hxan_e <=> hxan_p b0929 or b2215 or b0241 or b1377
#
# IDONtex
# idon__L_e <=> idon__L_p b1377 or b0241 or b0929 or b2215
#
# ILEtex
# ile__L_e <=> ile__L_p b1377 or b0241 or b0929 or b2215
#
# INSTtex
# inost_e <=> inost_p b1377 or b0241 or b0929 or b2215
#
# INStex
# ins_e <=> ins_p b0411
#
# Ktex
# k_e <=> k_p b1377 or b0241 or b0929 or b2215
#
# D_LACtex
# lac__D_e <=> lac__D_p b1377 or b0241 or b0929 or b2215
#
# FRULYStex
# frulys_e <=> frulys_p b1377 or b0241 or b0929 or b2215
#
# ASPtex
# asp__L_e <=> asp__L_p b1377 or b0241 or b0929 or b2215
#
# INDOLEtex
# indole_e <=> indole_p b1377 or b0241 or b0929 or b2215
#
# L_LACtex
# lac__L_e <=> lac__L_p b2215 or b0929 or b1377 or b0241
#
# CPGNtonex
# cpgn_e + h_p --> cpgn_p + h_c b1102 and b3006 and b1252 and b3005
#
# GLCRtex
# glcr_e <=> glcr_p b1377 or b0241 or b0929 or b2215
#
# GLCNtex
# glcn_e <=> glcn_p b1377 or b0241 or b0929 or b2215
#
# GLCURtex
# glcur_e <=> glcur_p b1377 or b0241 or b0929 or b2215
#
# GLNtex
# gln__L_e <=> gln__L_p b2215 or b0929 or b1377 or b0241
#
# O2tex
# o2_e <=> o2_p b1377 or b0241 or b0929 or b2215
#
# OCTAtex
# octa_e <=> octa_p b1377 or b0241 or b0929 or b2215
#
# ORNtex
# orn_e <=> orn_p b1377 or b0241 or b0929 or b2215
#
# FEENTERtonex
# feenter_e + h_p --> feenter_p + h_c b0584 and b3006 and b1252 and b3005
#
# RMNtex
# rmn_e <=> rmn_p b0929 or b0241 or b2215 or b1377
#
# MALTTRtexi
# malttr_e --> malttr_p b4036
#
# MALTTTRtexi
# maltttr_e --> maltttr_p b4036
#
# MALTPTtexi
# maltpt_e --> maltpt_p b4036
#
# MALTtexi
# malt_e --> malt_p b4036
#
# GLCtex_copy1
# glc__D_e --> glc__D_p b4036
#
# FE3DCITtonex
# fe3dcit_e + h_p --> fe3dcit_p + h_c b3006 and b1252 and b3005 and b4291
#
# PHEtex
# phe__L_e <=> phe__L_p b1377 or b0241 or b0929 or b2215
#
# PItex
# pi_e <=> pi_p b1377 or b0241 or b0929 or b2215
#
# PNTOtex
# pnto__R_e <=> pnto__R_p b1377 or b0241 or b0929 or b2215
#
# PPPNtex
# pppn_e <=> pppn_p b1377 or b0241 or b0929 or b2215
#
# PPTtex
# ppt_e <=> ppt_p b1377 or b0241 or b0929 or b2215
#
# PTRCtex
# ptrc_e <=> ptrc_p b1377 or b0241 or b0929 or b2215
#
# PYRtex
# pyr_e <=> pyr_p b1377 or b0241 or b0929 or b2215
#
# DSERtex
# ser__D_e <=> ser__D_p b1377 or b0241 or b0929 or b2215
#
# SERtex
# ser__L_e <=> ser__L_p b1377 or b0241 or b0929 or b2215
#
# SO4tex
# so4_e <=> so4_p b1377 or b0241 or b0929 or b2215
#
# SPMDtex
# spmd_e <=> spmd_p b0929 or b2215 or b0241 or b1377
#
# SUCCtex
# succ_e <=> succ_p b1377 or b0241 or b0929 or b2215
#
# SUCRtex
# sucr_e <=> sucr_p b1377 or b0241 or b0929 or b2215
#
# TARTRtex
# tartr__L_e <=> tartr__L_p b1377 or b0241 or b0929 or b2215
#
# TAURtex
# taur_e <=> taur_p b1377 or b0241 or b0929 or b2215
#
# THRtex
# thr__L_e <=> thr__L_p b1377 or b0241 or b0929 or b2215
#
# THMDtex
# thymd_e <=> thymd_p b1377 or b0241 or b0929 or b2215
#
# METDtex
# met__D_e <=> met__D_p b1377 or b0241 or b0929 or b2215
#
# METtex
# met__L_e <=> met__L_p b1377 or b0241 or b0929 or b2215
#
# MNLtex
# mnl_e <=> mnl_p b0241 or b1377 or b2215 or b0929
#
# NAtex
# na1_e <=> na1_p b1377 or b0241 or b0929 or b2215
#
# NACtex
# nac_e <=> nac_p b1377 or b0241 or b0929 or b2215
#
# NH4tex
# nh4_e <=> nh4_p b0241 or b1377 or b2215 or b0929
#
# BUTtex
# but_e <=> but_p b1377 or b0241 or b0929 or b2215
#
# CHLtex
# chol_e <=> chol_p b1377 or b0241 or b0929 or b2215
#
# CO2tex
# co2_e <=> co2_p b1377 or b0241 or b0929 or b2215
#
# CRNtex
# crn_e <=> crn_p b1377 or b0241 or b0929 or b2215
#
# DINStex
# din_e <=> din_p b1377 or b0241 or b0929 or b2215
#
# DMStex
# dms_e <=> dms_p b1377 or b0241 or b0929 or b2215
#
# CSNtex
# csn_e <=> csn_p b1377 or b0241 or b0929 or b2215
#
# CYNTtex
# cynt_e <=> cynt_p b0929 or b2215 or b0241 or b1377
#
# CYStex
# cys__L_e <=> cys__L_p b1377 or b0241 or b0929 or b2215
#
# CYTDtex
# cytd_e <=> cytd_p b1377 or b0241 or b0929 or b2215
#
# DCAtex
# dca_e <=> dca_p b1377 or b0241 or b0929 or b2215
#
# DCYTtex
# dcyt_e <=> dcyt_p b0411
#
# DGSNtex
# dgsn_e <=> dgsn_p b1377 or b0241 or b0929 or b2215
#
# LCTStex
# lcts_e <=> lcts_p b1377 or b0241 or b0929 or b2215
#
# LEUtex
# leu__L_e <=> leu__L_p b1377 or b0241 or b0929 or b2215
#
# LYStex
# lys__L_e <=> lys__L_p b1377 or b0241 or b0929 or b2215
#
# LYXtex
# lyx__L_e <=> lyx__L_p b1377 or b0241 or b0929 or b2215
#
# MANtex
# man_e <=> man_p b1377 or b0241 or b0929 or b2215
#
# MAN6Ptex
# man6p_e <=> man6p_p b0929 or b2215 or b0241 or b1377
#
# MELIBtex
# melib_e <=> melib_p b1377 or b0241 or b0929 or b2215
#
# DMSOtex
# dmso_e <=> dmso_p b1377 or b0241 or b0929 or b2215
#
# DURItex
# duri_e <=> duri_p b0411
#
# FRUtex
# fru_e <=> fru_p b1377 or b0241 or b0929 or b2215
#
# FUCtex
# fuc__L_e <=> fuc__L_p b1377 or b0241 or b0929 or b2215
#
# FUMtex
# fum_e <=> fum_p b1377 or b0241 or b0929 or b2215
#
# FE2tex
# fe2_e <=> fe2_p b0241 or b1377 or b2215 or b0929
#
# NMNtex
# nmn_e <=> nmn_p b1377 or b0241 or b0929 or b2215
#
# NO2tex
# no2_e <=> no2_p b1377 or b0241 or b0929 or b2215
#
# GDPtex
# gdp_e <=> gdp_p b2215 or b0929 or b1377 or b0241
#
# TMAtex
# tma_e <=> tma_p b1377 or b0241 or b0929 or b2215
#
# TMAOtex
# tmao_e <=> tmao_p b1377 or b0241 or b0929 or b2215
#
# TREtex
# tre_e <=> tre_p b1377 or b0241 or b0929 or b2215
#
# TRPtex
# trp__L_e <=> trp__L_p b1377 or b0241 or b0929 or b2215
#
# TSULtex
# tsul_e <=> tsul_p b1377 or b0241 or b0929 or b2215
#
# TYRtex
# tyr__L_e <=> tyr__L_p b1377 or b0241 or b0929 or b2215
#
# URAtex
# ura_e <=> ura_p b1377 or b0241 or b0929 or b2215
#
# UREAtex
# urea_e <=> urea_p b1377 or b0241 or b0929 or b2215
#
# URItex
# uri_e <=> uri_p b0411
#
# VALtex
# val__L_e <=> val__L_p b1377 or b0241 or b0929 or b2215
#
# XANtex
# xan_e <=> xan_p b1377 or b0241 or b0929 or b2215
#
# XYLtex
# xyl__D_e <=> xyl__D_p b1377 or b0241 or b0929 or b2215
#
# ABUTtex
# 4abut_e <=> 4abut_p b1377 or b0241 or b0929 or b2215
#
# FEOXAMUtex
# feoxam_un_p + h_p --> feoxam_un_e + h_c
#
# ARBTNtex
# arbtn_p + h_p --> arbtn_e + h_c
#
# 23CAMPtex
# 23camp_e <=> 23camp_p b1377 or b0241 or b0929 or b2215
#
# 23CCMPtex
# 23ccmp_e <=> 23ccmp_p b1377 or b0241 or b0929 or b2215
#
# 23CUMPtex
# 23cump_e <=> 23cump_p b1377 or b0241 or b0929 or b2215
#
# 23CGMPtex
# 23cgmp_e <=> 23cgmp_p b1377 or b0241 or b0929 or b2215
#
# 3AMPtex
# 3amp_e <=> 3amp_p b1377 or b0241 or b0929 or b2215
#
# 3CMPtex
# 3cmp_e <=> 3cmp_p b1377 or b0241 or b0929 or b2215
#
# FEENTERtex
# enter_p + h_p --> enter_e + h_c b3035
#
# FE3HOXUtpp
# fe3hox_un_p + h_p --> fe3hox_un_e + h_c
#
# ETHSO3tex
# ethso3_e <=> ethso3_p b1377 or b0241 or b0929 or b2215
#
# BUTSO3tex
# butso3_e <=> butso3_p b1377 or b0241 or b0929 or b2215
#
# LIPOtex
# lipoate_e <=> lipoate_p b0929 or b1377 or b2215 or b0241
#
# GALBDtex
# gal_bD_e <=> gal_bD_p b0929 or b2215 or b0241 or b1377
#
# SULFACtex
# sulfac_e <=> sulfac_p b0241 or b1377 or b2215 or b0929
#
# NOtex
# no_e <=> no_p b1377 or b0241 or b0929 or b2215
#
# N2Otex
# n2o_e <=> n2o_p b1377 or b0241 or b0929 or b2215
#
# PEAMNtex
# peamn_e <=> peamn_p b1377 or b0241 or b0929 or b2215
#
# PACALDtex
# pacald_e <=> pacald_p b1377 or b0241 or b0929 or b2215
#
# PHEMEtiex
# pheme_p --> pheme_e
#
# CYANtex
# cyan_e <=> cyan_p b1377 or b0241 or b0929 or b2215
#
# SO3tex
# so3_e <=> so3_p b1377 or b0241 or b0929 or b2215
#
# TCYNTtex
# tcynt_e <=> tcynt_p b1377 or b0241 or b0929 or b2215
#
# METSOX1tex
# metsox_S__L_e <=> metsox_S__L_p b1377 or b0241 or b0929 or b2215
#
# METSOX2tex
# metsox_R__L_e <=> metsox_R__L_p b1377 or b0241 or b0929 or b2215
#
# 3UMPtex
# 3ump_e <=> 3ump_p b1377 or b0241 or b0929 or b2215
#
# 3GMPtex
# 3gmp_e <=> 3gmp_p b1377 or b0241 or b0929 or b2215
#
# DOPAtex
# dopa_e <=> dopa_p b1377 or b0241 or b0929 or b2215
#
# 4HOXPACDtex
# 4hoxpacd_e <=> 4hoxpacd_p b1377 or b0241 or b0929 or b2215
#
# ETHAtex
# etha_e <=> etha_p b1377 or b0241 or b0929 or b2215
#
# G3PStex
# g3ps_e <=> g3ps_p b1377 or b0241 or b0929 or b2215
#
# ACGAL1Ptex
# acgal1p_e <=> acgal1p_p b1377 or b0241 or b0929 or b2215
#
# ACGALtex
# acgal_e <=> acgal_p b1377 or b0241 or b0929 or b2215
#
# GLCUR1Ptex
# glcur1p_e <=> glcur1p_p b1377 or b0241 or b0929 or b2215
#
# UDPGLCURtex
# udpglcur_e <=> udpglcur_p b1377 or b0241 or b0929 or b2215
#
# ISETACtex
# isetac_e <=> isetac_p b1377 or b0241 or b0929 or b2215
#
# UDPGtex
# udpg_e <=> udpg_p b1377 or b0241 or b0929 or b2215
#
# UDPGALtex
# udpgal_e <=> udpgal_p b2215 or b0929 or b1377 or b0241
#
# ACGAM1Ptex
# acgam1p_e <=> acgam1p_p b1377 or b0241 or b0929 or b2215
#
# UACGAMtex
# uacgam_e <=> uacgam_p b1377 or b0241 or b0929 or b2215
#
# UDPACGALtex
# udpacgal_e <=> udpacgal_p b1377 or b0241 or b0929 or b2215
#
# MSO3tex
# mso3_e <=> mso3_p b1377 or b0241 or b0929 or b2215
#
# GLYC2Ptex
# glyc2p_e <=> glyc2p_p b1377 or b0241 or b0929 or b2215
#
# PSERtex
# pser__L_e <=> pser__L_p b1377 or b0241 or b0929 or b2215
#
# R5Ptex
# r5p_e <=> r5p_p b1377 or b0241 or b0929 or b2215
#
# THRPtex
# thrp_e <=> thrp_p b1377 or b0241 or b0929 or b2215
#
# TYRPtex
# tyrp_e <=> tyrp_p b1377 or b0241 or b0929 or b2215
#
# CPGNUtex
# cpgn_un_p + h_p --> cpgn_un_e + h_c
#
# CITtex
# cit_e <=> cit_p b1377 or b0241 or b0929 or b2215
#
# ACGAtex
# acgam_e <=> acgam_p b1377 or b0241 or b0929 or b2215
#
# DDCAtexi
# ddca_e --> ddca_p b2344
#
# TTDCAtexi
# ttdca_e --> ttdca_p b2344
#
# HDCAtexi
# hdca_e --> hdca_p b2344
#
# OCDCAtexi
# ocdca_e --> ocdca_p b2344
#
# OCDCEAtexi
# ocdcea_e --> ocdcea_p b2344
#
# G6Ptex
# g6p_e <=> g6p_p b1377 or b0241 or b0929 or b2215
#
# MOBDtex
# mobd_e <=> mobd_p b1377 or b0241 or b0929 or b2215
#
# NI2tex
# ni2_e <=> ni2_p b1377 or b0241 or b0929 or b2215
#
# FECRMtonex
# fecrm_e + h_p --> fecrm_p + h_c b3006 and b1252 and b3005 and b0150
#
# ARBTNtonex
# arbtn_fe3_e + h_p --> arbtn_fe3_p + h_c
#
# H2O2tex
# h2o2_e <=> h2o2_p b1377 or b0241 or b0929 or b2215
#
# ADEtex
# ade_e <=> ade_p b1377 or b0241 or b0929 or b2215
#
# ADNtex
# adn_e <=> adn_p b0411
#
# AGMtex
# agm_e <=> agm_p b1377 or b0241 or b0929 or b2215
#
# ALAtex
# ala__L_e <=> ala__L_p b2215 or b0241 or b1377 or b0929
#
# BALAtex
# ala_B_e <=> ala_B_p b1377 or b0241 or b0929 or b2215
#
# DALAtex
# ala__D_e <=> ala__D_p b1377 or b0241 or b0929 or b2215
#
# AMPtex
# amp_e <=> amp_p b0929 or b2215 or b0241 or b1377
#
# ARBtex
# arab__L_e <=> arab__L_p b1377 or b0241 or b0929 or b2215
#
# ARGtex
# arg__L_e <=> arg__L_p b1377 or b0241 or b0929 or b2215
#
# ASCBtex
# ascb__L_e <=> ascb__L_p b1377 or b0241 or b0929 or b2215
#
# FE3HOXtonex
# fe3hox_e + h_p --> fe3hox_p + h_c b3006 and b1252 and b3005 and b0150
#
# MMETtex
# mmet_e <=> mmet_p b1377 or b0241 or b0929 or b2215
#
# FE3tex
# fe3_e <=> fe3_p b1377 or b0241 or b0929 or b2215
#
# MG2tex
# mg2_e <=> mg2_p b1377 or b0241 or b0929 or b2215
#
# Zn2tex
# zn2_e <=> zn2_p b1377 or b0241 or b0929 or b2215
#
# CD2tex
# cd2_e <=> cd2_p b1377 or b0241 or b0929 or b2215
#
# 14GLUCANtexi
# 14glucan_e --> 14glucan_p b4036
#
# ASO3tex
# aso3_e <=> aso3_p b1377 or b0241 or b0929 or b2215
#
# MANGLYCtex
# manglyc_e <=> manglyc_p b1377 or b0241 or b0929 or b2215
#
# FRUURtex
# fruur_e <=> fruur_p b1377 or b0241 or b0929 or b2215
#
# GLYCAtex
# glyc__R_e <=> glyc__R_p b1377 or b0241 or b0929 or b2215
#
# COBALT2tex
# cobalt2_e <=> cobalt2_p b1377 or b0241 or b0929 or b2215
#
# DIMPtex
# dimp_e <=> dimp_p b1377 or b0241 or b0929 or b2215
#
# XTSNtex
# xtsn_e <=> xtsn_p b1377 or b0241 or b0929 or b2215
#
# HG2tex
# hg2_e <=> hg2_p b1377 or b0241 or b0929 or b2215
#
# DADNtex
# dad_2_e <=> dad_2_p b0411
#
# DHAtex
# dha_e <=> dha_p b1377 or b0241 or b0929 or b2215
#
# ETOHtex
# etoh_e <=> etoh_p b1377 or b0241 or b0929 or b2215
#
# ACACtex
# acac_e <=> acac_p b1377 or b0241 or b0929 or b2215
#
# ACNAMtex
# acnam_e <=> acnam_p b0929 or b4311 or b2215
#
# H2Stex
# h2s_e <=> h2s_p b0241 or b1377 or b2215 or b0929
#
# 4PEPTtex
# LalaDgluMdapDala_e <=> LalaDgluMdapDala_p b1377 or b0241 or b0929 or b2215
#
# CU2tex
# cu2_e <=> cu2_p b0241 or b1377 or b2215 or b0929
#
# FECRMUtex
# fecrm_un_p + h_p --> fecrm_un_e + h_c
#
# CLtex
# cl_e <=> cl_p b1377 or b0241 or b0929 or b2215
#
# PROtex
# pro__L_e <=> pro__L_p b0241 or b1377 or b2215 or b0929
#
# SBTtex
# sbt__D_e <=> sbt__D_p b1377 or b0241 or b0929 or b2215
#
# AKGtex
# akg_e <=> akg_p b1377 or b0241 or b0929 or b2215
#
# ALLTNtex
# alltn_e <=> alltn_p b1377 or b0241 or b0929 or b2215
#
# ASNtex
# asn__L_e <=> asn__L_p b1377 or b0241 or b0929 or b2215
#
# TYMtex
# tym_e <=> tym_p b1377 or b0241 or b0929 or b2215
#
# CMPtex
# cmp_e <=> cmp_p b1377 or b0241 or b0929 or b2215
#
# DUMPtex
# dump_e <=> dump_p b1377 or b0241 or b0929 or b2215
#
# XMPtex
# xmp_e <=> xmp_p b1377 or b0241 or b0929 or b2215
#
# 3PEPTtex
# LalaDgluMdap_e <=> LalaDgluMdap_p b1377 or b0241 or b0929 or b2215
#
# ANHGMtex
# anhgm_e <=> anhgm_p b1377 or b0241 or b0929 or b2215
#
# FALDtex
# fald_e <=> fald_p b1377 or b0241 or b0929 or b2215
#
# CYSDtex
# cys__D_e <=> cys__D_p b1377 or b0241 or b0929 or b2215
#
# G3PItex
# g3pi_e <=> g3pi_p b1377 or b0241 or b0929 or b2215
#
# G3PGtex
# g3pg_e <=> g3pg_p b1377 or b0241 or b0929 or b2215
#
# G3PEtex
# g3pe_e <=> g3pe_p b2215 or b0929 or b1377 or b0241
#
# G3PCtex
# g3pc_e <=> g3pc_p b1377 or b0241 or b0929 or b2215
#
# DAMPtex
# damp_e <=> damp_p b1377 or b0241 or b0929 or b2215
#
# DCMPtex
# dcmp_e <=> dcmp_p b1377 or b0241 or b0929 or b2215
#
# DGMPtex
# dgmp_e <=> dgmp_p b1377 or b0241 or b0929 or b2215
#
# DTMPtex
# dtmp_e <=> dtmp_p b1377 or b0241 or b0929 or b2215
#
# GMPtex
# gmp_e <=> gmp_p b0929 or b2215 or b0241 or b1377
#
# IMPtex
# imp_e <=> imp_p b1377 or b0241 or b0929 or b2215
#
# UMPtex
# ump_e <=> ump_p b2215 or b0929 or b1377 or b0241
#
# G1Ptex
# g1p_e <=> g1p_p b1377 or b0241 or b0929 or b2215
#
# SKMtex
# skm_e <=> skm_p b1377 or b0241 or b0929 or b2215
#
# MNtex
# mn2_e <=> mn2_p b1377 or b0241 or b0929 or b2215
#
# GAL1Ptex
# gal1p_e <=> gal1p_p b1377 or b0241 or b0929 or b2215
#
# O2Stex
# o2s_e <=> o2s_p b0241 or b1377 or b2215 or b0929
#
# HOMtex
# hom__L_e <=> hom__L_p b1377 or b0241 or b0929 or b2215
#
# SO2tex
# so2_e <=> so2_p b1377 or b0241 or b0929 or b2215
#
# ACSERtex
# acser_e <=> acser_p b0241 or b1377 or b2215 or b0929
#
# ALAALAtex
# alaala_e <=> alaala_p b1377 or b0241 or b0929 or b2215
#
# MALtex
# mal__L_e <=> mal__L_p b1377 or b0241 or b0929 or b2215
#
# NO3tex
# no3_e <=> no3_p b0929 or b1377 or b0241 or b2215
#
# TTDCEAtexi
# ttdcea_e --> ttdcea_p b2344
#
# HDCEAtexi
# hdcea_e --> hdcea_p b2344
#
# GSNtex
# gsn_e <=> gsn_p b1377 or b0241 or b0929 or b2215
#
# FORtex
# for_e <=> for_p b1377 or b0241 or b0929 or b2215
#
# RIBtex
# rib__D_e <=> rib__D_p b1377 or b0241 or b0929 or b2215
#
# THMtex
# thm_e <=> thm_p b1377 or b0241 or b0929 or b2215
#
# XYLUtex
# xylu__L_e <=> xylu__L_p b1377 or b0241 or b0929 or b2215
#
# ALLtex
# all__D_e <=> all__D_p b1377 or b0929 or b0241 or b2215
#
# 34dhpactex
# 34dhpac_e <=> 34dhpac_p b1377 or b0241 or b0929 or b2215
#
# MALTHXtexi
# malthx_e --> malthx_p b4036
#
# FE3DHBZStonex
# fe3dhbzs_e + h_p --> fe3dhbzs_p + h_c ( b3006 and b1252 and b3005 and b0805 ) or ( b3006 and b1252 and b3005 and b2155 )
#
# 23DAPPAtex
# 23dappa_e <=> 23dappa_p b1377 or b0241 or b0929 or b2215
#
# FEOXAMtonex
# feoxam_e + h_p --> feoxam_p + h_c b0150 and b3006 and b1252 and b3005
#
# GLCtex_copy2
# glc__D_e <=> glc__D_p b0241 or b0929 or b1377 or b2215
#
# MINOHPtexi
# minohp_e --> minohp_p
#
# PPALtex
# ppal_e <=> ppal_p b1377 or b0241 or b0929 or b2215
#
# CA2tex
# ca2_e <=> ca2_p b1377 or b0241 or b0929 or b2215
#
# CUtex
# cu_e <=> cu_p b1377 or b0241 or b0929 or b2215
#
# 12PPDRtex
# 12ppd__R_e <=> 12ppd__R_p b1377 or b0241 or b0929 or b2215
#
# F6Ptex
# f6p_e <=> f6p_p b1377 or b0241 or b0929 or b2215
#
# GAMAN6Ptex
# gam6p_e <=> gam6p_p b1377 or b0241 or b0929 or b2215
#
# PROGLYtex
# progly_e <=> progly_p b1377 or b0241 or b0929 or b2215
#
# CGLYtex
# cgly_e <=> cgly_p b1377 or b0241 or b0929 or b2215
#
# GTHOXtex
# gthox_e <=> gthox_p b1377 or b0241 or b0929 or b2215
#
# GTHRDtex
# gthrd_e <=> gthrd_p b1377 or b0241 or b0929 or b2215
#
# TUNGStex
# tungs_e <=> tungs_p b1377 or b0929 or b2215 or b0241
#
# GALCTNLtex
# galctn__L_e <=> galctn__L_p b0929 or b2215 or b1377 or b0241
#
# MALDtex
# mal__D_e <=> mal__D_p b0241 or b1377 or b2215 or b0929
#
# OROTtex
# orot_e <=> orot_p b2215 or b1377 or b0929 or b0241
#
# 5DGLCNtex
# 5dglcn_e <=> 5dglcn_p b0929 or b1377 or b0241 or b2215
#
# PPAtex
# ppa_e <=> ppa_p b0929 or b0241 or b1377 or b2215
#
# PSCLYStex
# psclys_e <=> psclys_p b1377 or b0929 or b2215 or b0241
#
# THYMtex
# thym_e <=> thym_p b2215 or b0241 or b1377 or b0929
#
# LIPAabctex
# atp_c + h2o_c + lipa_p --> adp_c + h_c + lipa_e + pi_c b0054 and b3201 and b4261 and b4262 and b3199 and b3200 and b0641
#
# CMtpp
# cm_p + h_p --> cm_e + h_c ( b3035 and b0463 and b2470 ) or ( b3035 and b0463 and b0462 )
#
# FUSAtpp
# fusa_p + h_p --> fusa_e + h_c ( b3035 and b0463 and b0462 ) or ( b3035 and b0463 and b2470 )
#
# RFAMPtex
# rfamp_e <=> rfamp_p s0001
#
# MINCYCtex
# mincyc_e <=> mincyc_p b0929 or b1377 or b0241 or b2215
#
# MINCYCtpp
# h_p + mincyc_p --> h_c + mincyc_e ( b3035 and b0463 and b2470 ) or ( b3035 and b0463 and b0462 )
#
# DOXRBCNtex
# doxrbcn_e <=> doxrbcn_p b1377 or b0929 or b2215 or b0241
#
# DOXRBCNtpp
# doxrbcn_p + h_p --> doxrbcn_e + h_c ( b3035 and b0463 and b0462 ) or ( b3035 and b0463 and b2470 )
#
# NOVBCNtpp
# h_p + novbcn_p --> h_c + novbcn_e ( b3035 and b0463 and b2470 ) or ( b3035 and b0463 and b0462 )
#
# CMtex
# cm_e <=> cm_p b1377 or b2215 or b0929 or b0241
#
# LALALGLUtex
# LalaLglu_e <=> LalaLglu_p b0929 or b1377 or b0241 or b2215
#
# 5MTRtex
# 5mtr_e <=> 5mtr_p b2215 or b1377 or b0929 or b0241
#
# LALADGLUtex
# LalaDglu_e <=> LalaDglu_p b0241 or b2215 or b1377 or b0929
#
# 3HPPtex
# 3hpp_e <=> 3hpp_p b2215 or b1377 or b0929 or b0241
#
# FUSAtex
# fusa_e <=> fusa_p b1377 or b2215 or b0929 or b0241
#
# NOVBCNtex
# novbcn_e <=> novbcn_p s0001
#
# QUIN2tex
# quin_e <=> quin_p b0241 or b2215 or b1377 or b0929
#
# O16A4COLIPAabctex
# atp_c + h2o_c + o16a4colipa_p --> adp_c + h_c + o16a4colipa_e + pi_c b0054 and b3201 and b4261 and b4262 and b3199 and b3200 and b0641
#
# COLIPAabctex
# atp_c + colipa_p + h2o_c --> adp_c + colipa_e + h_c + pi_c b0054 and b3201 and b3200 and b0641 and b4262 and b3199 and b4261
#
# ENLIPAabctex
# atp_c + enlipa_p + h2o_c --> adp_c + enlipa_e + h_c + pi_c b0054 and b3201 and b4261 and b4262 and b3199 and b3200 and b0641
#
# CLIPAabctex
# atp_c + h2o_c + lipa_cold_p --> adp_c + h_c + lipa_cold_e + pi_c b0054 and b3201 and b4261 and b4262 and b3199 and b3200 and b0641
#
# K2L4Aabctex
# atp_c + h2o_c + kdo2lipid4_p --> adp_c + h_c + kdo2lipid4_e + pi_c b0054 and b3201 and b4261 and b4262 and b3199 and b3200 and b0641
#
# SELtex
# sel_e <=> sel_p b2215 or b1377 or b0929 or b0241
#
# MEOHtex
# meoh_e <=> meoh_p b2215 or b0929 or b1377 or b0241
#
# TTRCYCtex
# ttrcyc_e <=> ttrcyc_p b1377 or b0929 or b0241 or b2215
#
# TTRCYCtpp
# h_p + ttrcyc_p --> h_c + ttrcyc_e ( b3035 and b0463 and b2470 ) or ( b3035 and b0463 and b0462 )
#
# SLNTtex
# slnt_e <=> slnt_p b2215 or b1377 or b0929 or b0241
#
# RFAMPtpp
# h_p + rfamp_p --> h_c + rfamp_e ( b3035 and b0463 and b0462 ) or ( b3035 and b0463 and b2470 )
#
# ACOLIPAabctex
# acolipa_p + atp_c + h2o_c --> acolipa_e + adp_c + h_c + pi_c b0054 and b3201 and b4261 and b4262 and b3199 and b3200 and b0641
#
# ECA4COLIPAabctex
# atp_c + eca4colipa_p + h2o_c --> adp_c + eca4colipa_e + h_c + pi_c b0054 and b3201 and b4261 and b4262 and b3199 and b3200 and b0641
#
# COLIPAPabctex
# atp_c + colipap_p + h2o_c --> adp_c + colipap_e + h_c + pi_c b0054 and b3201 and b4261 and b4262 and b3199 and b3200 and b0641
#
# CH4tex
# ch4_e <=> ch4_p
#
# TARTRDtex
# tartr__D_e <=> tartr__D_p b0241 or b1377 or b2215 or b0929
#
# BTNtex
# btn_e <=> btn_p b0241 or b2215 or b1377 or b0929
#
# ARBTtex
# arbt_e --> arbt_p b1377 or b2215 or b0929 or b0241
#
# PYDXtex
# pydx_e <=> pydx_p b1377 or b2215 or b0929 or b0241
#
# PYDXNtex
# pydxn_e <=> pydxn_p b1377 or b2215 or b0929 or b0241
#
# PYDAMtex
# pydam_e <=> pydam_p b1377 or b2215 or b0929 or b0241
#
# CHTBStex
# chtbs_e <=> chtbs_p b0241 or b0929 or b2215 or b1377 or b0681
#
# CRNDtex
# crn__D_e <=> crn__D_p b0241 or b1377 or b2215 or b0929
#
# DXYLONtex
# dxylnt_e <=> dxylnt_p b0929 or b1377 or b2215
#
# PSURItex
# psuri_e <=> psuri_p b2215 or b0929 or b1377 or b0241
#
# DHPStex
# dhps_e <=> dhps_p b3875
#
# FMNtex
# fmn_p <=> fmn_e b2215 or b0929 or b0241 or b1377
#
# CLBtex
# cellb_e <=> cellb_p b0929 or b0241 or b1377 or b2215
#
# FADtex
# fad_p <=> fad_e b1377 or b0241 or b2215 or b0929
#
# 2DGLCtex
# 2dglc_e <=> 2dglc_p b2215 or b1377 or b0241 or b0929
#
# SQtex
# sq_e <=> sq_p b3875
#
# URATEtex
# urate_e <=> urate_p b0929 or b2215 or b0241 or b1377
#
# CBL1tonex
# cbl1_e + h_p --> cbl1_p + h_c b3006 and b1252 and b3005 and b3966
#
# CBItonex
# cbi_e + h_p --> cbi_p + h_c b3006 and b1252 and b3005 and b3966
#
# Ftex
# f_p <=> f_e b2215 or b0241 or b0929 or b1377
#
# CYSItex
# cysi__L_e <=> cysi__L_p b1377 or b0929 or b0241 or b2215
#
# CS1tex
# cs1_e <=> cs1_p b0241 or b0929 or b2215 or b1377
#
# ADOCBLtonex
# adocbl_e + h_p --> adocbl_p + h_c b3006 and b1252 and b3005 and b3966
#
# MEPNtex
# mepn_e <=> mepn_p b2215 or b0929 or b0241 or b1377
#
# 4ABZGLUtex
# 4abzglu_e <=> 4abzglu_p b2215 or b0241 or b1377 or b0929
#
# METGLCURtex
# metglcur_e <=> metglcur_p b2215 or b1377 or b0241 or b0929
#
# AI2tex
# mththf_e <=> mththf_p b0241 or b2215 or b0929 or b1377
#
# BIOMASS_Ec_iML1515_core_75p37M
# 0.000223 10fthf_c + 2.6e-05 2fe2s_c + 0.000223 2ohph_c + 0.00026 4fe4s_c + 0.513689 ala__L_c + 0.000223 amet_c + 0.295792 arg__L_c + 0.241055 asn__L_c + 0.241055 asp__L_c + 75.55223 atp_c + 2e-06 btn_c + 0.005205 ca2_c + 0.005205 cl_c + 0.000576 coa_c + 2.5e-05 cobalt2_c + 0.133508 ctp_c + 0.000709 cu2_c + 0.09158 cys__L_c + 0.026166 datp_c + 0.027017 dctp_c + 0.027017 dgtp_c + 0.026166 dttp_c + 0.000223 fad_c + 0.006715 fe2_c + 0.007808 fe3_c + 0.26316 gln__L_c + 0.26316 glu__L_c + 0.612638 gly_c + 0.215096 gtp_c + 70.028756 h2o_c + 0.094738 his__L_c + 0.290529 ile__L_c + 0.195193 k_c + 0.019456 kdo2lipid4_e + 0.450531 leu__L_c + 0.343161 lys__L_c + 0.153686 met__L_c + 0.008675 mg2_c + 0.000223 mlthf_c + 0.000691 mn2_c + 7e-06 mobd_c + 0.013894 murein5px4p_p + 0.001831 nad_c + 0.000447 nadp_c + 0.013013 nh4_c + 0.000323 ni2_c + 0.063814 pe160_p + 0.075214 pe161_p + 0.185265 phe__L_c + 0.000223 pheme_c + 0.221055 pro__L_c + 0.000223 pydx5p_c + 0.000223 ribflv_c + 0.215792 ser__L_c + 0.000223 sheme_c + 0.004338 so4_c + 9.8e-05 succoa_c + 0.000223 thf_c + 0.000223 thmpp_c + 0.253687 thr__L_c + 0.056843 trp__L_c + 0.137896 tyr__L_c + 5.5e-05 udcpdp_c + 0.144104 utp_c + 0.423162 val__L_c + 0.000341 zn2_c --> 75.37723 adp_c + 75.37723 h_c + 75.37323 pi_c + 0.773903 ppi_c
#
# BIOMASS_Ec_iML1515_WT_75p37M
# 0.000223 10fthf_c + 0.000223 2dmmql8_c + 2.5e-05 2fe2s_c + 0.000248 4fe4s_c + 0.000223 5mthf_c + 0.000279 accoa_c + 0.000223 adocbl_c + 0.499149 ala__L_c + 0.000223 amet_c + 0.28742 arg__L_c + 0.234232 asn__L_c + 0.234232 asp__L_c + 75.55223 atp_c + 2e-06 btn_c + 0.004952 ca2_c + 0.000223 chor_c + 0.004952 cl_c + 0.002944 clpn160_p + 0.00229 clpn161_p + 0.00118 clpn181_p + 0.000168 coa_c + 2.4e-05 cobalt2_c + 0.008151 colipa_e + 0.129799 ctp_c + 0.000674 cu2_c + 0.088988 cys__L_c + 0.024805 datp_c + 0.025612 dctp_c + 0.025612 dgtp_c + 0.024805 dttp_c + 0.000223 enter_c + 0.000223 fad_c + 0.006388 fe2_c + 0.007428 fe3_c + 0.255712 gln__L_c + 0.255712 glu__L_c + 0.595297 gly_c + 0.154187 glycogen_c + 0.000223 gthrd_c + 0.209121 gtp_c + 70.028756 h2o_c + 0.000223 hemeO_c + 0.092056 his__L_c + 0.282306 ile__L_c + 0.18569 k_c + 0.437778 leu__L_c + 3e-06 lipopb_c + 0.333448 lys__L_c + 3.1e-05 malcoa_c + 0.149336 met__L_c + 0.008253 mg2_c + 0.000223 mlthf_c + 0.000658 mn2_c + 7e-06 mobd_c + 7e-06 mococdp_c + 7e-06 mocogdp_c + 0.000223 mql8_c + 0.001345 murein3p3p_p + 0.000605 murein3px4p_p + 0.005381 murein4p4p_p + 0.005448 murein4px4p_p + 0.000673 murein4px4px4p_p + 0.001787 nad_c + 4.5e-05 nadh_c + 0.000112 nadp_c + 0.000335 nadph_c + 0.012379 nh4_c + 0.000307 ni2_c + 0.044164 pe160_p + 0.03435 pe161_p + 0.017704 pe181_p + 0.010599 pg160_p + 0.008244 pg161_p + 0.004249 pg181_p + 0.180021 phe__L_c + 0.000223 pheme_c + 0.214798 pro__L_c + 0.03327 ptrc_c + 0.000223 pydx5p_c + 0.000223 q8h2_c + 0.000223 ribflv_c + 0.209684 ser__L_c + 0.000223 sheme_c + 0.004126 so4_c + 0.006744 spmd_c + 9.8e-05 succoa_c + 0.000223 thf_c + 0.000223 thmpp_c + 0.246506 thr__L_c + 0.055234 trp__L_c + 0.133993 tyr__L_c + 5.5e-05 udcpdp_c + 0.140101 utp_c + 0.411184 val__L_c + 0.000324 zn2_c --> 75.37723 adp_c + 75.37723 h_c + 75.37323 pi_c + 0.749831 ppi_c

# %%
for line in open('../Results/gap_filled_reactions_try.txt'):print(line)
# Out:
# >datp_c DATP C10H12N5O12P3 DATP_c
#
# EX_pi_e	Phosphate exchange	Pi_e <=>
#
# GLCtex_copy1		Glucopyranose_e --> Glucopyranose_c	b4036
#
# EX_nh4_e	Ammonia exchange	AMMONIUM_e <=>
#
# DM_PROTON_c	H+ demand_smiley	PROTON_c -->
#
# DM_H2CO3_c	carbonic acid demand_smiley	H2CO3_c -->
#
#
#
# >dctp_c DCTP C9H12N3O13P3 DCTP_c
#
# EX_pi_e	Phosphate exchange	Pi_e <=>
#
# UREAtex	Urea transport via diffusion (extracellular to periplasm)	UREA_e <=> UREA_c	b1377 or b0241 or b0929 or b2215
#
# CITtex	Citrate transport via diffusion (extracellular to periplasm)	CIT_e <=> CIT_c	b1377 or b0241 or b0929 or b2215
#
# GLCtex_copy2		Glucopyranose_e <=> Glucopyranose_c	b0241 or b0929 or b1377 or b2215
#
# DM_FORMATE_c	formate demand_smiley	FORMATE_c -->
#
#
#
# >dgtp_c DGTP C10H12N5O13P3 DGTP_c
#
# EX_pi_e	Phosphate exchange	Pi_e <=>
#
# GLCtex_copy1		Glucopyranose_e --> Glucopyranose_c	b4036
#
# EX_nh4_e	Ammonia exchange	AMMONIUM_e <=>
#
# DM_PROTON_c	H+ demand_smiley	PROTON_c -->
#
# DM_H2CO3_c	carbonic acid demand_smiley	H2CO3_c -->
#
#
#
# >dttp_c DTTP C10H13N2O14P3 TTP_c
#
# EX_pi_e	Phosphate exchange	Pi_e <=>
#
# GLCtex_copy1		Glucopyranose_e --> Glucopyranose_c	b4036
#
# UREAtex	Urea transport via diffusion (extracellular to periplasm)	UREA_e <=> UREA_c	b1377 or b0241 or b0929 or b2215
#
# DM_PROTON_c	H+ demand_smiley	PROTON_c -->
#
# DM_H2CO3_c	carbonic acid demand_smiley	H2CO3_c -->
#
#
#
# >cobalt2_c Co2+ CO+2_c
#
# No need for gap-filling
#
#
#
# >cu2_c Copper CU+2_c
#
# No need for gap-filling
#
#
#
# >fe2_c Fe2+ mitochondria FE+2_c
#
# FE2tex	Iron (II) transport via diffusion (extracellular to periplasm)	FE+2_e <=> FE+2_c	b0241 or b1377 or b2215 or b0929
#
#
#
# >fe3_c Iron (Fe3+) FE+3_c
#
# No need for gap-filling
#
#
#
# >k_c Potassium K+_c
#
# Ktex	Potassium transport via diffusion (extracellular to periplasm)	K+_e <=> K+_c	b1377 or b0241 or b0929 or b2215
#
#
#
# >mg2_c Magnesium MG+2_c
#
# No need for gap-filling
#
#
#
# >mn2_c Manganese MN+2_c
#
# No need for gap-filling
#
#
#
# >mobd_c Molybdate CPD-3_c
#
# MOBDtex	Molybdate transport via diffusion (extracellular to periplasm)	CPD-3_e <=> CPD-3_c	b1377 or b0241 or b0929 or b2215
#
#
#
# >ni2_c Nickel NI+2_c
#
# NI2tex	Nickel transport via diffusion (extracellular to periplasm)	NI+2_e <=> NI+2_c	b1377 or b0241 or b0929 or b2215
#
#
#
# >so4_c Sulfate SULFATE_c
#
# SO4tex	Sulfate transport via diffusion (extracellular to periplasm)	SULFATE_e <=> SULFATE_c	b1377 or b0241 or b0929 or b2215
#
# EX_so4_e	Sulfate exchange	SULFATE_e <=>
#
#
#
# >zn2_c Zinc ZN+2_c
#
# Zn2tex	Zinc (Zn+2) transport via diffusion (extracellular to periplasm)	ZN+2_e <=> ZN+2_c	b1377 or b0241 or b0929 or b2215
#
#
#
# >ca2_c Calcium CA+2_c
#
# No need for gap-filling
#
#
#
# >cl_c Chloride CL-_c
#
# CLtex	Chloride (Cl-1) transport via diffusion (extracellular to periplasm)	CL-_e <=> CL-_c	b1377 or b0241 or b0929 or b2215
#
#
#
# >nh4_c Ammonium AMMONIUM_c
#
# EX_nh4_e	Ammonia exchange	AMMONIUM_e <=>
#
#
#
# >kdo2lipid4_e KDO(2)-lipid IV(A) KDO2-LIPID-IVA_e
#
# EX_pi_e	Phosphate exchange	Pi_e <=>
#
# UREAtex	Urea transport via diffusion (extracellular to periplasm)	UREA_e <=> UREA_c	b1377 or b0241 or b0929 or b2215
#
# GLCtex_copy2		Glucopyranose_e <=> Glucopyranose_c	b0241 or b0929 or b1377 or b2215
#
# K2L4Aabctex	KDO(2)-lipid IV A transport via ABC system (periplasm to extracellular)	ATP_c + KDO2-LIPID-IVA_c + WATER_c --> ADP_c + KDO2-LIPID-IVA_e + PROTON_c + Pi_c	b0054 and b3201 and b4261 and b4262 and b3199 and b3200 and b0641
#
# DM_PROTON_c	H+ demand_smiley	PROTON_c -->
#
# DM_CARBON-DIOXIDE_c	CO2 demand_smiley	CARBON-DIOXIDE_c -->
#
#
#
# >pe160_p Phosphatidylethanolamine (dihexadecanoyl, n-C16:0) CPD-12819_c
#
# EX_pi_e	Phosphate exchange	Pi_e <=>
#
# UREAtex	Urea transport via diffusion (extracellular to periplasm)	UREA_e <=> UREA_c	b1377 or b0241 or b0929 or b2215
#
# CITtex	Citrate transport via diffusion (extracellular to periplasm)	CIT_e <=> CIT_c	b1377 or b0241 or b0929 or b2215
#
# AGPAT160	1-hexadecanoyl-sn-glycerol 3-phosphate O-acyltransferase (n-C16:0)	1hdecg3p_c + palmACP_c --> ACP_c + CPD0-1422_c	b3018
#
# PSSA160	Phosphatidylserine syntase (n-C16:0)	SER_c + cdpdhdecg_c --> CMP_c + CPD-12817_c + PROTON_c	b2585
#
# DM_CARBON-DIOXIDE_c	CO2 demand_smiley	CARBON-DIOXIDE_c -->
#
#
#
# >pe161_p Phosphatidylethanolamine (dihexadec-9enoyl, n-C16:1) CPD-17086_c
#
# EX_pi_e	Phosphate exchange	Pi_e <=>
#
# UREAtex	Urea transport via diffusion (extracellular to periplasm)	UREA_e <=> UREA_c	b1377 or b0241 or b0929 or b2215
#
# CITtex	Citrate transport via diffusion (extracellular to periplasm)	CIT_e <=> CIT_c	b1377 or b0241 or b0929 or b2215
#
# PSSA161	Phosphatidylserine syntase (n-C16:1)	SER_c + cdpdhdec9eg_c --> CMP_c + PROTON_c + ps161_c	b2585
#
# AGPAT161	1-hexadec-7-enoyl-sn-glycerol 3-phosphate O-acyltransferase (n-C16:1)	1hdec9eg3p_c + hdeACP_c --> ACP_c + pa161_c	b3018
#
# DM_CARBON-DIOXIDE_c	CO2 demand_smiley	CARBON-DIOXIDE_c -->
#
#
#
# >ala__L_c L-Alanine L-ALPHA-ALANINE_c
#
# UREAtex	Urea transport via diffusion (extracellular to periplasm)	UREA_e <=> UREA_c	b1377 or b0241 or b0929 or b2215
#
# CITtex	Citrate transport via diffusion (extracellular to periplasm)	CIT_e <=> CIT_c	b1377 or b0241 or b0929 or b2215
#
# DM_CARBON-DIOXIDE_c	CO2 demand_smiley	CARBON-DIOXIDE_c -->
#
#
#
# >arg__L_c L-Arginine ARG_c
#
# UREAtex	Urea transport via diffusion (extracellular to periplasm)	UREA_e <=> UREA_c	b1377 or b0241 or b0929 or b2215
#
# CITtex	Citrate transport via diffusion (extracellular to periplasm)	CIT_e <=> CIT_c	b1377 or b0241 or b0929 or b2215
#
# DM_CARBON-DIOXIDE_c	CO2 demand_smiley	CARBON-DIOXIDE_c -->
#
#
#
# >asn__L_c L-Asparagine ASN_c
#
# ASNS2	Asparagine synthetase	AMMONIUM_c + ATP_c + L-ASPARTATE_c --> AMP_c + ASN_c + PPI_c + PROTON_c	b3744 or b0674
#
# CITtex	Citrate transport via diffusion (extracellular to periplasm)	CIT_e <=> CIT_c	b1377 or b0241 or b0929 or b2215
#
# EX_nh4_e	Ammonia exchange	AMMONIUM_e <=>
#
# DM_WATER_c	H2O demand_smiley	WATER_c -->
#
#
#
# >asp__L_c L-Aspartate L-ASPARTATE_c
#
# CITtex	Citrate transport via diffusion (extracellular to periplasm)	CIT_e <=> CIT_c	b1377 or b0241 or b0929 or b2215
#
# EX_nh4_e	Ammonia exchange	AMMONIUM_e <=>
#
# DM_GLYCOLLATE_c	glycolate demand_smiley	GLYCOLLATE_c -->
#
#
#
# >cys__L_c L-Cysteine CYS_c
#
# ADSK	Adenylyl-sulfate kinase	APS_c + ATP_c --> ADP_c + PAPS_c + PROTON_c	b2750
#
# UREAtex	Urea transport via diffusion (extracellular to periplasm)	UREA_e <=> UREA_c	b1377 or b0241 or b0929 or b2215
#
# CITtex	Citrate transport via diffusion (extracellular to periplasm)	CIT_e <=> CIT_c	b1377 or b0241 or b0929 or b2215
#
# EX_so4_e	Sulfate exchange	SULFATE_e <=>
#
# DM_CARBON-DIOXIDE_c	CO2 demand_smiley	CARBON-DIOXIDE_c -->
#
#
#
# >gln__L_c L-Glutamine GLN_c
#
# UREAtex	Urea transport via diffusion (extracellular to periplasm)	UREA_e <=> UREA_c	b1377 or b0241 or b0929 or b2215
#
# CITtex	Citrate transport via diffusion (extracellular to periplasm)	CIT_e <=> CIT_c	b1377 or b0241 or b0929 or b2215
#
# DM_CARBON-DIOXIDE_c	CO2 demand_smiley	CARBON-DIOXIDE_c -->
#
#
#
# >glu__L_c L-Glutamate GLT_c
#
# UREAtex	Urea transport via diffusion (extracellular to periplasm)	UREA_e <=> UREA_c	b1377 or b0241 or b0929 or b2215
#
# CITtex	Citrate transport via diffusion (extracellular to periplasm)	CIT_e <=> CIT_c	b1377 or b0241 or b0929 or b2215
#
# DM_CARBON-DIOXIDE_c	CO2 demand_smiley	CARBON-DIOXIDE_c -->
#
#
#
# >gly_c Glycine GLY_c
#
# CITtex	Citrate transport via diffusion (extracellular to periplasm)	CIT_e <=> CIT_c	b1377 or b0241 or b0929 or b2215
#
# EX_nh4_e	Ammonia exchange	AMMONIUM_e <=>
#
# DM_WATER_c	H2O demand_smiley	WATER_c -->
#
#
#
# >his__L_c L-Histidine HIS_c
#
# UREAtex	Urea transport via diffusion (extracellular to periplasm)	UREA_e <=> UREA_c	b1377 or b0241 or b0929 or b2215
#
# GLCtex_copy2		Glucopyranose_e <=> Glucopyranose_c	b0241 or b0929 or b1377 or b2215
#
# DM_PROTON_c	H+ demand_smiley	PROTON_c -->
#
# DM_GLYCOLLATE_c	glycolate demand_smiley	GLYCOLLATE_c -->
#
#
#
# >ile__L_c L-Isoleucine ILE_c
#
# HSK	Homoserine kinase	ATP_c + HOMO-SER_c --> ADP_c + O-PHOSPHO-L-HOMOSERINE_c + PROTON_c	b0003
#
# HSDy	Homoserine dehydrogenase (NADPH)	HOMO-SER_c + NADP_c <=> L-ASPARTATE-SEMIALDEHYDE_c + NADPH_c + PROTON_c	b3940 or b0002
#
# UREAtex	Urea transport via diffusion (extracellular to periplasm)	UREA_e <=> UREA_c	b1377 or b0241 or b0929 or b2215
#
# CITtex	Citrate transport via diffusion (extracellular to periplasm)	CIT_e <=> CIT_c	b1377 or b0241 or b0929 or b2215
#
# DM_CARBON-DIOXIDE_c	CO2 demand_smiley	CARBON-DIOXIDE_c -->
#
#
#
# >leu__L_c L-Leucine LEU_c
#
# UREAtex	Urea transport via diffusion (extracellular to periplasm)	UREA_e <=> UREA_c	b1377 or b0241 or b0929 or b2215
#
# CITtex	Citrate transport via diffusion (extracellular to periplasm)	CIT_e <=> CIT_c	b1377 or b0241 or b0929 or b2215
#
# DM_CARBON-DIOXIDE_c	CO2 demand_smiley	CARBON-DIOXIDE_c -->
#
#
#
# >lys__L_c L-Lysine LYS_c
#
# UREAtex	Urea transport via diffusion (extracellular to periplasm)	UREA_e <=> UREA_c	b1377 or b0241 or b0929 or b2215
#
# CITtex	Citrate transport via diffusion (extracellular to periplasm)	CIT_e <=> CIT_c	b1377 or b0241 or b0929 or b2215
#
# THDPS	Tetrahydrodipicolinate succinylase	DELTA1-PIPERIDEINE-2-6-DICARBOXYLATE_c + SUC-COA_c + WATER_c --> CO-A_c + N-SUCCINYL-2-AMINO-6-KETOPIMELATE_c	b0166
#
# DM_CARBON-DIOXIDE_c	CO2 demand_smiley	CARBON-DIOXIDE_c -->
#
#
#
# >met__L_c L-Methionine MET_c
#
# ADSK	Adenylyl-sulfate kinase	APS_c + ATP_c --> ADP_c + PAPS_c + PROTON_c	b2750
#
# HSDy	Homoserine dehydrogenase (NADPH)	HOMO-SER_c + NADP_c <=> L-ASPARTATE-SEMIALDEHYDE_c + NADPH_c + PROTON_c	b3940 or b0002
#
# UREAtex	Urea transport via diffusion (extracellular to periplasm)	UREA_e <=> UREA_c	b1377 or b0241 or b0929 or b2215
#
# CITtex	Citrate transport via diffusion (extracellular to periplasm)	CIT_e <=> CIT_c	b1377 or b0241 or b0929 or b2215
#
# EX_so4_e	Sulfate exchange	SULFATE_e <=>
#
# DM_CARBON-DIOXIDE_c	CO2 demand_smiley	CARBON-DIOXIDE_c -->
#
#
#
# >phe__L_c L-Phenylalanine PHE_c
#
# EX_nh4_e	Ammonia exchange	AMMONIUM_e <=>
#
# GLCtex_copy2		Glucopyranose_e <=> Glucopyranose_c	b0241 or b0929 or b1377 or b2215
#
# DM_PROTON_c	H+ demand_smiley	PROTON_c -->
#
# DM_CARBON-DIOXIDE_c	CO2 demand_smiley	CARBON-DIOXIDE_c -->
#
#
#
# >pro__L_c L-Proline PRO_c
#
# G5SADs	L-glutamate 5-semialdehyde dehydratase (spontaneous)	L-GLUTAMATE_GAMMA-SEMIALDEHYDE_c --> L-DELTA1-PYRROLINE_5-CARBOXYLATE_c + PROTON_c + WATER_c	s0001
#
# UREAtex	Urea transport via diffusion (extracellular to periplasm)	UREA_e <=> UREA_c	b1377 or b0241 or b0929 or b2215
#
# CITtex	Citrate transport via diffusion (extracellular to periplasm)	CIT_e <=> CIT_c	b1377 or b0241 or b0929 or b2215
#
# DM_CARBON-DIOXIDE_c	CO2 demand_smiley	CARBON-DIOXIDE_c -->
#
#
#
# >ser__L_c L-Serine SER_c
#
# GLCtex_copy1		Glucopyranose_e --> Glucopyranose_c	b4036
#
# UREAtex	Urea transport via diffusion (extracellular to periplasm)	UREA_e <=> UREA_c	b1377 or b0241 or b0929 or b2215
#
# DM_PROTON_c	H+ demand_smiley	PROTON_c -->
#
#
#
# >thr__L_c L-Threonine THR_c
#
# HSK	Homoserine kinase	ATP_c + HOMO-SER_c --> ADP_c + O-PHOSPHO-L-HOMOSERINE_c + PROTON_c	b0003
#
# HSDy	Homoserine dehydrogenase (NADPH)	HOMO-SER_c + NADP_c <=> L-ASPARTATE-SEMIALDEHYDE_c + NADPH_c + PROTON_c	b3940 or b0002
#
# UREAtex	Urea transport via diffusion (extracellular to periplasm)	UREA_e <=> UREA_c	b1377 or b0241 or b0929 or b2215
#
# CITtex	Citrate transport via diffusion (extracellular to periplasm)	CIT_e <=> CIT_c	b1377 or b0241 or b0929 or b2215
#
# DM_CARBON-DIOXIDE_c	CO2 demand_smiley	CARBON-DIOXIDE_c -->
#
#
#
# >trp__L_c L-Tryptophan TRP_c
#
# EX_nh4_e	Ammonia exchange	AMMONIUM_e <=>
#
# GLCtex_copy2		Glucopyranose_e <=> Glucopyranose_c	b0241 or b0929 or b1377 or b2215
#
# DM_PROTON_c	H+ demand_smiley	PROTON_c -->
#
# DM_H2CO3_c	carbonic acid demand_smiley	H2CO3_c -->
#
#
#
# >tyr__L_c L-Tyrosine TYR_c
#
# PPND	Prephenate dehydrogenase	NAD_c + PREPHENATE_c --> CARBON-DIOXIDE_c + NADH_c + P-HYDROXY-PHENYLPYRUVATE_c	b2600
#
# GLCtex_copy1		Glucopyranose_e --> Glucopyranose_c	b4036
#
# UREAtex	Urea transport via diffusion (extracellular to periplasm)	UREA_e <=> UREA_c	b1377 or b0241 or b0929 or b2215
#
# DM_PROTON_c	H+ demand_smiley	PROTON_c -->
#
# DM_OXALACETIC_ACID_c	oxaloacetate demand_smiley	OXALACETIC_ACID_c -->
#
#
#
# >val__L_c L-Valine VAL_c
#
# UREAtex	Urea transport via diffusion (extracellular to periplasm)	UREA_e <=> UREA_c	b1377 or b0241 or b0929 or b2215
#
# CITtex	Citrate transport via diffusion (extracellular to periplasm)	CIT_e <=> CIT_c	b1377 or b0241 or b0929 or b2215
#
# DM_CARBON-DIOXIDE_c	CO2 demand_smiley	CARBON-DIOXIDE_c -->
#
#
#
# >atp_c ATP C10H12N5O13P3 ATP_c
#
# EX_pi_e	Phosphate exchange	Pi_e <=>
#
# GLCtex_copy1		Glucopyranose_e --> Glucopyranose_c	b4036
#
# EX_nh4_e	Ammonia exchange	AMMONIUM_e <=>
#
# DM_PROTON_c	H+ demand_smiley	PROTON_c -->
#
# DM_H2CO3_c	carbonic acid demand_smiley	H2CO3_c -->
#
#
#
# >ctp_c CTP C9H12N3O14P3 CTP_c
#
# EX_pi_e	Phosphate exchange	Pi_e <=>
#
# F6PA	Fructose 6-phosphate aldolase	FRUCTOSE-6P_c <=> DIHYDROXYACETONE_c + GAP_c	b0825 or b3946
#
# CITtex	Citrate transport via diffusion (extracellular to periplasm)	CIT_e <=> CIT_c	b1377 or b0241 or b0929 or b2215
#
# EX_nh4_e	Ammonia exchange	AMMONIUM_e <=>
#
# DM_H2CO3_c	carbonic acid demand_smiley	H2CO3_c -->
#
#
#
# >gtp_c GTP C10H12N5O14P3 GTP_c
#
# EX_pi_e	Phosphate exchange	Pi_e <=>
#
# EX_nh4_e	Ammonia exchange	AMMONIUM_e <=>
#
# GLCtex_copy2		Glucopyranose_e <=> Glucopyranose_c	b0241 or b0929 or b1377 or b2215
#
# DM_PROTON_c	H+ demand_smiley	PROTON_c -->
#
# DM_H2CO3_c	carbonic acid demand_smiley	H2CO3_c -->
#
#
#
# >utp_c UTP C9H11N2O15P3 UTP_c
#
# EX_pi_e	Phosphate exchange	Pi_e <=>
#
# F6PA	Fructose 6-phosphate aldolase	FRUCTOSE-6P_c <=> DIHYDROXYACETONE_c + GAP_c	b0825 or b3946
#
# UREAtex	Urea transport via diffusion (extracellular to periplasm)	UREA_e <=> UREA_c	b1377 or b0241 or b0929 or b2215
#
# CITtex	Citrate transport via diffusion (extracellular to periplasm)	CIT_e <=> CIT_c	b1377 or b0241 or b0929 or b2215
#
# DM_CARBON-DIOXIDE_c	CO2 demand_smiley	CARBON-DIOXIDE_c -->
#
#
#
# >h_c H+ PROTON_c
#
# EX_h_e	H+ exchange	PROTON_e <=>
#
#
#
# >10fthf_c 10-Formyltetrahydrofolate 10-FORMYL-THF_c
#
# DNMPPA	Dihydroneopterin monophosphate dephosphorylase	DIHYDRONEOPTERIN-P_c + WATER_c --> CPD-11770_c + Pi_c
#
# DNTPPA	Dihydroneopterin triphosphate pyrophosphatase	DIHYDRONEOPTERIN-P3_c + WATER_c --> DIHYDRONEOPTERIN-P_c + PPI_c + PROTON_c	b1865 or b0099
#
# EX_nh4_e	Ammonia exchange	AMMONIUM_e <=>
#
# GCALDD	Glycolaldehyde dehydrogenase	GLYCOLALDEHYDE_c + NAD_c + WATER_c --> GLYCOLLATE_c + NADH_c + 2.0 PROTON_c	b1415
#
# GLCtex_copy2		Glucopyranose_e <=> Glucopyranose_c	b0241 or b0929 or b1377 or b2215
#
# DM_PROTON_c	H+ demand_smiley	PROTON_c -->
#
# DM_H2CO3_c	carbonic acid demand_smiley	H2CO3_c -->
#
#
#
# >2fe2s_c [2Fe-2S] iron-sulfur cluster 2fe2s_c
#
# ADSK	Adenylyl-sulfate kinase	APS_c + ATP_c --> ADP_c + PAPS_c + PROTON_c	b2750
#
# CITtex	Citrate transport via diffusion (extracellular to periplasm)	CIT_e <=> CIT_c	b1377 or b0241 or b0929 or b2215
#
# EX_so4_e	Sulfate exchange	SULFATE_e <=>
#
# DM_CARBON-DIOXIDE_c	CO2 demand_smiley	CARBON-DIOXIDE_c -->
#
# DM_PALMITATE_c	Hexadecanoate (n-C16:0) demand_smiley	PALMITATE_c -->
#
#
#
# >2ohph_c 2-Octaprenyl-6-hydroxyphenol 2-OCTAPRENYL-6-HYDROXYPHENOL_c
#
# O2tex	Oxygen transport via diffusion (extracellular to periplasm)	OXYGEN-MOLECULE_e <=> OXYGEN-MOLECULE_c	b1377 or b0241 or b0929 or b2215
#
# GLCtex_copy1		Glucopyranose_e --> Glucopyranose_c	b4036
#
# CITtex	Citrate transport via diffusion (extracellular to periplasm)	CIT_e <=> CIT_c	b1377 or b0241 or b0929 or b2215
#
# DM_H2CO3_c	carbonic acid demand_smiley	H2CO3_c -->
#
#
#
# >4fe4s_c [4Fe-4S] iron-sulfur cluster CPD-7_c
#
# ADSK	Adenylyl-sulfate kinase	APS_c + ATP_c --> ADP_c + PAPS_c + PROTON_c	b2750
#
# UREAtex	Urea transport via diffusion (extracellular to periplasm)	UREA_e <=> UREA_c	b1377 or b0241 or b0929 or b2215
#
# CITtex	Citrate transport via diffusion (extracellular to periplasm)	CIT_e <=> CIT_c	b1377 or b0241 or b0929 or b2215
#
# EX_so4_e	Sulfate exchange	SULFATE_e <=>
#
# DM_CARBON-DIOXIDE_c	CO2 demand_smiley	CARBON-DIOXIDE_c -->
#
#
#
# >amet_c S-Adenosyl-L-methionine S-ADENOSYLMETHIONINE_c
#
# ADSK	Adenylyl-sulfate kinase	APS_c + ATP_c --> ADP_c + PAPS_c + PROTON_c	b2750
#
# HSDy	Homoserine dehydrogenase (NADPH)	HOMO-SER_c + NADP_c <=> L-ASPARTATE-SEMIALDEHYDE_c + NADPH_c + PROTON_c	b3940 or b0002
#
# EX_nh4_e	Ammonia exchange	AMMONIUM_e <=>
#
# EX_so4_e	Sulfate exchange	SULFATE_e <=>
#
# GLCtex_copy2		Glucopyranose_e <=> Glucopyranose_c	b0241 or b0929 or b1377 or b2215
#
# DM_PROTON_c	H+ demand_smiley	PROTON_c -->
#
# DM_H2CO3_c	carbonic acid demand_smiley	H2CO3_c -->
#
#
#
# >btn_c Biotin BIOTIN_c
#
# ADSK	Adenylyl-sulfate kinase	APS_c + ATP_c --> ADP_c + PAPS_c + PROTON_c	b2750
#
# UREAtex	Urea transport via diffusion (extracellular to periplasm)	UREA_e <=> UREA_c	b1377 or b0241 or b0929 or b2215
#
# CITtex	Citrate transport via diffusion (extracellular to periplasm)	CIT_e <=> CIT_c	b1377 or b0241 or b0929 or b2215
#
# THDPS	Tetrahydrodipicolinate succinylase	DELTA1-PIPERIDEINE-2-6-DICARBOXYLATE_c + SUC-COA_c + WATER_c --> CO-A_c + N-SUCCINYL-2-AMINO-6-KETOPIMELATE_c	b0166
#
# EX_so4_e	Sulfate exchange	SULFATE_e <=>
#
# GLCtex_copy2		Glucopyranose_e <=> Glucopyranose_c	b0241 or b0929 or b1377 or b2215
#
# DM_CARBON-DIOXIDE_c	CO2 demand_smiley	CARBON-DIOXIDE_c -->
#
# DM_DIHYDROXYPENTANEDIONE_c	autoinducer 2 demand_smiley	DIHYDROXYPENTANEDIONE_c -->
#
# DM_CPD0-2167_c	5'-deoxyribose demand_smiley	CPD0-2167_c -->
#
# DM_METOH_c	methanol demand_smiley	METOH_c -->
#
# DM_ALLYSINE_c	(S)-2-amino-6-oxohexanoate demand_smiley	ALLYSINE_c -->
#
#
#
# >coa_c Coenzyme A CO-A_c
#
# EX_pi_e	Phosphate exchange	Pi_e <=>
#
# PNTK	Pantothenate kinase	ATP_c + PANTOTHENATE_c --> 4-P-PANTOTHENATE_c + ADP_c + PROTON_c	b3974
#
# ADSK	Adenylyl-sulfate kinase	APS_c + ATP_c --> ADP_c + PAPS_c + PROTON_c	b2750
#
# UREAtex	Urea transport via diffusion (extracellular to periplasm)	UREA_e <=> UREA_c	b1377 or b0241 or b0929 or b2215
#
# EX_so4_e	Sulfate exchange	SULFATE_e <=>
#
# GLCtex_copy2		Glucopyranose_e <=> Glucopyranose_c	b0241 or b0929 or b1377 or b2215
#
# DM_PROTON_c	H+ demand_smiley	PROTON_c -->
#
# DM_H2CO3_c	carbonic acid demand_smiley	H2CO3_c -->
#
#
#
# >fad_c Flavin adenine dinucleotide oxidized FAD_c
#
# EX_pi_e	Phosphate exchange	Pi_e <=>
#
# GLCtex_copy1		Glucopyranose_e --> Glucopyranose_c	b4036
#
# EX_nh4_e	Ammonia exchange	AMMONIUM_e <=>
#
# DM_PROTON_c	H+ demand_smiley	PROTON_c -->
#
# DM_H2CO3_c	carbonic acid demand_smiley	H2CO3_c -->
#
#
#
# >h2o_c H2O H2O WATER_c
#
# EX_h2o_e	H2O exchange	WATER_e <=>
#
#
#
# >mlthf_c 5,10-Methylenetetrahydrofolate METHYLENE-THF_c
#
# DNMPPA	Dihydroneopterin monophosphate dephosphorylase	DIHYDRONEOPTERIN-P_c + WATER_c --> CPD-11770_c + Pi_c
#
# DNTPPA	Dihydroneopterin triphosphate pyrophosphatase	DIHYDRONEOPTERIN-P3_c + WATER_c --> DIHYDRONEOPTERIN-P_c + PPI_c + PROTON_c	b1865 or b0099
#
# EX_nh4_e	Ammonia exchange	AMMONIUM_e <=>
#
# GLCtex_copy2		Glucopyranose_e <=> Glucopyranose_c	b0241 or b0929 or b1377 or b2215
#
# 4HTHRK	4-Hydroxy-L-threonine kinase	ATP_c + CPD0-2189_c --> 4-PHOSPHONOOXY-THREONINE_c + ADP_c + PROTON_c	b0003
#
# DM_PROTON_c	H+ demand_smiley	PROTON_c -->
#
# DM_H2CO3_c	carbonic acid demand_smiley	H2CO3_c -->
#
#
#
# >murein5px4p_p Two disacharide linked murein units, pentapeptide crosslinked tetrapeptide (A2pm->D-ala) (middle of chain) CPD0-2278_c
#
# UREAtex	Urea transport via diffusion (extracellular to periplasm)	UREA_e <=> UREA_c	b1377 or b0241 or b0929 or b2215
#
# THDPS	Tetrahydrodipicolinate succinylase	DELTA1-PIPERIDEINE-2-6-DICARBOXYLATE_c + SUC-COA_c + WATER_c --> CO-A_c + N-SUCCINYL-2-AMINO-6-KETOPIMELATE_c	b0166
#
# GLCtex_copy2		Glucopyranose_e <=> Glucopyranose_c	b0241 or b0929 or b1377 or b2215
#
# DM_PROTON_c	H+ demand_smiley	PROTON_c -->
#
# DM_CARBON-DIOXIDE_c	CO2 demand_smiley	CARBON-DIOXIDE_c -->
#
#
#
# >nad_c Nicotinamide adenine dinucleotide NAD_c
#
# EX_pi_e	Phosphate exchange	Pi_e <=>
#
# NADS1	NAD synthase (nh3)	AMMONIUM_c + ATP_c + DEAMIDO-NAD_c --> AMP_c + NAD_c + PPI_c + PROTON_c	b1740
#
# GLCtex_copy1		Glucopyranose_e --> Glucopyranose_c	b4036
#
# EX_nh4_e	Ammonia exchange	AMMONIUM_e <=>
#
# DM_PROTON_c	H+ demand_smiley	PROTON_c -->
#
# DM_H2CO3_c	carbonic acid demand_smiley	H2CO3_c -->
#
#
#
# >nadp_c Nicotinamide adenine dinucleotide phosphate NADP_c
#
# EX_pi_e	Phosphate exchange	Pi_e <=>
#
# NADS1	NAD synthase (nh3)	AMMONIUM_c + ATP_c + DEAMIDO-NAD_c --> AMP_c + NAD_c + PPI_c + PROTON_c	b1740
#
# EX_nh4_e	Ammonia exchange	AMMONIUM_e <=>
#
# GLCtex_copy2		Glucopyranose_e <=> Glucopyranose_c	b0241 or b0929 or b1377 or b2215
#
# DM_PROTON_c	H+ demand_smiley	PROTON_c -->
#
# DM_H2CO3_c	carbonic acid demand_smiley	H2CO3_c -->
#
#
#
# >pheme_c Protoheme C34H30FeN4O4 PROTOHEME_c
#
# O2tex	Oxygen transport via diffusion (extracellular to periplasm)	OXYGEN-MOLECULE_e <=> OXYGEN-MOLECULE_c	b1377 or b0241 or b0929 or b2215
#
# UREAtex	Urea transport via diffusion (extracellular to periplasm)	UREA_e <=> UREA_c	b1377 or b0241 or b0929 or b2215
#
# CITtex	Citrate transport via diffusion (extracellular to periplasm)	CIT_e <=> CIT_c	b1377 or b0241 or b0929 or b2215
#
# DM_CARBON-DIOXIDE_c	CO2 demand_smiley	CARBON-DIOXIDE_c -->
#
#
#
# >pydx5p_c Pyridoxal 5'-phosphate PYRIDOXAL_PHOSPHATE_c
#
# EX_pi_e	Phosphate exchange	Pi_e <=>
#
# O2tex	Oxygen transport via diffusion (extracellular to periplasm)	OXYGEN-MOLECULE_e <=> OXYGEN-MOLECULE_c	b1377 or b0241 or b0929 or b2215
#
# UREAtex	Urea transport via diffusion (extracellular to periplasm)	UREA_e <=> UREA_c	b1377 or b0241 or b0929 or b2215
#
# GLCtex_copy2		Glucopyranose_e <=> Glucopyranose_c	b0241 or b0929 or b1377 or b2215
#
# DM_CARBON-DIOXIDE_c	CO2 demand_smiley	CARBON-DIOXIDE_c -->
#
# DM_HYDROGEN-MOLECULE_c	H2 demand_smiley	HYDROGEN-MOLECULE_c -->
#
#
#
# >ribflv_c Riboflavin C17H20N4O6 RIBOFLAVIN_c
#
# GLCtex_copy1		Glucopyranose_e --> Glucopyranose_c	b4036
#
# UREAtex	Urea transport via diffusion (extracellular to periplasm)	UREA_e <=> UREA_c	b1377 or b0241 or b0929 or b2215
#
# DM_PROTON_c	H+ demand_smiley	PROTON_c -->
#
# DM_H2CO3_c	carbonic acid demand_smiley	H2CO3_c -->
#
#
#
# >sheme_c Siroheme C42H36FeN4O16 SIROHEME_c
#
# UREAtex	Urea transport via diffusion (extracellular to periplasm)	UREA_e <=> UREA_c	b1377 or b0241 or b0929 or b2215
#
# GLCtex_copy2		Glucopyranose_e <=> Glucopyranose_c	b0241 or b0929 or b1377 or b2215
#
# DM_PROTON_c	H+ demand_smiley	PROTON_c -->
#
# DM_GLYOX_c	glyoxylate demand_smiley	GLYOX_c -->
#
# DM_DIHYDROXYPENTANEDIONE_c	autoinducer 2 demand_smiley	DIHYDROXYPENTANEDIONE_c -->
#
#
#
# >succoa_c Succinyl-CoA SUC-COA_c
#
# EX_pi_e	Phosphate exchange	Pi_e <=>
#
# PNTK	Pantothenate kinase	ATP_c + PANTOTHENATE_c --> 4-P-PANTOTHENATE_c + ADP_c + PROTON_c	b3974
#
# ADSK	Adenylyl-sulfate kinase	APS_c + ATP_c --> ADP_c + PAPS_c + PROTON_c	b2750
#
# UREAtex	Urea transport via diffusion (extracellular to periplasm)	UREA_e <=> UREA_c	b1377 or b0241 or b0929 or b2215
#
# EX_so4_e	Sulfate exchange	SULFATE_e <=>
#
# GLCtex_copy2		Glucopyranose_e <=> Glucopyranose_c	b0241 or b0929 or b1377 or b2215
#
# DM_PROTON_c	H+ demand_smiley	PROTON_c -->
#
# DM_H2CO3_c	carbonic acid demand_smiley	H2CO3_c -->
#
#
#
# >thf_c 5,6,7,8-Tetrahydrofolate THF_c
#
# DNMPPA	Dihydroneopterin monophosphate dephosphorylase	DIHYDRONEOPTERIN-P_c + WATER_c --> CPD-11770_c + Pi_c
#
# DNTPPA	Dihydroneopterin triphosphate pyrophosphatase	DIHYDRONEOPTERIN-P3_c + WATER_c --> DIHYDRONEOPTERIN-P_c + PPI_c + PROTON_c	b1865 or b0099
#
# EX_nh4_e	Ammonia exchange	AMMONIUM_e <=>
#
# GLCtex_copy2		Glucopyranose_e <=> Glucopyranose_c	b0241 or b0929 or b1377 or b2215
#
# 4HTHRK	4-Hydroxy-L-threonine kinase	ATP_c + CPD0-2189_c --> 4-PHOSPHONOOXY-THREONINE_c + ADP_c + PROTON_c	b0003
#
# DM_PROTON_c	H+ demand_smiley	PROTON_c -->
#
# DM_H2CO3_c	carbonic acid demand_smiley	H2CO3_c -->
#
#
#
# >thmpp_c Thiamine diphosphate THIAMINE-PYROPHOSPHATE_c
#
# EX_pi_e	Phosphate exchange	Pi_e <=>
#
# ADSK	Adenylyl-sulfate kinase	APS_c + ATP_c --> ADP_c + PAPS_c + PROTON_c	b2750
#
# O2tex	Oxygen transport via diffusion (extracellular to periplasm)	OXYGEN-MOLECULE_e <=> OXYGEN-MOLECULE_c	b1377 or b0241 or b0929 or b2215
#
# GLCtex_copy1		Glucopyranose_e --> Glucopyranose_c	b4036
#
# UREAtex	Urea transport via diffusion (extracellular to periplasm)	UREA_e <=> UREA_c	b1377 or b0241 or b0929 or b2215
#
# EX_h2o_e	H2O exchange	WATER_e <=>
#
# EX_so4_e	Sulfate exchange	SULFATE_e <=>
#
# THZPSN3	Thiazole phosphate synthesis	ATP_c + CPD-12279_c + DEOXYXYLULOSE-5P_c + NADPH_c + PROTON_c + iscssh_c --> AMP_c + CARBON-DIOXIDE_c + NADP_c + PPI_c + THZ-P_c + 2.0 WATER_c + iscs_c	b3992 and b3990 and b0423 and b2530 and b4407
#
# DM_ACET_c	acetate demand_smiley	ACET_c -->
#
#
#
# >udcpdp_c Undecaprenyl diphosphate CPD-9649_c
#
# EX_pi_e	Phosphate exchange	Pi_e <=>
#
# GLCtex_copy2		Glucopyranose_e <=> Glucopyranose_c	b0241 or b0929 or b1377 or b2215
#
# DM_PROTON_c	H+ demand_smiley	PROTON_c -->
#
# DM_CARBON-DIOXIDE_c	CO2 demand_smiley	CARBON-DIOXIDE_c -->
#
#
#
# >adp_c ADP C10H12N5O10P2 ADP_c
#
# EX_pi_e	Phosphate exchange	Pi_e <=>
#
# GLCtex_copy1		Glucopyranose_e --> Glucopyranose_c	b4036
#
# EX_nh4_e	Ammonia exchange	AMMONIUM_e <=>
#
# DM_PROTON_c	H+ demand_smiley	PROTON_c -->
#
# DM_H2CO3_c	carbonic acid demand_smiley	H2CO3_c -->
#
#
#
# >pi_c Phosphate Pi_c
#
# EX_pi_e	Phosphate exchange	Pi_e <=>
#
# PItex	Phosphate transport via diffusion (extracellular to periplasm)	Pi_e <=> Pi_c	b1377 or b0241 or b0929 or b2215
#
#
#
# >ppi_c Diphosphate PPI_c
#
# EX_pi_e	Phosphate exchange	Pi_e <=>
#
# EX_h_e	H+ exchange	PROTON_e <=>
#
# CHLtex	Choline transport via diffusion (extracellular to periplasm)	CHOLINE_e <=> CHOLINE_c	b1377 or b0241 or b0929 or b2215
#
# DM_WATER_c	H2O demand_smiley	WATER_c -->
