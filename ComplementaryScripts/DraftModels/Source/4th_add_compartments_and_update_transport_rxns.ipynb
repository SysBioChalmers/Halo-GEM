# %%
from tools import *
import pickle

# %% [markdown]
# ## Add transported metabolites

# %%
def split_model_based_on_transport_rxns(model,tag):
    # model,   a metacyc based model
    # tag, for output file
    # 
    # Find all transport reactions in metacyc model. Save all these reactions into a new model.  
    # Remove those reactions from metacyc model
    #
    # Since there is no compartment information in the reaction, the metabolites transported are missing 
    # in the reaction because they exit in both side of the reaction. We will manually check the metacyc website
    # for those transporters and then add them back
    # 
    # check transport reaction in halo_meta
    # load transport reaction ids in metacyc database
    # The transport reactions were identified based on the transport reaction ids from RAVEN.
    is_transport = dict()
    for item in open('../../../ComplementaryData/metaCyc_transport_rxns.txt').read().split(): 
        is_transport[item] = True
    fhand = open('../Results/transport_rxns_{0}.tsv'.format(tag),'w')
    trmodel = cobra.Model('transmodel')
    non_trans_rxns = list()
    trans_rxns = list()
    k = 0
    for rxn in model.reactions:
        if is_transport.get(rxn.id,False): 
            k += 1
            print(k,rxn.id,rxn.name,':',rxn.reaction)
            fhand.write('{0}\t{1}\t{2}\t{3}\n'.format(k,rxn.id,rxn.name,rxn.reaction))
            trans_rxns.append(rxn.copy())
        else: non_trans_rxns.append(rxn.copy())
    trmodel.add_reactions(trans_rxns)
    for met in trmodel.metabolites: 
        try:met.charge = int(met.charge)
        except: met.charge=None
            
    fhand.close()

    ntrmodel = cobra.Model(model.id)
    ntrmodel.add_reactions(non_trans_rxns)
    
    return ntrmodel, trmodel

# %%
def the_TransRxns_For_Manual_Check(TransRxn_file):
    
    print('Ones have been manually checked')
    df_trans_old = pd.read_csv('../../../ComplementaryData/transport_rxns_mannual.tsv',
                               header=None,sep='\t',index_col=0)
    df_trans_old=df_trans_old.set_index(1)
    print(df_trans_old.shape)
    print(df_trans_old.head(5))
    print()
    
    print('Ones in the current model')
    df_trans_new = pd.read_csv(TransRxn_file,header=None,sep='\t',index_col=0)
    df_trans_new = df_trans_new.set_index(1)
    print(df_trans_new.head(5))
    print()
    
    print('Ones to be manually checked')
    print('''
    # if the below part is not empty, then add those to ../../../ComplementaryData/transport_rxns_mannual.tsv 
    # and manually collect transported metabolites from metacyc website
    ''')
    
    df_to_be_update = df_trans_new.loc[list(set(df_trans_new.index)-set(df_trans_old.index)),:]
    print(df_to_be_update)
    df_to_be_update.to_csv(TransRxn_file+'_to_be_manually_added.tsv',sep='\t',header=None)

# %%
def consider_all_rxns_happend_in_cytosal(model):
    for met in model.metabolites:
        met.id = met.id+'_c'
        met.compartment = 'c'
    model.repair()

# %%
def format_transported_met(rxn_id,transmodel,metacyc_model,direction,met_ids,weights):
    # rxn_id: rxn_id in transmodel
    # transmodel: the model containing all transport reactions
    # consider all transport reactions happen between cysotol and periplasm
    #
    # metacyc model: model reconstructed from MetaCyc
    # direction: 'in' or 'out'. 'in': p to c, out: c to p
    # met_ids: transported metabolite ids
    # weights: coeffs of tranported metabolite
    # 
    # Assume all metbolites in transport reactions before adding transported metabolit as in cyctosal.
    # 
    rxn = transmodel.reactions.get_by_id(rxn_id)
    #new_rxn = rxn.copy()
    
    # 1. add _c to exsiting metaboites in transport reaction
    coeffs = dict()
    for met in rxn.metabolites:
        new_id = met.id+'_c'

        try: new_met = metacyc_model.metabolites.get_by_id(new_id)
        except: 
            new_met = met.copy()
            new_met.id = new_met.id +'_c'
            new_met.compartment = 'c'
        coeffs[new_met] = rxn.get_coefficient(met)

    
    # 2. add transported metaboites
    def get_met_ec(met_id):
        try: met_c = metacyc_model.metabolites.get_by_id(met_id+'_c')
        except: 
            met_c = cobra.Metabolite(met_id+'_c')
            #met_c.name = met_id
            met_c.annotation = {'biocyc':'META:'+met_id,'id_source':'biocyc'}
            met_c.compartment = 'c'
            
            
        try: met_e = metacyc_model.metabolites.get_by_id(met_id+'_p')
        except: 
            met_e = cobra.Metabolite(met_id+'_p')
            met_e.annotation = met_c.annotation
            #met_e.name = met_id
            met_e.compartment = 'p'

        return met_e,met_c
    
    for i in range(len(met_ids)):
        met_id = met_ids[i]
        number_of_molecular = weights[i]
        met_e,met_c = get_met_ec(met_id)
        if direction == 'in': 
            coeffs[met_e] = coeffs.get(met_e,0)-number_of_molecular
            coeffs[met_c] = coeffs.get(met_c,0)+number_of_molecular
        elif direction == 'out':
            coeffs[met_c] = coeffs.get(met_c,0)-number_of_molecular
            coeffs[met_e] = coeffs.get(met_e,0)+number_of_molecular
        else: print('Error: check direction. ')

    
    new_rxn = rxn.copy()
    new_rxn.subtract_metabolites(new_rxn.metabolites)
    new_rxn.add_metabolites(coeffs)
    print(new_rxn.id,new_rxn.reaction)
    return new_rxn

# %%
def add_curated_transport_rxns(ntmodel,tmodel):
    trans_rxns_formated = list()
    trans_ids_to_be_add = [rxn.id for rxn in tmodel.reactions]
    for line in open('../../../ComplementaryData/transport_rxns_mannual.tsv'):
        cont = line.strip().split('\t')
        rxn_id = cont[1]
        if rxn_id not in trans_ids_to_be_add: continue
        direction = cont[5]
        met_ids = cont[4].split(',')
        weights = [int(item) for item in cont[6].split(',')]

        trans_rxns_formated.append(format_transported_met(rxn_id,tmodel,ntmodel,direction,
                                                      met_ids,weights)) 
    ntmodel.add_reactions(trans_rxns_formated)

# %%
def do_some_manual_curations(model):
    # curate the reversibility of several transport reactions
    print(model.reactions.get_by_id('TRANS-RXN0-244').reaction)
    model.reactions.get_by_id('TRANS-RXN0-244').lower_bound = 0
    print(model.reactions.get_by_id('TRANS-RXN0-244').reaction)
    
    print(model.reactions.get_by_id('TRANS-RXN0-200').reaction)
    model.reactions.get_by_id('TRANS-RXN0-200').upper_bound = 0
    print(model.reactions.get_by_id('TRANS-RXN0-200').reaction)
    
    
    # formation of NADPH is thermodynamically favored. Also in iML1515 THD2pp reaction
    # curate TRANS-RXN0-277
    # It should be NADP + NADH + H_p --> NADPH_c + NAD_c + H_c
    print(model.reactions.get_by_id('TRANS-RXN0-277').reaction)

    tmp_rxn = model.reactions.get_by_id('TRANS-RXN0-277')
    new_mets = {
        model.metabolites.get_by_id('NADPH_c'): 1,
        model.metabolites.get_by_id('NAD_c'): 1,
        model.metabolites.get_by_id('PROTON_c'): 1,
        model.metabolites.get_by_id('NADH_c'): -1,
        model.metabolites.get_by_id('NADP_c'): -1,
        model.metabolites.get_by_id('PROTON_p'): -1,
    }
    tmp_rxn.subtract_metabolites(tmp_rxn.metabolites)
    tmp_rxn.add_metabolites(new_mets)
    tmp_rxn.lower_bound = 0
    print(tmp_rxn.reaction)
    
    model.repair()

# %%
halo_meta = pickle.load(open('../Results/halo_metacycmodel_100_curated.pkl','rb'))
halo_mekg = pickle.load(open('../Results/halo_metacyc_kegg_curated.pkl','rb'))
# Out:
# Using license file /Users/gangl/gurobi.lic
# Academic license - for non-commercial use only
# Read LP format model from file /var/folders/dx/ghtq02dx2w307xx_5hncb421qny3_w/T/tmptt3rhltl.lp
# Reading time = 0.03 seconds
# : 1553 rows, 2642 columns, 12000 nonzeros
# Read LP format model from file /var/folders/dx/ghtq02dx2w307xx_5hncb421qny3_w/T/tmppgu5bi5o.lp
# Reading time = 0.02 seconds
# : 2528 rows, 4478 columns, 20234 nonzeros

# %%
halo_meta_nt, halo_meta_t = split_model_based_on_transport_rxns(halo_meta,'halo_meta')
# Out:
# 1 RXN-9615 ammonium transporter :  -->
# 2 TRANS-RXN-214 Na(+)-translocating NADH-quinone reductase : NADH + PROTON + Ubiquinones --> NAD + Ubiquinols
# 3 RXN0-21 glutathione exporter : ATP + CPD-15815 --> ADP + PROTON + Pi
# 4 TRANS-RXN0-277 pyridine nucleotide transhydrogenase;NAD(P) transhydrogenase : NAD + NADPH <=> NADH + NADP
# 5 ABC-4-RXN L-arginine transporter : ATP + CPD-15815 --> ADP + PROTON + Pi
# 6 ABC-19-RXN molybdate ABC transporter;transport of molybdate : ATP + CPD-15815 --> ADP + PROTON + Pi
# 7 TRANS-RXN-347 norfloxacin:Na+ antiport :  <=>
# 8 TRANS-RXN-237 transport of lipopolysaccharide : ATP + CPD-15815 --> ADP + PROTON + Pi
# 9 TRANS-RXN-167A D-glucosamine PTS permease : GLUCOSAMINE + Hpr-pi-phospho-L-histidines --> D-GLUCOSAMINE-6-P + Hpr-Histidine
# 10 TRANS-RXN0-513 lanthionine ABC transporter : ATP + CPD-15815 --> ADP + PROTON + Pi
# 11 TRANS-RXN-42 K+:H+ antiporter;K+ : H+ antiporter KefC;Na+/K+:H+ antiporter ChaA;K+ : H+ antiporter KefB :  <=>
# 12 ABC-35-RXN L-leucine transport;transport of L-leucine : ATP + CPD-15815 --> ADP + PROTON + Pi
# 13 TRANS-RXN-359 ethidium efflux pump :  -->
# 14 ABC-15-RXN transport of L-isoleucine : ATP + CPD-15815 --> ADP + PROTON + Pi
# 15 TRANS-RXN-296 cobinamide ABC transporter : ATP + CPD-15815 --> ADP + PROTON + Pi
# 16 TRANS-RXN-162 L-glutamate:H+ symporter :  <=>
# 17 TRANS-RXN-132 uracil:H+ symporter;uracil:H+ symporter UraA :  <=>
# 18 RXN0-1802 long-chain fatty acid outer membrane porin bacteriophage T2 binding :  -->
# 19 TRANS-RXN0-510 N-acetyl-DL-methionine transport : ATP + CPD-15815 --> ADP + PROTON + Pi
# 20 TRANS-RXN0-492 transport of beta-D-galactofuranose : ATP + CPD-15815 --> ADP + PROTON + Pi
# 21 TRANS-RXN0-447 transport of adenine :  <=>
# 22 TRANS-RXN0-244 Cd2+:H+ antiporter;Cd2+ export :  -->
# 23 TRANS-RXN-356 decanoate efflux pump :  -->
# 24 ABC-12-RXN transport of L-glutamine : ATP + CPD-15815 --> ADP + PROTON + Pi
# 25 TRANS-RXN-340 bicozamycin:H+ antiporter :  <=>
# 26 TRANS-RXN-273 nitroimidazole export :  -->
# 27 TRANS-RXN0-592 chenodeoxycholate efflux pump :  -->
# 28 RXN0-1721 ferric dihyroxybenzoylserine outer membrane transporter :  -->
# 29 TRANS-RXN-312 transport of L-phenylalanine;L-phenylalanine transport : ATP + CPD-15815 --> ADP + PROTON + Pi
# 30 RXN-18028 poly(glycerol phosphate) teichoic acid transporter : ATP + CPD-15815 --> ADP + PROTON + Pi
# 31 RXN-19739 glutaconyl-CoA decarboxylase : GLUTACONYL-COA + PROTON --> CARBON-DIOXIDE + CROTONYL-COA
# 32 ABC-70-RXN sulfate  ABC transporter;sulfate ABC transporter : ATP + CPD-15815 --> ADP + PROTON + Pi
# 33 ABC-27-RXN transport of phosphate : ATP + CPD-15815 --> ADP + PROTON + Pi
# 34 TRANS-RXN-353 novobiocin efflux pump :  -->
# 35 TRANS-RXN-242A L-homoserine lactone:H+ antiport :  <=>
# 36 TRANS-RXN0-503 maltotriose ABC transporter : ATP + CPD-15815 --> ADP + PROTON + Pi
# 37 3.6.3.16-RXN arsenite-translocating ATPase;arsenite export : ATP + CPD-15815 --> ADP + PROTON + Pi
# 38 TRANS-RXN0-269 L-valine exporter :  <=>
# 39 TRANS-RXN0-200 Zn2+ export;Zn2+:H+ antiporter :  -->
# 40 TRANS-RXN-366 cefoperazone ABC exporter : ATP + CPD-15815 --> ADP + PROTON + Pi
# 41 ABC-24-RXN putrescine/spermidine ABC transporter : ATP + CPD-15815 --> ADP + PROTON + Pi
# 42 RXN0-1924 export of L-cysteine;cysteine exporter :  -->
# 43 TRANS-RXN0-222 transport of L-aspartate : ATP + CPD-15815 --> ADP + PROTON + Pi
# 44 TRANS-RXN0-0244 L-threonine:H+ antiporter :  <=>
# 45 TRANS-RXN-363 nalidixate efflux pump :  -->
# 46 TRANS-RXN-348 tetraphenylphosphonium:Na+ antiport :  <=>
# 47 TRANS-RXN-325 canavanine exporter :  -->
# 48 TRANS-RXN0-553 fumarate transporter;transport of fumarate :  <=>
# 49 TRANS-RXN0-452 p-aminobenzoyl glutamate:H+ symporter :  <=>
# 50 ABC-36-RXN transport of L-valine : ATP + CPD-15815 --> ADP + PROTON + Pi
# 51 TRANS-RXN-360 gentamicin efflux pump :  -->
# 52 ABC-16-RXN maltose ABC transporter : ATP + CPD-15815 --> ADP + PROTON + Pi
# 53 TRANS-RXN-321 poly(3-O-beta-D-glucopyranosyl-N-acetylgalactosamine 1-phosphate) teichoic acid transporter :  -->
# 54 TRANS-RXN-297 ferric coprogen ABC transporter : ATP + CPD-15815 --> ADP + PROTON + Pi
# 55 TRANS-RXN-194 calcium-transporting ATPase;plasma membrane Ca2+-ATPase;plasma membrane calcium-transporting ATPase;plastid envelope ATPase;calmodulin-stimulated calcium-ATPase : ATP + CPD-15815 --> ADP + PROTON + Pi
# 56 TRANS-RXN-137 nitrite transporter NirC;transport of nitrite :  -->
# 57 TRANS-RXN0-569 L-amino acid exporter :  -->
# 58 TRANS-RXN-118 proline:Na+ symporter :  <=>
# 59 TRANS-RXN0-549 transport of poly-beta-1,6-N-acetyl-D-glucosamine :  -->
# 60 TRANS-RXN0-511 L-methionine S-oxide transport : ATP + CPD-15815 --> ADP + PROTON + Pi
# 61 TRANS-RXN0-258 transport of N-acetyl-beta-D-glucosamine(anhydrous)-N-acetylmuramate :  <=>
# 62 TRANS-RXN-92 SDS efflux pump :  -->
# 63 TRANS-RXN-40 L-arabinose exporter :  <=>
# 64 TRANS-RXN-357 enterobactin efflux pump :  -->
# 65 ABC-13-RXN transport of L-glutamate : ATP + CPD-15815 --> ADP + PROTON + Pi
# 66 RXN0-3 L-cysteine exporter : ATP + CPD-15815 --> ADP + PROTON + Pi
# 67 TRANS-RXN0-593 L-cystine ABC transporter : ATP + CPD-15815 --> ADP + PROTON + Pi
# 68 TRANS-RXN0-508 djenkolate ABC transporter : ATP + CPD-15815 --> ADP + PROTON + Pi
# 69 TRANS-RXN0-239 nitrate:nitrite antiporter :  -->
# 70 RXN0-6 Fe2+:H+ antiporter :  <=>
# 71 RXN-5076 xanthine:H+ symporter XanQ;xanthine:H+ symporter XanP :  <=>
# 72 ABC-8-RXN Transport of a dipeptide : ATP + CPD-15815 --> ADP + PROTON + Pi
# 73 TRANS-RXN-354 acriflavin efflux pump;acriflavine efflux pump :  -->
# 74 ABC-10-RXN transport of ferric enterobactin : ATP + CPD-15815 --> ADP + PROTON + Pi
# 75 RXN0-5111 glycolate:cation symporter :  <=>
# 76 TRANS-RXN-290 D-cystine ABC transporter : ATP + CPD-15815 --> ADP + PROTON + Pi
# 77 RXN-8638 transport of a quarternary amine : ATP + CPD-15815 --> ADP + PROTON + Pi
# 78 RXN0-1701 transport of ferrichrome :  -->
# 79 TRANS-RXN0-504 maltotetraose ABC transporter : ATP + CPD-15815 --> ADP + PROTON + Pi
# 80 ABC-25-RXN putrescine/spermidine ABC transporter;transport of putresince : ATP + CPD-15815 --> ADP + PROTON + Pi
# 81 TRANS-RXN-351 sulfadiazine efflux pump :  -->
# 82 TRANS-RXN-220 glucosyl-oleandomycin-exporting ATPase : ATP + CPD-15815 --> ADP + PROTON + Pi
# 83 TRANS-RXN-145 water channel AqpZ :  <=>
# 84 TRANS-RXN0-576 transport of tellurite :  <=>
# 85 RXN0-11 transport of glutathione : ATP + CPD-15815 --> ADP + PROTON + Pi
# 86 TRANS-RXN0-478 selenate ABC transporter;selenate  ABC transporter : ATP + CPD-15815 --> ADP + PROTON + Pi
# 87 TRANS-RXN0-226 transport of GlcNAc-1,6-anhMurNAc-L-Ala-gamma-D-Glu-DAP-D-Ala :  <=>
# 88 TRANS-RXN0-162 ABC complex for formation and release of holoCcmE : ATP + CPD-15815 --> ADP + PROTON + Pi
# 89 ABC-5-RXN vitamin B12 ABC transporter : ATP + CPD-15815 --> ADP + PROTON + Pi
# 90 TRANS-RXN-364 CCCP efflux pump :  -->
# 91 ABC-20-RXN nickel ABC transporter : ATP + CPD-15815 --> ADP + PROTON + Pi
# 92 TRANS-RXN-349 deoxycholate:Na+ antiport :  <=>
# 93 TRANS-RXN-3 K+:H+ symporter Kup;K+ transporter TrkH;K+ transporter TrkG :  <=>
# 94 RXN0-4083 serine/threonine:Na+ symporter :  <=>
# 95 TRANS-RXN-2 K+ transporting ATPase : ATP + CPD-15815 --> ADP + PROTON + Pi
# 96 RXN0-22 guanosine:H+ antiporter :  <=>
# 97 TRANS-RXN0-573 transport of a glycerophosphodiester : ATP + CPD-15815 --> ADP + PROTON + Pi
# 98 TRANS-RXN0-453 autoinducer 2 exporter :  <=>
# 99 TRANS-RXN0-281 acetoacetate transporter :  -->
# 100 TRANS-RXN-298 ferrichrome ABC transporter : ATP + CPD-15815 --> ADP + PROTON + Pi
# 101 RXN0-4522 methionine transport : ATP + CPD-15815 --> ADP + PROTON + Pi
# 102 TRANS-RXN-167 N-acetyl-D-galactosamine PTS;N-acetylglucosamine PTS permease;N-acetyl-D-glucosamine PTS permease : Hpr-pi-phospho-L-histidines + N-acetyl-D-glucosamine --> Hpr-Histidine + N-ACETYL-D-GLUCOSAMINE-6-P
# 103 TRANS-RXN0-617 homocystine ABC transporter : ATP + CPD-15815 --> ADP + PROTON + Pi
# 104 TRANS-RXN-121 succinate:H+ symporter;transport of succinate;succinate transporter :  <=>
# 105 ABC-34-RXN transport of glycerol-3-phosphate : ATP + CPD-15815 --> ADP + PROTON + Pi
# 106 ATPSYN-RXN ATP synthase;ATP hydrolase;H+-translocating V-ATPase : ATP + CPD-15815 <=> ADP + PROTON + Pi
# 107 TRANS-RXN0-595 flavin mononucleotide (FMN) export :  -->
# 108 RXN0-18 inosine:H+ antiporter :  <=>
# 109 TRANS-RXN0-491 transport of alpha-D-galactofuranose : ATP + CPD-15815 --> ADP + PROTON + Pi
# 110 TRANS-RXN0-445 chitobiose transport;transport of N,N'-diacetyl-chitobiose :  -->
# 111 TRANS-RXN0-240 biotin transporter :  -->
# 112 ABC-9-RXN transport of ferric dicitrate : ATP + CPD-15815 --> ADP + PROTON + Pi
# 113 TRANS-RXN-355 n-hexane efflux pump :  -->
# 114 RXN0-5205 Zn2+-exporting ATPase : ATP + CPD-15815 --> ADP + PROTON + Pi
# 115 TRANS-RXN-291 diaminopimelate ABC transporter : ATP + CPD-15815 --> ADP + PROTON + Pi
# 116 TRANS-RXN-272 flavin adenine dinucleotide (FAD) export :  -->
# 117 TRANS-RXN-127 L-tartrate:succinate antiporter :  <=>
# 118 RXN0-1702 transport of ferric coprogen :  -->
# 119 RXN66-448 Sodium independent arginine transport;sodium independent arginine plasma membrane transport;L-arginine exporter :  <=>
# 120 TRANS-RXN0-505 propionate transporter :  -->
# 121 TRANS-RXN0-235 2,3-diketo-L-gulonate:Na+ symporter :  -->
# 122 TRANS-RXN0-202 methionine transport : ATP + CPD-15815 --> ADP + PROTON + Pi
# 123 ABC-7-RXN thiosulfate ABC transporter : ATP + CPD-15815 --> ADP + PROTON + Pi
# 124 ABC-26-RXN transport of proline : ATP + CPD-15815 --> ADP + PROTON + Pi
# 125 TRANS-RXN-352 deoxycholate efflux pump :  -->
# 126 TRANS-RXN-242 L-homoserine:H+ antiporter :  <=>
# 127 TRANS-RXN-178 copper P1B-ATPase;Cu transporting P-type ATPase;copper-transporting ATPase;Cu-ATPase : ATP + CPD-15815 --> ADP + PROTON + Pi
# 128 RXN0-1981 acetate:cation symporter :  <=>
# 129 TRANS-RXN0-479 selenite  ABC transporter;selenite ABC transporter : ATP + CPD-15815 --> ADP + PROTON + Pi
# 130 TRANS-RXN0-286 lipid II flippase :  -->
# 131 TRANS-RXN0-268 Transport of L-Ala-D-Glu-meso-A2pm : ATP + CPD-15815 --> ADP + PROTON + Pi
# 132 TRANS-RXN0-181 TatABCE protein export complex :  -->
# 133 TRANS-RXN-365 deoxycholate efflux pump :  -->
# 134 TRANS-RXN-283 glycine betaine ABC transporter : ATP + CPD-15815 --> ADP + PROTON + Pi
# 135 RXN0-1923 O-acetyl-L-serine exporter;export of O-acetyl-L-serine :  -->
# 136 TRANS-RXN-122A aspartate transport;L-aspartate:H+ symporter;transport of L-aspartate :  <=>
# 137 TRANS-RXN-99 choline:H+ symporter :  <=>

# %%
halo_mekg_nt, halo_mekg_t = split_model_based_on_transport_rxns(halo_mekg,'halo_mekg')
# Out:
# 1 RXN-9615 ammonium transporter :  -->
# 2 TRANS-RXN-214 Na(+)-translocating NADH-quinone reductase : NADH + PROTON + Ubiquinones --> NAD + Ubiquinols
# 3 RXN0-21 glutathione exporter : ATP + CPD-15815 --> ADP + PROTON + Pi
# 4 TRANS-RXN0-277 pyridine nucleotide transhydrogenase;NAD(P) transhydrogenase : NAD + NADPH <=> NADH + NADP
# 5 ABC-4-RXN L-arginine transporter : ATP + CPD-15815 --> ADP + PROTON + Pi
# 6 ABC-19-RXN molybdate ABC transporter;transport of molybdate : ATP + CPD-15815 --> ADP + PROTON + Pi
# 7 TRANS-RXN-347 norfloxacin:Na+ antiport :  <=>
# 8 TRANS-RXN-237 transport of lipopolysaccharide : ATP + CPD-15815 --> ADP + PROTON + Pi
# 9 TRANS-RXN-167A D-glucosamine PTS permease : GLUCOSAMINE + Hpr-pi-phospho-L-histidines --> D-GLUCOSAMINE-6-P + Hpr-Histidine
# 10 TRANS-RXN0-513 lanthionine ABC transporter : ATP + CPD-15815 --> ADP + PROTON + Pi
# 11 TRANS-RXN-42 K+:H+ antiporter;K+ : H+ antiporter KefC;Na+/K+:H+ antiporter ChaA;K+ : H+ antiporter KefB :  <=>
# 12 ABC-35-RXN L-leucine transport;transport of L-leucine : ATP + CPD-15815 --> ADP + PROTON + Pi
# 13 TRANS-RXN-359 ethidium efflux pump :  -->
# 14 ABC-15-RXN transport of L-isoleucine : ATP + CPD-15815 --> ADP + PROTON + Pi
# 15 TRANS-RXN-296 cobinamide ABC transporter : ATP + CPD-15815 --> ADP + PROTON + Pi
# 16 TRANS-RXN-162 L-glutamate:H+ symporter :  <=>
# 17 TRANS-RXN-132 uracil:H+ symporter;uracil:H+ symporter UraA :  <=>
# 18 RXN0-1802 long-chain fatty acid outer membrane porin bacteriophage T2 binding :  -->
# 19 TRANS-RXN0-510 N-acetyl-DL-methionine transport : ATP + CPD-15815 --> ADP + PROTON + Pi
# 20 TRANS-RXN0-492 transport of beta-D-galactofuranose : ATP + CPD-15815 --> ADP + PROTON + Pi
# 21 TRANS-RXN0-447 transport of adenine :  <=>
# 22 TRANS-RXN0-244 Cd2+:H+ antiporter;Cd2+ export :  -->
# 23 TRANS-RXN-356 decanoate efflux pump :  -->
# 24 ABC-12-RXN transport of L-glutamine : ATP + CPD-15815 --> ADP + PROTON + Pi
# 25 TRANS-RXN-340 bicozamycin:H+ antiporter :  <=>
# 26 TRANS-RXN-273 nitroimidazole export :  -->
# 27 TRANS-RXN0-592 chenodeoxycholate efflux pump :  -->
# 28 RXN0-1721 ferric dihyroxybenzoylserine outer membrane transporter :  -->
# 29 TRANS-RXN-312 transport of L-phenylalanine;L-phenylalanine transport : ATP + CPD-15815 --> ADP + PROTON + Pi
# 30 RXN-18028 poly(glycerol phosphate) teichoic acid transporter : ATP + CPD-15815 --> ADP + PROTON + Pi
# 31 RXN-19739 glutaconyl-CoA decarboxylase : GLUTACONYL-COA + PROTON --> CARBON-DIOXIDE + CROTONYL-COA
# 32 ABC-70-RXN sulfate  ABC transporter;sulfate ABC transporter : ATP + CPD-15815 --> ADP + PROTON + Pi
# 33 ABC-27-RXN transport of phosphate : ATP + CPD-15815 --> ADP + PROTON + Pi
# 34 TRANS-RXN-353 novobiocin efflux pump :  -->
# 35 TRANS-RXN-242A L-homoserine lactone:H+ antiport :  <=>
# 36 TRANS-RXN0-503 maltotriose ABC transporter : ATP + CPD-15815 --> ADP + PROTON + Pi
# 37 3.6.3.16-RXN arsenite-translocating ATPase;arsenite export : ATP + CPD-15815 --> ADP + PROTON + Pi
# 38 TRANS-RXN0-269 L-valine exporter :  <=>
# 39 TRANS-RXN0-200 Zn2+ export;Zn2+:H+ antiporter :  -->
# 40 TRANS-RXN-366 cefoperazone ABC exporter : ATP + CPD-15815 --> ADP + PROTON + Pi
# 41 ABC-24-RXN putrescine/spermidine ABC transporter : ATP + CPD-15815 --> ADP + PROTON + Pi
# 42 RXN0-1924 export of L-cysteine;cysteine exporter :  -->
# 43 TRANS-RXN0-222 transport of L-aspartate : ATP + CPD-15815 --> ADP + PROTON + Pi
# 44 TRANS-RXN0-0244 L-threonine:H+ antiporter :  <=>
# 45 TRANS-RXN-363 nalidixate efflux pump :  -->
# 46 TRANS-RXN-348 tetraphenylphosphonium:Na+ antiport :  <=>
# 47 TRANS-RXN-325 canavanine exporter :  -->
# 48 TRANS-RXN0-553 fumarate transporter;transport of fumarate :  <=>
# 49 TRANS-RXN0-452 p-aminobenzoyl glutamate:H+ symporter :  <=>
# 50 ABC-36-RXN transport of L-valine : ATP + CPD-15815 --> ADP + PROTON + Pi
# 51 TRANS-RXN-360 gentamicin efflux pump :  -->
# 52 ABC-16-RXN maltose ABC transporter : ATP + CPD-15815 --> ADP + PROTON + Pi
# 53 TRANS-RXN-321 poly(3-O-beta-D-glucopyranosyl-N-acetylgalactosamine 1-phosphate) teichoic acid transporter :  -->
# 54 TRANS-RXN-297 ferric coprogen ABC transporter : ATP + CPD-15815 --> ADP + PROTON + Pi
# 55 TRANS-RXN-194 calcium-transporting ATPase;plasma membrane Ca2+-ATPase;plasma membrane calcium-transporting ATPase;plastid envelope ATPase;calmodulin-stimulated calcium-ATPase : ATP + CPD-15815 --> ADP + PROTON + Pi
# 56 TRANS-RXN-137 nitrite transporter NirC;transport of nitrite :  -->
# 57 TRANS-RXN0-569 L-amino acid exporter :  -->
# 58 TRANS-RXN-118 proline:Na+ symporter :  <=>
# 59 TRANS-RXN0-549 transport of poly-beta-1,6-N-acetyl-D-glucosamine :  -->
# 60 TRANS-RXN0-511 L-methionine S-oxide transport : ATP + CPD-15815 --> ADP + PROTON + Pi
# 61 TRANS-RXN0-258 transport of N-acetyl-beta-D-glucosamine(anhydrous)-N-acetylmuramate :  <=>
# 62 TRANS-RXN-92 SDS efflux pump :  -->
# 63 TRANS-RXN-40 L-arabinose exporter :  <=>
# 64 TRANS-RXN-357 enterobactin efflux pump :  -->
# 65 ABC-13-RXN transport of L-glutamate : ATP + CPD-15815 --> ADP + PROTON + Pi
# 66 RXN0-3 L-cysteine exporter : ATP + CPD-15815 --> ADP + PROTON + Pi
# 67 TRANS-RXN0-593 L-cystine ABC transporter : ATP + CPD-15815 --> ADP + PROTON + Pi
# 68 TRANS-RXN0-508 djenkolate ABC transporter : ATP + CPD-15815 --> ADP + PROTON + Pi
# 69 TRANS-RXN0-239 nitrate:nitrite antiporter :  -->
# 70 RXN0-6 Fe2+:H+ antiporter :  <=>
# 71 RXN-5076 xanthine:H+ symporter XanQ;xanthine:H+ symporter XanP :  <=>
# 72 ABC-8-RXN Transport of a dipeptide : ATP + CPD-15815 --> ADP + PROTON + Pi
# 73 TRANS-RXN-354 acriflavin efflux pump;acriflavine efflux pump :  -->
# 74 ABC-10-RXN transport of ferric enterobactin : ATP + CPD-15815 --> ADP + PROTON + Pi
# 75 RXN0-5111 glycolate:cation symporter :  <=>
# 76 TRANS-RXN-290 D-cystine ABC transporter : ATP + CPD-15815 --> ADP + PROTON + Pi
# 77 RXN-8638 transport of a quarternary amine : ATP + CPD-15815 --> ADP + PROTON + Pi
# 78 RXN0-1701 transport of ferrichrome :  -->
# 79 TRANS-RXN0-504 maltotetraose ABC transporter : ATP + CPD-15815 --> ADP + PROTON + Pi
# 80 ABC-25-RXN putrescine/spermidine ABC transporter;transport of putresince : ATP + CPD-15815 --> ADP + PROTON + Pi
# 81 TRANS-RXN-351 sulfadiazine efflux pump :  -->
# 82 TRANS-RXN-220 glucosyl-oleandomycin-exporting ATPase : ATP + CPD-15815 --> ADP + PROTON + Pi
# 83 TRANS-RXN-145 water channel AqpZ :  <=>
# 84 TRANS-RXN0-576 transport of tellurite :  <=>
# 85 RXN0-11 transport of glutathione : ATP + CPD-15815 --> ADP + PROTON + Pi
# 86 TRANS-RXN0-478 selenate ABC transporter;selenate  ABC transporter : ATP + CPD-15815 --> ADP + PROTON + Pi
# 87 TRANS-RXN0-226 transport of GlcNAc-1,6-anhMurNAc-L-Ala-gamma-D-Glu-DAP-D-Ala :  <=>
# 88 TRANS-RXN0-162 ABC complex for formation and release of holoCcmE : ATP + CPD-15815 --> ADP + PROTON + Pi
# 89 ABC-5-RXN vitamin B12 ABC transporter : ATP + CPD-15815 --> ADP + PROTON + Pi
# 90 TRANS-RXN-364 CCCP efflux pump :  -->
# 91 ABC-20-RXN nickel ABC transporter : ATP + CPD-15815 --> ADP + PROTON + Pi
# 92 TRANS-RXN-349 deoxycholate:Na+ antiport :  <=>
# 93 TRANS-RXN-3 K+:H+ symporter Kup;K+ transporter TrkH;K+ transporter TrkG :  <=>
# 94 RXN0-4083 serine/threonine:Na+ symporter :  <=>
# 95 TRANS-RXN-2 K+ transporting ATPase : ATP + CPD-15815 --> ADP + PROTON + Pi
# 96 RXN0-22 guanosine:H+ antiporter :  <=>
# 97 TRANS-RXN0-573 transport of a glycerophosphodiester : ATP + CPD-15815 --> ADP + PROTON + Pi
# 98 TRANS-RXN0-453 autoinducer 2 exporter :  <=>
# 99 TRANS-RXN0-281 acetoacetate transporter :  -->
# 100 TRANS-RXN-298 ferrichrome ABC transporter : ATP + CPD-15815 --> ADP + PROTON + Pi
# 101 RXN0-4522 methionine transport : ATP + CPD-15815 --> ADP + PROTON + Pi
# 102 TRANS-RXN-167 N-acetyl-D-galactosamine PTS;N-acetylglucosamine PTS permease;N-acetyl-D-glucosamine PTS permease : Hpr-pi-phospho-L-histidines + N-acetyl-D-glucosamine --> Hpr-Histidine + N-ACETYL-D-GLUCOSAMINE-6-P
# 103 TRANS-RXN0-617 homocystine ABC transporter : ATP + CPD-15815 --> ADP + PROTON + Pi
# 104 TRANS-RXN-121 succinate:H+ symporter;transport of succinate;succinate transporter :  <=>
# 105 ABC-34-RXN transport of glycerol-3-phosphate : ATP + CPD-15815 --> ADP + PROTON + Pi
# 106 ATPSYN-RXN ATP synthase;ATP hydrolase;H+-translocating V-ATPase : ATP + CPD-15815 <=> ADP + PROTON + Pi
# 107 TRANS-RXN0-595 flavin mononucleotide (FMN) export :  -->
# 108 RXN0-18 inosine:H+ antiporter :  <=>
# 109 TRANS-RXN0-491 transport of alpha-D-galactofuranose : ATP + CPD-15815 --> ADP + PROTON + Pi
# 110 TRANS-RXN0-445 chitobiose transport;transport of N,N'-diacetyl-chitobiose :  -->
# 111 TRANS-RXN0-240 biotin transporter :  -->
# 112 ABC-9-RXN transport of ferric dicitrate : ATP + CPD-15815 --> ADP + PROTON + Pi
# 113 TRANS-RXN-355 n-hexane efflux pump :  -->
# 114 RXN0-5205 Zn2+-exporting ATPase : ATP + CPD-15815 --> ADP + PROTON + Pi
# 115 TRANS-RXN-291 diaminopimelate ABC transporter : ATP + CPD-15815 --> ADP + PROTON + Pi
# 116 TRANS-RXN-272 flavin adenine dinucleotide (FAD) export :  -->
# 117 TRANS-RXN-127 L-tartrate:succinate antiporter :  <=>
# 118 RXN0-1702 transport of ferric coprogen :  -->
# 119 RXN66-448 Sodium independent arginine transport;sodium independent arginine plasma membrane transport;L-arginine exporter :  <=>
# 120 TRANS-RXN0-505 propionate transporter :  -->
# 121 TRANS-RXN0-235 2,3-diketo-L-gulonate:Na+ symporter :  -->
# 122 TRANS-RXN0-202 methionine transport : ATP + CPD-15815 --> ADP + PROTON + Pi
# 123 ABC-7-RXN thiosulfate ABC transporter : ATP + CPD-15815 --> ADP + PROTON + Pi
# 124 ABC-26-RXN transport of proline : ATP + CPD-15815 --> ADP + PROTON + Pi
# 125 TRANS-RXN-352 deoxycholate efflux pump :  -->
# 126 TRANS-RXN-242 L-homoserine:H+ antiporter :  <=>
# 127 TRANS-RXN-178 copper P1B-ATPase;Cu transporting P-type ATPase;copper-transporting ATPase;Cu-ATPase : ATP + CPD-15815 --> ADP + PROTON + Pi
# 128 RXN0-1981 acetate:cation symporter :  <=>
# 129 TRANS-RXN0-479 selenite  ABC transporter;selenite ABC transporter : ATP + CPD-15815 --> ADP + PROTON + Pi
# 130 TRANS-RXN0-286 lipid II flippase :  -->
# 131 TRANS-RXN0-268 Transport of L-Ala-D-Glu-meso-A2pm : ATP + CPD-15815 --> ADP + PROTON + Pi
# 132 TRANS-RXN0-181 TatABCE protein export complex :  -->
# 133 TRANS-RXN-365 deoxycholate efflux pump :  -->
# 134 TRANS-RXN-283 glycine betaine ABC transporter : ATP + CPD-15815 --> ADP + PROTON + Pi
# 135 RXN0-1923 O-acetyl-L-serine exporter;export of O-acetyl-L-serine :  -->
# 136 TRANS-RXN-122A aspartate transport;L-aspartate:H+ symporter;transport of L-aspartate :  <=>
# 137 TRANS-RXN-99 choline:H+ symporter :  <=>

# %%
the_TransRxns_For_Manual_Check('../Results/transport_rxns_halo_meta.tsv')
# Out:
# Ones have been manually checked
# (140, 5)
#                                                                 2  \
# 1
# RXN0-21                                      glutathione exporter
# RXN-9615                                     ammonium transporter
# TRANS-RXN0-479  selenite ABC transporter;selenite  ABC transpo...
# ABC-70-RXN       sulfate  ABC transporter;sulfate ABC transporter
# ABC-27-RXN                                 transport of phosphate
#
#                                                 3            4    5  6
# 1
# RXN0-21         ATP + WATER --> ADP + PROTON + Pi  GLUTATHIONE  out  1
# RXN-9615                                     -->      AMMONIUM   in  1
# TRANS-RXN0-479  ATP + WATER --> ADP + PROTON + Pi     SELENITE   in  1
# ABC-70-RXN      ATP + WATER --> ADP + PROTON + Pi      SULFATE   in  1
# ABC-27-RXN      ATP + WATER --> ADP + PROTON + Pi           Pi   in  1
#
# Ones in the current model
#                                                                 2  \
# 1
# RXN-9615                                     ammonium transporter
# TRANS-RXN-214          Na(+)-translocating NADH-quinone reductase
# RXN0-21                                      glutathione exporter
# TRANS-RXN0-277  pyridine nucleotide transhydrogenase;NAD(P) tr...
# ABC-4-RXN                                  L-arginine transporter
#
#                                                                3
# 1
# RXN-9615                                                    -->
# TRANS-RXN-214   NADH + PROTON + Ubiquinones --> NAD + Ubiquinols
# RXN0-21                    ATP + CPD-15815 --> ADP + PROTON + Pi
# TRANS-RXN0-277                       NAD + NADPH <=> NADH + NADP
# ABC-4-RXN                  ATP + CPD-15815 --> ADP + PROTON + Pi
#
# Ones to be manually checked
#
#     # if the below part is not empty, then add those to ../../../ComplementaryData/transport_rxns_mannual.tsv
#     # and manually collect transported metabolites from metacyc website
#
# Empty DataFrame
# Columns: [2, 3]
# Index: []

# %%
the_TransRxns_For_Manual_Check('../Results/transport_rxns_halo_mekg.tsv')
# Out:
# Ones have been manually checked
# (140, 5)
#                                                                 2  \
# 1
# RXN0-21                                      glutathione exporter
# RXN-9615                                     ammonium transporter
# TRANS-RXN0-479  selenite ABC transporter;selenite  ABC transpo...
# ABC-70-RXN       sulfate  ABC transporter;sulfate ABC transporter
# ABC-27-RXN                                 transport of phosphate
#
#                                                 3            4    5  6
# 1
# RXN0-21         ATP + WATER --> ADP + PROTON + Pi  GLUTATHIONE  out  1
# RXN-9615                                     -->      AMMONIUM   in  1
# TRANS-RXN0-479  ATP + WATER --> ADP + PROTON + Pi     SELENITE   in  1
# ABC-70-RXN      ATP + WATER --> ADP + PROTON + Pi      SULFATE   in  1
# ABC-27-RXN      ATP + WATER --> ADP + PROTON + Pi           Pi   in  1
#
# Ones in the current model
#                                                                 2  \
# 1
# RXN-9615                                     ammonium transporter
# TRANS-RXN-214          Na(+)-translocating NADH-quinone reductase
# RXN0-21                                      glutathione exporter
# TRANS-RXN0-277  pyridine nucleotide transhydrogenase;NAD(P) tr...
# ABC-4-RXN                                  L-arginine transporter
#
#                                                                3
# 1
# RXN-9615                                                    -->
# TRANS-RXN-214   NADH + PROTON + Ubiquinones --> NAD + Ubiquinols
# RXN0-21                    ATP + CPD-15815 --> ADP + PROTON + Pi
# TRANS-RXN0-277                       NAD + NADPH <=> NADH + NADP
# ABC-4-RXN                  ATP + CPD-15815 --> ADP + PROTON + Pi
#
# Ones to be manually checked
#
#     # if the below part is not empty, then add those to ../../../ComplementaryData/transport_rxns_mannual.tsv
#     # and manually collect transported metabolites from metacyc website
#
# Empty DataFrame
# Columns: [2, 3]
# Index: []

# %%
consider_all_rxns_happend_in_cytosal(halo_mekg_nt)
consider_all_rxns_happend_in_cytosal(halo_meta_nt)

# %%
add_curated_transport_rxns(halo_meta_nt, halo_meta_t)
# Out:
# RXN0-21 ATP_c + CPD-15815_c + GLUTATHIONE_c --> ADP_c + GLUTATHIONE_p + PROTON_c + Pi_c
# RXN-9615 AMMONIUM_p --> AMMONIUM_c
# TRANS-RXN0-479 ATP_c + CPD-15815_c + SELENITE_p --> ADP_c + PROTON_c + Pi_c + SELENITE_c
# ABC-70-RXN ATP_c + CPD-15815_c + SULFATE_p --> ADP_c + PROTON_c + Pi_c + SULFATE_c
# ABC-27-RXN ATP_c + CPD-15815_c + Pi_p --> ADP_c + PROTON_c + 2.0 Pi_c
# TRANS-RXN0-286 C6_c --> C6_p
# TRANS-RXN0-268 ATP_c + CPD-15815_c + L-ALA-GAMMA-D-GLU-DAP_p --> ADP_c + L-ALA-GAMMA-D-GLU-DAP_c + PROTON_c + Pi_c
# TRANS-RXN-355 CPD-9288_c + PROTON_c --> CPD-9288_p + PROTON_p
# RXN0-11 ATP_c + CPD-15815_c + GLUTATHIONE_p --> ADP_c + GLUTATHIONE_c + PROTON_c + Pi_c
# TRANS-RXN-167 Hpr-pi-phospho-L-histidines_c + N-acetyl-D-glucosamine_p --> Hpr-Histidine_c + N-ACETYL-D-GLUCOSAMINE-6-P_c
# ABC-24-RXN ATP_c + CPD-15815_c + SPERMIDINE_p --> ADP_c + PROTON_c + Pi_c + SPERMIDINE_c
# TRANS-RXN-352 DEOXYCHOLATE_c + PROTON_c --> DEOXYCHOLATE_p + PROTON_p
# TRANS-RXN-296 ATP_c + COBINAMIDE_p + CPD-15815_c --> ADP_c + COBINAMIDE_c + PROTON_c + Pi_c
# RXN-19739 GLUTACONYL-COA_c + NA+_c + PROTON_c --> CARBON-DIOXIDE_c + CROTONYL-COA_c + NA+_p
# TRANS-RXN0-513 ATP_c + CPD-15815_c + CPD-3736_p --> ADP_c + CPD-3736_c + PROTON_c + Pi_c
# TRANS-RXN0-244 CD+2_c + PROTON_p --> CD+2_p + PROTON_c
# TRANS-RXN-42 K+_p + PROTON_c <=> K+_c + PROTON_p
# TRANS-RXN-365 DEOXYCHOLATE_c + PROTON_c --> DEOXYCHOLATE_p + PROTON_p
# TRANS-RXN-273 CPD-14545_c --> CPD-14545_p
# TRANS-RXN-127 SUC_p + TARTRATE_c <=> SUC_c + TARTRATE_p
# TRANS-RXN0-510 ATP_c + CPD-15815_c + CPD-3738_p --> ADP_c + CPD-3738_c + PROTON_c + Pi_c
# TRANS-RXN0-492 ATP_c + CPD-15815_c + CPD0-2485_p --> ADP_c + CPD0-2485_c + PROTON_c + Pi_c
# ABC-36-RXN ATP_c + CPD-15815_c + VAL_p --> ADP_c + PROTON_c + Pi_c + VAL_c
# TRANS-RXN0-447 ADENINE_p + PROTON_p <=> ADENINE_c + PROTON_c
# ABC-16-RXN ATP_c + CPD-15815_c + MALTOSE_p --> ADP_c + MALTOSE_c + PROTON_c + Pi_c
# ATPSYN-RXN ATP_c + CPD-15815_c + 3.0 PROTON_c <=> ADP_c + 4 PROTON_p + Pi_c
# TRANS-RXN-347 CPD-21015_c + NA+_p <=> CPD-21015_p + NA+_c
# RXN0-3 ATP_c + CPD-15815_c + CYS_c --> ADP_c + CYS_p + PROTON_c + Pi_c
# TRANS-RXN-312 ATP_c + CPD-15815_c + PHE_p --> ADP_c + PHE_c + PROTON_c + Pi_c
# RXN0-18 INOSINE_c + PROTON_p <=> INOSINE_p + PROTON_c
# TRANS-RXN-242 HOMO-SER_p + PROTON_c <=> HOMO-SER_c + PROTON_p
# ABC-13-RXN ATP_c + CPD-15815_c + GLT_p --> ADP_c + GLT_c + PROTON_c + Pi_c
# TRANS-RXN0-200 PROTON_c + ZN+2_p --> PROTON_p + ZN+2_c
# RXN0-5111 GLYCOLLATE_p + NA+_p <=> GLYCOLLATE_c + NA+_c
# TRANS-RXN-359 CPD0-1938_c + PROTON_c --> CPD0-1938_p + PROTON_p
# TRANS-RXN-325 CANAVANINE_c --> CANAVANINE_p
# RXN0-1702 CPD0-621_p + PROTON_c --> CPD0-621_c + PROTON_p
# TRANS-RXN0-593 ATP_c + CPD-15815_c + CYSTINE_p --> ADP_c + CYSTINE_c + PROTON_c + Pi_c
# TRANS-RXN-122A L-ASPARTATE_p + 2 PROTON_p <=> L-ASPARTATE_c + 2 PROTON_c
# TRANS-RXN0-503 ATP_c + CPD-15815_c + MALTOTRIOSE_p --> ADP_c + MALTOTRIOSE_c + PROTON_c + Pi_c
# ABC-8-RXN ATP_c + CPD-15815_c + DIPEPTIDES_p --> ADP_c + DIPEPTIDES_c + PROTON_c + Pi_c
# ABC-10-RXN ATP_c + CPD-15815_c + FERRIC-ENTEROBACTIN-COMPLEX_p --> ADP_c + FERRIC-ENTEROBACTIN-COMPLEX_c + PROTON_c + Pi_c
# TRANS-RXN0-269 VAL_p <=> VAL_c
# TRANS-RXN0-222 ATP_c + CPD-15815_c + TRANS-RXN0-222_p --> ADP_c + PROTON_c + Pi_c + TRANS-RXN0-222_c
# TRANS-RXN0-0244 PROTON_c + THR_p <=> PROTON_p + THR_c
# TRANS-RXN-356 CPD-3617_c + PROTON_c --> CPD-3617_p + PROTON_p
# TRANS-RXN-340 CPD-20921_p + PROTON_c <=> CPD-20921_c + PROTON_p
# RXN0-1981 ACET_p + NA+_p <=> ACET_c + NA+_c
# TRANS-RXN-167A GLUCOSAMINE_p + Hpr-pi-phospho-L-histidines_c --> D-GLUCOSAMINE-6-P_c + Hpr-Histidine_c
# RXN-5076 PROTON_p + XANTHINE_p <=> PROTON_c + XANTHINE_c
# ABC-25-RXN ATP_c + CPD-15815_c + PUTRESCINE_p --> ADP_c + PROTON_c + PUTRESCINE_c + Pi_c
# RXN0-4083 NA+_p + SER_p <=> NA+_c + SER_c
# TRANS-RXN-353 CPD-15417_c + PROTON_c --> CPD-15417_p + PROTON_p
# TRANS-RXN-297 ATP_c + CPD-15815_c + CPD0-621_p --> ADP_c + CPD0-621_c + PROTON_c + Pi_c
# RXN0-22 GUANOSINE_p + PROTON_c <=> GUANOSINE_c + PROTON_p
# RXN0-1923 ACETYLSERINE_c --> ACETYLSERINE_p
# TRANS-RXN-162 GLT_p + 2 PROTON_p <=> GLT_c + 2 PROTON_c
# TRANS-RXN-132 PROTON_p + URACIL_p <=> PROTON_c + URACIL_c
# RXN0-6 FE+2_p + PROTON_c <=> FE+2_c + PROTON_p
# ABC-5-RXN ATP_c + COB-I-ALAMIN_p + CPD-15815_c --> ADP_c + COB-I-ALAMIN_c + PROTON_c + Pi_c
# TRANS-RXN0-452 CPD0-889_p + PROTON_p <=> CPD0-889_c + PROTON_c
# ABC-20-RXN ATP_c + CPD-15815_c + NI+2_p --> ADP_c + NI+2_c + PROTON_c + Pi_c
# TRANS-RXN0-258 CPD0-1081_p + PROTON_p <=> CPD0-1081_c + PROTON_c
# RXN0-4522 ATP_c + CPD-15815_c + MET_p --> ADP_c + MET_c + PROTON_c + Pi_c
# TRANS-RXN-366 ATP_c + CPD-15815_c + CPD-19953_c --> ADP_c + CPD-19953_p + PROTON_c + Pi_c
# TRANS-RXN0-549 CPD0-1192_c --> CPD0-1192_p
# TRANS-RXN0-511 ATP_c + CPD-15815_c + L-Methionine-sulfoxides_p --> ADP_c + L-Methionine-sulfoxides_c + PROTON_c + Pi_c
# TRANS-RXN0-239 NITRATE_p + NITRITE_c --> NITRATE_c + NITRITE_p
# TRANS-RXN-99 CHOLINE_p + PROTON_p <=> CHOLINE_c + PROTON_c
# TRANS-RXN-40 L-ARABINOSE_p + PROTON_c <=> L-ARABINOSE_c + PROTON_p
# TRANS-RXN-363 CPD-21025_c + PROTON_c --> CPD-21025_p + PROTON_p
# TRANS-RXN-348 CPD-20890_c + NA+_p <=> CPD-20890_p + NA+_c
# TRANS-RXN-290 ATP_c + CPD-15815_c + CPD0-1564_p --> ADP_c + CPD0-1564_c + PROTON_c + Pi_c
# RXN0-1802 Long-Chain-Fatty-Acids_p --> Long-Chain-Fatty-Acids_c
# TRANS-RXN-242A CPD-15554_p + PROTON_c <=> CPD-15554_c + PROTON_p
# TRANS-RXN0-617 ATP_c + CPD-15815_c + HOMOCYSTINE_p --> ADP_c + HOMOCYSTINE_c + PROTON_c + Pi_c
# TRANS-RXN0-569 LYS_c --> LYS_p
# TRANS-RXN0-508 ATP_c + CPD-15815_c + CPD-3740_p --> ADP_c + CPD-3740_c + PROTON_c + Pi_c
# ABC-34-RXN ATP_c + CPD-15815_c + GLYCEROL-3P_p --> ADP_c + GLYCEROL-3P_c + PROTON_c + Pi_c
# RXN-8638 ATP_c + CPD-15815_c + Quaternary-Amines_p --> ADP_c + PROTON_c + Pi_c + Quaternary-Amines_c
# TRANS-RXN-360 Gentamycins_c + PROTON_c --> Gentamycins_p + PROTON_p
# RXN0-1721 CPD0-2482_p --> CPD0-2482_c
# TRANS-RXN0-595 FMN_c --> FMN_p
# TRANS-RXN0-504 ATP_c + CPD-15815_c + MALTOTETRAOSE_p --> ADP_c + MALTOTETRAOSE_c + PROTON_c + Pi_c
# ABC-9-RXN ATP_c + CPD-15815_c + FERRIC-CITRATE-COMPLEX_p --> ADP_c + FERRIC-CITRATE-COMPLEX_c + PROTON_c + Pi_c
# TRANS-RXN0-226 CPD0-1080_p + PROTON_p <=> CPD0-1080_c + PROTON_c
# TRANS-RXN0-162 ATP_c + CPD-15815_c + TRANS-RXN0-162_c --> ADP_c + PROTON_c + Pi_c + TRANS-RXN0-162_p
# TRANS-RXN-357 ENTEROBACTIN_c + PROTON_c --> ENTEROBACTIN_p + PROTON_p
# TRANS-RXN-3 K+_p + PROTON_p <=> K+_c + PROTON_c
# TRANS-RXN0-478 ATP_c + CPD-15815_c + SELENATE_p --> ADP_c + PROTON_c + Pi_c + SELENATE_c
# ABC-7-RXN ABC-7-RXN_p + ATP_c + CPD-15815_c --> ABC-7-RXN_c + ADP_c + PROTON_c + Pi_c
# ABC-26-RXN ATP_c + CPD-15815_c + PRO_p --> ADP_c + PROTON_c + PRO_c + Pi_c
# TRANS-RXN-354 CPD-21070_p + PROTON_p --> CPD-21070_c + PROTON_c
# TRANS-RXN-298 ATP_c + CPD-15815_c + CPD0-2241_p --> ADP_c + CPD0-2241_c + PROTON_c + Pi_c
# RXN0-1924 CYS_c --> CYS_p
# TRANS-RXN-194 ATP_c + CA+2_c + CPD-15815_c --> ADP_c + CA+2_p + PROTON_c + Pi_c
# TRANS-RXN-137 NITRITE_c --> NITRITE_p
# TRANS-RXN0-576 CPD-4544_p + NA+_p <=> CPD-4544_c + NA+_c
# TRANS-RXN-118 NA+_p + PRO_p <=> NA+_c + PRO_c
# TRANS-RXN0-453 TRANS-RXN0-453_p <=> TRANS-RXN0-453_c
# TRANS-RXN0-281 3-KETOBUTYRATE_p --> 3-KETOBUTYRATE_c
# TRANS-RXN-351 CPD-20940_c + PROTON_c --> CPD-20940_p + PROTON_p
# TRANS-RXN0-573 ATP_c + CPD-15815_c + Glycerophosphodiesters_p --> ADP_c + Glycerophosphodiesters_c + PROTON_c + Pi_c
# RXN66-448 ARG_p <=> ARG_c
# ABC-4-RXN ARG_p + ATP_c + CPD-15815_c --> ADP_c + ARG_c + PROTON_c + Pi_c
# ABC-19-RXN ATP_c + CPD-15815_c + CPD-3_p --> ADP_c + CPD-3_c + PROTON_c + Pi_c
# TRANS-RXN0-240 BIOTIN_p --> BIOTIN_c
# TRANS-RXN-364 CPD-7970_c + PROTON_c --> CPD-7970_p + PROTON_p
# TRANS-RXN-349 DEOXYCHOLATE_p + NA+_c <=> DEOXYCHOLATE_c + NA+_p
# TRANS-RXN-291 ATP_c + CPD-15815_c + MESO-DIAMINOPIMELATE_p --> ADP_c + MESO-DIAMINOPIMELATE_c + PROTON_c + Pi_c
# TRANS-RXN-272 FAD_c --> FAD_p
# TRANS-RXN0-491 ATP_c + CPD-15815_c + CPD0-2486_p --> ADP_c + CPD0-2486_c + PROTON_c + Pi_c
# ABC-35-RXN ATP_c + CPD-15815_c + LEU_p --> ADP_c + LEU_c + PROTON_c + Pi_c
# TRANS-RXN0-445 CHITOBIOSE_p --> CHITOBIOSE_c
# ABC-15-RXN ATP_c + CPD-15815_c + ILE_p --> ADP_c + ILE_c + PROTON_c + Pi_c
# TRANS-RXN0-235 CPD-334_p + NA+_p --> CPD-334_c + NA+_c
# TRANS-RXN0-202 ATP_c + CPD-15815_c + CPD-218_p --> ADP_c + CPD-218_c + PROTON_c + Pi_c
# TRANS-RXN-220 ATP_c + CPD-13949_c + CPD-15815_c --> ADP_c + CPD-13949_p + PROTON_c + Pi_c
# TRANS-RXN-145 WATER_p <=> WATER_c
# TRANS-RXN0-505 TRANS-RXN0-505_p --> TRANS-RXN0-505_c
# ABC-12-RXN ATP_c + CPD-15815_c + GLN_p --> ADP_c + GLN_c + PROTON_c + Pi_c
# TRANS-RXN0-181 General-Protein-Substrates_c --> General-Protein-Substrates_p
# TRANS-RXN-283 ATP_c + BETAINE_p + CPD-15815_c --> ADP_c + BETAINE_c + PROTON_c + Pi_c
# RXN0-1701 CPD0-2241_p + PROTON_c --> CPD0-2241_c + PROTON_p
# TRANS-RXN-2 ATP_c + CPD-15815_c + K+_p --> ADP_c + K+_c + PROTON_c + Pi_c
# TRANS-RXN0-592 CPD-15189_c + PROTON_c --> CPD-15189_p + PROTON_p
# TRANS-RXN0-277 NADPH_c + NAD_c + PROTON_p <=> NADH_c + NADP_c + PROTON_c
# TRANS-RXN-237 ATP_c + CPD-15815_c + Lipopolysaccharides_c --> ADP_c + Lipopolysaccharides_p + PROTON_c + Pi_c
# TRANS-RXN-214 NA+_c + NADH_c + PROTON_c + Ubiquinones_c --> NA+_p + NAD_c + Ubiquinols_c
# 3.6.3.16-RXN ATP_c + CPD-15815_c + CPD-763_c --> ADP_c + CPD-763_p + PROTON_c + Pi_c
# RXN-18028 ATP_c + CPD-15815_c + Teichoic-P-Gro-Glc_c --> ADP_c + PROTON_c + Pi_c + Teichoic-P-Gro-Glc_p
# TRANS-RXN-321 CPD-19345_c --> CPD-19345_p
# RXN0-5205 ATP_c + CPD-15815_c + ZN+2_c --> ADP_c + PROTON_c + Pi_c + ZN+2_p
# TRANS-RXN-92 CPD-8876_c + PROTON_c --> CPD-8876_p + PROTON_p
# TRANS-RXN-121 2 PROTON_p + SUC_p <=> 2 PROTON_c + SUC_c
# TRANS-RXN0-553 FUM_p + 2 PROTON_p <=> FUM_c + 2 PROTON_c
# TRANS-RXN-178 ATP_c + CPD-15815_c + CU+2_c --> ADP_c + CU+2_p + PROTON_c + Pi_c

# %%
add_curated_transport_rxns(halo_mekg_nt, halo_mekg_t)
# Out:
# RXN0-21 ATP_c + CPD-15815_c + GLUTATHIONE_c --> ADP_c + GLUTATHIONE_p + PROTON_c + Pi_c
# RXN-9615 AMMONIUM_p --> AMMONIUM_c
# TRANS-RXN0-479 ATP_c + CPD-15815_c + SELENITE_p --> ADP_c + PROTON_c + Pi_c + SELENITE_c
# ABC-70-RXN ATP_c + CPD-15815_c + SULFATE_p --> ADP_c + PROTON_c + Pi_c + SULFATE_c
# ABC-27-RXN ATP_c + CPD-15815_c + Pi_p --> ADP_c + PROTON_c + 2.0 Pi_c
# TRANS-RXN0-286 C6_c --> C6_p
# TRANS-RXN0-268 ATP_c + CPD-15815_c + L-ALA-GAMMA-D-GLU-DAP_p --> ADP_c + L-ALA-GAMMA-D-GLU-DAP_c + PROTON_c + Pi_c
# TRANS-RXN-355 CPD-9288_c + PROTON_c --> CPD-9288_p + PROTON_p
# RXN0-11 ATP_c + CPD-15815_c + GLUTATHIONE_p --> ADP_c + GLUTATHIONE_c + PROTON_c + Pi_c
# TRANS-RXN-167 Hpr-pi-phospho-L-histidines_c + N-acetyl-D-glucosamine_p --> Hpr-Histidine_c + N-ACETYL-D-GLUCOSAMINE-6-P_c
# ABC-24-RXN ATP_c + CPD-15815_c + SPERMIDINE_p --> ADP_c + PROTON_c + Pi_c + SPERMIDINE_c
# TRANS-RXN-352 DEOXYCHOLATE_c + PROTON_c --> DEOXYCHOLATE_p + PROTON_p
# TRANS-RXN-296 ATP_c + COBINAMIDE_p + CPD-15815_c --> ADP_c + COBINAMIDE_c + PROTON_c + Pi_c
# RXN-19739 GLUTACONYL-COA_c + NA+_c + PROTON_c --> CARBON-DIOXIDE_c + CROTONYL-COA_c + NA+_p
# TRANS-RXN0-513 ATP_c + CPD-15815_c + CPD-3736_p --> ADP_c + CPD-3736_c + PROTON_c + Pi_c
# TRANS-RXN0-244 CD+2_c + PROTON_p --> CD+2_p + PROTON_c
# TRANS-RXN-42 K+_p + PROTON_c <=> K+_c + PROTON_p
# TRANS-RXN-365 DEOXYCHOLATE_c + PROTON_c --> DEOXYCHOLATE_p + PROTON_p
# TRANS-RXN-273 CPD-14545_c --> CPD-14545_p
# TRANS-RXN-127 SUC_p + TARTRATE_c <=> SUC_c + TARTRATE_p
# TRANS-RXN0-510 ATP_c + CPD-15815_c + CPD-3738_p --> ADP_c + CPD-3738_c + PROTON_c + Pi_c
# TRANS-RXN0-492 ATP_c + CPD-15815_c + CPD0-2485_p --> ADP_c + CPD0-2485_c + PROTON_c + Pi_c
# ABC-36-RXN ATP_c + CPD-15815_c + VAL_p --> ADP_c + PROTON_c + Pi_c + VAL_c
# TRANS-RXN0-447 ADENINE_p + PROTON_p <=> ADENINE_c + PROTON_c
# ABC-16-RXN ATP_c + CPD-15815_c + MALTOSE_p --> ADP_c + MALTOSE_c + PROTON_c + Pi_c
# ATPSYN-RXN ATP_c + CPD-15815_c + 3.0 PROTON_c <=> ADP_c + 4 PROTON_p + Pi_c
# TRANS-RXN-347 CPD-21015_c + NA+_p <=> CPD-21015_p + NA+_c
# RXN0-3 ATP_c + CPD-15815_c + CYS_c --> ADP_c + CYS_p + PROTON_c + Pi_c
# TRANS-RXN-312 ATP_c + CPD-15815_c + PHE_p --> ADP_c + PHE_c + PROTON_c + Pi_c
# RXN0-18 INOSINE_c + PROTON_p <=> INOSINE_p + PROTON_c
# TRANS-RXN-242 HOMO-SER_p + PROTON_c <=> HOMO-SER_c + PROTON_p
# ABC-13-RXN ATP_c + CPD-15815_c + GLT_p --> ADP_c + GLT_c + PROTON_c + Pi_c
# TRANS-RXN0-200 PROTON_c + ZN+2_p --> PROTON_p + ZN+2_c
# RXN0-5111 GLYCOLLATE_p + NA+_p <=> GLYCOLLATE_c + NA+_c
# TRANS-RXN-359 CPD0-1938_c + PROTON_c --> CPD0-1938_p + PROTON_p
# TRANS-RXN-325 CANAVANINE_c --> CANAVANINE_p
# RXN0-1702 CPD0-621_p + PROTON_c --> CPD0-621_c + PROTON_p
# TRANS-RXN0-593 ATP_c + CPD-15815_c + CYSTINE_p --> ADP_c + CYSTINE_c + PROTON_c + Pi_c
# TRANS-RXN-122A L-ASPARTATE_p + 2 PROTON_p <=> L-ASPARTATE_c + 2 PROTON_c
# TRANS-RXN0-503 ATP_c + CPD-15815_c + MALTOTRIOSE_p --> ADP_c + MALTOTRIOSE_c + PROTON_c + Pi_c
# ABC-8-RXN ATP_c + CPD-15815_c + DIPEPTIDES_p --> ADP_c + DIPEPTIDES_c + PROTON_c + Pi_c
# ABC-10-RXN ATP_c + CPD-15815_c + FERRIC-ENTEROBACTIN-COMPLEX_p --> ADP_c + FERRIC-ENTEROBACTIN-COMPLEX_c + PROTON_c + Pi_c
# TRANS-RXN0-269 VAL_p <=> VAL_c
# TRANS-RXN0-222 ATP_c + CPD-15815_c + TRANS-RXN0-222_p --> ADP_c + PROTON_c + Pi_c + TRANS-RXN0-222_c
# TRANS-RXN0-0244 PROTON_c + THR_p <=> PROTON_p + THR_c
# TRANS-RXN-356 CPD-3617_c + PROTON_c --> CPD-3617_p + PROTON_p
# TRANS-RXN-340 CPD-20921_p + PROTON_c <=> CPD-20921_c + PROTON_p
# RXN0-1981 ACET_p + NA+_p <=> ACET_c + NA+_c
# TRANS-RXN-167A GLUCOSAMINE_p + Hpr-pi-phospho-L-histidines_c --> D-GLUCOSAMINE-6-P_c + Hpr-Histidine_c
# RXN-5076 PROTON_p + XANTHINE_p <=> PROTON_c + XANTHINE_c
# ABC-25-RXN ATP_c + CPD-15815_c + PUTRESCINE_p --> ADP_c + PROTON_c + PUTRESCINE_c + Pi_c
# RXN0-4083 NA+_p + SER_p <=> NA+_c + SER_c
# TRANS-RXN-353 CPD-15417_c + PROTON_c --> CPD-15417_p + PROTON_p
# TRANS-RXN-297 ATP_c + CPD-15815_c + CPD0-621_p --> ADP_c + CPD0-621_c + PROTON_c + Pi_c
# RXN0-22 GUANOSINE_p + PROTON_c <=> GUANOSINE_c + PROTON_p
# RXN0-1923 ACETYLSERINE_c --> ACETYLSERINE_p
# TRANS-RXN-162 GLT_p + 2 PROTON_p <=> GLT_c + 2 PROTON_c
# TRANS-RXN-132 PROTON_p + URACIL_p <=> PROTON_c + URACIL_c
# RXN0-6 FE+2_p + PROTON_c <=> FE+2_c + PROTON_p
# ABC-5-RXN ATP_c + COB-I-ALAMIN_p + CPD-15815_c --> ADP_c + COB-I-ALAMIN_c + PROTON_c + Pi_c
# TRANS-RXN0-452 CPD0-889_p + PROTON_p <=> CPD0-889_c + PROTON_c
# ABC-20-RXN ATP_c + CPD-15815_c + NI+2_p --> ADP_c + NI+2_c + PROTON_c + Pi_c
# TRANS-RXN0-258 CPD0-1081_p + PROTON_p <=> CPD0-1081_c + PROTON_c
# RXN0-4522 ATP_c + CPD-15815_c + MET_p --> ADP_c + MET_c + PROTON_c + Pi_c
# TRANS-RXN-366 ATP_c + CPD-15815_c + CPD-19953_c --> ADP_c + CPD-19953_p + PROTON_c + Pi_c
# TRANS-RXN0-549 CPD0-1192_c --> CPD0-1192_p
# TRANS-RXN0-511 ATP_c + CPD-15815_c + L-Methionine-sulfoxides_p --> ADP_c + L-Methionine-sulfoxides_c + PROTON_c + Pi_c
# TRANS-RXN0-239 NITRATE_p + NITRITE_c --> NITRATE_c + NITRITE_p
# TRANS-RXN-99 CHOLINE_p + PROTON_p <=> CHOLINE_c + PROTON_c
# TRANS-RXN-40 L-ARABINOSE_p + PROTON_c <=> L-ARABINOSE_c + PROTON_p
# TRANS-RXN-363 CPD-21025_c + PROTON_c --> CPD-21025_p + PROTON_p
# TRANS-RXN-348 CPD-20890_c + NA+_p <=> CPD-20890_p + NA+_c
# TRANS-RXN-290 ATP_c + CPD-15815_c + CPD0-1564_p --> ADP_c + CPD0-1564_c + PROTON_c + Pi_c
# RXN0-1802 Long-Chain-Fatty-Acids_p --> Long-Chain-Fatty-Acids_c
# TRANS-RXN-242A CPD-15554_p + PROTON_c <=> CPD-15554_c + PROTON_p
# TRANS-RXN0-617 ATP_c + CPD-15815_c + HOMOCYSTINE_p --> ADP_c + HOMOCYSTINE_c + PROTON_c + Pi_c
# TRANS-RXN0-569 LYS_c --> LYS_p
# TRANS-RXN0-508 ATP_c + CPD-15815_c + CPD-3740_p --> ADP_c + CPD-3740_c + PROTON_c + Pi_c
# ABC-34-RXN ATP_c + CPD-15815_c + GLYCEROL-3P_p --> ADP_c + GLYCEROL-3P_c + PROTON_c + Pi_c
# RXN-8638 ATP_c + CPD-15815_c + Quaternary-Amines_p --> ADP_c + PROTON_c + Pi_c + Quaternary-Amines_c
# TRANS-RXN-360 Gentamycins_c + PROTON_c --> Gentamycins_p + PROTON_p
# RXN0-1721 CPD0-2482_p --> CPD0-2482_c
# TRANS-RXN0-595 FMN_c --> FMN_p
# TRANS-RXN0-504 ATP_c + CPD-15815_c + MALTOTETRAOSE_p --> ADP_c + MALTOTETRAOSE_c + PROTON_c + Pi_c
# ABC-9-RXN ATP_c + CPD-15815_c + FERRIC-CITRATE-COMPLEX_p --> ADP_c + FERRIC-CITRATE-COMPLEX_c + PROTON_c + Pi_c
# TRANS-RXN0-226 CPD0-1080_p + PROTON_p <=> CPD0-1080_c + PROTON_c
# TRANS-RXN0-162 ATP_c + CPD-15815_c + TRANS-RXN0-162_c --> ADP_c + PROTON_c + Pi_c + TRANS-RXN0-162_p
# TRANS-RXN-357 ENTEROBACTIN_c + PROTON_c --> ENTEROBACTIN_p + PROTON_p
# TRANS-RXN-3 K+_p + PROTON_p <=> K+_c + PROTON_c
# TRANS-RXN0-478 ATP_c + CPD-15815_c + SELENATE_p --> ADP_c + PROTON_c + Pi_c + SELENATE_c
# ABC-7-RXN ABC-7-RXN_p + ATP_c + CPD-15815_c --> ABC-7-RXN_c + ADP_c + PROTON_c + Pi_c
# ABC-26-RXN ATP_c + CPD-15815_c + PRO_p --> ADP_c + PROTON_c + PRO_c + Pi_c
# TRANS-RXN-354 CPD-21070_p + PROTON_p --> CPD-21070_c + PROTON_c
# TRANS-RXN-298 ATP_c + CPD-15815_c + CPD0-2241_p --> ADP_c + CPD0-2241_c + PROTON_c + Pi_c
# RXN0-1924 CYS_c --> CYS_p
# TRANS-RXN-194 ATP_c + CA+2_c + CPD-15815_c --> ADP_c + CA+2_p + PROTON_c + Pi_c
# TRANS-RXN-137 NITRITE_c --> NITRITE_p
# TRANS-RXN0-576 CPD-4544_p + NA+_p <=> CPD-4544_c + NA+_c
# TRANS-RXN-118 NA+_p + PRO_p <=> NA+_c + PRO_c
# TRANS-RXN0-453 TRANS-RXN0-453_p <=> TRANS-RXN0-453_c
# TRANS-RXN0-281 3-KETOBUTYRATE_p --> 3-KETOBUTYRATE_c
# TRANS-RXN-351 CPD-20940_c + PROTON_c --> CPD-20940_p + PROTON_p
# TRANS-RXN0-573 ATP_c + CPD-15815_c + Glycerophosphodiesters_p --> ADP_c + Glycerophosphodiesters_c + PROTON_c + Pi_c
# RXN66-448 ARG_p <=> ARG_c
# ABC-4-RXN ARG_p + ATP_c + CPD-15815_c --> ADP_c + ARG_c + PROTON_c + Pi_c
# ABC-19-RXN ATP_c + CPD-15815_c + CPD-3_p --> ADP_c + CPD-3_c + PROTON_c + Pi_c
# TRANS-RXN0-240 BIOTIN_p --> BIOTIN_c
# TRANS-RXN-364 CPD-7970_c + PROTON_c --> CPD-7970_p + PROTON_p
# TRANS-RXN-349 DEOXYCHOLATE_p + NA+_c <=> DEOXYCHOLATE_c + NA+_p
# TRANS-RXN-291 ATP_c + CPD-15815_c + MESO-DIAMINOPIMELATE_p --> ADP_c + MESO-DIAMINOPIMELATE_c + PROTON_c + Pi_c
# TRANS-RXN-272 FAD_c --> FAD_p
# TRANS-RXN0-491 ATP_c + CPD-15815_c + CPD0-2486_p --> ADP_c + CPD0-2486_c + PROTON_c + Pi_c
# ABC-35-RXN ATP_c + CPD-15815_c + LEU_p --> ADP_c + LEU_c + PROTON_c + Pi_c
# TRANS-RXN0-445 CHITOBIOSE_p --> CHITOBIOSE_c
# ABC-15-RXN ATP_c + CPD-15815_c + ILE_p --> ADP_c + ILE_c + PROTON_c + Pi_c
# TRANS-RXN0-235 CPD-334_p + NA+_p --> CPD-334_c + NA+_c
# TRANS-RXN0-202 ATP_c + CPD-15815_c + CPD-218_p --> ADP_c + CPD-218_c + PROTON_c + Pi_c
# TRANS-RXN-220 ATP_c + CPD-13949_c + CPD-15815_c --> ADP_c + CPD-13949_p + PROTON_c + Pi_c
# TRANS-RXN-145 WATER_p <=> WATER_c
# TRANS-RXN0-505 TRANS-RXN0-505_p --> TRANS-RXN0-505_c
# ABC-12-RXN ATP_c + CPD-15815_c + GLN_p --> ADP_c + GLN_c + PROTON_c + Pi_c
# TRANS-RXN0-181 General-Protein-Substrates_c --> General-Protein-Substrates_p
# TRANS-RXN-283 ATP_c + BETAINE_p + CPD-15815_c --> ADP_c + BETAINE_c + PROTON_c + Pi_c
# RXN0-1701 CPD0-2241_p + PROTON_c --> CPD0-2241_c + PROTON_p
# TRANS-RXN-2 ATP_c + CPD-15815_c + K+_p --> ADP_c + K+_c + PROTON_c + Pi_c
# TRANS-RXN0-592 CPD-15189_c + PROTON_c --> CPD-15189_p + PROTON_p
# TRANS-RXN0-277 NADPH_c + NAD_c + PROTON_p <=> NADH_c + NADP_c + PROTON_c
# TRANS-RXN-237 ATP_c + CPD-15815_c + Lipopolysaccharides_c --> ADP_c + Lipopolysaccharides_p + PROTON_c + Pi_c
# TRANS-RXN-214 NA+_c + NADH_c + PROTON_c + Ubiquinones_c --> NA+_p + NAD_c + Ubiquinols_c
# 3.6.3.16-RXN ATP_c + CPD-15815_c + CPD-763_c --> ADP_c + CPD-763_p + PROTON_c + Pi_c
# RXN-18028 ATP_c + CPD-15815_c + Teichoic-P-Gro-Glc_c --> ADP_c + PROTON_c + Pi_c + Teichoic-P-Gro-Glc_p
# TRANS-RXN-321 CPD-19345_c --> CPD-19345_p
# RXN0-5205 ATP_c + CPD-15815_c + ZN+2_c --> ADP_c + PROTON_c + Pi_c + ZN+2_p
# TRANS-RXN-92 CPD-8876_c + PROTON_c --> CPD-8876_p + PROTON_p
# TRANS-RXN-121 2 PROTON_p + SUC_p <=> 2 PROTON_c + SUC_c
# TRANS-RXN0-553 FUM_p + 2 PROTON_p <=> FUM_c + 2 PROTON_c
# TRANS-RXN-178 ATP_c + CPD-15815_c + CU+2_c --> ADP_c + CU+2_p + PROTON_c + Pi_c

# %%
do_some_manual_curations(halo_meta_nt)
# Out:
# CD+2_c + PROTON_p --> CD+2_p + PROTON_c
# CD+2_c + PROTON_p --> CD+2_p + PROTON_c
# PROTON_c + ZN+2_p --> PROTON_p + ZN+2_c
# PROTON_c + ZN+2_p --> PROTON_p + ZN+2_c
# NADPH_c + NAD_c + PROTON_p <=> NADH_c + NADP_c + PROTON_c
# NADH_c + NADP_c + PROTON_p --> NADPH_c + NAD_c + PROTON_c

# %%
do_some_manual_curations(halo_mekg_nt)
# Out:
# CD+2_c + PROTON_p --> CD+2_p + PROTON_c
# CD+2_c + PROTON_p --> CD+2_p + PROTON_c
# PROTON_c + ZN+2_p --> PROTON_p + ZN+2_c
# PROTON_c + ZN+2_p --> PROTON_p + ZN+2_c
# NADPH_c + NAD_c + PROTON_p <=> NADH_c + NADP_c + PROTON_c
# NADH_c + NADP_c + PROTON_p --> NADPH_c + NAD_c + PROTON_c

# %%
report_model_status(halo_meta)
# Out:
# Number of reactions: 1321
# Number of metabolits: 1553
# Number of compartments: 1 {'s': ''}
# Number of genes: 1252
# Number of missing genes: 0
# Number of reactions with missing genes: 0

# %%
report_model_status(halo_meta_nt)
# Out:
# Number of reactions: 1321
# Number of metabolits: 1676
# Number of compartments: 2 {'c': '', 'p': ''}
# Number of genes: 1252
# Number of missing genes: 0
# Number of reactions with missing genes: 0

# %%
report_model_status(halo_mekg)
# Out:
# Number of reactions: 2239
# Number of metabolits: 2528
# Number of compartments: 1 {'s': ''}
# Number of genes: 1326
# Number of missing genes: 0
# Number of reactions with missing genes: 0

# %%
report_model_status(halo_mekg_nt)
# Out:
# Number of reactions: 2239
# Number of metabolits: 2651
# Number of compartments: 2 {'c': '', 'p': ''}
# Number of genes: 1326
# Number of missing genes: 0
# Number of reactions with missing genes: 0

# %% [markdown]
# ## Save model

# %%
pickle.dump(refresh_model(halo_meta_nt),open('../Results/halo_metacycmodel_100_curated_compart.pkl','wb'))
# Out:
# Number of reactions: 1321
# Number of metabolits: 1676
# Number of compartments: 2 {'c': '', 'p': ''}
# Number of genes: 1252
# Number of missing genes: 0
# Number of reactions with missing genes: 0

# %%
pickle.dump(refresh_model(halo_mekg_nt),open('../Results/halo_metacyc_kegg_curated_compart.pkl','wb'))
# Out:
# Number of reactions: 2239
# Number of metabolits: 2651
# Number of compartments: 2 {'c': '', 'p': ''}
# Number of genes: 1326
# Number of missing genes: 0
# Number of reactions with missing genes: 0
