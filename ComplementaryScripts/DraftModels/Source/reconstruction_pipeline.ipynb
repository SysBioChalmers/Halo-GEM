# %% [markdown]
# # Reconstruction of HaloGEM

# %%
import cobra
import pandas as pd
import xlrd
import time
import os
from Bio import SeqIO
from scipy.io import loadmat
import re
import matplotlib.pyplot as plt
import numpy as np
import urllib

# %% [markdown]
# ## Create draft model from template iML1515
# * 1. use Bi-directional Best Hit to identify the ortholog pairs between halomonas and E coli
# * 2. get all reactions associated with all these genes
# * 3. For those reactions with missing genes in the gr rule, try to find homologes in _H.TD01_ based on the same identity and coverage thresholds (Not BBH). The coverage threshold used in this study is 45%
# * 4. resolve gr rules.

# %%
def load_ecoli_model(mat_file,sbml_file):
    # iJO1366: load mat file: containssubsystem information. while sbml doesn't
    # mat file doesn't contain annotation field for reaction and metabolites. smbl does
    # 
    # add subsystem information into sbml model
    # 
    mat_model = cobra.io.load_matlab_model(mat_file)
    sbml_model = cobra.io.read_sbml_model(sbml_file)
    
    for rxn in mat_model.reactions:
        rxn_xml = sbml_model.reactions.get_by_id(rxn.id)
        rxn_xml.subsystem = rxn.subsystem
    
    return sbml_model

# %% [markdown]
# #### Download genes in template model based on uniprot ids

# %%
def retrive_from_uniprot(uniprot_id):
    # get fasta content for given uniprot_id, return as string format
    url = 'https://www.uniprot.org/uniprot/{0}.fasta'.format(uniprot_id)
    response = urllib.request.urlopen(url)
    rec = response.read()
    return rec

# %%
def download_genes(model,outname):
    # 1. load ids that have been done
    done_ids = [line.split('|')[1] for line in open(outname) if line.startswith('>')]
    
    fhand = open(outname,'a')
    for g in model.genes:
        uniprot_id = g.annotation.get('uniprot')
        if uniprot_id is None: 
            print(g.id,g.name,g.annotation)
            continue
        if uniprot_id in done_ids: continue
            
        try:
            rec = retrive_from_uniprot(uniprot_id)
            fhand.write(str(rec)[2:-1].replace('\\n','\n'))
        except: print('Failed to retrive sequence for',uniprot_id)

    fhand.close()

# %%
def update_fasta_format(model,fastafile):
    # Replace the uniprot gene ids in fastafile with gene ids in the model
    
    if '.fasta' in fastafile: outname = fastafile.replace('.fasta','_formated.fasta')
    elif '.fa' in fastafile: outname = fastafile.replace('.fa','_formated.fasta')
    else: outname = fastafile + '_formated.fasta'
    fhand = open(outname,'w')
    
    # load uniprotid-geneid
    uni2gene = dict()
    for gene in model.genes:
        uni = gene.annotation.get('uniprot')
        if uni is not None: uni2gene[uni] = gene.id
    
    for rec in SeqIO.parse(fastafile,'fasta'):
        uni = rec.id.split('|')[1]
        fhand.write('>{0}\n{1}\n'.format(uni2gene[uni],rec.seq))
    fhand.close()

# %% [markdown]
# #### Perform blastp to identify BBH

# %%
def add_coverage(combined_fasta,blast_results):
    # combined_fasta: combined fasta file, which contains all sequnces from both query and target proteome.
    # blast_results: tsv file produced by blastp
    # 
    # Output: add a new column: coverage at the end of the blast_results.
    # Coverage is caculated as: length of aligned query sequence/length of query sequence * 100
    # 
    
    # Load sequence lenght
    Lenghs = dict()
    for rec in SeqIO.parse(combined_fasta,'fasta'): Lenghs[rec.id] = len(rec.seq)
    
    
    # calculate coverage
    outfile = blast_results.replace('.tab','_cov.tab')
    if outfile == blast_results: outfile += '_cov.tab'
    
    fhand = open(outfile,'w')
    for line in open(blast_results):
        cont = line.split()
        aln_lengh = float(cont[7])-float(cont[6])
        cov = aln_lengh/Lenghs[cont[0]]*100
        fhand.write(line.strip()+'\t{0}\n'.format(cov))
    fhand.close()
    
    # replace the orginal blast results file with the new one.
    os.system('mv {0} {1}'.format(outfile,blast_results))

# %%
def do_blast(query_fasta,target_fasta):
    # query_fasta: fasta file for the organsims to be modelled
    # target_fasta: fasata file that contains enzyme sequences in the template model
    
    # combine two fasta files, do blast. Use default evalue. The blast results will be filetered based on evalue
    # in the BBH extraction step
    
    # build combined fasta file for blast
    fhand = open('input.fa','w')
    for rec in SeqIO.parse(query_fasta,'fasta'):
        fhand.write('>query|{0}\n{1}\n'.format(rec.id,rec.seq))
    
    for rec in SeqIO.parse(target_fasta,'fasta'):
        fhand.write('>target|{0}\n{1}\n'.format(rec.id,rec.seq))
    
    fhand.close()
    
    blast_cmd = '''mkdir blast_tmps
    mv input.fa blast_tmps
    makeblastdb -dbtype prot -in blast_tmps/input.fa  -out blast_tmps/DB
    blastp -query blast_tmps/input.fa -db blast_tmps/DB -outfmt 6  -max_target_seqs 500 -max_hsps 1  -num_threads 1 -out ../Results/bidirectional_blast.tab
    '''
    os.system(blast_cmd)
    add_coverage('blast_tmps/input.fa','../Results/bidirectional_blast.tab')
    os.system('rm -r blast_tmps')

# %%
def extract_BBHs(blastfile,BBH_evalue,report=False,coverage=45):
    # BBH_evalue: like 1e-10
    # report: if True, print out the nubmer of BBHs
    # coverage: the lower bound of query coverage to determine a true hit. from 0-100
    # 
    
    target_query = dict()
    query_target = dict()
    for line in open(blastfile):
        cont = line.split()
        evalue = float(cont[10])
        cov = float(cont[12])
        # filter based on evalue and coverage
        if evalue > BBH_evalue: continue
        if cov < coverage: continue
        
        if cont[0].startswith('target|') and cont[1].startswith('query|'):
            target_gene = cont[0].split('|')[1]
            query_gene = cont[1].split('|')[1]
            if target_query.get(target_gene,(None,1000))[1]>evalue: target_query[target_gene] = (query_gene,evalue)
        elif cont[0].startswith('query|') and cont[1].startswith('target|'):
            target_gene = cont[1].split('|')[1]
            query_gene = cont[0].split('|')[1]
            if query_target.get(query_gene,(None,1000))[1]>evalue: query_target[query_gene] = (target_gene,evalue)
        else: None

    # 3. find BBH, the overlaped gene pairs
    BBH = list()
    for target_gene, (query_gene,evalue) in target_query.items():
        if query_target.get(query_gene,(None,1000))[0] == target_gene: BBH.append((query_gene,target_gene))
    
    if report:
        print('Number of homologs for query genes (evalue = {0}):'.format(BBH_evalue),len(query_target))
        print('Number of homologs for target genes (evalue = {0}):'.format(BBH_evalue),len(target_query))
        print('Number of BBHs (evalue = {0}):'.format(BBH_evalue),len(BBH))
    return BBH

# %% [markdown]
# #### Get all reactions associated with all genes in BBH

# %%
def get_all_rxns_in_BBH(template_model, BBHs):
    # model file: template model file
    # BBH, best bidirectional hit

    # get all reactions
    candidate_rxn_ids = list()
    candidate_rxns = list()
    for query_gene,target_gene in BBHs:
        gene = template_model.genes.get_by_id(target_gene)
        for rxn in gene.reactions:
            if rxn.id not in candidate_rxn_ids: 
                candidate_rxn_ids.append(rxn.id)
                candidate_rxns.append(rxn)
    print('Number of candiate reactions:',len(candidate_rxn_ids))
    
    return candidate_rxns

# %% [markdown]
# #### Update gene-reaction rules

# %%
def parse_gr(gr):
    # return a list of genes in gr rule
    genes = list(set([item for item in gr.replace('(','').replace(')','').split() if item not in ['and','or']]))
    genes.sort()
    return genes

# %%
def parse_gr_parts(gr):
    if ' and ' in gr and ' or ' not in gr: gene_parts = ['( {0} )'.format(gr)]
    else:
        complexes = re.findall('(\(.*?\))',gr)
        gr1 = gr
        for i in range(len(complexes)):
            gr1 = gr1.replace(complexes[i],'comp_{0}'.format(i))
        gene_parts = parse_gr(gr1)

        for i in range(len(gene_parts)):
            if 'comp_' in gene_parts[i]: gene_parts[i] = complexes[int(gene_parts[i].split('_')[1])]
    return list(set(gene_parts))

# %%
def missing_type(gene_part):
    # determin if a gene/coplex is totally, partly missing or complete
    assert ' or ' not in gene_part
    genes = parse_gr(gene_part)
    missing_parts = re.findall('_missing',gene_part)
    
    if len(missing_parts) == 0: tpe = 'complete' # complete
    elif len(missing_parts) == len(genes): tpe = 'missing'
    else: tpe = 'partial'
    return tpe

# %%
def remove_repeated_gene_in_and(gene_part):
    # for case: A and A
    assert ' or ' not in gene_part
    genes = parse_gr(gene_part)
    
    new_part = ''
    for gene in genes: new_part += gene + ' and '
    new_part = new_part[:-5]
    
    # in case the final gr rule is (A and B), remove parathesis
    if len(genes) > 1: new_part = '( {0} )'.format(new_part) 
    return new_part

# %%
def remove_repeated_gene_parts(gr):
    gene_parts = parse_gr_parts(gr)
    
    # remove repeated genes in each part 
    new_gene_parts = list()
    for gene_part in gene_parts:
        new_gene_part = remove_repeated_gene_in_and(gene_part)
        if new_gene_part not in new_gene_parts: new_gene_parts.append(new_gene_part)
    
    new_gr = ''
    for gene_part in new_gene_parts: 
        new_gr += gene_part + ' or '
    new_gr = new_gr[:-4]
    
    # in case the final gr rule is (A and B), remove parathesis
    if len(new_gene_parts) == 1 and '(' in new_gr: new_gr = new_gr[1:-1].strip()
    return new_gr

# %%
def update_and_or_case(gr):
    genes1 = parse_gr_parts(gr)
    tpes = list()
    for g in genes1: tpes.append(missing_type(g))

    # case 1: if one of parts is complete, remove all parts with are missing or partial
    if 'complete' in tpes:
        new_gr = ''
        for i in range(len(genes1)):
            if tpes[i] == 'complete': new_gr += genes1[i] + ' or '
    # case 2: if none of parts is complete, only remove those ones that are missing
    else:
        new_gr = ''
        for i in range(len(genes1)):
            if tpes[i] != 'missing': new_gr += genes1[i] + ' or '
    new_gr = new_gr[:-4]
    
    # in case the final gr rule is (A and B), remove parathesis
    if 'or' not in new_gr and '(' in new_gr: new_gr = new_gr[1:-1].strip()
    
    new_gr = remove_repeated_gene_parts(new_gr)
    return new_gr

# %%
def update_gr(gr,BBHs):
    # replace the targetli gene ids in gr rule with the ones in querymonas based on BBH. For those targetli genes
    # wihout BBH in querymonas, add a tag '_missing' at the end of the gene id
    
    target2query_map = dict()
    for query_gene,target_gene in BBHs: target2query_map[target_gene] = query_gene
    
    genes = parse_gr(gr)
    new_gr = gr
    for gene in genes:
        query_gene = target2query_map.get(gene)
        if query_gene is None: query_gene = gene+'_missing'
        new_gr = new_gr.replace(gene,query_gene)
    
    # refine new gr rule. 
     
    # case 1: if 'missing' not in gr rule, do not need to update
    if '_missing' not in new_gr: refined_gr = new_gr
    
    # case 2: only 'or' relationships are in gr rule, remove all genes with '_missing' tag
    elif ' and ' not in new_gr: 
        new_genes = [item for item in parse_gr(new_gr) if '_missing' not in item]
        refined_gr = ''
        for g in new_genes: refined_gr += g + ' or '
        refined_gr = refined_gr[:-4]
    
    # case 3: if 'or' not in gr rule, keep missing genes
    elif 'or' not in new_gr: refined_gr = new_gr
    
    # case 4: if (A and B) or (C and D_missing) or E. In such or structure, if one of the gene/gene complex is 
    #         complete, then remove all others with missing gene(s). if all parts are incompelte, only removes 
    #         those part which are totally missing.
    elif 'and' in new_gr and 'or' in new_gr: refined_gr = update_and_or_case(new_gr)

    # Ohter cases: export to a txt file and manully edit
    else:  refined_gr = new_gr
    return refined_gr

# %%
def report_model_status(model):
    print('Number of reactions:',len(model.reactions))
    print('Number of metabolits:',len(model.metabolites))
    print('Number of compartments:',len(model.compartments))
    k = 0
    for gene in model.genes:
        if 'missing' in gene.id: k += 1
    print('Number of genes:',len(model.genes))
    print('Number of missing genes:',k)
    
    k = 0
    for rxn in model.reactions:
        if '_missing' in rxn.gene_reaction_rule: k += 1
    print('Number of reactions with missing genes:',k)

# %%
def build_model_from_template(candidate_rxns,BBHs,report=False):
    rxns_to_add = list()
    for rxn in candidate_rxns:
        new_gr = update_gr(rxn.gene_reaction_rule,BBHs)
        new_rxn = rxn.copy()
        new_rxn.gene_reaction_rule = new_gr
        rxns_to_add.append(new_rxn)
    model_from_template = cobra.Model('model_from_template')
    model_from_template.add_reactions(rxns_to_add)
    if report: report_model_status(model_from_template)
    return model_from_template

# %%
def update_missing_genes(model,homolog_evalue,report=False,coverage=45):
    # homolog_evalue: evalue used in blast to infer homology relationships
    # model: tmeplate model from BBH, which in most cases contains missing genes in gene-reaction rules
    
    # load best hit based on homolog_evalue
    best_hits = dict()
    # best_hits = {eco_gene_id:(halo_gene,evalue)}
    for line in open('../Results/bidirectional_blast.tab'):
        cont = line.split()
        evalue = float(cont[10])
        cov = float(cont[12])
        
        # filter hits based on evalue and coverage
        if evalue > homolog_evalue: continue
        if cov < coverage: continue
        
        if line.startswith('target|') and cont[1].startswith('query'):
            target = cont[0].split('|')[1]
            query = cont[1].split('|')[1]
            best_hit, best_evalue = best_hits.get(target,(None,0))
            if best_hit is None or best_evalue > evalue: best_hits[target] = (query,evalue)
    
    # update missing genes in the model. Replace the missing genes with homologs found in above step
    
    updated_rxns = list()
    for rxn in model.reactions:
        rxn_copy = rxn.copy()
        gr = rxn_copy.gene_reaction_rule

        if '_missing' in gr:
            genes = parse_gr(gr)
            for gene in genes:
                if '_missing' in gene: 
                    homolog = best_hits.get(gene.replace('_missing',''),(None,None))[0]
                    if homolog is not None: gr = gr.replace(gene,homolog)
        
        gr = remove_repeated_gene_parts(gr)
        gr = update_and_or_case(gr)
        rxn_copy.gene_reaction_rule = gr

        updated_rxns.append(rxn_copy)
    
    # create a new model
    new_model = cobra.Model('model_from_template')
    new_model.add_reactions(updated_rxns)
    if report: report_model_status(new_model)
    return new_model

# %%
def remove_rxns_with_missing_genes(model,report=True):
    rxns = list()
    for rxn in model.reactions:
        if '_missing' in rxn.gene_reaction_rule: continue
        rxns.append(rxn)
    new_model = cobra.Model('model_from_template')
    new_model.add_reactions(rxns)
    if report: report_model_status(new_model)
    return new_model

# %% [markdown]
# ### Run pipeline for reconstruction of draft model from template model

# %%
# template_model = cobra.io.read_sbml_model('../Dataset/iJO1366.xml')
template_model = load_ecoli_model('../../../ComplementaryData/iML1515.mat',
                                  '../../../ComplementaryData/iML1515.xml')
# Out:
# Using license file /Users/gangl/gurobi.lic
# Academic license - for non-commercial use only

# %%
# download enzyme sequences in the template model
# download_genes(template_model,outname='../../../ComplementaryData/orf_iML1515.fasta')
# update_fasta_format(template_model,'../../../ComplementaryData/orf_iML1515.fasta')

# %%
# blast
#do_blast('../../../ComplementaryData/protein_sequences_v2.0.fasta',
#         '../../../ComplementaryData/orf_iML1515_formated.fasta')

# %%
# BBH, try different evalues
evalues =  np.arange(0,110,10,dtype=float)
BBH_nums = list()
for evalue in evalues:
    BBH = extract_BBHs('../Results/bidirectional_blast.tab',10**(-evalue))
    BBH_nums.append(len(BBH))
plt.figure(figsize=(4,3))
plt.plot(evalues,BBH_nums)
plt.xlabel('-log$_{10}$(evalue)')
plt.ylabel('Number of BBHs')
plt.tight_layout()

# %%
BBHs = extract_BBHs('../Results/bidirectional_blast.tab',1e-20,True)
# Out:
# Number of homologs for query genes (evalue = 1e-20): 1034
# Number of homologs for target genes (evalue = 1e-20): 944
# Number of BBHs (evalue = 1e-20): 718

# %%
# Build first template model
candidate_rxns = get_all_rxns_in_BBH(template_model, BBHs)
# Out:
# Number of candiate reactions: 1235

# %%
model_from_template = build_model_from_template(candidate_rxns,BBHs,True)
# Out:
# Number of reactions: 1235
# Number of metabolits: 1208
# Number of compartments: 3
# Number of genes: 857
# Number of missing genes: 144
# Number of reactions with missing genes: 136

# %%
# test different evalues
evalues =  np.arange(0,110,10,dtype=float)
missing_genes = list()
rxns_with_missing_genes = list()
for evalue in evalues:
    model_from_template2 = update_missing_genes(model_from_template,10**(-evalue))
    missing_genes.append(len([gene for gene in model_from_template2.genes if 'missing' in gene.id]))
    rxns_with_missing_genes.append(len([rxn for rxn in model_from_template2.reactions if 'missing' in rxn.gene_reaction_rule]))
plt.figure(figsize=(4,3))
plt.plot(evalues,missing_genes,label='missing genes')
plt.plot(evalues,rxns_with_missing_genes,label='rxns with missing genes')
plt.xlabel('-log$_{10}$(evalue)')
plt.ylabel('Number of missing genes')
plt.legend()
plt.tight_layout()
plt.show()

# %%
model_from_template2 = update_missing_genes(model_from_template,1e-20,True)
# Out:
# Number of reactions: 1235
# Number of metabolits: 1208
# Number of compartments: 3
# Number of genes: 825
# Number of missing genes: 96
# Number of reactions with missing genes: 116

# %%
k = 0
for rxn in model_from_template2.reactions:
    meta_id = rxn.annotation.get('biocyc')
    if meta_id is not None:
        k += 1
print('Number of reactions with MetaCyc id:',k,'/',len(model_from_template2.reactions))
# Out:
# Number of reactions with MetaCyc id: 541 / 1235

# %%
and_or_rxns = 0
rxns_with_missing_genes = 0
for rxn in model_from_template2.reactions:
    gr = rxn.gene_reaction_rule
    if ' and ' in gr and ' or ' in gr: 
        and_or_rxns += 1
    if '_missing' in gr: rxns_with_missing_genes += 1
        
print('and or rxns: {0}/{1}'.format(and_or_rxns,len(model_from_template2.reactions)))
print('reactions with missing genes: {0}/{1}'.format(rxns_with_missing_genes,len(model_from_template2.reactions)))
# Out:
# and or rxns: 28/1235
# reactions with missing genes: 116/1235

# %%
# remove reactions with missing genes from the draft model
model_from_template3 = remove_rxns_with_missing_genes(model_from_template2)
# Out:
# Number of reactions: 1119
# Number of metabolits: 1099
# Number of compartments: 3
# Number of genes: 662
# Number of missing genes: 0
# Number of reactions with missing genes: 0

# %%
cobra.io.save_json_model(model_from_template2,
                        '../Results/halo_iML1515_template_with_missing_genes.json')
cobra.io.save_json_model(model_from_template3,
                    '../Results/halo_iML1515_template_without_missing_genes.json')

# %% [markdown]
# ## All models and templates we have now
# * draft model reconstructed from MetaCyc by RAVEN
# * draft model reconstructed from KEGG by RAVEN
# * draft model reconstructed from template iML1515<br>
#
# <br>Next step, we are going to merge the model from MetaCyc and iML1515. We decided not using the draft model from KEGG due to following reasons:
# * 1. MetaCyc contains experimentally elucidated pathways only;, while KEGG contains ortholog groups based annotations
# * 2. The reactions from MetaCyc is charge balanced

# %%
halo_meta = '../Results/halo_metacycmodel_100.mat'
halo_kegg = '../Results/halo_keggmodel_50.mat'
halo_iJO = '../Results/halo_iML1515_template_without_missing_genes.json'
ecoli_sbml = '../../../ComplementaryData/iML1515.xml'
ecoli_mat = '../../../ComplementaryData/iML1515.mat'

# %%
def load_metacyc_mat(model_file):
    # model_file: a mat file of the model. This model is the model that is reconstructed from MetaCyc with RAVEN.
    # return a dictionary, with filed name as key, field values as value
    # like data['id'] = 'metacycmodel'
    #
    
    ###### 
    # load mat model with cobrapy
    model = cobra.io.load_matlab_model(model_file)
    
    
    ###### 
    # load mnx of metabolites
    meta2mnx = dict()
    dfmnx = pd.read_csv('../../../ComplementaryData/MNX2metacyc.tsv',index_col=1,sep='\t')

    for ind in dfmnx.index:meta2mnx[ind] = meta2mnx.get(ind,[]) + [dfmnx.loc[ind,'MNX']]
    
    
    ######
    # load annotation fields
    data = dict()
    
    mat = mat = loadmat(model_file)
    meta_vars = {"__globals__", "__header__", "__version__"}
    for item in mat.keys(): 
        if item not in meta_vars: model_id = item
    
    # field names
    names = mat[model_id].dtype.names
    
    # save data into a dictionary
    for i,item in enumerate(mat[model_id][0][0]):
        if names[i] in ['rxns','rxnNames','eccodes','rxnReferences','mets','metNames','metFormulas','inchis']:
            data[names[i]] = [i[0][0] if len(i[0])!=0 else '' for i in item]
        
        elif names[i] in ['subSystems']:
            lst = []
            for sub_item in item:
                try: lst.append([k[0] for k in sub_item[0][0]])
                except: lst.append([])
            data[names[i]] = lst
        elif names[i] in ['rxnMiriams','metMiriams']:
            lst = []
            for sub_item in item:
                anno = dict()
                try:
                    sub_item = sub_item[0][0][0]
                    for j in range(len(sub_item['name'])):
                        name = sub_item['name'][j][0][0]
                        value = sub_item['value'][j][0][0]
                        anno[name] = str(value)
                except:pass
                lst.append(anno)
            data[names[i]] = lst
        elif names[i] in ['rxnConfidenceScores','metCharges']:
            data[names[i]] = [k[0] for k in item]
        else: pass
    
    print('Loaded fields:',data.keys())
    
    ######
    # there are some metabolites formula cannot be correctly parsed by cobrapy. like ZN1 from RAVEN, which will
    # be treated as Z1N1. Most of such metabolites are ions
    for i,item in enumerate(data['metFormulas']):
        for element in ['ZN','MN','CU','MG','FE','CL','BR','AS','CA','CD','MO','TE','SE','NA']: 
            if element in item: item = item.replace(element,element.lower().title())
            data['metFormulas'][i] = item
    
    ######
    # assign annotation to the cobrapy model
    ## 1. assign rxn annotation and reaction subsystem
    
    for i in range(len(data['rxns'])):
        rxn_id = data['rxns'][i]
        anno = data['rxnMiriams'][i]
        
        # ec number
        ec = data['eccodes'][i]
        ec = ec.replace('ec-code/','')

        if len(ec) == 0: pass
        elif len(ec.split(';')) == 1: anno['ec-code'] = ec
        else: anno['ec-code'] = ec.split(';')
        
        # metacyc id
        anno['biocyc'] = 'META:'+rxn_id
        
        rxn = model.reactions.get_by_id(rxn_id)
        rxn.annotation = anno
        
        # assign reaction subsystem
        subss = ''
        for item in data['subSystems'][i]: 
            subss += item +';'
        if subss.endswith(';'): subss = subss[:-1]
        rxn.subsystem = subss
    
    ## assign metabolites annotation
    for i in range(len(data['mets'])):
        met_id = data['mets'][i]
        anno = data['metMiriams'][i]
        
        # assign metacyc id
        anno['biocyc'] = 'META:'+met_id
        
        # assign mnx id
        mnx_id = meta2mnx.get(met_id)
        if mnx_id is not None: anno['metanetx.chemical'] = mnx_id
        
        met = model.metabolites.get_by_id(met_id)
        met.annotation = anno
        
        # assign charge
        met.charge = data['metCharges'][i]
        
        # assign formula
        met.formula = data['metFormulas'][i]

    return model

# %%
halo_meta = load_metacyc_mat(halo_meta)
halo_kegg = cobra.io.load_matlab_model(halo_kegg)
halo_iJO = cobra.io.load_json_model(halo_iJO)
eco = load_ecoli_model(ecoli_mat,ecoli_sbml)
# Out:
# Using license file /Users/gangl/gurobi.lic
# Academic license - for non-commercial use only
# Loaded fields: dict_keys(['rxns', 'rxnNames', 'eccodes', 'subSystems', 'rxnMiriams', 'rxnReferences', 'rxnConfidenceScores', 'mets', 'metNames', 'metFormulas', 'metCharges', 'inchis', 'metMiriams'])

# %% [markdown]
# for rxn in halo_iJO.reactions: print(rxn.annotation)

# %%
halo_meta.solver = 'gurobi'

# %%
def print_keggrxn(rxn):
    eq = rxn.reaction
    for met in rxn.metabolites:
        eq = eq.replace(met.id,met.name)
    print('KEGG:',eq)

# %%
def report_model_status(model):
    print('Number of reactions:',len(model.reactions))
    print('Number of metabolits:',len(model.metabolites))
    print('Number of compartments:',len(model.compartments))
    k = 0
    for gene in model.genes:
        if 'missing' in gene.id: k += 1
    print('Number of genes:',len(model.genes))
    print('Number of missing genes:',k)
    
    k = 0
    for rxn in model.reactions:
        if '_missing' in rxn.gene_reaction_rule: k += 1
    print('Number of reactions with missing genes:',k)

# %%
report_model_status(halo_kegg)
# Out:
# Number of reactions: 1462
# Number of metabolits: 1639
# Number of compartments: 1
# Number of genes: 852
# Number of missing genes: 0
# Number of reactions with missing genes: 0

# %%
report_model_status(halo_meta)
# Out:
# Number of reactions: 1271
# Number of metabolits: 1520
# Number of compartments: 1
# Number of genes: 1230
# Number of missing genes: 0
# Number of reactions with missing genes: 0

# %%
report_model_status(halo_iJO)
# Out:
# Number of reactions: 1119
# Number of metabolits: 1099
# Number of compartments: 3
# Number of genes: 662
# Number of missing genes: 0
# Number of reactions with missing genes: 0

# %% [markdown]
# ##  Check all metabolites ends with -GLU-N. Re-associate these metabolites to non-GLU-N format
# We identified that some metabolites are in the form of -GLU-N(poly-glutamine). After carefully check the MetaCyc website and cross-referenced to KEGG database, N in those metabolites should be 0. Then we replaced those ones in -GLU-N format with non-GLU-N format.

# %%
# load all metacyc-kegg reaction pair
dfrxnpair = pd.read_csv('../../../ComplementaryData/metacyc2keggrxns.tsv',sep='\t',index_col=0)
print(dfrxnpair.shape,dfrxnpair.columns)
# Out:
# (5747, 1) Index(['kegg'], dtype='object')

# %%
# load metacyc-kegg metabolites pairs
dfmetpair = pd.read_csv('../../../ComplementaryData/metaCycMets_KEGG_pair.tsv',sep='\t',index_col=1)
print(dfmetpair.shape,dfmetpair.columns)
# Out:
# (5401, 1) Index(['metacyc'], dtype='object')

# %%
# For each of metabolites that endswith '-GLU-N', find one reaction that are from metacyc model 
# which has been associated with a kegg reaction
for met in halo_meta.metabolites:
    if met.id.upper().endswith('-GLU-N'): 
        print(met.id)
        for rxn in met.reactions:
            try: 
                kegg_id = dfrxnpair.loc[rxn.id,'kegg']
                kegg_rxn = halo_kegg.reactions.get_by_id(kegg_id)
                break
            except: continue
        print(rxn.reaction)
        print_keggrxn(kegg_rxn)
        print(kegg_rxn.reaction)
        print('')
# Out:
# 5-10-METHENYL-THF-GLU-N
# 5-10-METHENYL-THF-GLU-N + WATER <=> FORMYL-THF-GLU-N + PROTON
# KEGG: H2O + 5,10-Methenyltetrahydrofolate <=> H+ + 10-Formyltetrahydrofolate
# C00001 + C00445 <=> C00080 + C00234
#
# 5-METHYL-THF-GLU-N
# 5-METHYL-THF-GLU-N + HOMO-CYS --> MET + THF-GLU-N
# KEGG: L-Homocysteine + 5-Methyltetrahydrofolate <=> L-Methionine + Tetrahydrofolate
# C00155 + C00440 <=> C00073 + C00101
#
# DIHYDROFOLATE-GLU-N
# DIHYDROFOLATE-GLU-N + NADPH + PROTON --> NADP + THF-GLU-N
# KEGG: NADP+ + Tetrahydrofolate <=> NADPH + H+ + Dihydrofolate
# C00006 + C00101 <=> C00005 + C00080 + C00415
#
# FORMYL-THF-GLU-N
# 5-PHOSPHO-RIBOSYL-GLYCINEAMIDE + FORMYL-THF-GLU-N <=> 5-P-RIBOSYL-N-FORMYLGLYCINEAMIDE + PROTON + THF-GLU-N
# KEGG: 10-Formyltetrahydrofolate + 5'-Phosphoribosylglycinamide <=> Tetrahydrofolate + 5'-Phosphoribosyl-N-formylglycinamide
# C00234 + C03838 <=> C00101 + C04376
#
# METHYLENE-THF-GLU-N
# AMINOMETHYLDIHYDROLIPOYL-GCVH + THF-GLU-N <=> AMMONIUM + DIHYDROLIPOYL-GCVH + METHYLENE-THF-GLU-N
# KEGG: Tetrahydrofolate + S-Aminomethyldihydrolipoylprotein <=> Ammonia + 5,10-Methylenetetrahydrofolate + Dihydrolipoylprotein
# C00101 + C01242 <=> C00014 + C00143 + C02972
#
# N5-Formyl-THF-Glu-N
# 5-10-METHENYL-THF-GLU-N + WATER --> N5-Formyl-THF-Glu-N + PROTON
# KEGG: H2O + 5,10-Methenyltetrahydrofolate --> Folinic acid
# C00001 + C00445 --> C03479
#
# THF-GLU-N
# AMINOMETHYLDIHYDROLIPOYL-GCVH + THF-GLU-N <=> AMMONIUM + DIHYDROLIPOYL-GCVH + METHYLENE-THF-GLU-N
# KEGG: Tetrahydrofolate + S-Aminomethyldihydrolipoylprotein <=> Ammonia + 5,10-Methylenetetrahydrofolate + Dihydrolipoylprotein
# C00101 + C01242 <=> C00014 + C00143 + C02972

# %%
# Manually check above reactions, associate each of '*-GLU-N' metabolites to a kegg id 
# based on metacyc-kegg reaction pairs
GluNs = {
    '5-10-METHENYL-THF-GLU-N': 'C00445',
    '5-METHYL-THF-GLU-N': 'C00440',
    'DIHYDROFOLATE-GLU-N':'C00415',
    'FORMYL-THF-GLU-N':'C00234',
    'METHYLENE-THF-GLU-N': 'C00143',
    'N5-Formyl-THF-Glu-N':'C03479',
    'THF-GLU-N': 'C00101'
}

# %%
# Reassociate those GLU-N to non-GLU metabolites in metacyc
for metg,kegg_id in GluNs.items():
    print(metg,kegg_id,dfmetpair.loc[kegg_id,'metacyc'])
# Out:
# 5-10-METHENYL-THF-GLU-N C00445 5-10-METHENYL-THF
# 5-METHYL-THF-GLU-N C00440 5-METHYL-THF
# DIHYDROFOLATE-GLU-N C00415 DIHYDROFOLATE
# FORMYL-THF-GLU-N C00234 10-FORMYL-THF
# METHYLENE-THF-GLU-N C00143 METHYLENE-THF
# N5-Formyl-THF-Glu-N C03479 5-FORMYL-THF
# THF-GLU-N C00101 THF

# %%
def update_rxn(model,old_met_id,new_met_id):
    old_met = model.metabolites.get_by_id(old_met_id)
    for old_rxn in old_met.reactions:
        
        # create a new reaction with replaced metabolite
        new_rxn = cobra.Reaction(old_rxn.id)
        new_rxn.name = old_rxn.name
        new_rxn.subsystem = old_rxn.subsystem
        new_rxn.lower_bound = old_rxn.lower_bound
        new_rxn.upper_bound = old_rxn.upper_bound
        
        new_met = cobra.Metabolite(new_met_id,name=new_met_id,compartment=old_met.compartment)
        
        coeffs = dict()
        for met in old_rxn.metabolites:
            if met.id == old_met.id: coeffs[new_met] = old_rxn.get_coefficient(met)
            else: coeffs[met] = old_rxn.get_coefficient(met)
        new_rxn.add_metabolites(coeffs)
        new_rxn.gene_reaction_rule = old_rxn.gene_reaction_rule 
        
        # remove old reactions and add new reaction
        model.remove_reactions([old_rxn])
        model.add_reaction(new_rxn)
    
    # findally, remove old metabolites
    model.remove_metabolites([old_met])
    return model

# %%
## Replace the all metabolites that endswith -GLU-N with non-GLU-N format
for met in halo_meta.metabolites:
    if met.id.upper().endswith('-GLU-N'):
        kegg_id = GluNs[met.id]
        new_id = dfmetpair.loc[kegg_id,'metacyc']
        halo_meta = update_rxn(halo_meta,met.id,new_id)

# %%
# print all changed reactions to have a final manual check
for metg,kegg_id in GluNs.items():
    new_id = dfmetpair.loc[kegg_id,'metacyc']
    met = halo_meta.metabolites.get_by_id(new_id)
    for rxn in met.reactions: print(rxn.reaction)
# Out:
# METHYLENE-THF + NADP <=> 5-10-METHENYL-THF + NADPH
# 5-10-METHENYL-THF + WATER --> 5-FORMYL-THF + PROTON
# 5-10-METHENYL-THF + WATER <=> 10-FORMYL-THF + PROTON
# 5-FORMYL-THF + ATP --> 5-10-METHENYL-THF + ADP + Pi
# SS-DIMETHYL-BETA-PROPIOTHETIN + THF --> 5-METHYL-THF + CPD-7672 + PROTON
# 5-METHYL-THF + HOMO-CYS --> MET + THF
# METHYLENE-THF + NADH + PROTON --> 5-METHYL-THF + NAD
# DUMP + METHYLENE-THF --> DIHYDROFOLATE + TMP
# DIHYDROFOLATE + NADPH + PROTON --> NADP + THF
# Acceptor + GLY + GTP + METHYLENE-THF + WATER + tRNA-uridine34 --> DIHYDROFOLATE + Donor-H2 + GDP + 2.0 PROTON + Pi + tRNA-containing-5-CarbMeAminome-uridine
# 7-8-DIHYDROPTEROATE + ATP + GLT --> ADP + DIHYDROFOLATE + PROTON + Pi
# Acceptor + GLY + GTP + METHYLENE-THF + WATER + tRNA-2-thiouridine34 --> DIHYDROFOLATE + Donor-H2 + GDP + 2.0 PROTON + Pi + tRNA-containing-5-CarbMeAminome-2-ThioU
# 10-FORMYL-THF + L-methionyl-tRNAfmet --> N-formyl-L-methionyl-tRNAfmet + PROTON + THF
# 10-FORMYL-THF + AICAR <=> PHOSPHORIBOSYL-FORMAMIDO-CARBOXAMIDE + THF
# 5-10-METHENYL-THF + WATER <=> 10-FORMYL-THF + PROTON
# 10-FORMYL-THF + WATER --> FORMATE + PROTON + THF
# 10-FORMYL-THF + 5-PHOSPHO-RIBOSYL-GLYCINEAMIDE <=> 5-P-RIBOSYL-N-FORMYLGLYCINEAMIDE + PROTON + THF
# Acceptor + GLY + GTP + METHYLENE-THF + WATER + tRNA-uridine34 --> DIHYDROFOLATE + Donor-H2 + GDP + 2.0 PROTON + Pi + tRNA-containing-5-CarbMeAminome-uridine
# METHYLENE-THF + NADH + PROTON --> 5-METHYL-THF + NAD
# METHYLENE-THF + NADP <=> 5-10-METHENYL-THF + NADPH
# GLY + NAD + THF <=> AMMONIUM + CARBON-DIOXIDE + METHYLENE-THF + NADH
# Acceptor + GLY + GTP + METHYLENE-THF + WATER + tRNA-2-thiouridine34 --> DIHYDROFOLATE + Donor-H2 + GDP + 2.0 PROTON + Pi + tRNA-containing-5-CarbMeAminome-2-ThioU
# SER + THF <=> GLY + METHYLENE-THF + WATER
# DUMP + METHYLENE-THF --> DIHYDROFOLATE + TMP
# 2-KETO-ISOVALERATE + METHYLENE-THF + WATER <=> 2-DEHYDROPANTOATE + THF
# AMINOMETHYLDIHYDROLIPOYL-GCVH + THF <=> AMMONIUM + DIHYDROLIPOYL-GCVH + METHYLENE-THF
# 5-10-METHENYL-THF + WATER --> 5-FORMYL-THF + PROTON
# 5-FORMYL-THF + ATP --> 5-10-METHENYL-THF + ADP + Pi
# 10-FORMYL-THF + L-methionyl-tRNAfmet --> N-formyl-L-methionyl-tRNAfmet + PROTON + THF
# DIHYDROFOLATE + NADPH + PROTON --> NADP + THF
# 10-FORMYL-THF + 5-PHOSPHO-RIBOSYL-GLYCINEAMIDE <=> 5-P-RIBOSYL-N-FORMYLGLYCINEAMIDE + PROTON + THF
# GLY + NAD + THF <=> AMMONIUM + CARBON-DIOXIDE + METHYLENE-THF + NADH
# SER + THF <=> GLY + METHYLENE-THF + WATER
# 2-KETO-ISOVALERATE + METHYLENE-THF + WATER <=> 2-DEHYDROPANTOATE + THF
# 10-FORMYL-THF + AICAR <=> PHOSPHORIBOSYL-FORMAMIDO-CARBOXAMIDE + THF
# AMINOMETHYLDIHYDROLIPOYL-GCVH + THF <=> AMMONIUM + DIHYDROLIPOYL-GCVH + METHYLENE-THF
# 5-METHYL-THF + HOMO-CYS --> MET + THF
# 10-FORMYL-THF + WATER --> FORMATE + PROTON + THF
# SS-DIMETHYL-BETA-PROPIOTHETIN + THF --> 5-METHYL-THF + CPD-7672 + PROTON

# %% [markdown]
# ## Manually curate metabolites ids
# Since some metabolites have multiple metacyc ids. In the case that one metabolites has more than one metacyc id existing in the model, remove one of them

# %%
# 'HS' and 'CPD-7046' are both in the halo_meta model. 
# They represent the same metabolit with mnx id: 'MNXM89582'
# Replace 'CPD-7046' by 'HS'
rxns = list()
old_met = halo_meta.metabolites.get_by_id('CPD-7046' )
for rxn in old_met.reactions:
    rxn1 = rxn.copy()
    rxn1.subtract_metabolites(rxn1.metabolites)
    coeffs = dict()
    for met in rxn.metabolites:
        coeff = rxn.get_coefficient(met)
        if met.id == 'CPD-7046':
            met = halo_meta.metabolites.get_by_id('HS')
        coeffs[met] = coeff
    
    rxn1.add_metabolites(coeffs)
    print(rxn1.reaction)
    rxns.append(rxn1)
halo_meta.remove_reactions(old_met.reactions)
halo_meta.add_reactions(rxns)
halo_meta.repair()
# Out:
# Fe4S4-Cluster-Protein + Octanoylated-domains + 6.0 PROTON + 2.0 Reduced-ferredoxins + 2.0 S-ADENOSYLMETHIONINE --> 2.0 CH33ADO + Dihydro-Lipoyl-Proteins + 4.0 FE+2 + 2.0 HS + Iron-Sulfur-Cluster-Scaffold-Proteins + 2.0 MET + 2.0 Oxidized-ferredoxins

# %% [markdown]
# ## Find all transport reactions in metacyc model. Save all these reactions into a new model. Remove those reactions from metacyc model
# Sincd there is no compartment information in the reaction, the metabolites transported are missing in the reaction because they exit in both side of the reaction. We will manually check the metacyc website for those transporters and then add them back

# %%
# check transport reaction in halo_meta
# load transport reaction ids in metacyc database
# The transport reactions were identified based on the transport reaction ids from RAVEN.
is_transport = dict()
for item in open('../../../ComplementaryData/metaCyc_transport_rxns.txt').read().split(): is_transport[item] = True
fhand = open('../Results/transport_rxns.tsv','w')
transmodel = cobra.Model('transmodel')
non_trans_rxns = list()
trans_rxns = list()
k = 0
for rxn in halo_meta.reactions:
    if is_transport.get(rxn.id,False): 
        k += 1
        print(k,rxn.id,rxn.name,':',rxn.reaction)
        fhand.write('{0}\t{1}\t{2}\t{3}\n'.format(k,rxn.id,rxn.name,rxn.reaction))
        trans_rxns.append(rxn)
    else: non_trans_rxns.append(rxn)
transmodel.add_reactions(trans_rxns)
for met in transmodel.metabolites: met.charge = int(met.charge)
halo_meta.remove_reactions(trans_rxns)
cobra.io.write_sbml_model(transmodel,'../Results/transport_rxns.xml')
fhand.close()

halo_meta = cobra.Model(halo_meta.id)
halo_meta.add_reactions(non_trans_rxns)
# Out:
# 1 RXN0-21 glutathione exporter : ATP + WATER --> ADP + PROTON + Pi
# 2 RXN-9615 ammonium transporter :  -->
# 3 TRANS-RXN0-479 selenite ABC transporter;selenite  ABC transporter : ATP + WATER --> ADP + PROTON + Pi
# 4 ABC-70-RXN sulfate  ABC transporter;sulfate ABC transporter : ATP + WATER --> ADP + PROTON + Pi
# 5 ABC-27-RXN transport of phosphate : ATP + WATER --> ADP + PROTON + Pi
# 6 TRANS-RXN0-286 lipid II flippase :  -->
# 7 TRANS-RXN0-268 Transport of L-Ala-D-Glu-meso-A2pm : ATP + WATER --> ADP + PROTON + Pi
# 8 TRANS-RXN-355 n-hexane efflux pump :  -->
# 9 RXN0-11 transport of glutathione : ATP + WATER --> ADP + PROTON + Pi
# 10 TRANS-RXN-167 N-acetyl-D-galactosamine PTS;N-acetylglucosamine PTS permease;N-acetyl-D-glucosamine PTS permease : Hpr-pi-phospho-L-histidines + N-acetyl-D-glucosamine --> Hpr-Histidine + N-ACETYL-D-GLUCOSAMINE-6-P
# 11 ABC-24-RXN putrescine/spermidine ABC transporter : ATP + WATER --> ADP + PROTON + Pi
# 12 TRANS-RXN-352 deoxycholate efflux pump :  -->
# 13 TRANS-RXN-296 cobinamide ABC transporter : ATP + WATER --> ADP + PROTON + Pi
# 14 RXN-19739 glutaconyl-CoA decarboxylase : GLUTACONYL-COA + PROTON --> CARBON-DIOXIDE + CROTONYL-COA
# 15 TRANS-RXN0-513 lanthionine ABC transporter : ATP + WATER --> ADP + PROTON + Pi
# 16 TRANS-RXN0-244 Cd2+:H+ antiporter :  <=>
# 17 TRANS-RXN-42 K+ : H+ antiporter KefB;K+ : H+ antiporter KefC;K+:H+ antiporter;Na+/K+:H+ antiporter ChaA :  <=>
# 18 TRANS-RXN-365 deoxycholate efflux pump :  -->
# 19 RXN0-2501 chloride:H+ antiporter;chloride:H+ antiporter ClcA :  <=>
# 20 TRANS-RXN-273 nitroimidazole export :  -->
# 21 TRANS-RXN-127 L-tartrate:succinate antiporter :  <=>
# 22 TRANS-RXN0-510 N-acetyl-DL-methionine transport : ATP + WATER --> ADP + PROTON + Pi
# 23 TRANS-RXN0-492 transport of beta-D-galactofuranose : ATP + WATER --> ADP + PROTON + Pi
# 24 ABC-36-RXN transport of L-valine : ATP + WATER --> ADP + PROTON + Pi
# 25 TRANS-RXN0-447 transport of adenine :  <=>
# 26 ABC-16-RXN maltose ABC transporter : ATP + WATER --> ADP + PROTON + Pi
# 27 ATPSYN-RXN ATP synthase;H+-translocating V-ATPase;ATP hydrolase : ATP + WATER <=> ADP + PROTON + Pi
# 28 TRANS-RXN-347 norfloxacin:Na+ antiport :  <=>
# 29 RXN0-3 L-cysteine exporter : ATP + WATER --> ADP + PROTON + Pi
# 30 TRANS-RXN-312 L-phenylalanine transport;transport of L-phenylalanine : ATP + WATER --> ADP + PROTON + Pi
# 31 RXN0-18 inosine:H+ antiporter :  <=>
# 32 TRANS-RXN-242 L-homoserine:H+ antiporter :  <=>
# 33 ABC-13-RXN transport of L-glutamate : ATP + WATER --> ADP + PROTON + Pi
# 34 TRANS-RXN0-200 Zn2+:H+ antiporter :  <=>
# 35 RXN0-5111 glycolate:cation symporter :  <=>
# 36 TRANS-RXN-359 ethidium efflux pump :  -->
# 37 TRANS-RXN-325 canavanine exporter :  -->
# 38 RXN0-1702 transport of ferric coprogen :  -->
# 39 TRANS-RXN0-593 L-cystine ABC transporter : ATP + WATER --> ADP + PROTON + Pi
# 40 TRANS-RXN-122A transport of L-aspartate;L-aspartate:H+ symporter;aspartate transport :  <=>
# 41 TRANS-RXN0-503 maltotriose ABC transporter : ATP + WATER --> ADP + PROTON + Pi
# 42 ABC-8-RXN Transport of a dipeptide : ATP + WATER --> ADP + PROTON + Pi
# 43 ABC-10-RXN transport of ferric enterobactin : ATP + WATER --> ADP + PROTON + Pi
# 44 TRANS-RXN0-269 L-valine exporter :  <=>
# 45 TRANS-RXN0-222 transport of L-aspartate : ATP + WATER --> ADP + PROTON + Pi
# 46 TRANS-RXN0-0244 L-threonine:H+ antiport;L-threonine:H+ antiporter :  <=>
# 47 TRANS-RXN-356 decanoate efflux pump :  -->
# 48 TRANS-RXN-340 bicozamycin:H+ antiporter :  <=>
# 49 RXN0-1981 acetate:cation symporter :  <=>
# 50 TRANS-RXN-167A D-glucosamine PTS permease : GLUCOSAMINE + Hpr-pi-phospho-L-histidines --> D-GLUCOSAMINE-6-P + Hpr-Histidine
# 51 RXN-5076 xanthine:H+ symporter XanQ;xanthine:H+ symporter XanP :  <=>
# 52 ABC-25-RXN putrescine/spermidine ABC transporter;transport of putresince : ATP + WATER --> ADP + PROTON + Pi
# 53 RXN0-4083 serine/threonine:Na+ symporter :  <=>
# 54 TRANS-RXN-353 novobiocin efflux pump :  -->
# 55 TRANS-RXN-297 ferric coprogen ABC transporter : ATP + WATER --> ADP + PROTON + Pi
# 56 RXN0-22 guanosine:H+ antiporter :  <=>
# 57 RXN0-1923 O-acetyl-L-serine exporter;export of O-acetyl-L-serine :  -->
# 58 TRANS-RXN-162 L-glutamate:H+ symporter :  <=>
# 59 TRANS-RXN-132 uracil:H+ symporter;uracil:H+ symporter UraA :  <=>
# 60 RXN0-6 Fe2+:H+ antiporter :  <=>
# 61 ABC-5-RXN vitamin B12 ABC transporter : ATP + WATER --> ADP + PROTON + Pi
# 62 TRANS-RXN0-452 p-aminobenzoyl glutamate:H+ symporter :  <=>
# 63 ABC-20-RXN nickel ABC transporter : ATP + WATER --> ADP + PROTON + Pi
# 64 TRANS-RXN0-258 transport of N-acetyl-beta-D-glucosamine(anhydrous)-N-acetylmuramate :  <=>
# 65 TRANS-RXN0-207 Cu+ exporting P-type ATPase : ATP + WATER --> ADP + PROTON + Pi
# 66 RXN0-4522 methionine transport : ATP + WATER --> ADP + PROTON + Pi
# 67 TRANS-RXN-366 cefoperazone ABC exporter : ATP + WATER --> ADP + PROTON + Pi
# 68 TRANS-RXN0-549 transport of poly-beta-1,6-N-acetyl-D-glucosamine :  -->
# 69 TRANS-RXN0-511 L-methionine S-oxide transport : ATP + WATER --> ADP + PROTON + Pi
# 70 TRANS-RXN0-239 nitrate:nitrite antiporter :  -->
# 71 TRANS-RXN-99 choline:H+ symporter :  <=>
# 72 TRANS-RXN-40 L-arabinose exporter :  <=>
# 73 TRANS-RXN-363 nalidixate efflux pump :  -->
# 74 TRANS-RXN-348 tetraphenylphosphonium:Na+ antiport :  <=>
# 75 TRANS-RXN-290 D-cystine ABC transporter : ATP + WATER --> ADP + PROTON + Pi
# 76 RXN0-1802 long-chain fatty acid outer membrane porin bacteriophage T2 binding :  -->
# 77 TRANS-RXN-242A L-homoserine lactone:H+ antiport :  <=>
# 78 TRANS-RXN0-617 homocystine ABC transporter : ATP + WATER --> ADP + PROTON + Pi
# 79 TRANS-RXN0-569 L-amino acid exporter :  -->
# 80 TRANS-RXN0-508 djenkolate ABC transporter : ATP + WATER --> ADP + PROTON + Pi
# 81 ABC-34-RXN transport of glycerol-3-phosphate : ATP + WATER --> ADP + PROTON + Pi
# 82 RXN-8638 transport of a quarternary amine : ATP + WATER --> ADP + PROTON + Pi
# 83 TRANS-RXN-360 gentamicin efflux pump :  -->
# 84 RXN0-1721 ferric dihyroxybenzoylserine outer membrane transporter :  -->
# 85 TRANS-RXN0-595 flavin mononucleotide (FMN) export :  -->
# 86 TRANS-RXN0-504 maltotetraose ABC transporter : ATP + WATER --> ADP + PROTON + Pi
# 87 ABC-9-RXN transport of ferric dicitrate : ATP + WATER --> ADP + PROTON + Pi
# 88 TRANS-RXN0-226 transport of GlcNAc-1,6-anhMurNAc-L-Ala-gamma-D-Glu-DAP-D-Ala :  <=>
# 89 TRANS-RXN0-162 ABC complex for formation and release of holoCcmE : ATP + WATER --> ADP + PROTON + Pi
# 90 TRANS-RXN-357 enterobactin efflux pump :  -->
# 91 TRANS-RXN-3 K+ transporter Kup;K+ transporter TrkH;K+ transporter TrkG :  <=>
# 92 TRANS-RXN0-478 selenate ABC transporter;selenate  ABC transporter : ATP + WATER --> ADP + PROTON + Pi
# 93 ABC-7-RXN thiosulfate ABC transporter : ATP + WATER --> ADP + PROTON + Pi
# 94 ABC-26-RXN transport of proline : ATP + WATER --> ADP + PROTON + Pi
# 95 TRANS-RXN-354 acriflavine efflux pump;acriflavin efflux pump :  -->
# 96 TRANS-RXN-298 ferrichrome ABC transporter : ATP + WATER --> ADP + PROTON + Pi
# 97 RXN0-1924 cysteine exporter;export of L-cysteine :  -->
# 98 TRANS-RXN-194 calmodulin-stimulated calcium-ATPase;plastid envelope ATPase;calcium-transporting ATPase;plasma membrane calcium-transporting ATPase;plasma membrane Ca2+-ATPase : ATP + WATER --> ADP + PROTON + Pi
# 99 TRANS-RXN-137 transport of nitrite;nitrite transporter NirC :  -->
# 100 TRANS-RXN0-576 transport of tellurite :  <=>
# 101 TRANS-RXN-118 proline:Na+ symporter :  <=>
# 102 TRANS-RXN0-453 autoinducer 2 exporter :  <=>
# 103 TRANS-RXN0-281 acetoacetate transporter :  -->
# 104 TRANS-RXN-351 sulfadiazine efflux pump :  -->
# 105 TRANS-RXN0-573 transport of a glycerophosphodiester : ATP + WATER --> ADP + PROTON + Pi
# 106 RXN66-448 Sodium independent arginine transport;L-arginine exporter;sodium independent arginine plasma membrane transport :  <=>
# 107 ABC-4-RXN L-arginine transporter : ATP + WATER --> ADP + PROTON + Pi
# 108 ABC-19-RXN transport of molybdate;molybdate ABC transporter : ATP + WATER --> ADP + PROTON + Pi
# 109 TRANS-RXN0-240 biotin transporter :  -->
# 110 TRANS-RXN-364 CCCP efflux pump :  -->
# 111 TRANS-RXN-349 deoxycholate:Na+ antiport :  <=>
# 112 TRANS-RXN-291 diaminopimelate ABC transporter : ATP + WATER --> ADP + PROTON + Pi
# 113 TRANS-RXN-272 flavin adenine dinucleotide (FAD) export :  -->
# 114 TRANS-RXN0-491 transport of alpha-D-galactofuranose : ATP + WATER --> ADP + PROTON + Pi
# 115 ABC-35-RXN transport of L-leucine;L-leucine transport : ATP + WATER --> ADP + PROTON + Pi
# 116 TRANS-RXN0-445 chitobiose transport;transport of N,N'-diacetyl-chitobiose :  -->
# 117 ABC-15-RXN transport of L-isoleucine : ATP + WATER --> ADP + PROTON + Pi
# 118 TRANS-RXN0-235 2,3-diketo-L-gulonate:Na+ symporter :  -->
# 119 RXN-18029 teichoic acid transporter : ATP + WATER --> ADP + PROTON + Pi
# 120 TRANS-RXN0-202 methionine transport : ATP + WATER --> ADP + PROTON + Pi
# 121 TRANS-RXN-220 glucosyl-oleandomycin-exporting ATPase : ATP + WATER --> ADP + PROTON + Pi
# 122 TRANS-RXN-145 water channel AqpZ :  <=>
# 123 TRANS-RXN0-505 propionate transporter :  -->
# 124 ABC-12-RXN transport of L-glutamine : ATP + WATER --> ADP + PROTON + Pi
# 125 TRANS-RXN0-181 TatABCE protein export complex :  -->
# 126 TRANS-RXN-283 glycine betaine ABC transporter : ATP + WATER --> ADP + PROTON + Pi
# 127 RXN0-1701 transport of ferrichrome :  -->
# 128 TRANS-RXN-2 K+ transporting ATPase : ATP + WATER --> ADP + PROTON + Pi
# 129 TRANS-RXN0-592 chenodeoxycholate efflux pump :  -->
# 130 TRANS-RXN0-277 NAD(P) transhydrogenase;pyridine nucleotide transhydrogenase : NADH + NADP --> NAD + NADPH
# 131 TRANS-RXN-237 transport of lipopolysaccharide : ATP + WATER --> ADP + PROTON + Pi
# 132 TRANS-RXN-214 Na(+)-translocating NADH-quinone reductase : NADH + PROTON + Ubiquinones --> NAD + Ubiquinols

# %% [markdown]
# ### Add _c for all metabolite identifiers. Change the compartment to 'c'

# %%
halo_meta.repair()
for met in halo_meta.metabolites:
    met.id = met.id+'_c'
    met.compartment = 'c'
halo_meta.repair()

# %% [markdown]
# ### Add transport reactions back manully

# %%
transmodel = cobra.io.read_sbml_model('../Results/transport_rxns.xml')
report_model_status(transmodel)
# Out:
# No objective coefficients in model. Unclear what should be optimized
# Number of reactions: 132
# Number of metabolits: 20
# Number of compartments: 1
# Number of genes: 236
# Number of missing genes: 0
# Number of reactions with missing genes: 0

# %%
def format_transported_met(rxn_id,transmodel,metacyc_model,direction,met_ids,weights):
    # rxn_id: rxn_id in transmodel
    # transmodel: the model containing all transport reactions
    # metacyc model: model reconstructed from MetaCyc
    # direction: 'in' or 'out'. 'in': e to c, out: c to e
    # met_ids: transported metabolite ids
    # weights: coeffs of tranported metabolite
    # 
    # Assume all metbolites in transport reactions before adding transported metabolit as in cyctosal.
    # 
    rxn = transmodel.reactions.get_by_id(rxn_id)
    new_rxn = rxn.copy()
    
    # 1. add _c to exsiting metaboites in transport reaction
    coeffs = dict()
    for met in rxn.metabolites:
        new_id = met.id+'_c'
        try: new_met = metacyc_model.metabolites.get(new_id)
        except: 
            new_met = met.copy()
            new_met.id = new_met.id +'_c'
            new_met.compartment = 'c'
        coeffs[new_met] = rxn.get_coefficient(met)
    
    # 2. add transported metaboites
    def get_met_ec(met_id):
        try: met_e = metacyc_model.metabolites.get_by_id(met_id+'_e')
        except: 
            met_e = cobra.Metabolite(met_id+'_e')
            met_e.annotation = {'biocyc':'META:'+met_id}
            #met_e.name = met_id
            met_e.compartment = 'e'
            
    
        try: met_c = metacyc_model.metabolites.get_by_id(met_id+'_c')
        except: 
            met_c = cobra.Metabolite(met_id+'_c')
            #met_c.name = met_id
            met_e.annotation = {'biocyc':'META:'+met_id}
            met_c.compartment = 'c'
    
        return met_e,met_c
    
    for i in range(len(met_ids)):
        met_id = met_ids[i]
        number_of_molecular = weights[i]
        met_e,met_c = get_met_ec(met_id)
        if direction == 'in': 
            coeffs[met_e] = -number_of_molecular
            coeffs[met_c] = number_of_molecular
        elif direction == 'out':
            coeffs[met_c] = -number_of_molecular
            coeffs[met_e] = number_of_molecular
        else: print('Error: check direction. ')
    new_rxn = rxn.copy()
    new_rxn.subtract_metabolites(new_rxn.metabolites)
    new_rxn.add_metabolites(coeffs)
    print(rxn.id,new_rxn.reaction)
    return new_rxn

# %%
report_model_status(halo_meta)
# Out:
# Number of reactions: 1139
# Number of metabolits: 1460
# Number of compartments: 1
# Number of genes: 994
# Number of missing genes: 0
# Number of reactions with missing genes: 0

# %%
trans_rxns_formated = list()
for line in open('../../../ComplementaryData/transport_rxns_mannual.tsv'):
    cont = line.strip().split('\t')
    rxn_id = cont[1]
    direction = cont[5]
    met_ids = cont[4].split(',')
    weights = [int(item) for item in cont[6].split(',')]
        
    trans_rxns_formated.append(format_transported_met(rxn_id,transmodel,halo_meta,direction,
                                                  met_ids,weights))
# Out:
# RXN0-21 ATP_c + GLUTATHIONE_c + WATER_c --> ADP_c + GLUTATHIONE_e + PROTON_c + Pi_c
# RXN-9615 AMMONIUM_e --> AMMONIUM_c
# TRANS-RXN0-479 ATP_c + SELENITE_e + WATER_c --> ADP_c + PROTON_c + Pi_c + SELENITE_c
# ABC-70-RXN ATP_c + SULFATE_e + WATER_c --> ADP_c + PROTON_c + Pi_c + SULFATE_c
# ABC-27-RXN ATP_c + Pi_e + WATER_c --> ADP_c + PROTON_c + Pi_c + Pi_c
# TRANS-RXN0-286 C6_c --> C6_e
# TRANS-RXN0-268 ATP_c + L-ALA-GAMMA-D-GLU-DAP_e + WATER_c --> ADP_c + L-ALA-GAMMA-D-GLU-DAP_c + PROTON_c + Pi_c
# TRANS-RXN-355 CPD-9288_c --> CPD-9288_e
# RXN0-11 ATP_c + GLUTATHIONE_e + WATER_c --> ADP_c + GLUTATHIONE_c + PROTON_c + Pi_c
# TRANS-RXN-167 Hpr-pi-phospho-L-histidines_c + N-acetyl-D-glucosamine_c + N-acetyl-D-glucosamine_e --> Hpr-Histidine_c + N-ACETYL-D-GLUCOSAMINE-6-P_c + N-acetyl-D-glucosamine_c
# ABC-24-RXN ATP_c + SPERMIDINE_e + WATER_c --> ADP_c + PROTON_c + Pi_c + SPERMIDINE_c
# TRANS-RXN-352 DEOXYCHOLATE_c --> DEOXYCHOLATE_e
# TRANS-RXN-296 ATP_c + COBINAMIDE_e + WATER_c --> ADP_c + COBINAMIDE_c + PROTON_c + Pi_c
# RXN-19739 GLUTACONYL-COA_c + NA+_c + PROTON_c --> CARBON-DIOXIDE_c + CROTONYL-COA_c + NA+_e
# TRANS-RXN0-513 ATP_c + CPD-3736_e + WATER_c --> ADP_c + CPD-3736_c + PROTON_c + Pi_c
# TRANS-RXN0-244 CD+2_e + PROTON_e <=> CD+2_c + PROTON_c
# TRANS-RXN-42 K+_e + PROTON_e <=> K+_c + PROTON_c
# TRANS-RXN-365 DEOXYCHOLATE_c + PROTON_c --> DEOXYCHOLATE_e + PROTON_e
# RXN0-2501 2 CL-_e + PROTON_e <=> 2 CL-_c + PROTON_c
# TRANS-RXN-273 CPD-14545_c --> CPD-14545_e
# TRANS-RXN-127 SUC_e + TARTRATE_e <=> SUC_c + TARTRATE_c
# TRANS-RXN0-510 ATP_c + CPD-3738_e + WATER_c --> ADP_c + CPD-3738_c + PROTON_c + Pi_c
# TRANS-RXN0-492 ATP_c + CPD0-2485_e + WATER_c --> ADP_c + CPD0-2485_c + PROTON_c + Pi_c
# ABC-36-RXN ATP_c + VAL_e + WATER_c --> ADP_c + PROTON_c + Pi_c + VAL_c
# TRANS-RXN0-447 ADENINE_e + PROTON_e <=> ADENINE_c + PROTON_c
# ABC-16-RXN ATP_c + MALTOSE_e + WATER_c --> ADP_c + MALTOSE_c + PROTON_c + Pi_c
# ATPSYN-RXN ATP_c + 4 PROTON_e + WATER_c <=> ADP_c + PROTON_c + 4 PROTON_c + Pi_c
# TRANS-RXN-347 CPD-21015_e + NA+_e <=> CPD-21015_c + NA+_c
# RXN0-3 ATP_c + CYS_c + WATER_c --> ADP_c + CYS_e + PROTON_c + Pi_c
# TRANS-RXN-312 ATP_c + PHE_e + WATER_c --> ADP_c + PHE_c + PROTON_c + Pi_c
# RXN0-18 INOSINE_e + PROTON_e <=> INOSINE_c + PROTON_c
# TRANS-RXN-242 HOMO-SER_e + PROTON_e <=> HOMO-SER_c + PROTON_c
# ABC-13-RXN ATP_c + GLT_e + WATER_c --> ADP_c + GLT_c + PROTON_c + Pi_c
# TRANS-RXN0-200 PROTON_e + ZN+2_e <=> PROTON_c + ZN+2_c
# RXN0-5111 GLYCOLLATE_e + NA+_e <=> GLYCOLLATE_c + NA+_c
# TRANS-RXN-359 CPD0-1938_e + PROTON_e --> CPD0-1938_c + PROTON_c
# TRANS-RXN-325 CANAVANINE_c --> CANAVANINE_e
# RXN0-1702 CPD0-621_e + PROTON_e --> CPD0-621_c + PROTON_c
# TRANS-RXN0-593 ATP_c + CYSTINE_e + WATER_c --> ADP_c + CYSTINE_c + PROTON_c + Pi_c
# TRANS-RXN-122A L-ASPARTATE_e + 2 PROTON_e <=> L-ASPARTATE_c + 2 PROTON_c
# TRANS-RXN0-503 ATP_c + MALTOTRIOSE_e + WATER_c --> ADP_c + MALTOTRIOSE_c + PROTON_c + Pi_c
# ABC-8-RXN ATP_c + DIPEPTIDES_e + WATER_c --> ADP_c + DIPEPTIDES_c + PROTON_c + Pi_c
# ABC-10-RXN ATP_c + FERRIC-ENTEROBACTIN-COMPLEX_e + WATER_c --> ADP_c + FERRIC-ENTEROBACTIN-COMPLEX_c + PROTON_c + Pi_c
# TRANS-RXN0-269 VAL_e <=> VAL_c
# TRANS-RXN0-222 ATP_c + TRANS-RXN0-222_e + WATER_c --> ADP_c + PROTON_c + Pi_c + TRANS-RXN0-222_c
# TRANS-RXN0-0244 PROTON_e + THR_e <=> PROTON_c + THR_c
# TRANS-RXN-356 CPD-3617_c + PROTON_c --> CPD-3617_e + PROTON_e
# TRANS-RXN-340 CPD-20921_e + PROTON_e <=> CPD-20921_c + PROTON_c
# RXN0-1981 ACET_e + NA+_e <=> ACET_c + NA+_c
# TRANS-RXN-167A GLUCOSAMINE_c + GLUCOSAMINE_e + Hpr-pi-phospho-L-histidines_c --> D-GLUCOSAMINE-6-P_c + GLUCOSAMINE_c + Hpr-Histidine_c
# RXN-5076 PROTON_e + XANTHINE_e <=> PROTON_c + XANTHINE_c
# ABC-25-RXN ATP_c + PUTRESCINE_e + WATER_c --> ADP_c + PROTON_c + PUTRESCINE_c + Pi_c
# RXN0-4083 NA+_e + SER_e <=> NA+_c + SER_c
# TRANS-RXN-353 CPD-15417_c + PROTON_c --> CPD-15417_e + PROTON_e
# TRANS-RXN-297 ATP_c + CPD0-621_e + WATER_c --> ADP_c + CPD0-621_c + PROTON_c + Pi_c
# RXN0-22 GUANOSINE_e + PROTON_e <=> GUANOSINE_c + PROTON_c
# RXN0-1923 ACETYLSERINE_c --> ACETYLSERINE_e
# TRANS-RXN-162 GLT_e + 2 PROTON_e <=> GLT_c + 2 PROTON_c
# TRANS-RXN-132 PROTON_e + URACIL_e <=> PROTON_c + URACIL_c
# RXN0-6 FE+2_e + PROTON_e <=> FE+2_c + PROTON_c
# ABC-5-RXN ATP_c + COB-I-ALAMIN_e + WATER_c --> ADP_c + COB-I-ALAMIN_c + PROTON_c + Pi_c
# TRANS-RXN0-452 CPD0-889_e + PROTON_e <=> CPD0-889_c + PROTON_c
# ABC-20-RXN ATP_c + NI+2_e + WATER_c --> ADP_c + NI+2_c + PROTON_c + Pi_c
# TRANS-RXN0-258 CPD0-1081_e + PROTON_e <=> CPD0-1081_c + PROTON_c
# TRANS-RXN0-207 ATP_c + CU+_c + WATER_c --> ADP_c + CU+_e + PROTON_c + Pi_c
# RXN0-4522 ATP_c + MET_e + WATER_c --> ADP_c + MET_c + PROTON_c + Pi_c
# TRANS-RXN-366 ATP_c + CPD-19953_c + WATER_c --> ADP_c + CPD-19953_e + PROTON_c + Pi_c
# TRANS-RXN0-549 CPD0-1192_c --> CPD0-1192_e
# TRANS-RXN0-511 ATP_c + L-Methionine-sulfoxides_e + WATER_c --> ADP_c + L-Methionine-sulfoxides_c + PROTON_c + Pi_c
# TRANS-RXN0-239 NITRATE_e + NITRITE_c --> NITRATE_c + NITRITE_e
# TRANS-RXN-99 CHOLINE_e + PROTON_e <=> CHOLINE_c + PROTON_c
# TRANS-RXN-40 L-ARABINOSE_e + PROTON_e <=> L-ARABINOSE_c + PROTON_c
# TRANS-RXN-363 CPD-21025_c + PROTON_c --> CPD-21025_e + PROTON_e
# TRANS-RXN-348 CPD-20890_e + NA+_e <=> CPD-20890_c + NA+_c
# TRANS-RXN-290 ATP_c + CPD0-1564_e + WATER_c --> ADP_c + CPD0-1564_c + PROTON_c + Pi_c
# RXN0-1802 Long-Chain-Fatty-Acids_e --> Long-Chain-Fatty-Acids_c
# TRANS-RXN-242A CPD-15554_e + PROTON_e <=> CPD-15554_c + PROTON_c
# TRANS-RXN0-617 ATP_c + HOMOCYSTINE_e + WATER_c --> ADP_c + HOMOCYSTINE_c + PROTON_c + Pi_c
# TRANS-RXN0-569 LYS_c --> LYS_e
# TRANS-RXN0-508 ATP_c + CPD-3740_e + WATER_c --> ADP_c + CPD-3740_c + PROTON_c + Pi_c
# ABC-34-RXN ATP_c + GLYCEROL-3P_e + WATER_c --> ADP_c + GLYCEROL-3P_c + PROTON_c + Pi_c
# RXN-8638 ATP_c + Quaternary-Amines_e + WATER_c --> ADP_c + PROTON_c + Pi_c + Quaternary-Amines_c
# TRANS-RXN-360 Gentamycins_c + PROTON_c --> Gentamycins_e + PROTON_e
# RXN0-1721 CPD0-2482_e --> CPD0-2482_c
# TRANS-RXN0-595 FMN_c --> FMN_e
# TRANS-RXN0-504 ATP_c + MALTOTETRAOSE_e + WATER_c --> ADP_c + MALTOTETRAOSE_c + PROTON_c + Pi_c
# ABC-9-RXN ATP_c + FERRIC-CITRATE-COMPLEX_e + WATER_c --> ADP_c + FERRIC-CITRATE-COMPLEX_c + PROTON_c + Pi_c
# TRANS-RXN0-226 CPD0-1080_e + PROTON_e <=> CPD0-1080_c + PROTON_c
# TRANS-RXN0-162 ATP_c + TRANS-RXN0-162_c + WATER_c --> ADP_c + PROTON_c + Pi_c + TRANS-RXN0-162_e
# TRANS-RXN-357 ENTEROBACTIN_c + PROTON_c --> ENTEROBACTIN_e + PROTON_e
# TRANS-RXN-3 K+_e + PROTON_e <=> K+_c + PROTON_c
# TRANS-RXN0-478 ATP_c + SELENATE_e + WATER_c --> ADP_c + PROTON_c + Pi_c + SELENATE_c
# ABC-7-RXN ABC-7-RXN_e + ATP_c + WATER_c --> ABC-7-RXN_c + ADP_c + PROTON_c + Pi_c
# ABC-26-RXN ATP_c + PRO_e + WATER_c --> ADP_c + PROTON_c + PRO_c + Pi_c
# TRANS-RXN-354 CPD-21070_e + PROTON_e --> CPD-21070_c + PROTON_c
# TRANS-RXN-298 ATP_c + CPD0-2241_e + WATER_c --> ADP_c + CPD0-2241_c + PROTON_c + Pi_c
# RXN0-1924 CYS_c --> CYS_e
# TRANS-RXN-194 ATP_c + CA+2_c + WATER_c --> ADP_c + CA+2_e + PROTON_c + Pi_c
# TRANS-RXN-137 NITRITE_c --> NITRITE_e
# TRANS-RXN0-576 CPD-4544_e + NA+_e <=> CPD-4544_c + NA+_c
# TRANS-RXN-118 NA+_e + PRO_e <=> NA+_c + PRO_c
# TRANS-RXN0-453 TRANS-RXN0-453_e <=> TRANS-RXN0-453_c
# TRANS-RXN0-281 3-KETOBUTYRATE_e --> 3-KETOBUTYRATE_c
# TRANS-RXN-351 CPD-20940_c --> CPD-20940_e
# TRANS-RXN0-573 ATP_c + Glycerophosphodiesters_e + WATER_c --> ADP_c + Glycerophosphodiesters_c + PROTON_c + Pi_c
# RXN66-448 ARG_e <=> ARG_c
# ABC-4-RXN ARG_e + ATP_c + WATER_c --> ADP_c + ARG_c + PROTON_c + Pi_c
# ABC-19-RXN ATP_c + CPD-3_e + WATER_c --> ADP_c + CPD-3_c + PROTON_c + Pi_c
# TRANS-RXN0-240 BIOTIN_e --> BIOTIN_c
# TRANS-RXN-364 CPD-7970_c + PROTON_c --> CPD-7970_e + PROTON_e
# TRANS-RXN-349 DEOXYCHOLATE_e + NA+_e <=> DEOXYCHOLATE_c + NA+_c
# TRANS-RXN-291 ATP_c + MESO-DIAMINOPIMELATE_e + WATER_c --> ADP_c + MESO-DIAMINOPIMELATE_c + PROTON_c + Pi_c
# TRANS-RXN-272 FAD_c --> FAD_e
# TRANS-RXN0-491 ATP_c + CPD0-2486_e + WATER_c --> ADP_c + CPD0-2486_c + PROTON_c + Pi_c
# ABC-35-RXN ATP_c + LEU_e + WATER_c --> ADP_c + LEU_c + PROTON_c + Pi_c
# TRANS-RXN0-445 CHITOBIOSE_e --> CHITOBIOSE_c
# ABC-15-RXN ATP_c + ILE_e + WATER_c --> ADP_c + ILE_c + PROTON_c + Pi_c
# TRANS-RXN0-235 CPD-334_e + NA+_e --> CPD-334_c + NA+_c
# RXN-18029 ATP_c + CPD-19309_c + WATER_c --> ADP_c + CPD-19309_e + PROTON_c + Pi_c
# TRANS-RXN0-202 ATP_c + CPD-218_e + WATER_c --> ADP_c + CPD-218_c + PROTON_c + Pi_c
# TRANS-RXN-220 ATP_c + CPD-13949_c + WATER_c --> ADP_c + CPD-13949_e + PROTON_c + Pi_c
# TRANS-RXN-145 WATER_e <=> WATER_c
# TRANS-RXN0-505 TRANS-RXN0-505_e --> TRANS-RXN0-505_c
# ABC-12-RXN ATP_c + GLN_e + WATER_c --> ADP_c + GLN_c + PROTON_c + Pi_c
# TRANS-RXN0-181 General-Protein-Substrates_c --> General-Protein-Substrates_e
# TRANS-RXN-283 ATP_c + BETAINE_e + WATER_c --> ADP_c + BETAINE_c + PROTON_c + Pi_c
# RXN0-1701 CPD0-2241_e + PROTON_e --> CPD0-2241_c + PROTON_c
# TRANS-RXN-2 ATP_c + K+_e + WATER_c --> ADP_c + K+_c + PROTON_c + Pi_c
# TRANS-RXN0-592 CPD-15189_c + PROTON_c --> CPD-15189_e + PROTON_e
# TRANS-RXN0-277 NADH_c + NADP_c + PROTON_e --> NADPH_c + NAD_c + PROTON_c
# TRANS-RXN-237 ATP_c + Lipopolysaccharides_c + WATER_c --> ADP_c + Lipopolysaccharides_e + PROTON_c + Pi_c
# TRANS-RXN-214 NA+_c + NADH_c + PROTON_c + Ubiquinones_c --> NA+_e + NAD_c + Ubiquinols_c

# %%
halo_meta.add_reactions(trans_rxns_formated)
halo_meta.repair()
report_model_status(halo_meta)
# Out:
# Number of reactions: 1271
# Number of metabolits: 1641
# Number of compartments: 2
# Number of genes: 1230
# Number of missing genes: 0
# Number of reactions with missing genes: 0

# %%
print(halo_meta.compartments)
# Out:
# {'c': '', 'e': ''}

# %% [markdown]
# ### Add annotation field to rxn and met in metacyc model. Add 'biocyc' to both

# %% [markdown]
# for rxn in halo_meta.reactions:
#     rxn.annotation['biocyc'] = rxn.id
#     print(rxn.id,rxn.annotation)

# %% [markdown]
# for met in halo_meta.metabolites:
#     met.annotation['biocyc'] = met.id.replace('_c','').replace('_e','')
#     print(met.id,met.annotation)

# %%
eco
# Out:
# <Model iML1515 at 0x1325818c88>

# %% [markdown]
# ## Combine draft models based on metacyc and iML1515
# * For template model on iML1515
#     * replace _p with _c
#     * use metacyc id for metabolites and reactions if available
#     * if multiple metacyc ids exist, use the one in halomodel if available
#     * ignore transport reaction between c and e
# * Add reactions from metacyc into above model

# %%
def create_universal_met(eco_met,halomodel,universal,mnx2meta):
    is_in_halo = dict()
    for met in halomodel.metabolites: is_in_halo[met.id] = True
    mnx_id = eco_met.annotation.get('metanetx.chemical')
    
    comp = eco_met.compartment
    if comp == 'p': comp = 'c'
    met_id = None
    
    if mnx_id is None or mnx2meta.get(mnx_id,None) is None: 
        # if there is no mnx id or no metacyc id, use bigg id instead
        met_id = eco_met.annotation['bigg.metabolite'] + '_' + comp
    else:
        meta_ids = mnx2meta[mnx_id]
        for item in meta_ids:
            if is_in_halo.get(item+ '_' + comp,False): 
                met_id = item+ '_' + comp
                break
        if met_id is None: met_id = meta_ids[0] + '_' + comp
    try: 
        new_met = halomodel.metabolites.get_by_id(met_id)
    except:
        try:
            new_met = universal.metabolites.get_by_id(met_id)
        except:
            new_met = eco_met.copy()
            new_met.id = met_id
            new_met.compartment = comp
    return new_met

# %%
def update_rxnid(new_rxn,halomodel,universal):
    # metacyc reaction ids in halomodel:
    halo_rxn_ids = dict()
    halo_rxn_mets = dict()
    mets_rxn = dict()
    for rxn in halomodel.reactions: 
        halo_rxn_ids[rxn.id] = True
        mets = [met.id for met in rxn.metabolites]
        mets.sort()
        mets = tuple(mets)
        halo_rxn_mets[mets] = True
        mets_rxn[mets] = rxn
        
    # 1. check metacyc id
    meta_ids = new_rxn.annotation.get('biocyc')
    new_rxn_id = new_rxn.id
    # case 1: there is metacyc ids, map metacyc id
    if meta_ids is not None:
        if type(meta_ids) == str: meta_ids = [meta_ids]
        for meta_id in meta_ids:
            meta_id = meta_id.replace('META:','')
            if halo_rxn_ids.get(meta_id,False): new_rxn_id = meta_id
    
    # case 2: if case 1 failed, check reaction equations
    else:
        new_mets = [met.id for met in new_rxn.metabolites]
        new_mets.sort()
        new_mets = tuple(new_mets)
        if halo_rxn_mets.get(new_mets,False): 
            # the two reactions contain the same metabolites. Now compare the equations, including direction
            eq1 = new_rxn.reaction
            eq2 = mets_rxn[new_mets].reaction
            eq1 = eq1.split()
            eq2 = eq2.split()
            
            eq1.sort()
            eq2.sort()
            if eq1 == eq2:
                # print(new_rxn.id,new_rxn.reaction)
                # print(mets_rxn[new_mets].id,mets_rxn[new_mets].reaction)
                # print('')
                new_rxn_id = mets_rxn[new_mets].id
            
    new_rxn.id = new_rxn_id
    
    # if new_rxn_id is in universal model, use the reactions in univeral model
    try: 
        rxn_universal = universal.reactions.get_by_id(new_rxn_id)
        gr_rule = new_rxn.gene_reaction_rule 
        new_rxn = rxn_universal.copy()
        new_rxn.gene_reaction_rule = gr_rule
    except: None
    
    
    return new_rxn

# %%
def create_universal_rxn(eco_rxn,halomodel,universal,mnx2meta):
    coeffs = dict()
    is_transport = False
    
    # convert metabolite ids
    mets = list()
    for eco_met in eco_rxn.metabolites:
        new_met = create_universal_met(eco_met,halomodel,universal,mnx2meta)
        if new_met.id in mets:
            is_transport = True

        mets.append(new_met.id)
        coeffs[new_met] = coeffs.get(new_met,0) + eco_rxn.get_coefficient(eco_met)

    if is_transport and 'BIOMASS' not in eco_rxn.id: return None
    else:
        # convert reaction ids
        new_rxn = eco_rxn.copy()
        new_rxn.subtract_metabolites(new_rxn.metabolites)
        new_rxn.add_metabolites(coeffs)
        
        new_rxn = update_rxnid(new_rxn,halomodel,universal)
        return new_rxn

# %%
def remove_transport_rxn_from_model_on_template(model):
    rxns = list()
    
    for rxn in model.reactions:
        is_transport = False
        mets = dict()
        for met in rxn.metabolites: 
            comp = met.compartment
            met_id = met.id.replace('_{0}'.format(comp),'')
            if mets.get(met_id) is not None: is_transport = True
            else: mets[met_id] = 0

        if not is_transport: rxns.append(rxn)
    
    new_model = cobra.Model('model_from_template_without_transport')
    new_model.add_reactions(rxns)
    print('{0} transport reactions were removed'.format(len(model.reactions)-len(rxns)))
    return new_model

# %%
# break point
# print(gang)

# %% [markdown]
# #### 1. covert iML1515 to a universal model
# * replace _p with _c
# * use metacyc id for metabolites and reactions if available
# * if multiple metacyc ids exist, use the one in halomodel if available
# * ignore transport reaction between c and e

# %%
universal = cobra.Model('universal')
mnx2meta = dict()
for line in open('../../../ComplementaryData/MNX2metacyc.tsv'):
    cont = line.split()
    mnx2meta[cont[0]] = mnx2meta.get(cont[0],[]) + [cont[1]]

univeral_rxns = dict()
for eco_rxn in eco.reactions:
    new_rxn = create_universal_rxn(eco_rxn,halo_meta,universal,mnx2meta)
    if new_rxn is None: continue
    
    univeral_rxns[new_rxn.id] = new_rxn
universal.add_reactions(univeral_rxns.values())

# %%
report_model_status(universal)
# Out:
# Number of reactions: 2225
# Number of metabolits: 1503
# Number of compartments: 2
# Number of genes: 1093
# Number of missing genes: 0
# Number of reactions with missing genes: 0

# %% [markdown]
# def block_amino_acid_update_eco(model):
#     amino_acids = ['CYS_c','L-ASPARTATE_c','GLT_c','PHE_c','GLY_c',
#                   'HIS_c','ILE_c','LYS_c','LEU_c','MET_c','ASN_c',
#                   'PRO_c','GLN_c','ARG_c','SER_c','THR_c','VAL_c',
#                   'TRP_c','L-ALPHA-ALANINE_c','TYR_c']
#     for met_id in amino_acids:
#         met = model.metabolites.get_by_id(met_id)
#         for rxn in met.reactions:
#             if 'BIOMASS' in rxn.name: continue
#             if rxn.id.endswith('tex'):
#                 rxn.upper_bound = 0
#                 print(rxn.id,rxn.reaction)
#     return model

# %%
universal.objective = 'BIOMASS_Ec_iML1515_core_75p37M'
eco.objective = 'BIOMASS_Ec_iML1515_core_75p37M'

# check why? make sure growth rate is higher after removal of compartment p. 
print(universal.optimize())
print(eco.optimize())
# Out:
# <Solution 0.344 at 0x1321995160>
# <Solution 0.877 at 0x13219950f0>

# %% [markdown]
# for rxn in eco.reactions:
#     try:
#         if 'biomass' in rxn.name.lower():print(rxn.id,rxn.name)
#     except: pass

# %% [markdown]
# #### 2. convert  the draft model based template to a small universal model. Remove all transport reactions

# %%
# change the ids in model halo_iJO with metacyc ids.
halo_iJO_meta = cobra.Model('halo_iML1515_metacycids')
template_rxns = dict()

for rxn in halo_iJO.reactions:
    new_rxn = create_universal_rxn(rxn,halo_meta,universal,mnx2meta)
    if new_rxn is None: continue
    template_rxns[new_rxn.id] = new_rxn
halo_iJO_meta.add_reactions(template_rxns.values())
halo_iJO_meta = remove_transport_rxn_from_model_on_template(halo_iJO_meta)
# Out:
# 8 transport reactions were removed

# %%
report_model_status(halo_iJO)
# Out:
# Number of reactions: 1119
# Number of metabolits: 1099
# Number of compartments: 3
# Number of genes: 662
# Number of missing genes: 0
# Number of reactions with missing genes: 0

# %%
report_model_status(halo_iJO_meta)
# Out:
# Number of reactions: 933
# Number of metabolits: 837
# Number of compartments: 1
# Number of genes: 533
# Number of missing genes: 0
# Number of reactions with missing genes: 0

# %% [markdown]
# #### 3. compare draft models from template and metacyc

# %%
k = 1
meta_model_ids = [rxn.id for rxn in halo_meta.reactions]
for rxn in halo_iJO_meta.reactions:
    if rxn.id in meta_model_ids:
        rxn1 = halo_meta.reactions.get_by_id(rxn.id)
        print(k,rxn.id,rxn.reaction)
        print(k,rxn1.id,rxn1.reaction)
        print('')
        k += 1
# Out:
# 1 DEOXYRIBOSE-P-ALD-RXN DEOXY-RIBOSE-5P_c --> ACETALD_c + GAP_c
# 1 DEOXYRIBOSE-P-ALD-RXN DEOXY-RIBOSE-5P_c <=> ACETALD_c + GAP_c
#
# 2 RXN-6321 5-FORMYL-THF_c + PROTON_c --> 5-10-METHENYL-THF_c + WATER_c
# 2 RXN-6321 5-10-METHENYL-THF_c + WATER_c --> 5-FORMYL-THF_c + PROTON_c
#
# 3 GLYOHMETRANS-RXN SER_c + THF_c <=> GLY_c + METHYLENE-THF_c + WATER_c
# 3 GLYOHMETRANS-RXN SER_c + THF_c <=> GLY_c + METHYLENE-THF_c + WATER_c
#
# 4 LTAA-RXN L-ALLO-THREONINE_c --> ACETALD_c + GLY_c
# 4 LTAA-RXN L-ALLO-THREONINE_c --> ACETALD_c + GLY_c
#
# 5 RXN0-5240 D-ALANINE_c + PYRIDOXAL_PHOSPHATE_c --> PYRIDOXAMINE-5P_c + PYRUVATE_c
# 5 RXN0-5240 D-ALANINE_c + PYRIDOXAL_PHOSPHATE_c <=> PYRIDOXAMINE-5P_c + PYRUVATE_c
#
# 6 THREONINE-ALDOLASE-RXN THR_c --> ACETALD_c + GLY_c
# 6 THREONINE-ALDOLASE-RXN THR_c --> ACETALD_c + GLY_c
#
# 7 RXN0-6563 CPD0-2189_c <=> GLYCOLALDEHYDE_c + GLY_c
# 7 RXN0-6563 CPD0-2189_c <=> GLYCOLALDEHYDE_c + GLY_c
#
# 8 DIMETHUROPORDEHYDROG-RXN DIHYDROSIROHYDROCHLORIN_c + NAD_c --> NADH_c + PROTON_c + SIROHYDROCHLORIN_c
# 8 DIMETHUROPORDEHYDROG-RXN DIHYDROSIROHYDROCHLORIN_c + NAD_c --> NADH_c + 2.0 PROTON_c + SIROHYDROCHLORIN_c
#
# 9 RXN-13403 2.0 S-ADENOSYLMETHIONINE_c + UROPORPHYRINOGEN-III_c --> 2.0 ADENOSYL-HOMO-CYS_c + DIHYDROSIROHYDROCHLORIN_c + PROTON_c
# 9 RXN-13403 2.0 S-ADENOSYLMETHIONINE_c + UROPORPHYRINOGEN-III_c --> 2.0 ADENOSYL-HOMO-CYS_c + DIHYDROSIROHYDROCHLORIN_c + PROTON_c
#
# 10 SIROHEME-FERROCHELAT-RXN FE+2_c + SIROHYDROCHLORIN_c --> 3.0 PROTON_c + SIROHEME_c
# 10 SIROHEME-FERROCHELAT-RXN FE+2_c + SIROHYDROCHLORIN_c --> 2.0 PROTON_c + SIROHEME_c
#
# 11 RXN0-1461 COPROPORPHYRINOGEN_III_c + OXYGEN-MOLECULE_c + 2.0 PROTON_c --> 2.0 CARBON-DIOXIDE_c + PROTOPORPHYRINOGEN_c + 2.0 WATER_c
# 11 RXN0-1461 COPROPORPHYRINOGEN_III_c + OXYGEN-MOLECULE_c + 2.0 PROTON_c --> 2.0 CARBON-DIOXIDE_c + PROTOPORPHYRINOGEN_c + 2.0 WATER_c
#
# 12 GLUTATHIONE-REDUCT-NADPH-RXN NADPH_c + OXIDIZED-GLUTATHIONE_c + PROTON_c <=> 2.0 GLUTATHIONE_c + NADP_c
# 12 GLUTATHIONE-REDUCT-NADPH-RXN NADPH_c + OXIDIZED-GLUTATHIONE_c + PROTON_c --> 2.0 GLUTATHIONE_c + NADP_c
#
# 13 RXN0-2382 INDOLE_c + SER_c --> TRP_c + WATER_c
# 13 RXN0-2382 INDOLE_c + SER_c --> TRP_c + WATER_c
#
# 14 TRYPSYN-RXN INDOLE-3-GLYCEROL-P_c + SER_c --> GAP_c + TRP_c + WATER_c
# 14 TRYPSYN-RXN INDOLE-3-GLYCEROL-P_c + SER_c --> GAP_c + TRP_c + WATER_c
#
# 15 RXN0-2381 INDOLE-3-GLYCEROL-P_c --> GAP_c + INDOLE_c
# 15 RXN0-2381 INDOLE-3-GLYCEROL-P_c <=> GAP_c + INDOLE_c
#
# 16 BRANCHED-CHAINAMINOTRANSFERILEU-RXN 2-KETOGLUTARATE_c + ILE_c <=> 2-KETO-3-METHYL-VALERATE_c + GLT_c
# 16 BRANCHED-CHAINAMINOTRANSFERILEU-RXN 2-KETOGLUTARATE_c + ILE_c <=> 2-KETO-3-METHYL-VALERATE_c + GLT_c
#
# 17 BRANCHED-CHAINAMINOTRANSFERVAL-RXN 2-KETOGLUTARATE_c + VAL_c <=> 2-KETO-ISOVALERATE_c + GLT_c
# 17 BRANCHED-CHAINAMINOTRANSFERVAL-RXN 2-KETOGLUTARATE_c + VAL_c <=> 2-KETO-ISOVALERATE_c + GLT_c
#
# 18 BRANCHED-CHAINAMINOTRANSFERLEU-RXN 2K-4CH3-PENTANOATE_c + GLT_c --> 2-KETOGLUTARATE_c + LEU_c
# 18 BRANCHED-CHAINAMINOTRANSFERLEU-RXN 2-KETOGLUTARATE_c + LEU_c <=> 2K-4CH3-PENTANOATE_c + GLT_c
#
# 19 TYROSINE-AMINOTRANSFERASE-RXN 2-KETOGLUTARATE_c + TYR_c <=> GLT_c + P-HYDROXY-PHENYLPYRUVATE_c
# 19 TYROSINE-AMINOTRANSFERASE-RXN 2-KETOGLUTARATE_c + TYR_c <=> GLT_c + P-HYDROXY-PHENYLPYRUVATE_c
#
# 20 SHIKIMATE-5-DEHYDROGENASE-RXN 3-DEHYDRO-SHIKIMATE_c + NADPH_c + PROTON_c <=> NADP_c + SHIKIMATE_c
# 20 SHIKIMATE-5-DEHYDROGENASE-RXN 3-DEHYDRO-SHIKIMATE_c + NADPH_c + PROTON_c --> NADP_c + SHIKIMATE_c
#
# 21 GLUTSEMIALDEHYDROG-RXN L-GLUTAMATE-5-P_c + NADPH_c + PROTON_c --> L-GLUTAMATE_GAMMA-SEMIALDEHYDE_c + NADP_c + Pi_c
# 21 GLUTSEMIALDEHYDROG-RXN L-GLUTAMATE-5-P_c + NADPH_c + PROTON_c --> L-GLUTAMATE_GAMMA-SEMIALDEHYDE_c + NADP_c + Pi_c
#
# 22 RIBOFLAVINSYNDEAM-RXN DIAMINO-OH-PHOSPHORIBOSYLAMINO-PYR_c + PROTON_c + WATER_c --> AMMONIUM_c + CPD-602_c
# 22 RIBOFLAVINSYNDEAM-RXN DIAMINO-OH-PHOSPHORIBOSYLAMINO-PYR_c + PROTON_c + WATER_c --> AMMONIUM_c + CPD-602_c
#
# 23 RIBOFLAVINSYNREDUC-RXN CPD-602_c + NADPH_c + PROTON_c --> CPD-1086_c + NADP_c
# 23 RIBOFLAVINSYNREDUC-RXN CPD-602_c + NADPH_c + PROTON_c --> CPD-1086_c + NADP_c
#
# 24 RIBOFLAVINKIN-RXN ATP_c + RIBOFLAVIN_c --> ADP_c + FMN_c + PROTON_c
# 24 RIBOFLAVINKIN-RXN ATP_c + RIBOFLAVIN_c --> ADP_c + FMN_c + PROTON_c
#
# 25 FADSYN-RXN ATP_c + FMN_c + PROTON_c --> FAD_c + PPI_c
# 25 FADSYN-RXN ATP_c + FMN_c + PROTON_c --> FAD_c + PPI_c
#
# 26 RIBOPHOSPHAT-RXN CPD-1086_c + WATER_c --> AMINO-RIBOSYLAMINO-1H-3H-PYR-DIONE_c + Pi_c
# 26 RIBOPHOSPHAT-RXN CPD-1086_c + WATER_c --> AMINO-RIBOSYLAMINO-1H-3H-PYR-DIONE_c + Pi_c
#
# 27 RXN0-5187 FMN_c + WATER_c --> Pi_c + RIBOFLAVIN_c
# 27 RXN0-5187 FMN_c + WATER_c --> Pi_c + RIBOFLAVIN_c
#
# 28 RIBOFLAVIN-SYN-RXN 2.0 DIMETHYL-D-RIBITYL-LUMAZINE_c --> AMINO-RIBOSYLAMINO-1H-3H-PYR-DIONE_c + RIBOFLAVIN_c
# 28 RIBOFLAVIN-SYN-RXN 2.0 DIMETHYL-D-RIBITYL-LUMAZINE_c + PROTON_c --> AMINO-RIBOSYLAMINO-1H-3H-PYR-DIONE_c + RIBOFLAVIN_c
#
# 29 FPPSYN-RXN DELTA3-ISOPENTENYL-PP_c + GERANYL-PP_c --> FARNESYL-PP_c + PPI_c
# 29 FPPSYN-RXN DELTA3-ISOPENTENYL-PP_c + GERANYL-PP_c --> FARNESYL-PP_c + PPI_c
#
# 30 GPPSYN-RXN CPD-4211_c + DELTA3-ISOPENTENYL-PP_c --> GERANYL-PP_c + PPI_c
# 30 GPPSYN-RXN CPD-4211_c + DELTA3-ISOPENTENYL-PP_c --> GERANYL-PP_c + PPI_c
#
# 31 UROGENIIISYN-RXN HYDROXYMETHYLBILANE_c --> UROPORPHYRINOGEN-III_c + WATER_c
# 31 UROGENIIISYN-RXN HYDROXYMETHYLBILANE_c --> UROPORPHYRINOGEN-III_c + WATER_c
#
# 32 UROGENDECARBOX-RXN 4.0 PROTON_c + UROPORPHYRINOGEN-III_c --> 4.0 CARBON-DIOXIDE_c + COPROPORPHYRINOGEN_III_c
# 32 UROGENDECARBOX-RXN 4.0 PROTON_c + UROPORPHYRINOGEN-III_c --> 4.0 CARBON-DIOXIDE_c + COPROPORPHYRINOGEN_III_c
#
# 33 THYM-PHOSPH-RXN Pi_c + THYMIDINE_c <=> DEOXY-D-RIBOSE-1-PHOSPHATE_c + THYMINE_c
# 33 THYM-PHOSPH-RXN Pi_c + THYMIDINE_c <=> DEOXY-D-RIBOSE-1-PHOSPHATE_c + THYMINE_c
#
# 34 URA-PHOSPH-RXN DEOXYURIDINE_c + Pi_c <=> DEOXY-D-RIBOSE-1-PHOSPHATE_c + URACIL_c
# 34 URA-PHOSPH-RXN DEOXYURIDINE_c + Pi_c <=> DEOXY-D-RIBOSE-1-PHOSPHATE_c + URACIL_c
#
# 35 CARBODEHYDRAT-RXN CARBON-DIOXIDE_c + WATER_c <=> H2CO3_c + PROTON_c
# 35 CARBODEHYDRAT-RXN H2CO3_c <=> CARBON-DIOXIDE_c + WATER_c
#
# 36 AICARTRANSFORM-RXN 10-FORMYL-THF_c + AICAR_c <=> PHOSPHORIBOSYL-FORMAMIDO-CARBOXAMIDE_c + THF_c
# 36 AICARTRANSFORM-RXN 10-FORMYL-THF_c + AICAR_c <=> PHOSPHORIBOSYL-FORMAMIDO-CARBOXAMIDE_c + THF_c
#
# 37 IMPCYCLOHYDROLASE-RXN IMP_c + WATER_c <=> PHOSPHORIBOSYL-FORMAMIDO-CARBOXAMIDE_c
# 37 IMPCYCLOHYDROLASE-RXN IMP_c + WATER_c <=> PHOSPHORIBOSYL-FORMAMIDO-CARBOXAMIDE_c
#
# 38 IMP-DEHYDROG-RXN IMP_c + NAD_c + WATER_c --> NADH_c + PROTON_c + XANTHOSINE-5-PHOSPHATE_c
# 38 IMP-DEHYDROG-RXN IMP_c + NAD_c + WATER_c <=> NADH_c + PROTON_c + XANTHOSINE-5-PHOSPHATE_c
#
# 39 RXN-11667 CPD-12173_c <=> CROTONYL-COA_c + WATER_c
# 39 RXN-11667 S-3-HYDROXYBUTANOYL-COA_c <=> CROTONYL-COA_c + WATER_c
#
# 40 RXN-12567 OH-HEXANOYL-COA_c <=> CPD0-2121_c + WATER_c
# 40 RXN-12567 OH-HEXANOYL-COA_c --> CPD0-2121_c + WATER_c
#
# 41 RXN-11662 ACETOACETYL-COA_c + NADH_c + PROTON_c <=> CPD-12173_c + NAD_c
# 41 RXN-11662 NAD_c + S-3-HYDROXYBUTANOYL-COA_c <=> ACETOACETYL-COA_c + NADH_c + PROTON_c
#
# 42 RXN-12490 CPD0-2123_c + NADH_c + PROTON_c <=> CPD0-2244_c + NAD_c
# 42 RXN-12490 CPD0-2244_c + NAD_c --> CPD0-2123_c + NADH_c + PROTON_c
#
# 43 RXN-13616 CPD0-2244_c <=> T2-DECENOYL-COA_c + WATER_c
# 43 RXN-13616 T2-DECENOYL-COA_c + WATER_c --> CPD0-2244_c
#
# 44 HYPOXANPRIBOSYLTRAN-RXN HYPOXANTHINE_c + PRPP_c --> IMP_c + PPI_c
# 44 HYPOXANPRIBOSYLTRAN-RXN HYPOXANTHINE_c + PRPP_c --> IMP_c + PPI_c
#
# 45 GUANPRIBOSYLTRAN-RXN GUANINE_c + PRPP_c --> GMP_c + PPI_c
# 45 GUANPRIBOSYLTRAN-RXN GUANINE_c + PRPP_c --> GMP_c + PPI_c
#
# 46 XANPRIBOSYLTRAN-RXN PRPP_c + XANTHINE_c --> PPI_c + XANTHOSINE-5-PHOSPHATE_c
# 46 XANPRIBOSYLTRAN-RXN PRPP_c + XANTHINE_c --> PPI_c + XANTHOSINE-5-PHOSPHATE_c
#
# 47 ADENYL-KIN-RXN AMP_c + ATP_c <=> 2.0 ADP_c
# 47 ADENYL-KIN-RXN AMP_c + ATP_c <=> 2.0 ADP_c
#
# 48 DTDPKIN-RXN ATP_c + TDP_c <=> ADP_c + TTP_c
# 48 DTDPKIN-RXN ATP_c + TDP_c --> ADP_c + TTP_c
#
# 49 GDPKIN-RXN ATP_c + GDP_c <=> ADP_c + GTP_c
# 49 GDPKIN-RXN ATP_c + GDP_c --> ADP_c + GTP_c
#
# 50 RXN-14074 AMP_c + GTP_c <=> ADP_c + GDP_c
# 50 RXN-14074 AMP_c + GTP_c --> ADP_c + GDP_c
#
# 51 DGDPKIN-RXN ATP_c + DGDP_c <=> ADP_c + DGTP_c
# 51 DGDPKIN-RXN ATP_c + DGDP_c --> ADP_c + DGTP_c
#
# 52 DADPKIN-RXN ATP_c + DADP_c <=> ADP_c + DATP_c
# 52 DADPKIN-RXN ATP_c + DADP_c --> ADP_c + DATP_c
#
# 53 UDPKIN-RXN ATP_c + UDP_c <=> ADP_c + UTP_c
# 53 UDPKIN-RXN ATP_c + UDP_c --> ADP_c + UTP_c
#
# 54 CDPKIN-RXN ATP_c + CDP_c <=> ADP_c + CTP_c
# 54 CDPKIN-RXN ATP_c + CDP_c --> ADP_c + CTP_c
#
# 55 DUDPKIN-RXN ATP_c + DUDP_c <=> ADP_c + DUTP_c
# 55 DUDPKIN-RXN ATP_c + DUDP_c --> ADP_c + DUTP_c
#
# 56 DCDPKIN-RXN ATP_c + DCDP_c <=> ADP_c + DCTP_c
# 56 DCDPKIN-RXN ATP_c + DCDP_c --> ADP_c + DCTP_c
#
# 57 DIHYDROOROT-RXN DI-H-OROTATE_c + WATER_c <=> CARBAMYUL-L-ASPARTATE_c + PROTON_c
# 57 DIHYDROOROT-RXN DI-H-OROTATE_c + WATER_c <=> CARBAMYUL-L-ASPARTATE_c + PROTON_c
#
# 58 OROTPDECARB-RXN OROTIDINE-5-PHOSPHATE_c + PROTON_c --> CARBON-DIOXIDE_c + UMP_c
# 58 OROTPDECARB-RXN OROTIDINE-5-PHOSPHATE_c + PROTON_c --> CARBON-DIOXIDE_c + UMP_c
#
# 59 CITSYN-RXN ACETYL-COA_c + OXALACETIC_ACID_c + WATER_c --> CIT_c + CO-A_c + PROTON_c
# 59 CITSYN-RXN ACETYL-COA_c + OXALACETIC_ACID_c + WATER_c --> CIT_c + CO-A_c + PROTON_c
#
# 60 ACETALD-DEHYDROG-RXN ACETALD_c + CO-A_c + NAD_c <=> ACETYL-COA_c + NADH_c + PROTON_c
# 60 ACETALD-DEHYDROG-RXN ACETALD_c + CO-A_c + NAD_c <=> ACETYL-COA_c + NADH_c + PROTON_c
#
# 61 INORGPYROPHOSPHAT-RXN PPI_c + WATER_c --> PROTON_c + 2.0 Pi_c
# 61 INORGPYROPHOSPHAT-RXN PPI_c + WATER_c --> PROTON_c + 2.0 Pi_c
#
# 62 TRIPHOSPHATASE-RXN P3I_c + WATER_c --> PPI_c + PROTON_c + Pi_c
# 62 TRIPHOSPHATASE-RXN P3I_c + WATER_c --> PPI_c + Pi_c
#
# 63 RXN-7607 IMP_c + WATER_c --> INOSINE_c + Pi_c
# 63 RXN-7607 IMP_c + WATER_c --> INOSINE_c + Pi_c
#
# 64 RXN-14142 DGMP_c + WATER_c --> DEOXYGUANOSINE_c + Pi_c
# 64 RXN-14142 DGMP_c + WATER_c --> DEOXYGUANOSINE_c + Pi_c
#
# 65 XMPXAN-RXN WATER_c + XANTHOSINE-5-PHOSPHATE_c --> Pi_c + XANTHOSINE_c
# 65 XMPXAN-RXN WATER_c + XANTHOSINE-5-PHOSPHATE_c --> Pi_c + XANTHOSINE_c
#
# 66 AMP-DEPHOSPHORYLATION-RXN AMP_c + WATER_c --> ADENOSINE_c + Pi_c
# 66 AMP-DEPHOSPHORYLATION-RXN AMP_c + WATER_c --> ADENOSINE_c + Pi_c
#
# 67 RXN-7609 GMP_c + WATER_c --> GUANOSINE_c + Pi_c
# 67 RXN-7609 GMP_c + WATER_c --> GUANOSINE_c + Pi_c
#
# 68 PEPCARBOXYKIN-RXN ATP_c + OXALACETIC_ACID_c --> ADP_c + CARBON-DIOXIDE_c + PHOSPHO-ENOL-PYRUVATE_c
# 68 PEPCARBOXYKIN-RXN ATP_c + OXALACETIC_ACID_c --> ADP_c + CARBON-DIOXIDE_c + PHOSPHO-ENOL-PYRUVATE_c
#
# 69 1.1.1.39-RXN MAL_c + NAD_c --> CARBON-DIOXIDE_c + NADH_c + PYRUVATE_c
# 69 1.1.1.39-RXN MAL_c + NAD_c --> CARBON-DIOXIDE_c + NADH_c + PYRUVATE_c
#
# 70 ALARACECAT-RXN L-ALPHA-ALANINE_c <=> D-ALANINE_c
# 70 ALARACECAT-RXN L-ALPHA-ALANINE_c <=> D-ALANINE_c
#
# 71 ALANINE-AMINOTRANSFERASE-RXN 2-KETOGLUTARATE_c + L-ALPHA-ALANINE_c <=> GLT_c + PYRUVATE_c
# 71 ALANINE-AMINOTRANSFERASE-RXN 2-KETOGLUTARATE_c + L-ALPHA-ALANINE_c <=> GLT_c + PYRUVATE_c
#
# 72 XYLULOKIN-RXN ATP_c + D-XYLULOSE_c --> ADP_c + PROTON_c + XYLULOSE-5-PHOSPHATE_c
# 72 XYLULOKIN-RXN ATP_c + D-XYLULOSE_c --> ADP_c + PROTON_c + XYLULOSE-5-PHOSPHATE_c
#
# 73 GLYCEROL-KIN-RXN ATP_c + GLYCEROL_c --> ADP_c + GLYCEROL-3P_c + PROTON_c
# 73 GLYCEROL-KIN-RXN ATP_c + GLYCEROL_c <=> ADP_c + GLYCEROL-3P_c + PROTON_c
#
# 74 D-PPENTOMUT-RXN DEOXY-D-RIBOSE-1-PHOSPHATE_c <=> DEOXY-RIBOSE-5P_c
# 74 D-PPENTOMUT-RXN DEOXY-D-RIBOSE-1-PHOSPHATE_c <=> DEOXY-RIBOSE-5P_c
#
# 75 PEPDEPHOS-RXN ADP_c + PHOSPHO-ENOL-PYRUVATE_c + PROTON_c --> ATP_c + PYRUVATE_c
# 75 PEPDEPHOS-RXN ADP_c + PHOSPHO-ENOL-PYRUVATE_c + PROTON_c --> ATP_c + PYRUVATE_c
#
# 76 DARAB5PISOM-RXN RIBULOSE-5P_c <=> ARABINOSE-5P_c
# 76 DARAB5PISOM-RXN ARABINOSE-5P_c <=> RIBULOSE-5P_c
#
# 77 RXN-8991 2-D-THREO-HYDROXY-3-CARBOXY-ISOCAPROATE_c <=> CPD-9451_c + WATER_c
# 77 RXN-8991 2-D-THREO-HYDROXY-3-CARBOXY-ISOCAPROATE_c <=> CPD-9451_c + WATER_c
#
# 78 3-ISOPROPYLMALISOM-RXN CPD-9451_c + WATER_c <=> 3-CARBOXY-3-HYDROXY-ISOCAPROATE_c
# 78 3-ISOPROPYLMALISOM-RXN CPD-9451_c + WATER_c <=> 3-CARBOXY-3-HYDROXY-ISOCAPROATE_c
#
# 79 ACETOLACTSYN-RXN PROTON_c + 2.0 PYRUVATE_c --> 2-ACETO-LACTATE_c + CARBON-DIOXIDE_c
# 79 ACETOLACTSYN-RXN PROTON_c + 2.0 PYRUVATE_c --> 2-ACETO-LACTATE_c + CARBON-DIOXIDE_c
#
# 80 ACETOOHBUTSYN-RXN 2-OXOBUTANOATE_c + PROTON_c + PYRUVATE_c --> 2-ACETO-2-HYDROXY-BUTYRATE_c + CARBON-DIOXIDE_c
# 80 ACETOOHBUTSYN-RXN 2-OXOBUTANOATE_c + PROTON_c + PYRUVATE_c --> 2-ACETO-2-HYDROXY-BUTYRATE_c + CARBON-DIOXIDE_c
#
# 81 2.5.1.19-RXN PHOSPHO-ENOL-PYRUVATE_c + SHIKIMATE-5P_c <=> 3-ENOLPYRUVYL-SHIKIMATE-5P_c + Pi_c
# 81 2.5.1.19-RXN PHOSPHO-ENOL-PYRUVATE_c + SHIKIMATE-5P_c <=> 3-ENOLPYRUVYL-SHIKIMATE-5P_c + Pi_c
#
# 82 PRTRANS-RXN ANTHRANILATE_c + PRPP_c --> N-5-PHOSPHORIBOSYL-ANTHRANILATE_c + PPI_c
# 82 PRTRANS-RXN N-5-PHOSPHORIBOSYL-ANTHRANILATE_c + PPI_c <=> ANTHRANILATE_c + PRPP_c
#
# 83 ANTHRANSYN-RXN CHORISMATE_c + GLN_c --> ANTHRANILATE_c + GLT_c + PROTON_c + PYRUVATE_c
# 83 ANTHRANSYN-RXN CHORISMATE_c + GLN_c <=> ANTHRANILATE_c + GLT_c + PROTON_c + PYRUVATE_c
#
# 84 PREPHENATEDEHYDRAT-RXN PREPHENATE_c + PROTON_c --> CARBON-DIOXIDE_c + PHENYL-PYRUVATE_c + WATER_c
# 84 PREPHENATEDEHYDRAT-RXN PREPHENATE_c + PROTON_c <=> CARBON-DIOXIDE_c + PHENYL-PYRUVATE_c + WATER_c
#
# 85 CHORISMATEMUT-RXN CHORISMATE_c --> PREPHENATE_c
# 85 CHORISMATEMUT-RXN CHORISMATE_c <=> PREPHENATE_c
#
# 86 CHORISMATE-SYNTHASE-RXN 3-ENOLPYRUVYL-SHIKIMATE-5P_c --> CHORISMATE_c + Pi_c
# 86 CHORISMATE-SYNTHASE-RXN 3-ENOLPYRUVYL-SHIKIMATE-5P_c --> CHORISMATE_c + Pi_c
#
# 87 IGPSYN-RXN CARBOXYPHENYLAMINO-DEOXYRIBULOSE-P_c + PROTON_c --> CARBON-DIOXIDE_c + INDOLE-3-GLYCEROL-P_c + WATER_c
# 87 IGPSYN-RXN CARBOXYPHENYLAMINO-DEOXYRIBULOSE-P_c + PROTON_c --> CARBON-DIOXIDE_c + INDOLE-3-GLYCEROL-P_c + WATER_c
#
# 88 PRAISOM-RXN N-5-PHOSPHORIBOSYL-ANTHRANILATE_c --> CARBOXYPHENYLAMINO-DEOXYRIBULOSE-P_c
# 88 PRAISOM-RXN N-5-PHOSPHORIBOSYL-ANTHRANILATE_c --> CARBOXYPHENYLAMINO-DEOXYRIBULOSE-P_c
#
# 89 2PGADEHYDRAT-RXN 2-PG_c <=> PHOSPHO-ENOL-PYRUVATE_c + WATER_c
# 89 2PGADEHYDRAT-RXN 2-PG_c <=> PHOSPHO-ENOL-PYRUVATE_c + WATER_c
#
# 90 METHGLYSYN-RXN DIHYDROXY-ACETONE-PHOSPHATE_c --> METHYL-GLYOXAL_c + Pi_c
# 90 METHGLYSYN-RXN DIHYDROXY-ACETONE-PHOSPHATE_c --> METHYL-GLYOXAL_c + Pi_c
#
# 91 PEPSYNTH-RXN ATP_c + PYRUVATE_c + WATER_c --> AMP_c + PHOSPHO-ENOL-PYRUVATE_c + 2.0 PROTON_c + Pi_c
# 91 PEPSYNTH-RXN ATP_c + PYRUVATE_c + WATER_c <=> AMP_c + PHOSPHO-ENOL-PYRUVATE_c + 2.0 PROTON_c + Pi_c
#
# 92 PGLUCISOM-RXN D-glucopyranose-6-phosphate_c <=> FRUCTOSE-6P_c
# 92 PGLUCISOM-RXN D-glucopyranose-6-phosphate_c <=> FRUCTOSE-6P_c
#
# 93 PHOSGLYPHOS-RXN ATP_c + G3P_c <=> ADP_c + DPG_c
# 93 PHOSGLYPHOS-RXN ATP_c + G3P_c <=> ADP_c + DPG_c
#
# 94 KDPGALDOL-RXN 2-KETO-3-DEOXY-6-P-GLUCONATE_c --> GAP_c + PYRUVATE_c
# 94 KDPGALDOL-RXN 2-KETO-3-DEOXY-6-P-GLUCONATE_c --> GAP_c + PYRUVATE_c
#
# 95 OXALODECARB-RXN OXALACETIC_ACID_c + PROTON_c --> CARBON-DIOXIDE_c + PYRUVATE_c
# 95 OXALODECARB-RXN OXALACETIC_ACID_c + PROTON_c --> CARBON-DIOXIDE_c + PYRUVATE_c
#
# 96 RIBULP3EPIM-RXN RIBULOSE-5P_c <=> XYLULOSE-5-PHOSPHATE_c
# 96 RIBULP3EPIM-RXN RIBULOSE-5P_c <=> XYLULOSE-5-PHOSPHATE_c
#
# 97 TRANSALDOL-RXN D-SEDOHEPTULOSE-7-P_c + GAP_c <=> ERYTHROSE-4P_c + FRUCTOSE-6P_c
# 97 TRANSALDOL-RXN D-SEDOHEPTULOSE-7-P_c + GAP_c <=> ERYTHROSE-4P_c + FRUCTOSE-6P_c
#
# 98 2TRANSKETO-RXN ERYTHROSE-4P_c + XYLULOSE-5-PHOSPHATE_c <=> FRUCTOSE-6P_c + GAP_c
# 98 2TRANSKETO-RXN ERYTHROSE-4P_c + XYLULOSE-5-PHOSPHATE_c <=> FRUCTOSE-6P_c + GAP_c
#
# 99 ALCOHOL-DEHYDROG-RXN ETOH_c + NAD_c <=> ACETALD_c + NADH_c + PROTON_c
# 99 ALCOHOL-DEHYDROG-RXN ETOH_c + NAD_c <=> ACETALD_c + NADH_c + PROTON_c
#
# 100 2.7.7.1-RXN ATP_c + NICOTINAMIDE_NUCLEOTIDE_c + PROTON_c --> NAD_c + PPI_c
# 100 2.7.7.1-RXN ATP_c + NICOTINAMIDE_NUCLEOTIDE_c + PROTON_c --> NAD_c + PPI_c
#
# 101 NICONUCADENYLYLTRAN-RXN ATP_c + NICOTINATE_NUCLEOTIDE_c + PROTON_c <=> DEAMIDO-NAD_c + PPI_c
# 101 NICONUCADENYLYLTRAN-RXN ATP_c + NICOTINATE_NUCLEOTIDE_c + PROTON_c --> DEAMIDO-NAD_c + PPI_c
#
# 102 PYRIMSYN3-RXN AMINO-HYDROXYMETHYL-METHYL-PYR-P_c + ATP_c --> ADP_c + AMINO-HYDROXYMETHYL-METHYLPYRIMIDINE-PP_c
# 102 PYRIMSYN3-RXN AMINO-HYDROXYMETHYL-METHYL-PYR-P_c + ATP_c --> ADP_c + AMINO-HYDROXYMETHYL-METHYLPYRIMIDINE-PP_c
#
# 103 OHMETPYRKIN-RXN ATP_c + HMP_c --> ADP_c + AMINO-HYDROXYMETHYL-METHYL-PYR-P_c + PROTON_c
# 103 OHMETPYRKIN-RXN ATP_c + HMP_c --> ADP_c + AMINO-HYDROXYMETHYL-METHYL-PYR-P_c + PROTON_c
#
# 104 DEOXYINOPHOSPHOR-RXN DEOXYINOSINE_c + Pi_c <=> DEOXY-D-RIBOSE-1-PHOSPHATE_c + HYPOXANTHINE_c
# 104 DEOXYINOPHOSPHOR-RXN DEOXYINOSINE_c + Pi_c <=> DEOXY-D-RIBOSE-1-PHOSPHATE_c + HYPOXANTHINE_c
#
# 105 ADENPHOSPHOR-RXN ADENOSINE_c + Pi_c <=> ADENINE_c + RIBOSE-1P_c
# 105 ADENPHOSPHOR-RXN ADENOSINE_c + Pi_c <=> ADENINE_c + RIBOSE-1P_c
#
# 106 INOPHOSPHOR-RXN INOSINE_c + Pi_c <=> HYPOXANTHINE_c + RIBOSE-1P_c
# 106 INOPHOSPHOR-RXN INOSINE_c + Pi_c <=> HYPOXANTHINE_c + RIBOSE-1P_c
#
# 107 DEOXYGUANPHOSPHOR-RXN DEOXYGUANOSINE_c + Pi_c <=> DEOXY-D-RIBOSE-1-PHOSPHATE_c + GUANINE_c
# 107 DEOXYGUANPHOSPHOR-RXN DEOXYGUANOSINE_c + Pi_c <=> DEOXY-D-RIBOSE-1-PHOSPHATE_c + GUANINE_c
#
# 108 RXN0-5199 GUANOSINE_c + Pi_c <=> GUANINE_c + RIBOSE-1P_c
# 108 RXN0-5199 GUANOSINE_c + Pi_c <=> GUANINE_c + RIBOSE-1P_c
#
# 109 DEOXYADENPHOSPHOR-RXN DEOXYADENOSINE_c + Pi_c <=> ADENINE_c + DEOXY-D-RIBOSE-1-PHOSPHATE_c
# 109 DEOXYADENPHOSPHOR-RXN DEOXYADENOSINE_c + Pi_c <=> ADENINE_c + DEOXY-D-RIBOSE-1-PHOSPHATE_c
#
# 110 OROPRIBTRANS-RXN OROTIDINE-5-PHOSPHATE_c + PPI_c <=> OROTATE_c + PRPP_c
# 110 OROPRIBTRANS-RXN OROTIDINE-5-PHOSPHATE_c + PPI_c <=> OROTATE_c + PRPP_c
#
# 111 DIHYDROXYISOVALDEHYDRAT-RXN CPD-13357_c --> 2-KETO-ISOVALERATE_c + WATER_c
# 111 DIHYDROXYISOVALDEHYDRAT-RXN CPD-13357_c --> 2-KETO-ISOVALERATE_c + WATER_c
#
# 112 DIHYDROXYMETVALDEHYDRAT-RXN 1-KETO-2-METHYLVALERATE_c --> 2-KETO-3-METHYL-VALERATE_c + WATER_c
# 112 DIHYDROXYMETVALDEHYDRAT-RXN 1-KETO-2-METHYLVALERATE_c --> 2-KETO-3-METHYL-VALERATE_c + WATER_c
#
# 113 PHOSACETYLTRANS-RXN ACETYL-COA_c + Pi_c <=> ACETYL-P_c + CO-A_c
# 113 PHOSACETYLTRANS-RXN ACETYL-COA_c + Pi_c <=> ACETYL-P_c + CO-A_c
#
# 114 PTAALT-RXN PROPIONYL-COA_c + Pi_c --> CO-A_c + PROPIONYL-P_c
# 114 PTAALT-RXN PROPIONYL-COA_c + Pi_c <=> CO-A_c + PROPIONYL-P_c
#
# 115 ACETATEKIN-RXN ACET_c + ATP_c <=> ACETYL-P_c + ADP_c
# 115 ACETATEKIN-RXN ACET_c + ATP_c <=> ACETYL-P_c + ADP_c
#
# 116 KDOTRANS-RXN CMP-KDO_c + LIPID-IV-A_c --> CMP_c + KDO-LIPID-IVA_c + PROTON_c
# 116 KDOTRANS-RXN CMP-KDO_c + LIPID-IV-A_c --> CMP_c + KDO-LIPID-IVA_c + PROTON_c
#
# 117 KDOTRANS2-RXN CMP-KDO_c + KDO-LIPID-IVA_c --> CMP_c + KDO2-LIPID-IVA_c + PROTON_c
# 117 KDOTRANS2-RXN CMP-KDO_c + KDO-LIPID-IVA_c --> CMP_c + KDO2-LIPID-IVA_c + PROTON_c
#
# 118 LIPIDXSYNTHESIS-RXN OH-MYRISTOYL_c + WATER_c --> BISOHMYR-GLUCOSAMINYL-1P_c + 2.0 PROTON_c + UMP_c
# 118 LIPIDXSYNTHESIS-RXN OH-MYRISTOYL_c + WATER_c --> BISOHMYR-GLUCOSAMINYL-1P_c + 2.0 PROTON_c + UMP_c
#
# 119 LIPIDADISACCHARIDESYNTH-RXN BISOHMYR-GLUCOSAMINYL-1P_c + OH-MYRISTOYL_c --> BISOHMYR-GLC_c + PROTON_c + UDP_c
# 119 LIPIDADISACCHARIDESYNTH-RXN BISOHMYR-GLUCOSAMINYL-1P_c + OH-MYRISTOYL_c --> BISOHMYR-GLC_c + PROTON_c + UDP_c
#
# 120 TETRAACYLDISACC4KIN-RXN ATP_c + BISOHMYR-GLC_c --> ADP_c + LIPID-IV-A_c + PROTON_c
# 120 TETRAACYLDISACC4KIN-RXN ATP_c + BISOHMYR-GLC_c --> ADP_c + LIPID-IV-A_c + PROTON_c
#
# 121 RXN0-5107 TTP_c + WATER_c --> PPI_c + PROTON_c + TMP_c
# 121 RXN0-5107 TTP_c + WATER_c --> PPI_c + PROTON_c + TMP_c
#
# 122 RXN-14139 UTP_c + WATER_c --> PPI_c + PROTON_c + UMP_c
# 122 RXN-14139 UTP_c + WATER_c --> PPI_c + PROTON_c + UMP_c
#
# 123 ATP-PYROPHOSPHATASE-RXN ATP_c + WATER_c --> AMP_c + PPI_c + PROTON_c
# 123 ATP-PYROPHOSPHATASE-RXN ATP_c + WATER_c --> AMP_c + PPI_c + PROTON_c
#
# 124 1.1.1.83-RXN CPD-660_c + NAD_c --> CARBON-DIOXIDE_c + NADH_c + PYRUVATE_c
# 124 1.1.1.83-RXN CPD-660_c + NAD_c --> CARBON-DIOXIDE_c + NADH_c + PYRUVATE_c
#
# 125 RXN0-743 PHOSPHORIBOSYL-CARBOXY-AMINOIMIDAZOLE_c <=> CPD0-181_c
# 125 RXN0-743 CPD0-181_c --> PHOSPHORIBOSYL-CARBOXY-AMINOIMIDAZOLE_c
#
# 126 AMPSYN-RXN ADENYLOSUCC_c <=> AMP_c + FUM_c
# 126 AMPSYN-RXN ADENYLOSUCC_c <=> AMP_c + FUM_c
#
# 127 AICARSYN-RXN P-RIBOSYL-4-SUCCCARB-AMINOIMIDAZOLE_c <=> AICAR_c + FUM_c
# 127 AICARSYN-RXN P-RIBOSYL-4-SUCCCARB-AMINOIMIDAZOLE_c <=> AICAR_c + FUM_c
#
# 128 1.8.4.14-RXN CPD-8989_c + Red-Thioredoxin_c --> MET_c + Ox-Thioredoxin_c + WATER_c
# 128 1.8.4.14-RXN CPD-8990_c + Red-Thioredoxin_c --> MET_c + Ox-Thioredoxin_c + WATER_c
#
# 129 THIOREDOXIN-REDUCT-NADPH-RXN NADPH_c + Ox-Thioredoxin_c + PROTON_c --> NADP_c + Red-Thioredoxin_c
# 129 THIOREDOXIN-REDUCT-NADPH-RXN NADPH_c + Ox-Thioredoxin_c + PROTON_c --> NADP_c + Red-Thioredoxin_c
#
# 130 1.8.4.8-RXN PAPS_c + Red-Thioredoxin_c --> 3-5-ADP_c + Ox-Thioredoxin_c + 2.0 PROTON_c + SO3_c
# 130 1.8.4.8-RXN 3-5-ADP_c + Ox-Thioredoxin_c + 2.0 PROTON_c + SO3_c <=> PAPS_c + Red-Thioredoxin_c
#
# 131 THYMIDYLATESYN-RXN DUMP_c + METHYLENE-THF_c --> DIHYDROFOLATE_c + TMP_c
# 131 THYMIDYLATESYN-RXN DUMP_c + METHYLENE-THF_c --> DIHYDROFOLATE_c + TMP_c
#
# 132 P-PANTOCYSLIG-RXN 4-P-PANTOTHENATE_c + CTP_c + CYS_c --> CMP_c + PPI_c + PROTON_c + R-4-PHOSPHOPANTOTHENOYL-L-CYSTEINE_c
# 132 P-PANTOCYSLIG-RXN 4-P-PANTOTHENATE_c + CTP_c + CYS_c --> CMP_c + PPI_c + PROTON_c + R-4-PHOSPHOPANTOTHENOYL-L-CYSTEINE_c
#
# 133 P-PANTOCYSDECARB-RXN PROTON_c + R-4-PHOSPHOPANTOTHENOYL-L-CYSTEINE_c --> CARBON-DIOXIDE_c + PANTETHEINE-P_c
# 133 P-PANTOCYSDECARB-RXN PROTON_c + R-4-PHOSPHOPANTOTHENOYL-L-CYSTEINE_c --> CARBON-DIOXIDE_c + PANTETHEINE-P_c
#
# 134 FORMYLTHFDEFORMYL-RXN 10-FORMYL-THF_c + WATER_c --> FORMATE_c + PROTON_c + THF_c
# 134 FORMYLTHFDEFORMYL-RXN 10-FORMYL-THF_c + WATER_c --> FORMATE_c + PROTON_c + THF_c
#
# 135 PGLUCONDEHYDRAT-RXN CPD-2961_c --> 2-KETO-3-DEOXY-6-P-GLUCONATE_c + WATER_c
# 135 PGLUCONDEHYDRAT-RXN CPD-2961_c --> 2-KETO-3-DEOXY-6-P-GLUCONATE_c + WATER_c
#
# 136 FUMHYDR-RXN FUM_c + WATER_c <=> MAL_c
# 136 FUMHYDR-RXN MAL_c <=> FUM_c + WATER_c
#
# 137 D--TARTRATE-DEHYDRATASE-RXN D-TARTRATE_c --> OXALACETIC_ACID_c + WATER_c
# 137 D--TARTRATE-DEHYDRATASE-RXN D-TARTRATE_c <=> OXALACETIC_ACID_c + WATER_c
#
# 138 PMPOXI-RXN OXYGEN-MOLECULE_c + PYRIDOXAMINE-5P_c + WATER_c --> AMMONIUM_c + HYDROGEN-PEROXIDE_c + PYRIDOXAL_PHOSPHATE_c
# 138 PMPOXI-RXN OXYGEN-MOLECULE_c + PYRIDOXAMINE-5P_c + WATER_c --> AMMONIUM_c + HYDROGEN-PEROXIDE_c + PYRIDOXAL_PHOSPHATE_c
#
# 139 PNPOXI-RXN OXYGEN-MOLECULE_c + PYRIDOXINE-5P_c --> HYDROGEN-PEROXIDE_c + PYRIDOXAL_PHOSPHATE_c
# 139 PNPOXI-RXN OXYGEN-MOLECULE_c + PYRIDOXINE-5P_c --> HYDROGEN-PEROXIDE_c + PYRIDOXAL_PHOSPHATE_c
#
# 140 PSERTRANSAMPYR-RXN 3OH-4P-OH-ALPHA-KETOBUTYRATE_c + GLT_c <=> 2-KETOGLUTARATE_c + 4-PHOSPHONOOXY-THREONINE_c
# 140 PSERTRANSAMPYR-RXN 3OH-4P-OH-ALPHA-KETOBUTYRATE_c + GLT_c <=> 2-KETOGLUTARATE_c + 4-PHOSPHONOOXY-THREONINE_c
#
# 141 PSERTRANSAM-RXN 3-P-HYDROXYPYRUVATE_c + GLT_c --> 2-KETOGLUTARATE_c + 3-P-SERINE_c
# 141 PSERTRANSAM-RXN 2-KETOGLUTARATE_c + 3-P-SERINE_c <=> 3-P-HYDROXYPYRUVATE_c + GLT_c
#
# 142 SUCCINYLDIAMINOPIMTRANS-RXN 2-KETOGLUTARATE_c + N-SUCCINYLLL-2-6-DIAMINOPIMELATE_c <=> GLT_c + N-SUCCINYL-2-AMINO-6-KETOPIMELATE_c
# 142 SUCCINYLDIAMINOPIMTRANS-RXN 2-KETOGLUTARATE_c + N-SUCCINYLLL-2-6-DIAMINOPIMELATE_c <=> GLT_c + N-SUCCINYL-2-AMINO-6-KETOPIMELATE_c
#
# 143 HEMEOSYN-RXN FARNESYL-PP_c + PROTOHEME_c + WATER_c --> CPD-17063_c + PPI_c
# 143 HEMEOSYN-RXN FARNESYL-PP_c + PROTOHEME_c + WATER_c --> CPD-17063_c + PPI_c
#
# 144 AGMATIN-RXN AGMATHINE_c + WATER_c --> PUTRESCINE_c + UREA_c
# 144 AGMATIN-RXN AGMATHINE_c + WATER_c --> PUTRESCINE_c + UREA_c
#
# 145 ARGDECARBOX-RXN ARG_c + PROTON_c --> AGMATHINE_c + CARBON-DIOXIDE_c
# 145 ARGDECARBOX-RXN ARG_c + PROTON_c <=> AGMATHINE_c + CARBON-DIOXIDE_c
#
# 146 ARGSUCCINSYN-RXN ATP_c + L-ASPARTATE_c + L-CITRULLINE_c --> AMP_c + L-ARGININO-SUCCINATE_c + PPI_c + PROTON_c
# 146 ARGSUCCINSYN-RXN ATP_c + L-ASPARTATE_c + L-CITRULLINE_c --> AMP_c + L-ARGININO-SUCCINATE_c + PPI_c + PROTON_c
#
# 147 SPERMIDINESYN-RXN PUTRESCINE_c + S-ADENOSYLMETHIONINAMINE_c --> 5-METHYLTHIOADENOSINE_c + PROTON_c + SPERMIDINE_c
# 147 SPERMIDINESYN-RXN PUTRESCINE_c + S-ADENOSYLMETHIONINAMINE_c <=> 5-METHYLTHIOADENOSINE_c + PROTON_c + SPERMIDINE_c
#
# 148 GSAAMINOTRANS-RXN GLUTAMATE-1-SEMIALDEHYDE_c <=> 5-AMINO-LEVULINATE_c
# 148 GSAAMINOTRANS-RXN GLUTAMATE-1-SEMIALDEHYDE_c --> 5-AMINO-LEVULINATE_c
#
# 149 CPM-KDOSYNTH-RXN CTP_c + KDO_c --> CMP-KDO_c + PPI_c
# 149 CPM-KDOSYNTH-RXN CTP_c + KDO_c --> CMP-KDO_c + PPI_c
#
# 150 5.4.2.10-RXN GLUCOSAMINE-1P_c <=> D-GLUCOSAMINE-6-P_c
# 150 5.4.2.10-RXN D-GLUCOSAMINE-6-P_c <=> GLUCOSAMINE-1P_c
#
# 151 UDPNACETYLGLUCOSAMENOLPYRTRANS-RXN PHOSPHO-ENOL-PYRUVATE_c + UDP-N-ACETYL-D-GLUCOSAMINE_c --> Pi_c + UDP-ACETYL-CARBOXYVINYL-GLUCOSAMINE_c
# 151 UDPNACETYLGLUCOSAMENOLPYRTRANS-RXN PHOSPHO-ENOL-PYRUVATE_c + UDP-N-ACETYL-D-GLUCOSAMINE_c --> Pi_c + UDP-ACETYL-CARBOXYVINYL-GLUCOSAMINE_c
#
# 152 GLUTRACE-RXN D-GLT_c <=> GLT_c
# 152 GLUTRACE-RXN GLT_c <=> D-GLT_c
#
# 153 UDPGLCNACEPIM-RXN UDP-N-ACETYL-D-GLUCOSAMINE_c <=> UDP-MANNAC_c
# 153 UDPGLCNACEPIM-RXN UDP-N-ACETYL-D-GLUCOSAMINE_c <=> UDP-MANNAC_c
#
# 154 MALONYL-ACPDECARBOX-RXN MALONYL-ACP_c + PROTON_c --> ACETYL-ACP_c + CARBON-DIOXIDE_c
# 154 MALONYL-ACPDECARBOX-RXN MALONYL-ACP_c + PROTON_c --> ACETYL-ACP_c + CARBON-DIOXIDE_c
#
# 155 3-OXOACYL-ACP-SYNTH-BASE-RXN ACETYL-ACP_c + MALONYL-ACP_c + PROTON_c --> ACP_c + Acetoacetyl-ACPs_c + CARBON-DIOXIDE_c
# 155 3-OXOACYL-ACP-SYNTH-BASE-RXN ACETYL-ACP_c + MALONYL-ACP_c + PROTON_c --> ACP_c + Acetoacetyl-ACPs_c + CARBON-DIOXIDE_c
#
# 156 DHHB-METHYLTRANSFER-RXN OCTAPRENYL-METHYL-OH-METHOXY-BENZQ_c + S-ADENOSYLMETHIONINE_c --> ADENOSYL-HOMO-CYS_c + CPD-9956_c + PROTON_c
# 156 DHHB-METHYLTRANSFER-RXN OCTAPRENYL-METHYL-OH-METHOXY-BENZQ_c + S-ADENOSYLMETHIONINE_c --> ADENOSYL-HOMO-CYS_c + CPD-9956_c + PROTON_c
#
# 157 2-OCTAPRENYL-6-OHPHENOL-METHY-RXN 2-OCTAPRENYL-6-HYDROXYPHENOL_c + S-ADENOSYLMETHIONINE_c --> 2-OCTAPRENYL-6-METHOXYPHENOL_c + ADENOSYL-HOMO-CYS_c + PROTON_c
# 157 2-OCTAPRENYL-6-OHPHENOL-METHY-RXN 2-OCTAPRENYL-6-HYDROXYPHENOL_c + S-ADENOSYLMETHIONINE_c --> 2-OCTAPRENYL-6-METHOXYPHENOL_c + ADENOSYL-HOMO-CYS_c + PROTON_c
#
# 158 H2PTERIDINEPYROPHOSPHOKIN-RXN AMINO-OH-HYDROXYMETHYL-DIHYDROPTERIDINE_c + ATP_c --> AMP_c + DIHYDROPTERIN-CH2OH-PP_c + PROTON_c
# 158 H2PTERIDINEPYROPHOSPHOKIN-RXN AMINO-OH-HYDROXYMETHYL-DIHYDROPTERIDINE_c + ATP_c --> AMP_c + DIHYDROPTERIN-CH2OH-PP_c + PROTON_c
#
# 159 PANTEPADENYLYLTRAN-RXN ATP_c + PANTETHEINE-P_c + PROTON_c --> DEPHOSPHO-COA_c + PPI_c
# 159 PANTEPADENYLYLTRAN-RXN ATP_c + PANTETHEINE-P_c + PROTON_c --> DEPHOSPHO-COA_c + PPI_c
#
# 160 DXPREDISOM-RXN DEOXYXYLULOSE-5P_c + NADPH_c + PROTON_c --> 2-C-METHYL-D-ERYTHRITOL-4-PHOSPHATE_c + NADP_c
# 160 DXPREDISOM-RXN 2-C-METHYL-D-ERYTHRITOL-4-PHOSPHATE_c + NADP_c <=> DEOXYXYLULOSE-5P_c + NADPH_c + PROTON_c
#
# 161 3-OCTAPRENYL-4-OHBENZOATE-DECARBOX-RXN 3-OCTAPRENYL-4-HYDROXYBENZOATE_c + PROTON_c --> 2-OCTAPRENYLPHENOL_c + CARBON-DIOXIDE_c
# 161 3-OCTAPRENYL-4-OHBENZOATE-DECARBOX-RXN 3-OCTAPRENYL-4-HYDROXYBENZOATE_c + PROTON_c --> 2-OCTAPRENYLPHENOL_c + CARBON-DIOXIDE_c
#
# 162 GABATRANSAM-RXN 2-KETOGLUTARATE_c + 4-AMINO-BUTYRATE_c --> GLT_c + SUCC-S-ALD_c
# 162 GABATRANSAM-RXN 2-KETOGLUTARATE_c + 4-AMINO-BUTYRATE_c <=> GLT_c + SUCC-S-ALD_c
#
# 163 ACETYLORNTRANSAM-RXN 2-KETOGLUTARATE_c + N-ALPHA-ACETYLORNITHINE_c <=> CPD-469_c + GLT_c
# 163 ACETYLORNTRANSAM-RXN 2-KETOGLUTARATE_c + N-ALPHA-ACETYLORNITHINE_c <=> CPD-469_c + GLT_c
#
# 164 SUCCSEMIALDDEHYDROG-RXN NADP_c + SUCC-S-ALD_c + WATER_c --> NADPH_c + 2.0 PROTON_c + SUC_c
# 164 SUCCSEMIALDDEHYDROG-RXN NADP_c + SUCC-S-ALD_c + WATER_c --> NADPH_c + 2.0 PROTON_c + SUC_c
#
# 165 SUCCINATE-SEMIALDEHYDE-DEHYDROGENASE-RXN NAD_c + SUCC-S-ALD_c + WATER_c --> NADH_c + 2.0 PROTON_c + SUC_c
# 165 SUCCINATE-SEMIALDEHYDE-DEHYDROGENASE-RXN NAD_c + SUCC-S-ALD_c + WATER_c --> NADH_c + 2.0 PROTON_c + SUC_c
#
# 166 4.3.1.17-RXN SER_c --> AMMONIUM_c + PYRUVATE_c
# 166 4.3.1.17-RXN SER_c --> AMMONIUM_c + PYRUVATE_c
#
# 167 ACETOLACTREDUCTOISOM-RXN CPD-13357_c + NADP_c <=> 2-ACETO-LACTATE_c + NADPH_c + PROTON_c
# 167 ACETOLACTREDUCTOISOM-RXN 2-ACETO-LACTATE_c + NADPH_c + PROTON_c --> CPD-13357_c + NADP_c
#
# 168 ACETOOHBUTREDUCTOISOM-RXN 2-ACETO-2-HYDROXY-BUTYRATE_c + NADPH_c + PROTON_c <=> 1-KETO-2-METHYLVALERATE_c + NADP_c
# 168 ACETOOHBUTREDUCTOISOM-RXN 2-ACETO-2-HYDROXY-BUTYRATE_c + NADPH_c + PROTON_c --> 1-KETO-2-METHYLVALERATE_c + NADP_c
#
# 169 NAD-KIN-RXN ATP_c + NAD_c --> ADP_c + NADP_c + PROTON_c
# 169 NAD-KIN-RXN ATP_c + NAD_c --> ADP_c + NADP_c + PROTON_c
#
# 170 GLYOXI-RXN GLUTATHIONE_c + METHYL-GLYOXAL_c --> S-LACTOYL-GLUTATHIONE_c
# 170 GLYOXI-RXN S-LACTOYL-GLUTATHIONE_c <=> GLUTATHIONE_c + METHYL-GLYOXAL_c
#
# 171 3.1.3.74-RXN PYRIDOXAL_PHOSPHATE_c + WATER_c --> PYRIDOXAL_c + Pi_c
# 171 3.1.3.74-RXN PYRIDOXAL_PHOSPHATE_c + WATER_c --> PYRIDOXAL_c + Pi_c
#
# 172 DXS-RXN GAP_c + PROTON_c + PYRUVATE_c --> CARBON-DIOXIDE_c + DEOXYXYLULOSE-5P_c
# 172 DXS-RXN GAP_c + PROTON_c + PYRUVATE_c --> CARBON-DIOXIDE_c + DEOXYXYLULOSE-5P_c
#
# 173 2.7.1.148-RXN 4-CYTIDINE-5-DIPHOSPHO-2-C_c + ATP_c --> 2-PHOSPHO-4-CYTIDINE-5-DIPHOSPHO-2-C-MET_c + ADP_c + PROTON_c
# 173 2.7.1.148-RXN 4-CYTIDINE-5-DIPHOSPHO-2-C_c + ATP_c --> 2-PHOSPHO-4-CYTIDINE-5-DIPHOSPHO-2-C-MET_c + ADP_c + PROTON_c
#
# 174 RXN0-302 2-PHOSPHO-4-CYTIDINE-5-DIPHOSPHO-2-C-MET_c --> 2C-METH-D-ERYTHRITOL-CYCLODIPHOSPHATE_c + CMP_c
# 174 RXN0-302 2-PHOSPHO-4-CYTIDINE-5-DIPHOSPHO-2-C-MET_c --> 2C-METH-D-ERYTHRITOL-CYCLODIPHOSPHATE_c + CMP_c
#
# 175 PHOSMANMUT-RXN MANNOSE-1P_c <=> CPD-15979_c
# 175 PHOSMANMUT-RXN MANNOSE-1P_c <=> CPD-15979_c
#
# 176 PYRUVDEH-RXN CO-A_c + NAD_c + PYRUVATE_c --> ACETYL-COA_c + CARBON-DIOXIDE_c + NADH_c
# 176 PYRUVDEH-RXN CO-A_c + NAD_c + PYRUVATE_c --> ACETYL-COA_c + CARBON-DIOXIDE_c + NADH_c
#
# 177 2OXOGLUTARATEDEH-RXN 2-KETOGLUTARATE_c + CO-A_c + NAD_c --> CARBON-DIOXIDE_c + NADH_c + SUC-COA_c
# 177 2OXOGLUTARATEDEH-RXN 2-KETOGLUTARATE_c + CO-A_c + NAD_c --> CARBON-DIOXIDE_c + NADH_c + SUC-COA_c
#
# 178 MMUM-RXN CPD-397_c + HOMO-CYS_c --> 2.0 MET_c + PROTON_c
# 178 MMUM-RXN CPD-397_c + HOMO-CYS_c --> 2.0 MET_c + PROTON_c
#
# 179 TRE6PHYDRO-RXN TREHALOSE-6P_c + WATER_c --> D-glucopyranose-6-phosphate_c + Glucopyranose_c
# 179 TRE6PHYDRO-RXN TREHALOSE-6P_c + WATER_c --> D-glucopyranose-6-phosphate_c + Glucopyranose_c
#
# 180 GTP-CYCLOHYDRO-II-RXN GTP_c + 3.0 WATER_c --> DIAMINO-OH-PHOSPHORIBOSYLAMINO-PYR_c + FORMATE_c + PPI_c + 2.0 PROTON_c
# 180 GTP-CYCLOHYDRO-II-RXN GTP_c + 3.0 WATER_c --> DIAMINO-OH-PHOSPHORIBOSYLAMINO-PYR_c + FORMATE_c + PPI_c + 2.0 PROTON_c
#
# 181 MANNONOXIDOREDUCT-RXN D-MANNONATE_c + NAD_c <=> FRUCTURONATE_c + NADH_c + PROTON_c
# 181 MANNONOXIDOREDUCT-RXN D-MANNONATE_c + NAD_c <=> FRUCTURONATE_c + NADH_c + PROTON_c
#
# 182 GLYOCARBOLIG-RXN 2.0 GLYOX_c + PROTON_c --> CARBON-DIOXIDE_c + TARTRONATE-S-ALD_c
# 182 GLYOCARBOLIG-RXN 2.0 GLYOX_c + PROTON_c --> CARBON-DIOXIDE_c + TARTRONATE-S-ALD_c
#
# 183 QUINOPRIBOTRANS-RXN 2.0 PROTON_c + PRPP_c + QUINOLINATE_c --> CARBON-DIOXIDE_c + NICOTINATE_NUCLEOTIDE_c + PPI_c
# 183 QUINOPRIBOTRANS-RXN 2.0 PROTON_c + PRPP_c + QUINOLINATE_c --> CARBON-DIOXIDE_c + NICOTINATE_NUCLEOTIDE_c + PPI_c
#
# 184 MALONYL-COA-ACP-TRANSACYL-RXN ACP_c + MALONYL-COA_c <=> CO-A_c + MALONYL-ACP_c
# 184 MALONYL-COA-ACP-TRANSACYL-RXN ACP_c + MALONYL-COA_c --> CO-A_c + MALONYL-ACP_c
#
# 185 UDPNACETYLGLUCOSAMACYLTRANS-RXN R-3-hydroxymyristoyl-ACPs_c + UDP-N-ACETYL-D-GLUCOSAMINE_c <=> ACP_c + UDP-OHMYR-ACETYLGLUCOSAMINE_c
# 185 UDPNACETYLGLUCOSAMACYLTRANS-RXN R-3-hydroxymyristoyl-ACPs_c + UDP-N-ACETYL-D-GLUCOSAMINE_c --> ACP_c + UDP-OHMYR-ACETYLGLUCOSAMINE_c
#
# 186 SUCCDIAMINOPIMDESUCC-RXN N-SUCCINYLLL-2-6-DIAMINOPIMELATE_c + WATER_c --> LL-DIAMINOPIMELATE_c + SUC_c
# 186 SUCCDIAMINOPIMDESUCC-RXN N-SUCCINYLLL-2-6-DIAMINOPIMELATE_c + WATER_c --> LL-DIAMINOPIMELATE_c + SUC_c
#
# 187 ADENPRIBOSYLTRAN-RXN ADENINE_c + PRPP_c --> AMP_c + PPI_c
# 187 ADENPRIBOSYLTRAN-RXN ADENINE_c + PRPP_c --> AMP_c + PPI_c
#
# 188 RXN-8992 5.0 DELTA3-ISOPENTENYL-PP_c + FARNESYL-PP_c --> OCTAPRENYL-DIPHOSPHATE_c + 5.0 PPI_c
# 188 RXN-8992 5.0 DELTA3-ISOPENTENYL-PP_c + FARNESYL-PP_c --> OCTAPRENYL-DIPHOSPHATE_c + 5.0 PPI_c
#
# 189 CATAL-RXN 2.0 HYDROGEN-PEROXIDE_c --> OXYGEN-MOLECULE_c + 2.0 WATER_c
# 189 CATAL-RXN 2.0 HYDROGEN-PEROXIDE_c --> OXYGEN-MOLECULE_c + 2.0 WATER_c
#
# 190 RXN-10819 ATP_c + CO-A_c + PHENYLACETATE_c --> AMP_c + CPD-207_c + PPI_c
# 190 RXN-10819 ATP_c + CO-A_c + PHENYLACETATE_c --> AMP_c + CPD-207_c + PPI_c
#
# 191 3.6.1.41-RXN ADENOSYL-P4_c + WATER_c --> 2.0 ADP_c + 2.0 PROTON_c
# 191 3.6.1.41-RXN ADENOSYL-P4_c + WATER_c --> 2.0 ADP_c + 2.0 PROTON_c
#
# 192 RXN0-4342 ATP_c + D-BETA-D-HEPTOSE-1-P_c + PROTON_c --> ADP-D-GLYCERO-D-MANNO-HEPTOSE_c + PPI_c
# 192 RXN0-4342 ATP_c + D-BETA-D-HEPTOSE-1-P_c + PROTON_c --> ADP-D-GLYCERO-D-MANNO-HEPTOSE_c + PPI_c
#
# 193 RXN-7913 ATP_c + DCMP_c <=> ADP_c + DCDP_c
# 193 RXN-7913 ATP_c + DCMP_c --> ADP_c + DCDP_c
#
# 194 RXN-11832 ATP_c + CMP_c <=> ADP_c + CDP_c
# 194 RXN-11832 ATP_c + CMP_c <=> ADP_c + CDP_c
#
# 195 RXN-12002 ATP_c + UMP_c <=> ADP_c + UDP_c
# 195 RXN-12002 ATP_c + UMP_c --> ADP_c + UDP_c
#
# 196 GUANYL-KIN-RXN ATP_c + GMP_c <=> ADP_c + GDP_c
# 196 GUANYL-KIN-RXN ATP_c + GMP_c <=> ADP_c + GDP_c
#
# 197 GMKALT-RXN ATP_c + DGMP_c <=> ADP_c + DGDP_c
# 197 GMKALT-RXN ATP_c + DGMP_c <=> ADP_c + DGDP_c
#
# 198 ACETOACETYL-COA-TRANSFER-RXN 3-KETOBUTYRATE_c + ACETYL-COA_c --> ACETOACETYL-COA_c + ACET_c
# 198 ACETOACETYL-COA-TRANSFER-RXN 3-KETOBUTYRATE_c + ACETYL-COA_c <=> ACETOACETYL-COA_c + ACET_c
#
# 199 DTDPGLUCOSEPP-RXN GLC-1-P_c + PROTON_c + TTP_c --> DTDP-D-GLUCOSE_c + PPI_c
# 199 DTDPGLUCOSEPP-RXN GLC-1-P_c + PROTON_c + TTP_c --> DTDP-D-GLUCOSE_c + PPI_c
#
# 200 DTDPGLUCDEHYDRAT-RXN DTDP-D-GLUCOSE_c --> DTDP-DEOH-DEOXY-GLUCOSE_c + WATER_c
# 200 DTDPGLUCDEHYDRAT-RXN DTDP-D-GLUCOSE_c --> DTDP-DEOH-DEOXY-GLUCOSE_c + WATER_c
# 201 DTDPDEHYDRHAMEPIM-RXN DTDP-DEOH-DEOXY-GLUCOSE_c --> DTDP-DEOH-DEOXY-MANNOSE_c
# 201 DTDPDEHYDRHAMEPIM-RXN DTDP-DEOH-DEOXY-GLUCOSE_c --> DTDP-DEOH-DEOXY-MANNOSE_c
#
# 202 DTDPDEHYRHAMREDUCT-RXN DTDP-DEOH-DEOXY-MANNOSE_c + NADPH_c + PROTON_c --> DTDP-RHAMNOSE_c + NADP_c
# 202 DTDPDEHYRHAMREDUCT-RXN DTDP-RHAMNOSE_c + NADP_c <=> DTDP-DEOH-DEOXY-MANNOSE_c + NADPH_c + PROTON_c
#
# 203 UDPNACETYLMURAMATEDEHYDROG-RXN NADPH_c + PROTON_c + UDP-ACETYL-CARBOXYVINYL-GLUCOSAMINE_c --> NADP_c + UDP-N-ACETYLMURAMATE_c
# 203 UDPNACETYLMURAMATEDEHYDROG-RXN NADPH_c + PROTON_c + UDP-ACETYL-CARBOXYVINYL-GLUCOSAMINE_c --> NADP_c + UDP-N-ACETYLMURAMATE_c
#
# 204 RXN0-4301 D-SEDOHEPTULOSE-7-P_c --> D-ALPHABETA-D-HEPTOSE-7-PHOSPHATE_c
# 204 RXN0-4301 D-SEDOHEPTULOSE-7-P_c --> D-ALPHABETA-D-HEPTOSE-7-PHOSPHATE_c
#
# 205 RXN-9510 FMN_c + NADH_c + PROTON_c --> FMNH2_c + NAD_c
# 205 RXN-9510 FMNH2_c + NAD_c <=> FMN_c + NADH_c + 2.0 PROTON_c
#
# 206 RXN-12444 FMN_c + NADPH_c + PROTON_c --> FMNH2_c + NADP_c
# 206 RXN-12444 FMN_c + NADPH_c + 2.0 PROTON_c --> FMNH2_c + NADP_c
#
# 207 GDPPYPHOSKIN-RXN ATP_c + GDP_c --> AMP_c + GUANOSINE-5DP-3DP_c + PROTON_c
# 207 GDPPYPHOSKIN-RXN ATP_c + GDP_c --> AMP_c + GUANOSINE-5DP-3DP_c
#
# 208 GTPPYPHOSKIN-RXN ATP_c + GTP_c --> AMP_c + GDP-TP_c + PROTON_c
# 208 GTPPYPHOSKIN-RXN ATP_c + GTP_c --> AMP_c + GDP-TP_c
#
# 209 PROTOHEMEFERROCHELAT-RXN FE+2_c + PROTOPORPHYRIN_IX_c --> PROTOHEME_c + 2.0 PROTON_c
# 209 PROTOHEMEFERROCHELAT-RXN PROTOHEME_c + 2.0 PROTON_c <=> FE+2_c + PROTOPORPHYRIN_IX_c
#
# 210 DEPHOSPHOCOAKIN-RXN ATP_c + DEPHOSPHO-COA_c --> ADP_c + CO-A_c + PROTON_c
# 210 DEPHOSPHOCOAKIN-RXN ATP_c + DEPHOSPHO-COA_c --> ADP_c + CO-A_c + PROTON_c
#
# 211 THIAZOLSYN3-RXN ATP_c + THZ_c --> ADP_c + PROTON_c + THZ-P_c
# 211 THIAZOLSYN3-RXN ATP_c + THZ_c --> ADP_c + PROTON_c + THZ-P_c
#
# 212 KDO-8PPHOSPHAT-RXN KDO-8P_c + WATER_c --> KDO_c + Pi_c
# 212 KDO-8PPHOSPHAT-RXN KDO-8P_c + WATER_c --> KDO_c + Pi_c
#
# 213 ARGININE-N-SUCCINYLTRANSFERASE-RXN ARG_c + SUC-COA_c --> CO-A_c + CPD-421_c + PROTON_c
# 213 ARGININE-N-SUCCINYLTRANSFERASE-RXN ARG_c + SUC-COA_c --> CO-A_c + CPD-421_c + PROTON_c
#
# 214 SUCCGLUDESUCC-RXN N2-SUCCINYLGLUTAMATE_c + WATER_c --> GLT_c + SUC_c
# 214 SUCCGLUDESUCC-RXN N2-SUCCINYLGLUTAMATE_c + WATER_c --> GLT_c + SUC_c
#
# 215 GUANINE-DEAMINASE-RXN GUANINE_c + PROTON_c + WATER_c --> AMMONIUM_c + XANTHINE_c
# 215 GUANINE-DEAMINASE-RXN GUANINE_c + PROTON_c + WATER_c --> AMMONIUM_c + XANTHINE_c
#
# 216 DTMPKI-RXN ATP_c + TMP_c <=> ADP_c + TDP_c
# 216 DTMPKI-RXN ATP_c + TMP_c --> ADP_c + TDP_c
#
# 217 PHOSPHOGLUCMUT-RXN GLC-1-P_c <=> D-glucopyranose-6-phosphate_c
# 217 PHOSPHOGLUCMUT-RXN GLC-1-P_c <=> D-glucopyranose-6-phosphate_c
#
# 218 RXN0-5185 CPD-2961_c + WATER_c --> GLUCONATE_c + Pi_c
# 218 RXN0-5185 CPD-2961_c + WATER_c --> GLUCONATE_c + Pi_c
#
# 219 RIBOSYLHOMOCYSTEINASE-RXN CPD-564_c --> DIHYDROXYPENTANEDIONE_c + HOMO-CYS_c
# 219 RIBOSYLHOMOCYSTEINASE-RXN CPD-564_c --> DIHYDROXYPENTANEDIONE_c + HOMO-CYS_c
#
# 220 BADH-RXN BETAINE_ALDEHYDE_c + NAD_c + WATER_c --> BETAINE_c + NADH_c + 2.0 PROTON_c
# 220 BADH-RXN BETAINE_ALDEHYDE_c + NAD_c + WATER_c <=> BETAINE_c + NADH_c + 2.0 PROTON_c
#
# 221 PYRNUTRANSHYDROGEN-RXN NADPH_c + NAD_c --> NADH_c + NADP_c
# 221 PYRNUTRANSHYDROGEN-RXN NADPH_c + NAD_c --> NADH_c + NADP_c
#
# 222 GMP-SYN-GLUT-RXN ATP_c + GLN_c + WATER_c + XANTHOSINE-5-PHOSPHATE_c --> AMP_c + GLT_c + GMP_c + PPI_c + 2.0 PROTON_c
# 222 GMP-SYN-GLUT-RXN ATP_c + GLN_c + WATER_c + XANTHOSINE-5-PHOSPHATE_c --> AMP_c + GLT_c + GMP_c + PPI_c + 2.0 PROTON_c
#
# 223 GMP-SYN-NH3-RXN AMMONIUM_c + ATP_c + XANTHOSINE-5-PHOSPHATE_c --> AMP_c + GMP_c + PPI_c + 2.0 PROTON_c
# 223 GMP-SYN-NH3-RXN AMMONIUM_c + ATP_c + XANTHOSINE-5-PHOSPHATE_c --> AMP_c + GMP_c + PPI_c + 2.0 PROTON_c
#
# 224 PABASYN-RXN CHORISMATE_c + GLN_c --> 4-AMINO-4-DEOXYCHORISMATE_c + GLT_c
# 224 PABASYN-RXN CHORISMATE_c + GLN_c <=> 4-AMINO-4-DEOXYCHORISMATE_c + GLT_c
#
# 225 ADCLY-RXN 4-AMINO-4-DEOXYCHORISMATE_c --> P-AMINO-BENZOATE_c + PROTON_c + PYRUVATE_c
# 225 ADCLY-RXN 4-AMINO-4-DEOXYCHORISMATE_c --> P-AMINO-BENZOATE_c + PROTON_c + PYRUVATE_c
#
# 226 URACIL-PRIBOSYLTRANS-RXN PRPP_c + URACIL_c --> PPI_c + UMP_c
# 226 URACIL-PRIBOSYLTRANS-RXN PRPP_c + URACIL_c --> PPI_c + UMP_c
#
# 227 CTPSYN-RXN ATP_c + GLN_c + UTP_c + WATER_c --> ADP_c + CTP_c + GLT_c + 2.0 PROTON_c + Pi_c
# 227 CTPSYN-RXN ATP_c + GLN_c + UTP_c + WATER_c --> ADP_c + CTP_c + GLT_c + 2.0 PROTON_c + Pi_c
#
# 228 5.1.3.20-RXN ADP-D-GLYCERO-D-MANNO-HEPTOSE_c --> ADP-L-GLYCERO-D-MANNO-HEPTOSE_c
# 228 5.1.3.20-RXN ADP-D-GLYCERO-D-MANNO-HEPTOSE_c --> ADP-L-GLYCERO-D-MANNO-HEPTOSE_c
#
# 229 GLYOXYLATE-REDUCTASE-NADP+-RXN GLYOX_c + NADPH_c + PROTON_c --> GLYCOLLATE_c + NADP_c
# 229 GLYOXYLATE-REDUCTASE-NADP+-RXN GLYOX_c + NADPH_c + PROTON_c --> GLYCOLLATE_c + NADP_c
#
# 230 RXN0-300 NADPH_c + OH-PYR_c + PROTON_c --> GLYCERATE_c + NADP_c
# 230 RXN0-300 NADPH_c + OH-PYR_c + PROTON_c --> GLYCERATE_c + NADP_c
#
# 231 ACETYLORNDEACET-RXN N-ALPHA-ACETYLORNITHINE_c + WATER_c --> ACET_c + L-ORNITHINE_c
# 231 ACETYLORNDEACET-RXN N-ALPHA-ACETYLORNITHINE_c + WATER_c <=> ACET_c + L-ORNITHINE_c
#
# 232 ADDALT-RXN DEOXYADENOSINE_c + PROTON_c + WATER_c --> AMMONIUM_c + DEOXYINOSINE_c
# 232 ADDALT-RXN DEOXYADENOSINE_c + PROTON_c + WATER_c --> AMMONIUM_c + DEOXYINOSINE_c
#
# 233 ADENODEAMIN-RXN ADENOSINE_c + PROTON_c + WATER_c --> AMMONIUM_c + INOSINE_c
# 233 ADENODEAMIN-RXN ADENOSINE_c + PROTON_c + WATER_c --> AMMONIUM_c + INOSINE_c
#
# 234 ADENYLOSUCCINATE-SYNTHASE-RXN GTP_c + IMP_c + L-ASPARTATE_c --> ADENYLOSUCC_c + GDP_c + 2.0 PROTON_c + Pi_c
# 234 ADENYLOSUCCINATE-SYNTHASE-RXN GTP_c + IMP_c + L-ASPARTATE_c --> ADENYLOSUCC_c + GDP_c + 2.0 PROTON_c + Pi_c
#
# 235 ASPARAGHYD-RXN ASN_c + WATER_c --> AMMONIUM_c + L-ASPARTATE_c
# 235 ASPARAGHYD-RXN ASN_c + WATER_c --> AMMONIUM_c + L-ASPARTATE_c
#
# 236 ASPCARBTRANS-RXN CARBAMOYL-P_c + L-ASPARTATE_c --> CARBAMYUL-L-ASPARTATE_c + PROTON_c + Pi_c
# 236 ASPCARBTRANS-RXN CARBAMOYL-P_c + L-ASPARTATE_c <=> CARBAMYUL-L-ASPARTATE_c + PROTON_c + Pi_c
#
# 237 DIAMINOPIMEPIM-RXN LL-DIAMINOPIMELATE_c <=> MESO-DIAMINOPIMELATE_c
# 237 DIAMINOPIMEPIM-RXN LL-DIAMINOPIMELATE_c <=> MESO-DIAMINOPIMELATE_c
#
# 238 SUCCORNTRANSAM-RXN 2-KETOGLUTARATE_c + N2-SUCCINYLORNITHINE_c --> CPD-822_c + GLT_c
# 238 SUCCORNTRANSAM-RXN 2-KETOGLUTARATE_c + N2-SUCCINYLORNITHINE_c <=> CPD-822_c + GLT_c
#
# 239 THRESYN-RXN O-PHOSPHO-L-HOMOSERINE_c + WATER_c --> Pi_c + THR_c
# 239 THRESYN-RXN O-PHOSPHO-L-HOMOSERINE_c + WATER_c --> Pi_c + THR_c
#
# 240 DAHPSYN-RXN ERYTHROSE-4P_c + PHOSPHO-ENOL-PYRUVATE_c + WATER_c --> 3-DEOXY-D-ARABINO-HEPTULOSONATE-7-P_c + Pi_c
# 240 DAHPSYN-RXN ERYTHROSE-4P_c + PHOSPHO-ENOL-PYRUVATE_c + WATER_c <=> 3-DEOXY-D-ARABINO-HEPTULOSONATE-7-P_c + Pi_c
#
# 241 NMNAMIDOHYDRO-RXN NICOTINAMIDE_NUCLEOTIDE_c + WATER_c --> AMMONIUM_c + NICOTINATE_NUCLEOTIDE_c
# 241 NMNAMIDOHYDRO-RXN NICOTINAMIDE_NUCLEOTIDE_c + WATER_c --> AMMONIUM_c + NICOTINATE_NUCLEOTIDE_c
#
# 242 SPERMACTRAN-RXN ACETYL-COA_c + SPERMIDINE_c --> CO-A_c + CPD-568_c + PROTON_c
# 242 SPERMACTRAN-RXN ACETYL-COA_c + SPERMIDINE_c --> CO-A_c + CPD-568_c + PROTON_c
#
# 243 RXN0-7165 ACETYL-COA_c + SPERMIDINE_c --> CO-A_c + CPD-3462_c + PROTON_c
# 243 RXN0-7165 ACETYL-COA_c + SPERMIDINE_c --> CO-A_c + CPD-3462_c + PROTON_c
#
# 244 MALSYN-RXN ACETYL-COA_c + GLYOX_c + WATER_c --> CO-A_c + MAL_c + PROTON_c
# 244 MALSYN-RXN ACETYL-COA_c + GLYOX_c + WATER_c --> CO-A_c + MAL_c + PROTON_c
#
# 245 GLUC1PURIDYLTRANS-RXN GLC-1-P_c + PROTON_c + UTP_c --> CPD-12575_c + PPI_c
# 245 GLUC1PURIDYLTRANS-RXN GLC-1-P_c + PROTON_c + UTP_c <=> CPD-12575_c + PPI_c
#
# 246 UDPHYDROXYMYRGLUCOSAMNACETYLTRANS-RXN R-3-hydroxymyristoyl-ACPs_c + UDP-OHMYR-GLUCOSAMINE_c --> ACP_c + OH-MYRISTOYL_c + PROTON_c
# 246 UDPHYDROXYMYRGLUCOSAMNACETYLTRANS-RXN R-3-hydroxymyristoyl-ACPs_c + UDP-OHMYR-GLUCOSAMINE_c --> ACP_c + OH-MYRISTOYL_c + PROTON_c
#
# 247 UDP-NACMUR-ALA-LIG-RXN ATP_c + L-ALPHA-ALANINE_c + UDP-N-ACETYLMURAMATE_c --> ADP_c + CPD0-1456_c + PROTON_c + Pi_c
# 247 UDP-NACMUR-ALA-LIG-RXN ATP_c + L-ALPHA-ALANINE_c + UDP-N-ACETYLMURAMATE_c --> ADP_c + CPD0-1456_c + PROTON_c + Pi_c
#
# 248 UDP-NACMURALA-GLU-LIG-RXN ATP_c + CPD0-1456_c + D-GLT_c --> ADP_c + PROTON_c + Pi_c + UDP-AA-GLUTAMATE_c
# 248 UDP-NACMURALA-GLU-LIG-RXN ATP_c + CPD0-1456_c + D-GLT_c --> ADP_c + PROTON_c + Pi_c + UDP-AA-GLUTAMATE_c
#
# 249 UDPACYLGLCNACDEACETYL-RXN UDP-OHMYR-ACETYLGLUCOSAMINE_c + WATER_c --> ACET_c + UDP-OHMYR-GLUCOSAMINE_c
# 249 UDPACYLGLCNACDEACETYL-RXN UDP-OHMYR-ACETYLGLUCOSAMINE_c + WATER_c --> ACET_c + UDP-OHMYR-GLUCOSAMINE_c
#
# 250 IMIDPHOSDEHYD-RXN D-ERYTHRO-IMIDAZOLE-GLYCEROL-P_c --> IMIDAZOLE-ACETOL-P_c + WATER_c
# 250 IMIDPHOSDEHYD-RXN D-ERYTHRO-IMIDAZOLE-GLYCEROL-P_c --> IMIDAZOLE-ACETOL-P_c + WATER_c
#
# 251 PRIBFAICARPISOM-RXN PHOSPHORIBOSYL-FORMIMINO-AICAR-P_c <=> PHOSPHORIBULOSYL-FORMIMINO-AICAR-P_c
# 251 PRIBFAICARPISOM-RXN PHOSPHORIBOSYL-FORMIMINO-AICAR-P_c --> PHOSPHORIBULOSYL-FORMIMINO-AICAR-P_c
#
# 252 SERINE-O-ACETTRAN-RXN ACETYL-COA_c + SER_c <=> ACETYLSERINE_c + CO-A_c
# 252 SERINE-O-ACETTRAN-RXN ACETYL-COA_c + SER_c --> ACETYLSERINE_c + CO-A_c
#
# 253 ACSERLY-RXN ACETYLSERINE_c + HS_c --> ACET_c + CYS_c + PROTON_c
# 253 ACSERLY-RXN ACETYLSERINE_c + HS_c <=> ACET_c + CYS_c + PROTON_c
#
# 254 325-BISPHOSPHATE-NUCLEOTIDASE-RXN 3-5-ADP_c + WATER_c --> AMP_c + Pi_c
# 254 325-BISPHOSPHATE-NUCLEOTIDASE-RXN 3-5-ADP_c + WATER_c --> AMP_c + Pi_c
#
# 255 ASPARTATE-SEMIALDEHYDE-DEHYDROGENASE-RXN L-ASPARTATE-SEMIALDEHYDE_c + NADP_c + Pi_c <=> L-BETA-ASPARTYL-P_c + NADPH_c + PROTON_c
# 255 ASPARTATE-SEMIALDEHYDE-DEHYDROGENASE-RXN L-ASPARTATE-SEMIALDEHYDE_c + NADP_c + Pi_c <=> L-BETA-ASPARTYL-P_c + NADPH_c + PROTON_c
#
# 256 DIAMINOPIMDECARB-RXN MESO-DIAMINOPIMELATE_c + PROTON_c --> CARBON-DIOXIDE_c + LYS_c
# 256 DIAMINOPIMDECARB-RXN MESO-DIAMINOPIMELATE_c + PROTON_c --> CARBON-DIOXIDE_c + LYS_c
#
# 257 S-ADENMETSYN-RXN ATP_c + MET_c + WATER_c --> PPI_c + Pi_c + S-ADENOSYLMETHIONINE_c
# 257 S-ADENMETSYN-RXN ATP_c + MET_c + WATER_c --> PPI_c + Pi_c + S-ADENOSYLMETHIONINE_c
#
# 258 THI-P-KIN-RXN ATP_c + THIAMINE-P_c --> ADP_c + THIAMINE-PYROPHOSPHATE_c
# 258 THI-P-KIN-RXN ATP_c + THIAMINE-P_c --> ADP_c + THIAMINE-PYROPHOSPHATE_c
#
# 259 GKI-RXN ATP_c + GLYCERATE_c --> 2-PG_c + ADP_c + PROTON_c
# 259 GKI-RXN ATP_c + GLYCERATE_c --> 2-PG_c + ADP_c + PROTON_c
#
# 260 GLUCOKIN-RXN ATP_c + Glucopyranose_c --> ADP_c + D-glucopyranose-6-phosphate_c + PROTON_c
# 260 GLUCOKIN-RXN ATP_c + Glucopyranose_c --> ADP_c + D-glucopyranose-6-phosphate_c + PROTON_c
#
# 261 MALIC-NADP-RXN MAL_c + NADP_c --> CARBON-DIOXIDE_c + NADPH_c + PYRUVATE_c
# 261 MALIC-NADP-RXN MAL_c + NADP_c --> CARBON-DIOXIDE_c + NADPH_c + PYRUVATE_c
#
# 262 ARGSUCCINLYA-RXN L-ARGININO-SUCCINATE_c <=> ARG_c + FUM_c
# 262 ARGSUCCINLYA-RXN L-ARGININO-SUCCINATE_c <=> ARG_c + FUM_c
#
# 263 CARBPSYN-RXN 2.0 ATP_c + GLN_c + H2CO3_c + WATER_c --> 2.0 ADP_c + CARBAMOYL-P_c + GLT_c + 2.0 PROTON_c + Pi_c
# 263 CARBPSYN-RXN 2.0 ATP_c + GLN_c + HCO3_c + WATER_c --> 2.0 ADP_c + CARBAMOYL-P_c + GLT_c + 2.0 PROTON_c + Pi_c
#
# 264 GLUTKIN-RXN ATP_c + GLT_c --> ADP_c + L-GLUTAMATE-5-P_c
# 264 GLUTKIN-RXN ATP_c + GLT_c --> ADP_c + L-GLUTAMATE-5-P_c
#
# 265 2.3.1.180-RXN ACETYL-COA_c + MALONYL-ACP_c + PROTON_c --> Acetoacetyl-ACPs_c + CARBON-DIOXIDE_c + CO-A_c
# 265 2.3.1.180-RXN ACETYL-COA_c + MALONYL-ACP_c + PROTON_c --> Acetoacetyl-ACPs_c + CARBON-DIOXIDE_c + CO-A_c
#
# 266 SUPEROX-DISMUT-RXN 2.0 PROTON_c + 2.0 SUPER-OXIDE_c --> HYDROGEN-PEROXIDE_c + OXYGEN-MOLECULE_c
# 266 SUPEROX-DISMUT-RXN 2.0 PROTON_c + 2.0 SUPER-OXIDE_c --> HYDROGEN-PEROXIDE_c + OXYGEN-MOLECULE_c
#
# 267 ADENOSYLHOMOCYSTEINE-NUCLEOSIDASE-RXN ADENOSYL-HOMO-CYS_c + WATER_c --> ADENINE_c + CPD-564_c
# 267 ADENOSYLHOMOCYSTEINE-NUCLEOSIDASE-RXN ADENOSYL-HOMO-CYS_c + WATER_c --> ADENINE_c + CPD-564_c
#
# 268 METHYLTHIOADENOSINE-NUCLEOSIDASE-RXN 5-METHYLTHIOADENOSINE_c + WATER_c --> ADENINE_c + CPD-560_c
# 268 METHYLTHIOADENOSINE-NUCLEOSIDASE-RXN 5-METHYLTHIOADENOSINE_c + WATER_c --> ADENINE_c + CPD-560_c
#
# 269 THIOSULFATE-SULFURTRANSFERASE-RXN HCN_c + S2O3_c --> HSCN_c + PROTON_c + SO3_c
# 269 THIOSULFATE-SULFURTRANSFERASE-RXN HCN_c + S2O3_c --> HSCN_c + 2.0 PROTON_c + SO3_c
#
# 270 DETHIOBIOTIN-SYN-RXN ATP_c + CARBON-DIOXIDE_c + DIAMINONONANOATE_c --> ADP_c + DETHIOBIOTIN_c + 3.0 PROTON_c + Pi_c
# 270 DETHIOBIOTIN-SYN-RXN ATP_c + CARBON-DIOXIDE_c + DIAMINONONANOATE_c --> ADP_c + DETHIOBIOTIN_c + 3.0 PROTON_c + Pi_c
#
# 271 CYTDEAM-RXN CYTOSINE_c + PROTON_c + WATER_c --> AMMONIUM_c + URACIL_c
# 271 CYTDEAM-RXN CYTOSINE_c + PROTON_c + WATER_c --> AMMONIUM_c + URACIL_c
#
# 272 L-GLN-FRUCT-6-P-AMINOTRANS-RXN FRUCTOSE-6P_c + GLN_c --> D-GLUCOSAMINE-6-P_c + GLT_c
# 272 L-GLN-FRUCT-6-P-AMINOTRANS-RXN FRUCTOSE-6P_c + GLN_c <=> D-GLUCOSAMINE-6-P_c + GLT_c
#
# 273 GLUTCYSLIG-RXN ATP_c + CYS_c + GLT_c --> ADP_c + L-GAMMA-GLUTAMYLCYSTEINE_c + PROTON_c + Pi_c
# 273 GLUTCYSLIG-RXN ATP_c + CYS_c + GLT_c --> ADP_c + L-GAMMA-GLUTAMYLCYSTEINE_c + PROTON_c + Pi_c
#
# 274 GLUTAMIN-RXN GLN_c + WATER_c --> AMMONIUM_c + GLT_c
# 274 GLUTAMIN-RXN GLN_c + WATER_c --> AMMONIUM_c + GLT_c
#
# 275 PRPPAMIDOTRANS-RXN GLN_c + PRPP_c + WATER_c --> 5-P-BETA-D-RIBOSYL-AMINE_c + GLT_c + PPI_c
# 275 PRPPAMIDOTRANS-RXN 5-P-BETA-D-RIBOSYL-AMINE_c + GLT_c + PPI_c <=> GLN_c + PRPP_c + WATER_c
#
# 276 ORNCARBAMTRANSFER-RXN CARBAMOYL-P_c + L-ORNITHINE_c <=> L-CITRULLINE_c + PROTON_c + Pi_c
# 276 ORNCARBAMTRANSFER-RXN CARBAMOYL-P_c + L-ORNITHINE_c <=> L-CITRULLINE_c + PROTON_c + Pi_c
#
# 277 GART-RXN 10-FORMYL-THF_c + 5-PHOSPHO-RIBOSYL-GLYCINEAMIDE_c <=> 5-P-RIBOSYL-N-FORMYLGLYCINEAMIDE_c + PROTON_c + THF_c
# 277 GART-RXN 10-FORMYL-THF_c + 5-PHOSPHO-RIBOSYL-GLYCINEAMIDE_c <=> 5-P-RIBOSYL-N-FORMYLGLYCINEAMIDE_c + PROTON_c + THF_c
#
# 278 METHYLISOCITRATE-LYASE-RXN CPD-618_c <=> PYRUVATE_c + SUC_c
# 278 METHYLISOCITRATE-LYASE-RXN CPD-618_c <=> PYRUVATE_c + SUC_c
#
# 279 SUCCGLUALDDEHYD-RXN CPD-822_c + NAD_c + WATER_c --> N2-SUCCINYLGLUTAMATE_c + NADH_c + 2.0 PROTON_c
# 279 SUCCGLUALDDEHYD-RXN CPD-822_c + NAD_c + WATER_c --> N2-SUCCINYLGLUTAMATE_c + NADH_c + 2.0 PROTON_c
#
# 280 PORPHOBILSYNTH-RXN 2.0 5-AMINO-LEVULINATE_c --> PORPHOBILINOGEN_c + PROTON_c + 2.0 WATER_c
# 280 PORPHOBILSYNTH-RXN 2.0 5-AMINO-LEVULINATE_c --> PORPHOBILINOGEN_c + PROTON_c + 2.0 WATER_c
#
# 281 GLYRIBONUCSYN-RXN 5-P-BETA-D-RIBOSYL-AMINE_c + ATP_c + GLY_c <=> 5-PHOSPHO-RIBOSYL-GLYCINEAMIDE_c + ADP_c + PROTON_c + Pi_c
# 281 GLYRIBONUCSYN-RXN 5-P-BETA-D-RIBOSYL-AMINE_c + ATP_c + GLY_c --> 5-PHOSPHO-RIBOSYL-GLYCINEAMIDE_c + ADP_c + PROTON_c + Pi_c
#
# 282 ETHAMLY-RXN ETHANOL-AMINE_c --> ACETALD_c + AMMONIUM_c
# 282 ETHAMLY-RXN ETHANOL-AMINE_c --> ACETALD_c + AMMONIUM_c
#
# 283 RXN0-5408 D-MYO-INOSITOL-1-MONOPHOSPHATE_c + WATER_c --> MYO-INOSITOL_c + Pi_c
# 283 RXN0-5408 D-MYO-INOSITOL-1-MONOPHOSPHATE_c + WATER_c --> MYO-INOSITOL_c + Pi_c
#
# 284 GLYCEROL-2-PHOSPHATASE-RXN CPD-536_c + WATER_c --> GLYCEROL_c + Pi_c
# 284 GLYCEROL-2-PHOSPHATASE-RXN CPD-536_c + WATER_c --> GLYCEROL_c + Pi_c
#
# 285 2-METHYLCITRATE-SYNTHASE-RXN OXALACETIC_ACID_c + PROPIONYL-COA_c + WATER_c --> CO-A_c + CPD-622_c + PROTON_c
# 285 2-METHYLCITRATE-SYNTHASE-RXN OXALACETIC_ACID_c + PROPIONYL-COA_c + WATER_c <=> CO-A_c + CPD-622_c + PROTON_c
#
# 286 ATPASE-RXN ATP_c + WATER_c --> ADP_c + PROTON_c + Pi_c
# 286 ATPASE-RXN ATP_c + WATER_c --> ADP_c + PROTON_c + Pi_c
#
# 287 RXN0-5462 GTP_c + WATER_c --> GDP_c + PROTON_c + Pi_c
# 287 RXN0-5462 GTP_c + WATER_c --> GDP_c + PROTON_c + Pi_c
#
# 288 GLU6PDEHYDROG-RXN D-glucopyranose-6-phosphate_c + NADP_c <=> D-6-P-GLUCONO-DELTA-LACTONE_c + NADPH_c + PROTON_c
# 288 GLU6PDEHYDROG-RXN D-glucopyranose-6-phosphate_c + NADP_c --> D-6-P-GLUCONO-DELTA-LACTONE_c + NADPH_c + PROTON_c
#
# 289 UGD-RXN CPD-12575_c + 2.0 NAD_c + WATER_c --> 2.0 NADH_c + 3.0 PROTON_c + UDP-GLUCURONATE_c
# 289 UGD-RXN CPD-12575_c + 2.0 NAD_c + WATER_c --> 2.0 NADH_c + 3.0 PROTON_c + UDP-GLUCURONATE_c
#
# 290 UDPMANNACADEHYDROG-RXN 2.0 NAD_c + UDP-MANNAC_c + WATER_c --> 2.0 NADH_c + 3.0 PROTON_c + UDP-MANNACA_c
# 290 UDPMANNACADEHYDROG-RXN 2.0 NAD_c + UDP-MANNAC_c + WATER_c --> 2.0 NADH_c + 3.0 PROTON_c + UDP-MANNACA_c
#
# 291 GLUTDECARBOX-RXN GLT_c + PROTON_c --> 4-AMINO-BUTYRATE_c + CARBON-DIOXIDE_c
# 291 GLUTDECARBOX-RXN GLT_c + PROTON_c --> 4-AMINO-BUTYRATE_c + CARBON-DIOXIDE_c
#
# 292 CYSTATHIONINE-BETA-LYASE-RXN L-CYSTATHIONINE_c + WATER_c --> AMMONIUM_c + HOMO-CYS_c + PYRUVATE_c
# 292 CYSTATHIONINE-BETA-LYASE-RXN L-CYSTATHIONINE_c + WATER_c --> AMMONIUM_c + HOMO-CYS_c + PYRUVATE_c
#
# 293 RXN-12565 ACETYL-COA_c + BUTYRYL-COA_c <=> CO-A_c + K-HEXANOYL-COA_c
# 293 RXN-12565 ACETYL-COA_c + BUTYRYL-COA_c <=> CO-A_c + K-HEXANOYL-COA_c
#
# 294 RXN-13617 ACETYL-COA_c + CPD-196_c <=> CO-A_c + CPD0-2123_c
# 294 RXN-13617 CO-A_c + CPD0-2123_c --> ACETYL-COA_c + CPD-196_c
#
# 295 ACETYL-COA-ACETYLTRANSFER-RXN 2.0 ACETYL-COA_c <=> ACETOACETYL-COA_c + CO-A_c
# 295 ACETYL-COA-ACETYLTRANSFER-RXN 2.0 ACETYL-COA_c <=> ACETOACETYL-COA_c + CO-A_c
#
# 296 RXN0-5114 3-P-SERINE_c + WATER_c --> Pi_c + SER_c
# 296 RXN0-5114 3-P-SERINE_c + WATER_c --> Pi_c + SER_c
#
# 297 RXN-16701 CPD-381_c + NAD_c <=> 2-KETOGLUTARATE_c + NADH_c + PROTON_c
# 297 RXN-16701 CPD-381_c + NAD_c <=> 2-KETOGLUTARATE_c + NADH_c + PROTON_c
#
# 298 PGLYCDEHYDROG-RXN G3P_c + NAD_c --> 3-P-HYDROXYPYRUVATE_c + NADH_c + PROTON_c
# 298 PGLYCDEHYDROG-RXN G3P_c + NAD_c <=> 3-P-HYDROXYPYRUVATE_c + NADH_c + PROTON_c
#
# 299 GTP-CYCLOHYDRO-I-RXN GTP_c + WATER_c --> DIHYDRONEOPTERIN-P3_c + FORMATE_c + PROTON_c
# 299 GTP-CYCLOHYDRO-I-RXN GTP_c + WATER_c --> DIHYDRONEOPTERIN-P3_c + FORMATE_c + PROTON_c
#
# 300 DIHYDROFOLATESYNTH-RXN 7-8-DIHYDROPTEROATE_c + ATP_c + GLT_c --> ADP_c + DIHYDROFOLATE_c + PROTON_c + Pi_c
# 300 DIHYDROFOLATESYNTH-RXN 7-8-DIHYDROPTEROATE_c + ATP_c + GLT_c --> ADP_c + DIHYDROFOLATE_c + PROTON_c + Pi_c
#
# 301 SAICARSYN-RXN ATP_c + L-ASPARTATE_c + PHOSPHORIBOSYL-CARBOXY-AMINOIMIDAZOLE_c --> ADP_c + P-RIBOSYL-4-SUCCCARB-AMINOIMIDAZOLE_c + PROTON_c + Pi_c
# 301 SAICARSYN-RXN ATP_c + L-ASPARTATE_c + PHOSPHORIBOSYL-CARBOXY-AMINOIMIDAZOLE_c --> ADP_c + P-RIBOSYL-4-SUCCCARB-AMINOIMIDAZOLE_c + PROTON_c + Pi_c
#
# 302 RXN0-5289 NADH_c + PROTON_c + TARTRONATE-S-ALD_c <=> GLYCERATE_c + NAD_c
# 302 RXN0-5289 GLYCERATE_c + NAD_c <=> NADH_c + PROTON_c + TARTRONATE-S-ALD_c
#
# 303 H2PTEROATESYNTH-RXN DIHYDROPTERIN-CH2OH-PP_c + P-AMINO-BENZOATE_c --> 7-8-DIHYDROPTEROATE_c + PPI_c
# 303 H2PTEROATESYNTH-RXN DIHYDROPTERIN-CH2OH-PP_c + P-AMINO-BENZOATE_c --> 7-8-DIHYDROPTEROATE_c + PPI_c
#
# 304 METHYLENETHFDEHYDROG-NADP-RXN METHYLENE-THF_c + NADP_c <=> 5-10-METHENYL-THF_c + NADPH_c
# 304 METHYLENETHFDEHYDROG-NADP-RXN METHYLENE-THF_c + NADP_c <=> 5-10-METHENYL-THF_c + NADPH_c
#
# 305 METHENYLTHFCYCLOHYDRO-RXN 5-10-METHENYL-THF_c + WATER_c <=> 10-FORMYL-THF_c + PROTON_c
# 305 METHENYLTHFCYCLOHYDRO-RXN 5-10-METHENYL-THF_c + WATER_c <=> 10-FORMYL-THF_c + PROTON_c
#
# 306 RXN0-3942 CPD-9000_c + WATER_c --> 4-AMINO-BUTYRATE_c + GLT_c
# 306 RXN0-3942 CPD-9000_c + WATER_c --> 4-AMINO-BUTYRATE_c + GLT_c
#
# 307 RXN-6622 CYS-GLY_c + WATER_c --> CYS_c + GLY_c
# 307 RXN-6622 CYS-GLY_c + WATER_c --> CYS_c + GLY_c
#
# 308 RXN0-6981 CPD0-1445_c + WATER_c --> GLT_c + L-ALPHA-ALANINE_c
# 308 RXN0-6981 CPD0-1445_c + WATER_c --> GLT_c + L-ALPHA-ALANINE_c
#
# 309 RXN0-1483 4.0 FE+2_c + OXYGEN-MOLECULE_c + 4.0 PROTON_c --> 4.0 FE+3_c + 2.0 WATER_c
# 309 RXN0-1483 4.0 FE+2_c + OXYGEN-MOLECULE_c + 4.0 PROTON_c --> 4.0 FE+3_c + 2.0 WATER_c
#
# 310 BTUR2-RXN ATP_c + COBINAMIDE_c + PROTON_c <=> ADENOSYLCOBINAMIDE_c + P3I_c
# 310 BTUR2-RXN 2.0 ATP_c + 2.0 CPD-20903_c + Reduced-Flavoproteins_c --> 2.0 ADENOSYLCOBINAMIDE_c + Oxidized-Flavoproteins_c + 2.0 P3I_c + 2.0 PROTON_c
#
# 311 PPGPPSYN-RXN GUANOSINE-5DP-3DP_c + WATER_c --> GDP_c + PPI_c
# 311 PPGPPSYN-RXN GUANOSINE-5DP-3DP_c + WATER_c --> GDP_c + PPI_c + PROTON_c
#
# 312 RXN0-6427 GDP-TP_c + WATER_c --> GTP_c + PPI_c
# 312 RXN0-6427 GDP-TP_c + WATER_c --> GTP_c + PPI_c + PROTON_c
#
# 313 RXN0-1603 WATER_c + XTP_c --> PPI_c + PROTON_c + XANTHOSINE-5-PHOSPHATE_c
# 313 RXN0-1603 WATER_c + XTP_c --> PPI_c + PROTON_c + XANTHOSINE-5-PHOSPHATE_c
#
# 314 RXN0-6382 ITP_c + WATER_c --> IMP_c + PPI_c + PROTON_c
# 314 RXN0-6382 ITP_c + WATER_c --> IMP_c + PPI_c + PROTON_c
#
# 315 RXN0-1602 DITP_c + WATER_c --> DIMP_c + PPI_c + PROTON_c
# 315 RXN0-1602 DITP_c + WATER_c --> DIMP_c + PPI_c + PROTON_c
#
# 316 RXN-15744 LACTALD_c + NADPH_c + PROTON_c --> NADP_c + PROPANE-1-2-DIOL_c
# 316 RXN-15744 LACTALD_c + NADPH_c + PROTON_c --> NADP_c + PROPANE-1-2-DIOL_c
#
# 317 RXN-15743 CPD-358_c + NADPH_c + PROTON_c --> CPD-8891_c + NADP_c
# 317 RXN-15743 CPD-358_c + NADPH_c + PROTON_c --> CPD-8891_c + NADP_c
#
# 318 GLUCONOKIN-RXN ATP_c + GLUCONATE_c --> ADP_c + CPD-2961_c + PROTON_c
# 318 GLUCONOKIN-RXN ATP_c + GLUCONATE_c --> ADP_c + CPD-2961_c + PROTON_c
#
# 319 OHMETHYLBILANESYN-RXN 4.0 PORPHOBILINOGEN_c + WATER_c --> 4.0 AMMONIUM_c + HYDROXYMETHYLBILANE_c
# 319 OHMETHYLBILANESYN-RXN 4.0 PORPHOBILINOGEN_c + WATER_c --> 4.0 AMMONIUM_c + HYDROXYMETHYLBILANE_c
#
# 320 2.7.7.60-RXN 2-C-METHYL-D-ERYTHRITOL-4-PHOSPHATE_c + CTP_c + PROTON_c --> 4-CYTIDINE-5-DIPHOSPHO-2-C_c + PPI_c
# 320 2.7.7.60-RXN 2-C-METHYL-D-ERYTHRITOL-4-PHOSPHATE_c + CTP_c + PROTON_c --> 4-CYTIDINE-5-DIPHOSPHO-2-C_c + PPI_c
#
# 321 GLUTDEHYD-RXN GLT_c + NADP_c + WATER_c <=> 2-KETOGLUTARATE_c + AMMONIUM_c + NADPH_c + PROTON_c
# 321 GLUTDEHYD-RXN GLT_c + NADP_c + WATER_c <=> 2-KETOGLUTARATE_c + AMMONIUM_c + NADPH_c + PROTON_c
#
# 322 GLUTAMATESYN-RXN 2-KETOGLUTARATE_c + GLN_c + NADPH_c + PROTON_c --> 2.0 GLT_c + NADP_c
# 322 GLUTAMATESYN-RXN 2-KETOGLUTARATE_c + GLN_c + NADPH_c + PROTON_c --> 2.0 GLT_c + NADP_c
#
# 323 GLYOXII-RXN S-LACTOYL-GLUTATHIONE_c + WATER_c --> D-LACTATE_c + GLUTATHIONE_c + PROTON_c
# 323 GLYOXII-RXN S-LACTOYL-GLUTATHIONE_c + WATER_c --> D-LACTATE_c + GLUTATHIONE_c + PROTON_c
#
# 324 ERYTH4PDEHYDROG-RXN ERYTHROSE-4P_c + NAD_c + WATER_c <=> ERYTHRONATE-4P_c + NADH_c + 2.0 PROTON_c
# 324 ERYTH4PDEHYDROG-RXN ERYTHROSE-4P_c + NAD_c + WATER_c --> ERYTHRONATE-4P_c + NADH_c + 2.0 PROTON_c
#
# 325 GLUTAMIDOTRANS-RXN GLN_c + PHOSPHORIBULOSYL-FORMIMINO-AICAR-P_c --> AICAR_c + D-ERYTHRO-IMIDAZOLE-GLYCEROL-P_c + GLT_c + PROTON_c
# 325 GLUTAMIDOTRANS-RXN GLN_c + PHOSPHORIBULOSYL-FORMIMINO-AICAR-P_c --> AICAR_c + D-ERYTHRO-IMIDAZOLE-GLYCEROL-P_c + GLT_c + PROTON_c
#
# 326 DUTP-PYROP-RXN DUTP_c + WATER_c --> DUMP_c + PPI_c + PROTON_c
# 326 DUTP-PYROP-RXN DUTP_c + WATER_c --> DUMP_c + PPI_c + PROTON_c
#
# 327 THREDEHYD-RXN THR_c --> 2-OXOBUTANOATE_c + AMMONIUM_c
# 327 THREDEHYD-RXN THR_c --> 2-OXOBUTANOATE_c + AMMONIUM_c
#
# 328 2.7.9.3-RXN ATP_c + SE-2_c + WATER_c --> AMP_c + Pi_c + SEPO3_c
# 328 2.7.9.3-RXN ATP_c + SE-2_c + WATER_c --> AMP_c + Pi_c + SEPO3_c
#
# 329 SHIKIMATE-KINASE-RXN ATP_c + SHIKIMATE_c --> ADP_c + PROTON_c + SHIKIMATE-5P_c
# 329 SHIKIMATE-KINASE-RXN ATP_c + SHIKIMATE_c <=> ADP_c + PROTON_c + SHIKIMATE-5P_c
#
# 330 SUCCARGDIHYDRO-RXN CPD-421_c + 2.0 PROTON_c + 2.0 WATER_c --> 2.0 AMMONIUM_c + CARBON-DIOXIDE_c + N2-SUCCINYLORNITHINE_c
# 330 SUCCARGDIHYDRO-RXN CPD-421_c + 2.0 PROTON_c + 2.0 WATER_c --> 2.0 AMMONIUM_c + CARBON-DIOXIDE_c + N2-SUCCINYLORNITHINE_c
#
# 331 DAPASYN-RXN 8-AMINO-7-OXONONANOATE_c + S-ADENOSYLMETHIONINE_c <=> DIAMINONONANOATE_c + S-ADENOSYL-4-METHYLTHIO-2-OXOBUTANOATE_c
# 331 DAPASYN-RXN 8-AMINO-7-OXONONANOATE_c + S-ADENOSYLMETHIONINE_c <=> DIAMINONONANOATE_c + S-ADENOSYL-4-METHYLTHIO-2-OXOBUTANOATE_c
#
# 332 N-ACETYLTRANSFER-RXN ACETYL-COA_c + GLT_c --> ACETYL-GLU_c + CO-A_c + PROTON_c
# 332 N-ACETYLTRANSFER-RXN ACETYL-COA_c + GLT_c <=> ACETYL-GLU_c + CO-A_c + PROTON_c
#
# 333 RXN0-5038 CAMP_c + WATER_c --> AMP_c + PROTON_c
# 333 RXN0-5038 CAMP_c + WATER_c --> AMP_c + PROTON_c
#
# 334 DALADALALIG-RXN ATP_c + 2.0 D-ALANINE_c <=> ADP_c + D-ALA-D-ALA_c + PROTON_c + Pi_c
# 334 DALADALALIG-RXN ATP_c + 2.0 D-ALANINE_c --> ADP_c + D-ALA-D-ALA_c + PROTON_c + Pi_c
#
# 335 SUCCCOASYN-RXN ATP_c + CO-A_c + SUC_c <=> ADP_c + Pi_c + SUC-COA_c
# 335 SUCCCOASYN-RXN ATP_c + CO-A_c + SUC_c <=> ADP_c + Pi_c + SUC-COA_c
#
# 336 PANTOATE-BETA-ALANINE-LIG-RXN ATP_c + B-ALANINE_c + L-PANTOATE_c --> AMP_c + PANTOTHENATE_c + PPI_c + PROTON_c
# 336 PANTOATE-BETA-ALANINE-LIG-RXN ATP_c + B-ALANINE_c + L-PANTOATE_c --> AMP_c + PANTOTHENATE_c + PPI_c + PROTON_c
#
# 337 3-DEHYDROQUINATE-SYNTHASE-RXN 3-DEOXY-D-ARABINO-HEPTULOSONATE-7-P_c --> DEHYDROQUINATE_c + Pi_c
# 337 3-DEHYDROQUINATE-SYNTHASE-RXN 3-DEOXY-D-ARABINO-HEPTULOSONATE-7-P_c --> DEHYDROQUINATE_c + Pi_c
#
# 338 3PGAREARR-RXN 2-PG_c <=> G3P_c
# 338 3PGAREARR-RXN 2-PG_c <=> G3P_c
#
# 339 TRIOSEPISOMERIZATION-RXN DIHYDROXY-ACETONE-PHOSPHATE_c <=> GAP_c
# 339 TRIOSEPISOMERIZATION-RXN GAP_c <=> DIHYDROXY-ACETONE-PHOSPHATE_c
#
# 340 ERYTHRON4PDEHYDROG-RXN ERYTHRONATE-4P_c + NAD_c <=> 3OH-4P-OH-ALPHA-KETOBUTYRATE_c + NADH_c + PROTON_c
# 340 ERYTHRON4PDEHYDROG-RXN ERYTHRONATE-4P_c + NAD_c --> 3OH-4P-OH-ALPHA-KETOBUTYRATE_c + NADH_c + PROTON_c
#
# 341 RXN-8974 MALONATE-S-ALD_c + NADPH_c + PROTON_c --> 3-HYDROXY-PROPIONATE_c + NADP_c
# 341 RXN-8974 MALONATE-S-ALD_c + NADPH_c + PROTON_c --> 3-HYDROXY-PROPIONATE_c + NADP_c
#
# 342 GLUTATHIONE-SYN-RXN ATP_c + GLY_c + L-GAMMA-GLUTAMYLCYSTEINE_c --> ADP_c + GLUTATHIONE_c + PROTON_c + Pi_c
# 342 GLUTATHIONE-SYN-RXN ATP_c + GLY_c + L-GAMMA-GLUTAMYLCYSTEINE_c --> ADP_c + GLUTATHIONE_c + PROTON_c + Pi_c
#
# 343 RXN0-1863 5-BETA-L-THREO-PENTAPYRANOSYL-4-ULOSE-_c + GLT_c <=> 2-KETOGLUTARATE_c + UDP-4-AMINO-4-DEOXY-L-ARABINOSE_c
# 343 RXN0-1863 2-KETOGLUTARATE_c + UDP-4-AMINO-4-DEOXY-L-ARABINOSE_c <=> 5-BETA-L-THREO-PENTAPYRANOSYL-4-ULOSE-_c + GLT_c
#
# 344 RXN0-4281 METHYL-GLYOXAL_c + NADPH_c + PROTON_c --> ACETOL_c + NADP_c
# 344 RXN0-4281 METHYL-GLYOXAL_c + NADPH_c + PROTON_c --> ACETOL_c + NADP_c
#
# 345 RXN0-5061 ADP-L-GLYCERO-D-MANNO-HEPTOSE_c + CPD0-929_c --> ADP_c + CPD0-930_c + PROTON_c
# 345 RXN0-5061 ADP-L-GLYCERO-D-MANNO-HEPTOSE_c + CPD0-929_c --> ADP_c + CPD0-930_c + PROTON_c
#
# 346 HEMN-RXN COPROPORPHYRINOGEN_III_c + 2.0 S-ADENOSYLMETHIONINE_c --> 2.0 CARBON-DIOXIDE_c + 2.0 CH33ADO_c + 2.0 MET_c + PROTOPORPHYRINOGEN_c
# 346 HEMN-RXN COPROPORPHYRINOGEN_III_c + 2.0 S-ADENOSYLMETHIONINE_c --> 2.0 CARBON-DIOXIDE_c + 2.0 CH33ADO_c + 2.0 MET_c + PROTOPORPHYRINOGEN_c
#
# 347 DLACTDEHYDROGNAD-RXN D-LACTATE_c + NAD_c <=> NADH_c + PROTON_c + PYRUVATE_c
# 347 DLACTDEHYDROGNAD-RXN NADH_c + PROTON_c + PYRUVATE_c --> D-LACTATE_c + NAD_c
#
# 348 RXN-9537 R-3-hydroxymyristoyl-ACPs_c --> Tetradec-2-enoyl-ACPs_c + WATER_c
# 348 RXN-9537 R-3-hydroxymyristoyl-ACPs_c --> Tetradec-2-enoyl-ACPs_c + WATER_c
#
# 349 4.2.1.59-RXN 3-Hydroxy-octanoyl-ACPs_c --> 2-Octenoyl-ACPs_c + WATER_c
# 349 4.2.1.59-RXN 3-Hydroxy-octanoyl-ACPs_c --> 2-Octenoyl-ACPs_c + WATER_c
#
# 350 RXN0-305 OH-PYR_c <=> TARTRONATE-S-ALD_c
# 350 RXN0-305 OH-PYR_c <=> TARTRONATE-S-ALD_c
#
# 351 ADOMET-DMK-METHYLTRANSFER-RXN CPD-12115_c + S-ADENOSYLMETHIONINE_c --> ADENOSYL-HOMO-CYS_c + PROTON_c + REDUCED-MENAQUINONE_c
# 351 ADOMET-DMK-METHYLTRANSFER-RXN CPD-12115_c + S-ADENOSYLMETHIONINE_c --> ADENOSYL-HOMO-CYS_c + PROTON_c + REDUCED-MENAQUINONE_c
#
# 352 S-FORMYLGLUTATHIONE-HYDROLASE-RXN CPD-548_c + WATER_c --> FORMATE_c + GLUTATHIONE_c + PROTON_c
# 352 S-FORMYLGLUTATHIONE-HYDROLASE-RXN CPD-548_c + WATER_c --> FORMATE_c + GLUTATHIONE_c + PROTON_c
#
# 353 DMK-RXN DIHYDROXYNAPHTHOATE_c + OCTAPRENYL-DIPHOSPHATE_c + PROTON_c --> CARBON-DIOXIDE_c + CPD-12115_c + PPI_c
# 353 DMK-RXN DIHYDROXYNAPHTHOATE_c + OCTAPRENYL-DIPHOSPHATE_c + PROTON_c --> CARBON-DIOXIDE_c + CPD-12115_c + PPI_c
#
# 354 RXN-11477 3-Hydroxyglutaryl-ACP-methyl-ester_c --> Enoylglutaryl-ACP-methyl-esters_c + WATER_c
# 354 RXN-11477 3-Hydroxyglutaryl-ACP-methyl-ester_c --> Enoylglutaryl-ACP-methyl-esters_c + WATER_c
#
# 355 RXN-11481 3-hydroxypimeloyl-ACP-methyl-esters_c --> Enoylpimeloyl-ACP-methyl-esters_c + WATER_c
# 355 RXN-11481 3-hydroxypimeloyl-ACP-methyl-esters_c --> Enoylpimeloyl-ACP-methyl-esters_c + WATER_c
#
# 356 ACONITATEDEHYDR-RXN CIT_c <=> CIS-ACONITATE_c + WATER_c
# 356 ACONITATEDEHYDR-RXN CIT_c <=> CIS-ACONITATE_c + WATER_c
#
# 357 4.2.1.99-RXN CPD-1136_c + WATER_c <=> CPD-618_c
# 357 4.2.1.99-RXN CPD-618_c <=> CPD-1136_c + WATER_c
#
# 358 RXN-12093 AMMONIUM_c + ATP_c + CPD-13043_c --> 7-CYANO-7-DEAZAGUANINE_c + ADP_c + PROTON_c + Pi_c + WATER_c
# 358 RXN-12093 AMMONIUM_c + ATP_c + CPD-13043_c --> 7-CYANO-7-DEAZAGUANINE_c + ADP_c + PROTON_c + Pi_c + WATER_c
#
# 359 RXN0-4022 7-CYANO-7-DEAZAGUANINE_c + 2.0 NADPH_c + 3.0 PROTON_c --> 7-AMINOMETHYL-7-DEAZAGUANINE_c + 2.0 NADP_c
# 359 RXN0-4022 7-CYANO-7-DEAZAGUANINE_c + 2.0 NADPH_c + 3.0 PROTON_c --> 7-AMINOMETHYL-7-DEAZAGUANINE_c + 2.0 NADP_c
#
# 360 RXN-3641 3-KETO-ADIPYL-COA_c + CO-A_c --> ACETYL-COA_c + SUC-COA_c
# 360 RXN-3641 3-KETO-ADIPYL-COA_c + CO-A_c --> ACETYL-COA_c + SUC-COA_c
#
# 361 RXN0-2044 3-HYDROXYADIPYL-COA_c + NAD_c <=> 3-KETO-ADIPYL-COA_c + NADH_c + PROTON_c
# 361 RXN0-2044 3-HYDROXYADIPYL-COA_c + NAD_c <=> 3-KETO-ADIPYL-COA_c + NADH_c + PROTON_c
#
# 362 RXN-11484 L-ALPHA-ALANINE_c + Pimeloyl-ACPs_c --> 8-AMINO-7-OXONONANOATE_c + ACP_c + CARBON-DIOXIDE_c
# 362 RXN-11484 L-ALPHA-ALANINE_c + PROTON_c + Pimeloyl-ACPs_c --> 8-AMINO-7-OXONONANOATE_c + ACP_c + CARBON-DIOXIDE_c
#
# 363 RXN-11483 Pimeloyl-ACP-methyl-esters_c + WATER_c --> METOH_c + Pimeloyl-ACPs_c
# 363 RXN-11483 Pimeloyl-ACP-methyl-esters_c + WATER_c --> METOH_c + PROTON_c + Pimeloyl-ACPs_c
#
# 364 RXN0-5208 2.0 ATP_c + PROTON_c --> ADENOSYL-P4_c + PPI_c
# 364 RXN0-5208 2.0 ATP_c + PROTON_c --> ADENOSYL-P4_c + PPI_c
#
# 365 RXN0-5364 CPD-381_c + OXYGEN-MOLECULE_c --> 2-KETOGLUTARATE_c + HYDROGEN-PEROXIDE_c
# 365 RXN0-5364 CPD-381_c + OXYGEN-MOLECULE_c --> 2-KETOGLUTARATE_c + HYDROGEN-PEROXIDE_c
#
# 366 RXN0-7104 CPD-207_c + WATER_c --> CO-A_c + PHENYLACETATE_c + PROTON_c
# 366 RXN0-7104 CPD-207_c + WATER_c --> CO-A_c + PHENYLACETATE_c + PROTON_c
#
# 367 RXN0-6562 3-P-HYDROXYPYRUVATE_c + WATER_c --> OH-PYR_c + Pi_c
# 367 RXN0-6562 3-P-HYDROXYPYRUVATE_c + WATER_c --> OH-PYR_c + Pi_c
#
# 368 2-OCTAPRENYLPHENOL-HYDROX-RXN 2-OCTAPRENYLPHENOL_c + NADPH_c + OXYGEN-MOLECULE_c + PROTON_c --> 2-OCTAPRENYL-6-HYDROXYPHENOL_c + NADP_c + WATER_c
# 368 2-OCTAPRENYLPHENOL-HYDROX-RXN 2-OCTAPRENYLPHENOL_c + NADPH_c + OXYGEN-MOLECULE_c + PROTON_c --> 2-OCTAPRENYL-6-HYDROXYPHENOL_c + NADP_c + WATER_c

# %% [markdown]
# #### 4. Combine two draft models

# %%
def is_subset(lst1,lst2):
    # check if elements in lst1 are all in lst2
    is_ = True
    for item in lst1:
        if item not in lst2: is_ = False
    return is_

# %%
# add reactions in metacyc draft model to halo_iJO_meta model
combined_rxns = dict()
for rxn in halo_iJO_meta.reactions: combined_rxns[rxn.id] = rxn
for rxn in halo_meta.reactions:
    eco_rxn = combined_rxns.get(rxn.id)
    if eco_rxn is None: combined_rxns[rxn.id] = rxn
    else: 
        # if the rxn exist in both models, combine their gr rule 
        gr_eco = eco_rxn.gene_reaction_rule
        gr_meta = rxn.gene_reaction_rule
        if gr_eco == gr_meta: continue
            
        ## case 1: if 'and' not in both gr rules. Combine all genes with 'or'.
        if ' and ' not in gr_eco and ' and ' not in gr_meta:
            genes = set(parse_gr(gr_eco)+parse_gr(gr_meta))
            new_gr = ''
            for gene in genes: new_gr += gene + ' or '
            new_gr = new_gr[:-4]
            
            eco_rxn.gene_reaction_rule = new_gr
        
        ## case 2: if two grs only differ in 'and' 'or' while with the same genes. use the one from eco li
        elif parse_gr(gr_eco) == parse_gr(gr_meta): pass
        
        ## case 3: if genes in metacyc model is a subset of eco model, use the one from eco model
        elif is_subset(parse_gr(gr_meta),parse_gr(gr_eco)): pass
        else: 
            print(gr_eco)
            print(gr_meta)
            #print(new_gr)
            print('')
print('For above reactions, use the one from ecoli at the moment.')
            


halo_meta_c = cobra.Model('combined_metacyc_iJO1366')
halo_meta_c.add_reactions(combined_rxns.values())
# Out:
# TD01GL002722 and TD01GL002723
# TD01GL001634 or TD01GL002723
#
# TD01GL002722 and TD01GL002723
# TD01GL001635 or TD01GL002722
#
# TD01GL001227 and TD01GL002214
# TD01GL001226 or TD01GL001227 or TD01GL002214 or TD01GL002215
#
# TD01GL003202 and TD01GL003203
# TD01GL003202 or TD01GL003203 or TD01GL003289
#
# TD01GL003202 and TD01GL003203
# TD01GL003202 or TD01GL003203 or TD01GL003289
#
# TD01GL000278 and TD01GL001910
# TD01GL000277 or TD01GL000278
#
# ( TD01GL001243 and TD01GL001660 ) or ( TD01GL001130 and TD01GL001243 )
# TD01GL001130 or TD01GL001660 or TD01GL002558
#
# TD01GL000350 and TD01GL000351
# TD01GL000039 or TD01GL000350 or TD01GL000351
#
# TD01GL001060 and TD01GL003062 and TD01GL003063
# TD01GL001060 or TD01GL001380 or TD01GL003062
#
# TD01GL002722 and TD01GL002723
# TD01GL001634 or TD01GL001635
#
# For above reactions, use the one from ecoli at the moment.

# %%
report_model_status(halo_meta)
# Out:
# Number of reactions: 1271
# Number of metabolits: 1641
# Number of compartments: 2
# Number of genes: 1230
# Number of missing genes: 0
# Number of reactions with missing genes: 0

# %%
report_model_status(halo_meta_c)
# Out:
# Number of reactions: 1836
# Number of metabolits: 1979
# Number of compartments: 2
# Number of genes: 1270
# Number of missing genes: 0
# Number of reactions with missing genes: 0

# %% [markdown]
# #### 4.6 compare the combinded model and the universal model

# %%
# there are some reactions with the same id while with different equations
# 
k = 1
meta_model_ids = [rxn.id for rxn in halo_meta_c.reactions]
for rxn in universal.reactions:
    if rxn.id in meta_model_ids:
        rxn1 = halo_meta_c.reactions.get_by_id(rxn.id)
        if rxn.reaction != rxn1.reaction:
            print(k,rxn.id,rxn.reaction)
            print(k,rxn1.id,rxn1.reaction)
            print('')
            k += 1
# Out:
# 1 3-DEHYDROQUINATE-DEHYDRATASE-RXN DEHYDROQUINATE_c --> 3-DEHYDRO-SHIKIMATE_c + WATER_c
# 1 3-DEHYDROQUINATE-DEHYDRATASE-RXN DEHYDROQUINATE_c <=> 3-DEHYDRO-SHIKIMATE_c + WATER_c
#
# 2 TAGAALDOL-RXN TAGATOSE-1-6-DIPHOSPHATE_c <=> DIHYDROXY-ACETONE-PHOSPHATE_c + GAP_c
# 2 TAGAALDOL-RXN TAGATOSE-1-6-DIPHOSPHATE_c --> DIHYDROXY-ACETONE-PHOSPHATE_c + GAP_c
#
# 3 HISTPRATPHYD-RXN PHOSPHORIBOSYL-ATP_c + WATER_c --> PHOSPHORIBOSYL-AMP_c + PPI_c + PROTON_c
# 3 HISTPRATPHYD-RXN PHOSPHORIBOSYL-ATP_c + WATER_c --> PHOSPHORIBOSYL-AMP_c + PPI_c + 2.0 PROTON_c
#
# 4 ASPARTATEKIN-RXN ATP_c + L-ASPARTATE_c <=> ADP_c + L-BETA-ASPARTYL-P_c
# 4 ASPARTATEKIN-RXN ATP_c + L-ASPARTATE_c --> ADP_c + L-BETA-ASPARTYL-P_c
#
# 5 RXN0-5111 GLYCOLLATE_e <=> GLYCOLLATE_c
# 5 RXN0-5111 GLYCOLLATE_e + NA+_e <=> GLYCOLLATE_c + NA+_c
#
# 6 RXN0-1981 ACET_e <=> ACET_c
# 6 RXN0-1981 ACET_e + NA+_e <=> ACET_c + NA+_c
#
# 7 RXN-9615 AMMONIUM_e <=> AMMONIUM_c
# 7 RXN-9615 AMMONIUM_e --> AMMONIUM_c
#
# 8 RXN0-1924 CYS_e <=> CYS_c
# 8 RXN0-1924 CYS_c --> CYS_e
#
# 9 TRANS-RXN0-569 LYS_e <=> LYS_c
# 9 TRANS-RXN0-569 LYS_c --> LYS_e
#
# 10 TRANS-RXN-137 NITRITE_e <=> NITRITE_c
# 10 TRANS-RXN-137 NITRITE_c --> NITRITE_e
#
# 11 ACETYLGLUTKIN-RXN ACETYL-GLU_c + ATP_c --> ADP_c + N-ACETYL-GLUTAMYL-P_c
# 11 ACETYLGLUTKIN-RXN ACETYL-GLU_c + ATP_c <=> ADP_c + N-ACETYL-GLUTAMYL-P_c
#
# 12 TRANS-RXN0-281 3-KETOBUTYRATE_e <=> 3-KETOBUTYRATE_c
# 12 TRANS-RXN0-281 3-KETOBUTYRATE_e --> 3-KETOBUTYRATE_c
#
# 13 RXN0-1923 ACETYLSERINE_e <=> ACETYLSERINE_c
# 13 RXN0-1923 ACETYLSERINE_c --> ACETYLSERINE_e
#
# 14 TRANS-RXN0-240 BIOTIN_e <=> BIOTIN_c
# 14 TRANS-RXN0-240 BIOTIN_e --> BIOTIN_c
#
# 15 TRANS-RXN0-445 CHITOBIOSE_e <=> CHITOBIOSE_c
# 15 TRANS-RXN0-445 CHITOBIOSE_e --> CHITOBIOSE_c

# %%
# if there are some reactions with the same id while with different equations
# 
k = 1
meta_model_ids = [rxn.id for rxn in halo_iJO_meta.reactions]
for rxn in universal.reactions:
    if rxn.id in meta_model_ids:
        rxn1 = halo_meta_c.reactions.get_by_id(rxn.id)
        if rxn.reaction != rxn1.reaction:
            print(k,rxn.id,rxn.reaction)
            print(k,rxn1.id,rxn1.reaction)
            print('')
            k += 1

# %% [markdown]
# ## Add exchange reactions for all metabolites in medium. Use _e for extracellular compartment. Set all these exchange reversible
#
# * For those metabolites that doesn't have any transporters, add reversible transport reactions
# * use metacyc id for all metabolites. if no metacyc id, then use bigg.metabolite id
# * use 'Exchange_xx' for exhange reactions. xx is a metabolite id
# * use 'Transport_xx' for transport reactions. xx is a metabolite id

# %%
#####Last time stopped here
book = xlrd.open_workbook('../Results/core_biomass_medium_summary_iML1515.xlsx')
sh = book.sheet_by_name('medium')

mnx2meta = dict()
for line in open('../../../ComplementaryData/MNX2metacyc.tsv'):
    cont = line.split()
    mnx2meta[cont[0]] = mnx2meta.get(cont[0],[]) + [cont[1]]

all_rxns = halo_meta_c.reactions
for i in range(sh.nrows-1):
    i += 1
    mnx = sh.cell(i,6).value
    bigg = sh.cell(i,2).value
    name = sh.cell(i,0).value
    
    met_ids = mnx2meta.get(mnx,None)
    if met_ids is not None:
        met_id = None
        for item in met_ids:
            try: 
                halo_meta_c.metabolites.get_by_id(item)
                met_id = item
                break
            except: None
        if met_id is None: met_id = met_ids[0]
            
    else: met_id = bigg
    
    # create exchange reaction
    met_e = cobra.Metabolite(met_id+'_e')
    met_e.name = name
    met_e.compartment = 'e'
    exg_rxn = cobra.Reaction('Exchange_'+met_id)
    exg_rxn.upper_bound = 1000
    exg_rxn.lower_bound = -1000
    exg_rxn.add_metabolites({met_e:1})
    #halo_meta_c.add_reaction(exg_rxn) 
    all_rxns.append(exg_rxn)
    print(exg_rxn.id,exg_rxn.reaction)
    
    
    # create transport reaction for some ions which transporter were not found
    if met_id in ['CA+2','CO+2','CU+2','FE+3','MG+2','MN+2']:
        try: 
            met_c = halo_meta_c.metabolites.get_by_id(met_id+'_c')
            print(met_c,met_c.compartment)
        except:
            met_c = cobra.Metabolite(met_id+'_c')
            met_c.name = name
            met_c.compartment = 'c'

        tran_rxn = cobra.Reaction('Transport_'+met_id)
        tran_rxn.upper_bound = 1000
        tran_rxn.lower_bound = -1000
        tran_rxn.add_metabolites({met_e:-1,met_c:1})
        all_rxns.append(tran_rxn)
        print(tran_rxn.id,tran_rxn.reaction)
    
    
    # add exchange and transport reactions
    
    #halo_meta_c.add_reaction(tran_rxn)# ,
    
    #
    print('')
    
# if we use halo_meta_c.add_reactions([]) to add transport and exchange reactions, there would be a key error in 
# optlang costrant variant when use halo_meta_c.copy().
halo_meta_c = cobra.Model(halo_meta_c.id)
halo_meta_c.add_reactions(all_rxns)
# Out:
# Exchange_CPD0-2422  <=> CPD0-2422_e
#
# Exchange_CL-  <=> CL-_e
#
# Exchange_Glucopyranose  <=> Glucopyranose_e
#
# Exchange_UREA  <=> UREA_e
#
# Exchange_MG+2  <=> MG+2_e
# MG+2_c c
# Transport_MG+2 MG+2_e <=> MG+2_c
#
# Exchange_HSO4  <=> HSO4_e
#
# Exchange_CPD-16459  <=> CPD-16459_e
#
# Exchange_FE+3  <=> FE+3_e
# FE+3_c c
# Transport_FE+3 FE+3_e <=> FE+3_c
#
# Exchange_AMMONIA  <=> AMMONIA_e
#
# Exchange_CIT  <=> CIT_e
#
# Exchange_FE+2  <=> FE+2_e
#
# Exchange_CA+2  <=> CA+2_e
# CA+2_c c
# Transport_CA+2 CA+2_e <=> CA+2_c
#
# Exchange_ZN+2  <=> ZN+2_e
#
# Exchange_MN+2  <=> MN+2_e
# Transport_MN+2 MN+2_e <=> MN+2_c
#
# Exchange_CO+2  <=> CO+2_e
# CO+2_c c
# Transport_CO+2 CO+2_e <=> CO+2_c
#
# Exchange_K+  <=> K+_e
#
# Exchange_CU+2  <=> CU+2_e
# CU+2_c c
# Transport_CU+2 CU+2_e <=> CU+2_c
#
# Exchange_NI+2  <=> NI+2_e
#
# Exchange_CPD-3  <=> CPD-3_e
#
# Exchange_OXYGEN-MOLECULE  <=> OXYGEN-MOLECULE_e
#
# Exchange_L-ALPHA-ALANINE  <=> L-ALPHA-ALANINE_e
#
# Exchange_CYS  <=> CYS_e
#
# Exchange_L-ASPARTATE  <=> L-ASPARTATE_e
#
# Exchange_GLT  <=> GLT_e
#
# Exchange_PHE  <=> PHE_e
#
# Exchange_GLY  <=> GLY_e
#
# Exchange_HIS  <=> HIS_e
#
# Exchange_ILE  <=> ILE_e
#
# Exchange_LYS  <=> LYS_e
#
# Exchange_LEU  <=> LEU_e
#
# Exchange_MET  <=> MET_e
#
# Exchange_ASN  <=> ASN_e
#
# Exchange_PRO  <=> PRO_e
#
# Exchange_GLN  <=> GLN_e
#
# Exchange_ARG  <=> ARG_e
#
# Exchange_SER  <=> SER_e
#
# Exchange_THR  <=> THR_e
#
# Exchange_VAL  <=> VAL_e
#
# Exchange_TRP  <=> TRP_e
#
# Exchange_TYR  <=> TYR_e
#
# Exchange_ADENINE  <=> ADENINE_e
#
# Exchange_CPD-15990  <=> CPD-15990_e
#
# Exchange_L-LACTATE  <=> L-LACTATE_e

# %% [markdown]
# ###  Add exchange reactions for all secreted metabolites. Use _e for extracellular compartment. Set all these exchange irreversible
#
# * use metacyc id for all metabolites. if no metacyc id, then use bigg.metabolite id
# * use 'Exchange_xx' for exhange reactions. xx is a metabolite id

# %%
book = xlrd.open_workbook('../Results/core_biomass_medium_summary_iML1515.xlsx')
sh = book.sheet_by_name('secretion')

mnx2meta = dict()
for line in open('../../../ComplementaryData/MNX2metacyc.tsv'):
    cont = line.split()
    mnx2meta[cont[0]] = mnx2meta.get(cont[0],[]) + [cont[1]]

all_rxns = halo_meta_c.reactions
for i in range(sh.nrows-1):
    i += 1
    mnx = sh.cell(i,6).value
    bigg = sh.cell(i,2).value
    name = sh.cell(i,0).value
    
    met_ids = mnx2meta.get(mnx,None)
    if met_ids is not None:
        met_id = None
        for item in met_ids:
            try: 
                halo_meta_c.metabolites.get_by_id(item)
                met_id = item
                break
            except: None
        if met_id is None: met_id = met_ids[0]
            
    else: met_id = bigg
    
    # create exchange reaction
    met_e = cobra.Metabolite(met_id+'_e')
    met_e.name = name
    met_e.compartment = 'e'
    exg_rxn = cobra.Reaction('Exchange_'+met_id)
    exg_rxn.upper_bound = 1000
    exg_rxn.lower_bound = 0
    exg_rxn.add_metabolites({met_e:-1})
    #halo_meta_c.add_reaction(exg_rxn) 
    all_rxns.append(exg_rxn)
    
    
    # create transport reaction
    '''
    try: 
        met_c = halo_meta_c.metabolites.get_by_id(met_id+'_c')
        print(met_c,met_c.compartment)
    except:
        met_c = cobra.Metabolite(met_id+'_c')
        met_c.name = name
        met_c.compartment = 'c'
    
    tran_rxn = cobra.Reaction('Transport_'+met_id)
    tran_rxn.upper_bound = 1000
    tran_rxn.lower_bound = -1000
    tran_rxn.add_metabolites({met_e:-1,met_c:1})
    all_rxns.append(tran_rxn)
    '''
    # add exchange and transport reactions
    
    #halo_meta_c.add_reaction(tran_rxn)# ,
    print(exg_rxn.id,exg_rxn.reaction)
    #print(tran_rxn.id,tran_rxn.reaction)
    print('')
    
# if we use halo_meta_c.add_reactions([]) to add transport and exchange reactions, there would be a key error in 
# optlang costrant variant when use halo_meta_c.copy().
halo_meta_c = cobra.Model(halo_meta_c.id)
halo_meta_c.add_reactions(all_rxns)
# Out:
# Exchange_ac ac_e -->
#
# Exchange_pyr pyr_e -->
#
# Exchange_co2 co2_e -->
#
# Exchange_h2o h2o_e -->

# %%
report_model_status(halo_meta_c)
# Out:
# Number of reactions: 1889
# Number of metabolits: 2005
# Number of compartments: 2
# Number of genes: 1270
# Number of missing genes: 0
# Number of reactions with missing genes: 0

# %% [markdown]
# ## Add protein, dna, rna, ions, lipid synthesis

# %%
def find_halo_met_c(bigg_id,mnx_id,mnx2meta,halomodel):
    # check metacyc id
    meta_ids = mnx2meta.get(mnx_id,None)
    met = None
    if meta_ids is not None:
        # check which id is in model
        for item in meta_ids:
            try: 
                met = halomodel.metabolites.get_by_id(item+'_c')
                break
            except: met = cobra.Metabolite(item+'_c')
    else:
        item = bigg_id+'_c'
        try: met = halomodel.metabolites.get_by_id(item)
        except: met = cobra.Metabolite(item)
    return met

# %%
def test_if_model_can_produce(met,halomodel):
    # add sink reaction
    rxn_id = 'tmp'
    rxn_sink = cobra.Reaction(rxn_id)
    rxn_sink.add_metabolites({met:-1})
    halomodel.add_reaction(rxn_sink)
    halomodel.objective = 'tmp'
    f = halomodel.optimize().objective_value
    halomodel.remove_reactions([rxn_sink])
    print('maximal flux:',met.id,f)

# %%
def add_general_rxn(sheet_name,gen_met_name,gen_rxn_name,halomodel):
    # add reaction for protein synthesis. 20 aas -> protein
    book = xlrd.open_workbook('../Results/core_biomass_medium_summary_iML1515.xlsx')
    sh = book.sheet_by_name(sheet_name)

    mnx2meta = dict()
    for line in open('../../../ComplementaryData/MNX2metacyc.tsv'):
        cont = line.split()
        mnx2meta[cont[0]] = mnx2meta.get(cont[0],[]) + [cont[1]]

    coeffs = dict()
    for i in range(sh.nrows-1):
        i += 1
        mnx_id = sh.cell(i,9).value
        bigg_id = sh.cell(i,4).value
        met = find_halo_met_c(bigg_id,mnx_id,mnx2meta,halomodel)
        coeffs[met] = sh.cell(i,3).value
    met = cobra.Metabolite('{}_c'.format(gen_met_name))
    met.name = gen_met_name
    met.compartment = 'c'
    coeffs[met] = 1

    rxn = cobra.Reaction(gen_rxn_name)
    rxn.add_metabolites(coeffs)
    halomodel.add_reaction(rxn)
    print(rxn.reaction)
    test_if_model_can_produce(met,halomodel)

# %%
add_general_rxn('protein','protein','Protein_synthesis',halo_meta_c)
# Out:
# 0.295792 ARG_c + 0.241055 ASN_c + 0.09158 CYS_c + 0.26316 GLN_c + 0.26316 GLT_c + 0.612638 GLY_c + 0.094738 HIS_c + 0.290529 ILE_c + 0.513689 L-ALPHA-ALANINE_c + 0.241055 L-ASPARTATE_c + 0.450531 LEU_c + 0.343161 LYS_c + 0.153686 MET_c + 0.185265 PHE_c + 0.221055 PRO_c + 0.215792 SER_c + 0.253687 THR_c + 0.056843 TRP_c + 0.137896 TYR_c + 0.423162 VAL_c --> protein_c
# maximal flux: protein_c 0.0

# %%
add_general_rxn('dna','dna','DNA_synthesis',halo_meta_c)
# Out:
# 0.026166 DATP_c + 0.027017 DCTP_c + 0.027017 DGTP_c + 0.026166 TTP_c --> dna_c
# maximal flux: dna_c 0.0

# %%
add_general_rxn('rna','rna','RNA_synthesis',halo_meta_c)
# Out:
# 0.175 ATP_c + 0.133508 CTP_c + 0.215096 GTP_c + 0.144104 UTP_c --> rna_c
# maximal flux: rna_c 0.0

# %%
add_general_rxn('ions','ions','ions_pool',halo_meta_c)
# Out:
# 0.013013 AMMONIUM_c + 0.005205 CA+2_c + 0.005205 CL-_c + 2.5e-05 CO+2_c + 7e-06 CPD-3_c + 0.000709 CU+2_c + 0.006715 FE+2_c + 0.007808 FE+3_c + 0.195193 K+_c + 0.008675 MG+2_c + 0.000691 MN+2_c + 0.000323 NI+2_c + 0.004338 SULFATE_c + 0.000341 ZN+2_c --> ions_c
# maximal flux: ions_c 0.0

# %%
add_general_rxn('lipids','lipids','lipids_synthesis',halo_meta_c)
# Out:
# 0.063814 CPD-12819_c + 0.075214 CPD-17086_c + 0.019456 KDO2-LIPID-IVA_c --> lipids_c
# maximal flux: lipids_c 0.0

# %% [markdown]
# ## Check if model can produce the metabolites in biomass one by one
# Match metabolites based on
# * metacyc id
# * bigg id

# %%
def set_yeast_extraction(model,upper_bound):
    # given the evidence that TD01 strain can growth wihout supplyment of amino acids, 
    # the strain should be able to produce 20 amino acids by itself.
    # Block the uptake of 20 amino acids
    amino_acids = ['CYS_c','L-ASPARTATE_c','GLT_c','PHE_c','GLY_c',
                  'HIS_c','ILE_c','LYS_c','LEU_c','MET_c','ASN_c',
                  'PRO_c','GLN_c','ARG_c','SER_c','THR_c','VAL_c',
                  'TRP_c','L-ALPHA-ALANINE_c','TYR_c','L-LACTATE','CPD-15990', 'ADENINE']
    for met_id in amino_acids:
        exg_rxn = model.reactions.get_by_id('Exchange_'+met_id.replace('_c',''))
        exg_rxn.upper_bound = upper_bound

# %%
def check_if_model_can_produce_mets_in_biomass_one_by_one(model):
    book = xlrd.open_workbook('../Results/core_biomass_medium_summary_iML1515.xlsx')
    sheets = ['protein','dna','rna','ions','lipids','others']

    mnx2meta = dict()
    for line in open('../../../ComplementaryData/MNX2metacyc.tsv'):
        cont = line.split()
        mnx2meta[cont[0]] = mnx2meta.get(cont[0],[]) + [cont[1]]

    for name in sheets:
        sh = book.sheet_by_name(name)
        print(name)
        for i in range(sh.nrows-1):
            i += 1
            mnx_id = sh.cell(i,9).value
            bigg_id = sh.cell(i,4).value
            met = find_halo_met_c(bigg_id,mnx_id,mnx2meta,model)
            if met is None: print(bigg_id+'_c',0)
            else:
                # add sink reaction
                rxn_id = 'tmp'
                rxn_sink = cobra.Reaction(rxn_id)
                rxn_sink.add_metabolites({met:-1})
                model.add_reaction(rxn_sink)
                model.objective = 'tmp'
                f = model.optimize().objective_value
                model.remove_reactions([rxn_sink])
                print(met.id,met.name,f)
        print('')

# %%
set_yeast_extraction(halo_meta_c,0)
check_if_model_can_produce_mets_in_biomass_one_by_one(halo_meta_c)
# Out:
# protein
# L-ALPHA-ALANINE_c L-alanine 0.0
# ARG_c L-arginine 0.0
# ASN_c L-asparagine 0.0
# L-ASPARTATE_c L-aspartate 0.0
# CYS_c L-cysteine 0.0
# GLN_c L-glutamine 0.0
# GLT_c L-glutamate 0.0
# GLY_c glycine 0.0
# HIS_c L-histidine 0.0
# ILE_c L-isoleucine 0.0
# LEU_c L-leucine 0.0
# LYS_c L-lysine 0.0
# MET_c L-methionine 0.0
# PHE_c L-phenylalanine 0.0
# PRO_c L-proline 0.0
# SER_c L-serine 0.0
# THR_c L-threonine 0.0
# TRP_c L-tryptophan 0.0
# TYR_c L-tyrosine 0.0
# VAL_c L-valine 0.0
#
# dna
# DATP_c dATP 0.0
# DCTP_c dCTP 0.0
# DGTP_c dGTP 0.0
# TTP_c dTTP 0.0
#
# rna
# ATP_c ATP 0.0
# CTP_c CTP 0.0
# GTP_c GTP 0.0
# UTP_c UTP 0.0
#
# ions
# CO+2_c Co2+ 1000.0
# CU+2_c Cu2+ 1000.0
# FE+2_c Fe2+ 1000.0
# FE+3_c Fe3+ 1000.0
# K+_c  1000.0
# MG+2_c Mg2+ 1000.0
# MN+2_c Manganese 1000.0
# CPD-3_c molybdate 0.0
# NI+2_c  0.0
# SULFATE_c sulfate 0.0
# ZN+2_c  1000.0
# CA+2_c  1000.0
# CL-_c chloride 1000.0
# AMMONIUM_c ammonium 0.0
#
# lipids
# KDO2-LIPID-IVA_c alpha-Kdo-(2->4)-alpha-Kdo-(2->6)-lipid IVA 0.0
# CPD-12819_c Phosphatidylethanolamine (dihexadecanoyl, n-C16:0) 0.0
# CPD-17086_c Phosphatidylethanolamine (dihexadec-9enoyl, n-C16:1) 0.0
#
# others
# PROTON_c H+ 250.0
# 10-FORMYL-THF_c 10-FORMYL-THF 0.0
# 2fe2s_c [2Fe-2S] iron-sulfur cluster 0.0
# 2-OCTAPRENYL-6-HYDROXYPHENOL_c 3-(all-trans-octaprenyl)benzene-1,2-diol 0.0
# CPD-7_c [4Fe-4S] iron-sulfur cluster 0.0
# S-ADENOSYLMETHIONINE_c S-ADENOSYLMETHIONINE 0.0
# BIOTIN_c biotin 0.0
# CO-A_c coenzyme A 0.0
# FAD_c FAD 0.0
# WATER_c H2O 0.0
# METHYLENE-THF_c METHYLENE-THF 0.0
# CPD0-2278_c Two disacharide linked murein units, pentapeptide crosslinked tetrapeptide (A2pm->D-ala) (middle of chain) 0.0
# NAD_c NAD+ 0.0
# NADP_c NADP+ 0.0
# PROTOHEME_c ferroheme b 0.0
# PYRIDOXAL_PHOSPHATE_c pyridoxal 5'-phosphate 0.0
# RIBOFLAVIN_c riboflavin 0.0
# SIROHEME_c siroheme 0.0
# SUC-COA_c succinyl-CoA 0.0
# THF_c THF 0.0
# THIAMINE-PYROPHOSPHATE_c thiamine diphosphate 0.0
# CPD-9649_c Undecaprenyl diphosphate 0.0
# ADP_c ADP 0.0
# Pi_c phosphate 0.0
# PPI_c diphosphate 0.0
# ATP_c ATP 0.0

# %% [markdown]
# ### 9. Gap-filling with iML1515

# %%
def do_gap_filling(halo_met,halmodel,universal,**kwargs):
 
    rxn_id = 'tmp'
    try: 
        rxn_sink = halmodel.reactions.get_by_id(rxn_id)
        halmodel.remove_reactions([rxn_sink])
    except: None
    rxn_sink = cobra.Reaction(rxn_id)
    rxn_sink.add_metabolites({met:-1})
    halmodel.add_reaction(rxn_sink)
    halmodel.objective = 'tmp'
    f1 = halmodel.optimize().objective_value
    
    added_genes = dict()# {'rxn_id':'genes'}
    print(halo_met.id)
    print('Before gap-filling:',f1)
    if f1 != 0: print('No need for gap-filling')
    else:
        try: 
            solution = cobra.flux_analysis.gapfill(halmodel, universal,**kwargs)
            all_rxns = dict()
            rxns_to_add = list()
            for rxn in solution[0]:
                try: halmodel.reactions.get_by_id(rxn.id)
                except: 
                    rxn_clean = rxn.copy()
                    added_genes[rxn_clean.id] = rxn_clean.gene_reaction_rule
                    
                    # add _missing tag for those genes
                    new_gr = rxn_clean.gene_reaction_rule
                    for gene in parse_gr(rxn_clean.gene_reaction_rule):
                        new_gr = new_gr.replace(gene,gene+'_missing')
        
                    rxn_clean.gene_reaction_rule = new_gr
                    rxns_to_add.append(rxn_clean)
            halmodel.add_reactions(rxns_to_add)
            f2 = halmodel.optimize().objective_value
            print('After gap-filling:',f2)
            print('Added reactions:')
            for rxn in rxns_to_add:print(rxn.id,rxn.reaction)
        except: print('Gap-filling failed for',halo_met.id)

    halmodel.remove_reactions([rxn_sink])
    print('\n\n')
    return added_genes

# %%
def try_gap_filling(halo_met,halmodel,universal, **kwargs):
    # glycogen_c
    solution = [[]]
    rxn_id = 'tmp'
    try: 
        rxn_sink = halmodel.reactions.get_by_id(rxn_id)
        halmodel.remove_reactions([rxn_sink])
        halomodel.repair()
    except: None
    rxn_sink = cobra.Reaction(rxn_id)
    rxn_sink.add_metabolites({met:-1})
    halmodel.add_reaction(rxn_sink)
    halmodel.objective = 'tmp'
    optres = halmodel.optimize()
    f1 = optres.objective_value
    print('Before gap-filling:',f1)
    if f1 != 0: 
        print('No need for gap-filling')
        solution = [['No need for gap-filling']]
        
    else:
        try: 
            solution = cobra.flux_analysis.gapfill(halmodel, universal,**kwargs)
            halmodel.add_reactions(solution[0])
            f2 = halmodel.optimize().objective_value
            print('After gap-filling:',f2)
            print('Added reactions:')
            for rxn in solution[0]:print(rxn.id,rxn.reaction)
            halmodel.remove_reactions(solution[0])
        except: 
            print('Gap-filling failed for',halo_met.id)
            solution = [['Failed']]
    halmodel.remove_reactions([rxn_sink])
    print('\n\n')
    return solution

# %% [raw]
# # try to perform gap-filling for every component in biomass, get a list of reactions to be added.
# # output:
# # >met_id_in_eco, met_name, met_id_in_halo
# # rxn_id gr rule
# #
# set_yeast_extraction(halo_meta_c,0)
# fhand = open('../Results/gap_filled_reactions_try.txt','w')
# book = xlrd.open_workbook('../Results/core_biomass_medium_summary.xlsx')
# sh = book.sheet_by_name('BiomassComparison')
# for i in range(sh.nrows-1):
#     i += 1
#     eco_met = eco.metabolites.get_by_id(sh.cell(i,0).value)
#     met = create_universal_met(eco_met,halo_meta_c,universal,mnx2meta)
#     print(met)
#     rxns = try_gap_filling(met,halo_meta_c,universal)[0]
#
#     #if rxns[0] == 'Failed':
#     #    rxns = try_gap_filling(met,halo_meta_c,universal,demand_reactions=True)[0]
#
#     fhand.write('>{0} {1} {2}\n'.format(eco_met.id,eco_met.name,met.id))
#     if rxns[0] not in ['Failed','No need for gap-filling']:
#         for rxn in rxns:
#             fhand.write('{0}\t{1}\t{2}\t{3}\n'.format(rxn.id,rxn.name,rxn.reaction,rxn.gene_reaction_rule))
#     else:
#         fhand.write('{0}\n'.format(rxns[0]))
#     fhand.write('\n')
#     print('')
# fhand.close()

# %% [raw]
# # block free uptake of lactate and TREHALOSE. Perform gap-filling with glucose as sole carbon source
# set_yeast_extraction(halo_meta_c,1000)
# # halo_meta_c.reactions.get_by_id('Exchange_L-LACTATE').upper_bound=0
# # halo_meta_c.reactions.get_by_id('Exchange_CPD-15990').upper_bound=0

# %% [markdown]
# #### Block uptake of 20 amino acids,  do gap-filling with iJO1366 as universal model. Do gap-filling for metabolites in order of (1) DNA , RNA, Protein, lipids, Others

# %%
fhand = open('../Results/gap_filled_reactions_v1_without_missing_genes.txt','w')

# %%
def write_gap_fill_res(fhand,added_genes,met):
    fhand.write('>{0} {1}\n'.format(met.id,met.name))
    if len(added_genes)==0: fhand.write('None')
    else:
        for k,v in added_genes.items(): fhand.write('{0},{1}\n'.format(k,v))
    fhand.write('\n')

# %%
set_yeast_extraction(halo_meta_c,0)

# DNA
met = halo_meta_c.metabolites.dna_c
added_genes = do_gap_filling(met,halo_meta_c,universal,demand_reactions=False)
write_gap_fill_res(fhand,added_genes,met)

# RNA 
met = halo_meta_c.metabolites.rna_c
added_genes = do_gap_filling(met,halo_meta_c,universal,demand_reactions=False)
write_gap_fill_res(fhand,added_genes,met)

# Protein
met = halo_meta_c.metabolites.protein_c
added_genes = do_gap_filling(met,halo_meta_c,universal,demand_reactions=False)
write_gap_fill_res(fhand,added_genes,met)

# lipids
met = halo_meta_c.metabolites.lipids_c
added_genes = do_gap_filling(met,halo_meta_c,universal,demand_reactions=False)
write_gap_fill_res(fhand,added_genes,met)

# Others
book = xlrd.open_workbook('../Results/core_biomass_medium_summary_iML1515.xlsx')
sh = book.sheet_by_name('others')
for i in range(sh.nrows-1):
    i += 1
    eco_met = eco.metabolites.get_by_id(sh.cell(i,0).value)
    met = create_universal_met(eco_met,halo_meta_c,universal,mnx2meta)
    print(met)
    added_genes = do_gap_filling(met,halo_meta_c,universal,demand_reactions=False)
    write_gap_fill_res(fhand,added_genes,met)
    print('')
# Out:
# dna_c
# Before gap-filling: 0.0
# Read LP format model from file /var/folders/dx/ghtq02dx2w307xx_5hncb421qny3_w/T/tmpizh_5l3_.lp
# Reading time = 0.02 seconds
# : 2010 rows, 3790 columns, 17824 nonzeros
# Read LP format model from file /var/folders/dx/ghtq02dx2w307xx_5hncb421qny3_w/T/tmpud8xmt7j.lp
# Reading time = 0.02 seconds
# : 1503 rows, 4450 columns, 16736 nonzeros
# After gap-filling: 96.08565305719085
# Added reactions:
# EX_pi_e Pi_e <=>
# EX_h_e PROTON_e <=>
# GLCtex_copy1 Glucopyranose_e --> Glucopyranose_c
# PItex Pi_e <=> Pi_c
# UREAtex UREA_e <=> UREA_c
# CITtex CIT_e <=> CIT_c
#
#
#
# rna_c
# Before gap-filling: 16.813968049268396
# No need for gap-filling
#
#
#
# protein_c
# Before gap-filling: 0.0
# Read LP format model from file /var/folders/dx/ghtq02dx2w307xx_5hncb421qny3_w/T/tmpf0wtxmpz.lp
# Reading time = 0.02 seconds
# : 2010 rows, 3802 columns, 17844 nonzeros
# Read LP format model from file /var/folders/dx/ghtq02dx2w307xx_5hncb421qny3_w/T/tmprtgd8g5l.lp
# Reading time = 0.02 seconds
# : 1503 rows, 4450 columns, 16736 nonzeros
# Ignoring reaction 'EX_h_e' since it already exists.
# Ignoring reaction 'UREAtex' since it already exists.
# Ignoring reaction 'CITtex' since it already exists.
# After gap-filling: 7.646731749572431
# Added reactions:
# ASNS2 AMMONIUM_c + ATP_c + L-ASPARTATE_c --> AMP_c + ASN_c + PPI_c + PROTON_c
# HSK ATP_c + HOMO-SER_c --> ADP_c + O-PHOSPHO-L-HOMOSERINE_c + PROTON_c
# G5SADs L-GLUTAMATE_GAMMA-SEMIALDEHYDE_c --> L-DELTA1-PYRROLINE_5-CARBOXYLATE_c + PROTON_c + WATER_c
# PPND NAD_c + PREPHENATE_c --> CARBON-DIOXIDE_c + NADH_c + P-HYDROXY-PHENYLPYRUVATE_c
# ADSK APS_c + ATP_c --> ADP_c + PAPS_c + PROTON_c
# HSDy HOMO-SER_c + NADP_c <=> L-ASPARTATE-SEMIALDEHYDE_c + NADPH_c + PROTON_c
# THDPS DELTA1-PIPERIDEINE-2-6-DICARBOXYLATE_c + SUC-COA_c + WATER_c --> CO-A_c + N-SUCCINYL-2-AMINO-6-KETOPIMELATE_c
# EX_so4_e SULFATE_e <=>
# GLCtex_copy2 Glucopyranose_e <=> Glucopyranose_c
#
#
#
# lipids_c
# Before gap-filling: 0.0
# Read LP format model from file /var/folders/dx/ghtq02dx2w307xx_5hncb421qny3_w/T/tmpawcqqws9.lp
# Reading time = 0.02 seconds
# : 2010 rows, 3820 columns, 17922 nonzeros
# Read LP format model from file /var/folders/dx/ghtq02dx2w307xx_5hncb421qny3_w/T/tmp0gc4v07e.lp
# Reading time = 0.02 seconds
# : 1503 rows, 4450 columns, 16736 nonzeros
# Ignoring reaction 'EX_pi_e' since it already exists.
# Ignoring reaction 'PItex' since it already exists.
# Ignoring reaction 'UREAtex' since it already exists.
# Ignoring reaction 'GLCtex_copy2' since it already exists.
# After gap-filling: 113.89436024740593
# Added reactions:
# O2tex OXYGEN-MOLECULE_e <=> OXYGEN-MOLECULE_c
# EX_h2o_e WATER_e <=>
# PSSA161 SER_c + cdpdhdec9eg_c --> CMP_c + PROTON_c + ps161_c
# AGPAT160 1hdecg3p_c + palmACP_c --> ACP_c + CPD0-1422_c
# PSSA160 SER_c + cdpdhdecg_c --> CMP_c + CPD-12817_c + PROTON_c
# AGPAT161 1hdec9eg3p_c + hdeACP_c --> ACP_c + pa161_c
#
#
#
# PROTON_c
# PROTON_c
# Before gap-filling: 1000.0
# No need for gap-filling
#
#
#
#
# 10-FORMYL-THF_c
# 10-FORMYL-THF_c
# Before gap-filling: 0.0
# Read LP format model from file /var/folders/dx/ghtq02dx2w307xx_5hncb421qny3_w/T/tmpyisaohgd.lp
# Reading time = 0.02 seconds
# : 2010 rows, 3832 columns, 17964 nonzeros
# Read LP format model from file /var/folders/dx/ghtq02dx2w307xx_5hncb421qny3_w/T/tmppxgp9vye.lp
# Reading time = 0.02 seconds
# : 1503 rows, 4450 columns, 16736 nonzeros
# Ignoring reaction 'EX_h_e' since it already exists.
# Ignoring reaction 'GLCtex_copy1' since it already exists.
# Ignoring reaction 'CITtex' since it already exists.
# After gap-filling: 25.078369905956123
# Added reactions:
# DNMPPA DIHYDRONEOPTERIN-P_c + WATER_c --> CPD-11770_c + Pi_c
# DNTPPA DIHYDRONEOPTERIN-P3_c + WATER_c --> DIHYDRONEOPTERIN-P_c + PPI_c + PROTON_c
# EX_nh4_e AMMONIUM_e <=>
# 4HTHRK ATP_c + CPD0-2189_c --> 4-PHOSPHONOOXY-THREONINE_c + ADP_c + PROTON_c
#
#
#
#
# 2fe2s_c
# 2fe2s_c
# Before gap-filling: 56.20155038759691
# No need for gap-filling
#
#
#
#
# 2-OCTAPRENYL-6-HYDROXYPHENOL_c
# 2-OCTAPRENYL-6-HYDROXYPHENOL_c
# Before gap-filling: 17.595307917888594
# No need for gap-filling
#
#
#
#
# CPD-7_c
# CPD-7_c
# Before gap-filling: 28.68447082096933
# No need for gap-filling
#
#
#
#
# S-ADENOSYLMETHIONINE_c
# S-ADENOSYLMETHIONINE_c
# Before gap-filling: 30.71672354948808
# No need for gap-filling
#
#
#
#
# BIOTIN_c
# BIOTIN_c
# Before gap-filling: 0.0
# Read LP format model from file /var/folders/dx/ghtq02dx2w307xx_5hncb421qny3_w/T/tmpgaib7gmk.lp
# Reading time = 0.02 seconds
# : 2011 rows, 3840 columns, 17994 nonzeros
# Read LP format model from file /var/folders/dx/ghtq02dx2w307xx_5hncb421qny3_w/T/tmpfi8arh7j.lp
# Reading time = 0.01 seconds
# : 1503 rows, 4450 columns, 16736 nonzeros
# Ignoring reaction 'UREAtex' since it already exists.
# Ignoring reaction 'ADSK' since it already exists.
# Ignoring reaction 'HSDy' since it already exists.
# Ignoring reaction 'EX_so4_e' since it already exists.
# Ignoring reaction 'GLCtex_copy2' since it already exists.
# Ignoring reaction 'O2tex' since it already exists.
# Ignoring reaction 'EX_h2o_e' since it already exists.
# After gap-filling: 16.643550624133116
# Added reactions:
# DM_amob_c S-ADENOSYL-4-METHYLTHIO-2-OXOBUTANOATE_c -->
# EX_meoh_e ALCOHOL-GROUP_e -->
# DM_5drib_c CPD0-2167_c -->
# MEOHtex ALCOHOL-GROUP_e <=> METOH_c
# AI2K ATP_c + DIHYDROXYPENTANEDIONE_c --> ADP_c + PROTON_c + dhptdp_c
# PAI2I dhptdp_c --> dhptdd_c
# PAI2T CO-A_c + dhptdd_c --> ACETYL-COA_c + DIHYDROXY-ACETONE-PHOSPHATE_c
#
#
#
#
# CO-A_c
# CO-A_c
# Before gap-filling: 0.0
# Read LP format model from file /var/folders/dx/ghtq02dx2w307xx_5hncb421qny3_w/T/tmpy8qjt627.lp
# Reading time = 0.02 seconds
# : 2014 rows, 3854 columns, 18026 nonzeros
# Read LP format model from file /var/folders/dx/ghtq02dx2w307xx_5hncb421qny3_w/T/tmpgkfudm8f.lp
# Reading time = 0.02 seconds
# : 1503 rows, 4450 columns, 16736 nonzeros
# Ignoring reaction 'EX_pi_e' since it already exists.
# Ignoring reaction 'GLCtex_copy1' since it already exists.
# Ignoring reaction 'PItex' since it already exists.
# Ignoring reaction 'UREAtex' since it already exists.
# Ignoring reaction 'ADSK' since it already exists.
# Ignoring reaction 'EX_so4_e' since it already exists.
# Ignoring reaction 'O2tex' since it already exists.
# Ignoring reaction 'EX_h2o_e' since it already exists.
# After gap-filling: 22.547914317925574
# Added reactions:
# PNTK ATP_c + PANTOTHENATE_c --> 4-P-PANTOTHENATE_c + ADP_c + PROTON_c
#
#
#
#
# FAD_c
# FAD_c
# Before gap-filling: 17.91936286709807
# No need for gap-filling
#
#
#
#
# WATER_c
# WATER_c
# Before gap-filling: 1000.0
# No need for gap-filling
#
#
#
#
# METHYLENE-THF_c
# METHYLENE-THF_c
# Before gap-filling: 25.078369905956116
# No need for gap-filling
#
#
#
#
# CPD0-2278_c
# CPD0-2278_c
# Before gap-filling: 18.33180568285976
# No need for gap-filling
#
#
#
#
# NAD_c
# NAD_c
# Before gap-filling: 0.0
# Read LP format model from file /var/folders/dx/ghtq02dx2w307xx_5hncb421qny3_w/T/tmpsqhf1dyj.lp
# Reading time = 0.02 seconds
# : 2014 rows, 3856 columns, 18036 nonzeros
# Read LP format model from file /var/folders/dx/ghtq02dx2w307xx_5hncb421qny3_w/T/tmpcisnfyvm.lp
# Reading time = 0.04 seconds
# : 1503 rows, 4450 columns, 16736 nonzeros
# Ignoring reaction 'EX_pi_e' since it already exists.
# Ignoring reaction 'EX_h_e' since it already exists.
# Ignoring reaction 'GLCtex_copy1' since it already exists.
# Ignoring reaction 'PItex' since it already exists.
# Ignoring reaction 'CITtex' since it already exists.
# Ignoring reaction 'EX_nh4_e' since it already exists.
# After gap-filling: 27.252081756245275
# Added reactions:
# NADS1 AMMONIUM_c + ATP_c + DEAMIDO-NAD_c --> AMP_c + NAD_c + PPI_c + PROTON_c
#
#
#
#
# NADP_c
# NADP_c
# Before gap-filling: 26.011560693641684
# No need for gap-filling
#
#
#
#
# PROTOHEME_c
# PROTOHEME_c
# Before gap-filling: 25.247971145175832
# No need for gap-filling
#
#
#
#
# PYRIDOXAL_PHOSPHATE_c
# PYRIDOXAL_PHOSPHATE_c
# Before gap-filling: 128.5714285714286
# No need for gap-filling
#
#
#
#
# RIBOFLAVIN_c
# RIBOFLAVIN_c
# Before gap-filling: 33.388981636059945
# No need for gap-filling
#
#
#
#
# SIROHEME_c
# SIROHEME_c
# Before gap-filling: 24.904877205119348
# No need for gap-filling
#
#
#
#
# SUC-COA_c
# SUC-COA_c
# Before gap-filling: 21.76278563656146
# No need for gap-filling
#
#
#
#
# THF_c
# THF_c
# Before gap-filling: 26.092628832354855
# No need for gap-filling
#
#
#
#
# THIAMINE-PYROPHOSPHATE_c
# THIAMINE-PYROPHOSPHATE_c
# Before gap-filling: 0.0
# Read LP format model from file /var/folders/dx/ghtq02dx2w307xx_5hncb421qny3_w/T/tmp_4sl8poa.lp
# Reading time = 0.02 seconds
# : 2014 rows, 3858 columns, 18050 nonzeros
# Read LP format model from file /var/folders/dx/ghtq02dx2w307xx_5hncb421qny3_w/T/tmpenpc8dl1.lp
# Reading time = 0.02 seconds
# : 1503 rows, 4450 columns, 16736 nonzeros
# Ignoring reaction 'EX_pi_e' since it already exists.
# Ignoring reaction 'PItex' since it already exists.
# Ignoring reaction 'UREAtex' since it already exists.
# Ignoring reaction 'ADSK' since it already exists.
# Ignoring reaction 'EX_so4_e' since it already exists.
# Ignoring reaction 'GLCtex_copy2' since it already exists.
# Ignoring reaction 'O2tex' since it already exists.
# Ignoring reaction 'EX_h2o_e' since it already exists.
# After gap-filling: 28.865979381443296
# Added reactions:
# THZPSN3 ATP_c + CPD-12279_c + DEOXYXYLULOSE-5P_c + NADPH_c + PROTON_c + iscssh_c --> AMP_c + CARBON-DIOXIDE_c + NADP_c + PPI_c + THZ-P_c + 2.0 WATER_c + iscs_c
#
#
#
#
# CPD-9649_c
# CPD-9649_c
# Before gap-filling: 14.634146341463406
# No need for gap-filling
#
#
#
#
# ADP_c
# ADP_c
# Before gap-filling: 44.17177914110425
# No need for gap-filling
#
#
#
#
# Pi_c
# Pi_c
# Before gap-filling: 1000.0
# No need for gap-filling
#
#
#
#
# PPI_c
# PPI_c
# Before gap-filling: 499.99999999999994
# No need for gap-filling
#
#
#
#
# ATP_c
# ATP_c
# Before gap-filling: 40.723981900452515
# No need for gap-filling

# %%
report_model_status(halo_meta_c)
# Out:
# Number of reactions: 1929
# Number of metabolits: 2014
# Number of compartments: 2
# Number of genes: 1298
# Number of missing genes: 28
# Number of reactions with missing genes: 26

# %% [markdown]
# #### Update missing genes added by gap-filling. By find homologues in H. TD01

# %%
halo_meta_c = update_missing_genes(halo_meta_c,1e-20,report=True,coverage=45)
# Out:
# Number of reactions: 1929
# Number of metabolits: 2014
# Number of compartments: 2
# Number of genes: 1273
# Number of missing genes: 3
# Number of reactions with missing genes: 1

# %% [markdown]
# #### For those reactions with missing genes, remove its gr rule and put a note as :
# {'source':'gapfilled from iJO1366, genes were not found in H.TD01'}

# %%
updated_rxns = list()
for rxn in halo_meta_c.reactions:
    if '_missing' in rxn.gene_reaction_rule:
        print(rxn.id,rxn.gene_reaction_rule)
        rxn.gene_reaction_rule = ''
        rxn.notes['source']='gapfilled from iJO1366, genes were not found in H.TD01'
    updated_rxns.append(rxn)

print('')
halo_meta_c = cobra.Model('model_v1')
halo_meta_c.add_reactions(updated_rxns)
report_model_status(halo_meta_c)
# Out:
# THZPSN3 TD01GL000663 and TD01GL001192 and b0423_missing and b3990_missing and b4407_missing
#
# Number of reactions: 1929
# Number of metabolits: 2014
# Number of compartments: 2
# Number of genes: 1270
# Number of missing genes: 0
# Number of reactions with missing genes: 0

# %% [markdown]
# book = xlrd.open_workbook('../Results/core_biomass_medium_summary.xlsx')
# sh = book.sheet_by_name('protein')
# for i in range(sh.nrows-1):
#     i += 1
#     eco_met = eco.metabolites.get_by_id(sh.cell(i,0).value)
#     met = create_universal_met(eco_met,halo_meta_c,universal,mnx2meta)
#     print(met)
#     added_genes = do_gap_filling(met,halo_meta_c,universal,demand_reactions=False)
#     #write_gap_fill_res(fhand,added_genes,met)
#     print('')

# %% [markdown]
# ### Add Biomass verions 1

# %%
biomass_rxn = cobra.Reaction('Biomass_v1')
coeffs = {halo_meta_c.metabolites.protein_c:-1,
          halo_meta_c.metabolites.dna_c:-1,
          halo_meta_c.metabolites.rna_c:-1,
          halo_meta_c.metabolites.ions_c:-1,
          halo_meta_c.metabolites.lipids_c:-1}
# Others
book = xlrd.open_workbook('../Results/core_biomass_medium_summary_iML1515.xlsx')
sh = book.sheet_by_name('others')
for i in range(sh.nrows-1):
    i += 1
    eco_met = eco.metabolites.get_by_id(sh.cell(i,0).value)
    met = create_universal_met(eco_met,halo_meta_c,universal,mnx2meta)
    coeff = sh.cell(i,3).value
    coeffs[met] = coeff
biomass_rxn.add_metabolites(coeffs)
print(biomass_rxn.reaction)
halo_meta_c.add_reactions([biomass_rxn])
# Out:
# 0.000223 10-FORMYL-THF_c + 0.000223 2-OCTAPRENYL-6-HYDROXYPHENOL_c + 2.6e-05 2fe2s_c + 75.37723 ATP_c + 2e-06 BIOTIN_c + 0.000576 CO-A_c + 0.00026 CPD-7_c + 5.5e-05 CPD-9649_c + 0.013894 CPD0-2278_c + 0.000223 FAD_c + 0.000223 METHYLENE-THF_c + 0.000447 NADP_c + 0.001831 NAD_c + 0.000223 PROTOHEME_c + 0.000223 PYRIDOXAL_PHOSPHATE_c + 0.000223 RIBOFLAVIN_c + 0.000223 S-ADENOSYLMETHIONINE_c + 0.000223 SIROHEME_c + 9.8e-05 SUC-COA_c + 0.000223 THF_c + 0.000223 THIAMINE-PYROPHOSPHATE_c + 70.028756 WATER_c + dna_c + ions_c + lipids_c + protein_c + rna_c --> 75.37723 ADP_c + 0.773903 PPI_c + 75.37723 PROTON_c + 75.37323 Pi_c

# %% [markdown]
# halo_meta_c.objective = 'Biomass_v1'
# solution = cobra.flux_analysis.gapfill(halo_meta_c, universal,demand_reactions=False)

# %%
halo_meta_c.reactions.Exchange_Glucopyranose.upper_bound = 5
halo_meta_c.reactions.get_by_id('Exchange_L-LACTATE').upper_bound=10
halo_meta_c.reactions.get_by_id('Exchange_CPD-15990').upper_bound=10

# %%
#print(halo_meta_c.reactions.Exchange_Glucopyranose.upper_bound)
set_yeast_extraction(halo_meta_c,0)
halo_meta_c.objective = 'Biomass_v1'
print(halo_meta_c.optimize())
# Out:
# <Solution 5.748 at 0x1328929198>

# %%
set_yeast_extraction(halo_meta_c,1000)
halo_meta_c.objective = 'Biomass_v1'
print(halo_meta_c.optimize())
# Out:
# <Solution 6.187 at 0x1328929128>

# %% [markdown]
# #### Save model and filled reactions

# %%
set_yeast_extraction(halo_meta_c,0)
check_if_model_can_produce_mets_in_biomass_one_by_one(halo_meta_c)
# Out:
# protein
# L-ALPHA-ALANINE_c L-alanine 336.66666666666663
# ARG_c L-arginine 98.47826086956522
# ASN_c L-asparagine 264.04761904761915
# L-ASPARTATE_c L-aspartate 1000.0
# CYS_c L-cysteine 104.13793103448285
# GLN_c L-glutamine 252.5
# GLT_c L-glutamate 336.6666666666667
# GLY_c glycine 838.333333333333
# HIS_c L-histidine 7.5
# ILE_c L-isoleucine 113.33333333333331
# LEU_c L-leucine 112.22222222222221
# LYS_c L-lysine 117.6923076923077
# MET_c L-methionine 92.72727272727273
# PHE_c L-phenylalanine 15.0
# PRO_c L-proline 180.0
# SER_c L-serine 336.6666666666667
# THR_c L-threonine 278.1818181818182
# TRP_c L-tryptophan 5.0
# TYR_c L-tyrosine 15.0
# VAL_c L-valine 144.28571428571428
#
# dna
# DATP_c dATP 7.5
# DCTP_c dCTP 7.5
# DGTP_c dGTP 7.500000000000005
# TTP_c dTTP 7.5
#
# rna
# ATP_c ATP 7.5000000000000036
# CTP_c CTP 7.5
# GTP_c GTP 7.5
# UTP_c UTP 7.5
#
# ions
# CO+2_c Co2+ 1000.0
# CU+2_c Cu2+ 1000.0
# FE+2_c Fe2+ 1000.0
# FE+3_c Fe3+ 1000.0
# K+_c  1000.0
# MG+2_c Mg2+ 1000.0
# MN+2_c Manganese 1000.0
# CPD-3_c molybdate 750.0
# NI+2_c  750.0
# SULFATE_c sulfate 750.0000000000003
# ZN+2_c  1000.0
# CA+2_c  1000.0
# CL-_c chloride 1000.0
# AMMONIUM_c ammonium 1000.0
#
# lipids
# KDO2-LIPID-IVA_c alpha-Kdo-(2->4)-alpha-Kdo-(2->6)-lipid IVA 1.5
# CPD-12819_c Phosphatidylethanolamine (dihexadecanoyl, n-C16:0) 15.53299492385787
# CPD-17086_c Phosphatidylethanolamine (dihexadec-9enoyl, n-C16:1) 16.19047619047619
#
# others
# PROTON_c H+ 1000.0
# 10-FORMYL-THF_c 10-FORMYL-THF 7.5000000000000675
# 2fe2s_c [2Fe-2S] iron-sulfur cluster 55.666666666666764
# 2-OCTAPRENYL-6-HYDROXYPHENOL_c 3-(all-trans-octaprenyl)benzene-1,2-diol 12.8
# CPD-7_c [4Fe-4S] iron-sulfur cluster 28.412098298676746
# S-ADENOSYLMETHIONINE_c S-ADENOSYLMETHIONINE 7.5
# BIOTIN_c biotin 2.5
# CO-A_c coenzyme A 7.5
# FAD_c FAD 1.875
# WATER_c H2O 1000.0
# METHYLENE-THF_c METHYLENE-THF 7.5
# CPD0-2278_c Two disacharide linked murein units, pentapeptide crosslinked tetrapeptide (A2pm->D-ala) (middle of chain) 1.25
# NAD_c NAD+ 3.75
# NADP_c NADP+ 3.7500000000000036
# PROTOHEME_c ferroheme b 22.936708860759495
# PYRIDOXAL_PHOSPHATE_c pyridoxal 5'-phosphate 15.0
# RIBOFLAVIN_c riboflavin 2.5
# SIROHEME_c siroheme 3.75
# SUC-COA_c succinyl-CoA 7.5
# THF_c THF 7.5
# THIAMINE-PYROPHOSPHATE_c thiamine diphosphate 7.5
# CPD-9649_c Undecaprenyl diphosphate 10.534979423868315
# ADP_c ADP 7.5
# Pi_c phosphate 1000.0
# PPI_c diphosphate 499.9999999999999
# ATP_c ATP 7.5000000000000036

# %%
for met in halo_meta_c.metabolites: 
    try: met.charge = int(met.charge)
    except: pass

# %%
cobra.io.write_sbml_model(halo_meta_c,
        '../../../ModelFiles/xml/combine_halo_meta100_iML1515_gap_fill_with_core_biomass_without_missing_genes.xml')
fhand.close()

# %%
cobra.io.save_matlab_model(halo_meta_c,
'../../../ModelFiles/mat/combine_halo_meta100_iML1515_gap_fill_with_core_biomass_without_missing_genes.mat')

# %%
cobra.io.save_json_model(halo_meta_c,
        '../../../ModelFiles/json/combine_halo_meta100_iML1515_gap_fill_with_core_biomass_without_missing_genes.json')

# %% [markdown]
# cobra.io.save_yaml_model(halo_meta_c,
#         '../Results/combine_halo_meta100_iJO1366_gap_fill_with_core_biomass_without_missing_genes.yaml')

# %%
report_model_status(halo_meta_c)
# Out:
# Number of reactions: 1930
# Number of metabolits: 2014
# Number of compartments: 2
# Number of genes: 1270
# Number of missing genes: 0
# Number of reactions with missing genes: 0

# %%
report_model_status(eco)
# Out:
# Number of reactions: 2712
# Number of metabolits: 1877
# Number of compartments: 3
# Number of genes: 1516
# Number of missing genes: 0
# Number of reactions with missing genes: 0

# %% [markdown]
# #### Compare reactions: model_with/without missing genes

# %% [markdown]
# model_with_missing_genes = cobra.io.read_sbml_model('../Results/combine_halo_meta100_iJO1366_gap_fill_with_core_biomass_with_missing_genes.xml')

# %% [markdown]
# k = 0
# missing_reactions = 0
# for rxn in model_with_missing_genes.reactions:
#     if '_missing' in rxn.gene_reaction_rule:
#         missing_reactions += 1
#         try:
#             halo_meta_c.reactions.get_by_id(rxn.id)
#             k += 1
#         except: None
# print('Number of reactions with missing genes that were found by gap-filling:',k,'/',missing_reactions)
