# %%
import numpy as np
from cobra import Model, Reaction, Metabolite

# %%
import cobra

# %%
model = cobra.io.read_sbml_model('../../../../GECKO/models/ecYeastGEM/ecYeastGEM_batch.xml')
# Out:
# Using license file /Users/gangl/gurobi.lic
# Academic license - for non-commercial use only

# %%
for met in model.metabolites: 
    if 'prot' in met.name: print(met.id,met.name)
# Out:
# s_0628[m] dihydrolipoylprotein [mitochondrion]
# s_1098[m] lipoylprotein [mitochondrion]
# s_1383[m] protoporphyrin [mitochondrion]
# s_1384[c] protoporphyrinogen [cytoplasm]
# s_1385[m] protoporphyrinogen [mitochondrion]
# s_1410[m] S(8)-aminomethyldihydrolipoylprotein [mitochondrion]
# s_3717[c] protein [cytoplasm]
# prot_P00045[c] prot_P00045 [cytoplasm]
# prot_P32891[c] prot_P32891 [cytoplasm]
# prot_P00044[c] prot_P00044 [cytoplasm]
# prot_P39976[c] prot_P39976 [cytoplasm]
# prot_P46681[c] prot_P46681 [cytoplasm]
# prot_P39714[c] prot_P39714 [cytoplasm]
# prot_P00175[c] prot_P00175 [cytoplasm]
# prot_P40989[c] prot_P40989 [cytoplasm]
# prot_Q04952[c] prot_Q04952 [cytoplasm]
# prot_P25358[c] prot_P25358 [cytoplasm]
# prot_P38631[c] prot_P38631 [cytoplasm]
# prot_P40545[c] prot_P40545 [cytoplasm]
# prot_P07275[c] prot_P07275 [cytoplasm]
# prot_P32626[c] prot_P32626 [cytoplasm]
# prot_Q03677[c] prot_Q03677 [cytoplasm]
# prot_Q12362[c] prot_Q12362 [cytoplasm]
# ...

# %%
dir(met)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_bound',
#  '_id',
#  '_model',
#  '_reaction',
#  '_repr_html_',
#  '_set_id_with_model',
#  'annotation',
#  'charge',
#  'compartment',
#  'constraint',
#  'copy',
#  'elements',
#  'formula',
#  'formula_weight',
#  'id',
#  'model',
#  'name',
#  'notes',
#  'reactions',
#  'remove_from_model',
#  'shadow_price',
#  'summary',
#  'y']

# %%
np.random.uniform(0,0.5)
# Out:
# 0.3656770305260781
